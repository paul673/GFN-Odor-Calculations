# %% [markdown]
# # Calculate pine fragrance notes

# %%
import pandas as pd
from pom_models.functions import fragance_propabilities_from_smiles
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# Skipped loading some PyTorch models, missing a dependency. No module named 'tensorflow'

# %%
import numpy as np

# %%
df = pd.read_csv("intensities.csv")
df.head()
# Out:
#                   name         cas  composition                 fetched_name  \
# 0         alpha-Pinene     80-56-8        0.281                 (+)-α-Pinene
# 1       delta-3-Carene  13466-78-9        0.237                       carene
# 2  Caryophyllene oxide   1139-30-6        0.049  (−)-β-Caryophyllene epoxide
# 3       delta-Cadinene    483-76-1        0.048                   d-Cadinene
# 4             Camphene     79-92-5        0.034                     Camphene
#
#         vapour_pressure                                                url  \
# 0  3.5±0.1 mmHg at 25°C  https://www.chemspider.com/Chemical-Structure....
# 1  1.9±0.1 mmHg at 25°C  https://www.chemspider.com/Chemical-Structure....
# 2  0.0±0.6 mmHg at 25°C  https://www.chemspider.com/Chemical-Structure....
# 3  0.0±0.3 mmHg at 25°C  https://www.chemspider.com/Chemical-Structure....
# 4  3.4±0.1 mmHg at 25°C  https://www.chemspider.com/Chemical-Structure....
#
#    vapour_pressure2  logP_value  \
# 0               3.5        4.37
# 1               1.9        4.37
# 2               0.0        4.57
# 3               0.0        6.54
# 4               3.4        4.37
#
#                                           legacy_url  water_sol_from_logP  \
# 0  https://legacy.chemspider.com/Chemical-Structu...              4.07100
# 1  https://legacy.chemspider.com/Chemical-Structu...              4.58100
# 2  https://legacy.chemspider.com/Chemical-Structu...              2.21000
# 3  https://legacy.chemspider.com/Chemical-Structu...              0.04863
# 4  https://legacy.chemspider.com/Chemical-Structu...              6.27500
#
#    ...       kow [-]  cw [mg/L]   M [g/mol]     y [-]  x [-]  ODT [mg/m^3]  \
# 0  ...  2.344229e+04    4.07100  136.125201  1.019800  0.281      5.448859
# 1  ...  2.344229e+04    4.58100  136.125201  1.019800  0.237      2.686762
# 2  ...  3.715352e+04    2.21000  220.182715  0.921445  0.049      0.000000
# 3  ...  3.467369e+06    0.04863  204.187801  1.041275  0.048      0.000000
# 4  ...  2.344229e+04    6.27500  136.125201  1.015911  0.034      3.481921
#
#    Cgi [mg/m^3]       OV [-]  ODT (theory) [mg/m^3]  OV (theory) [-]
# 0   7346.889389  1348.335352                  0.295     24904.709794
# 1   3363.807109  1251.993079                  9.300       361.699689
# 2      0.000000          NaN                    NaN              NaN
# 3      0.000000          NaN                    NaN              NaN
# 4    860.255616   247.063528                    NaN              NaN
#
# [5 rows x 27 columns]

# %%
top_5_df = df.nlargest(5, "OV [-]")
top_5_df.head()
# Out:
#               name         cas  composition  fetched_name  \
# 0     alpha-Pinene     80-56-8        0.281  (+)-α-Pinene
# 1   delta-3-Carene  13466-78-9        0.237        carene
# 10         Myrcene    123-35-3        0.021     β-Myrcene
# 4         Camphene     79-92-5        0.034      Camphene
# 8      Terpinolene    586-62-9        0.026   TERPINOLENE
#
#          vapour_pressure                                                url  \
# 0   3.5±0.1 mmHg at 25°C  https://www.chemspider.com/Chemical-Structure....
# 1   1.9±0.1 mmHg at 25°C  https://www.chemspider.com/Chemical-Structure....
# 10  2.3±0.1 mmHg at 25°C  https://www.chemspider.com/Chemical-Structure....
# 4   3.4±0.1 mmHg at 25°C  https://www.chemspider.com/Chemical-Structure....
# 8   1.1±0.2 mmHg at 25°C  https://www.chemspider.com/Chemical-Structure....
#
#     vapour_pressure2  logP_value  \
# 0                3.5        4.37
# 1                1.9        4.37
# 10               2.3        4.58
# 4                3.4        4.37
# 8                1.1        4.67
#
#                                            legacy_url  water_sol_from_logP  \
# 0   https://legacy.chemspider.com/Chemical-Structu...                4.071
# 1   https://legacy.chemspider.com/Chemical-Structu...                4.581
# 10  https://legacy.chemspider.com/Chemical-Structu...                6.923
# 4   https://legacy.chemspider.com/Chemical-Structu...                6.275
# 8   https://legacy.chemspider.com/Chemical-Structu...                3.838
#
#     ...       kow [-]  cw [mg/L]   M [g/mol]     y [-]  x [-]  ODT [mg/m^3]  \
# 0   ...  23442.288153      4.071  136.125201  1.019800  0.281      5.448859
# 1   ...  23442.288153      4.581  136.125201  1.019800  0.237      2.686762
# 10  ...  38018.939632      6.923  136.125201  1.201470  0.021      1.355377
# 4   ...  23442.288153      6.275  136.125201  1.015911  0.034      3.481921
# 8   ...  46773.514129      3.838  136.125201  1.028665  0.026      0.960591
#
#     Cgi [mg/m^3]       OV [-]  ODT (theory) [mg/m^3]  OV (theory) [-]
# 0    7346.889389  1348.335352                  0.295     24904.709794
# 1    3363.807109  1251.993079                  9.300       361.699689
# 10    425.083406   313.627406                    NaN              NaN
# 4     860.255616   247.063528                    NaN              NaN
# 8     215.503397   224.344482                    NaN              NaN
#
# [5 rows x 27 columns]

# %%
combined_probs = np.zeros(138)
for i, smiles in enumerate(top_5_df["smiles"]):
    probs = fragance_propabilities_from_smiles(smiles)[0]
    weight = list(top_5_df["OV [-]"])[i]
    combined_probs += probs*weight 

combined_probs /= max(combined_probs)
max(combined_probs)
# Out:
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# 1.0

# %%
indices = np.argsort(-combined_probs)
indices
# Out:
# array([ 64, 137,  60,  53,  51,  21,  45,  82,  50, 119, 126,  38, 123,
#          4,  30,  99,  31,  58,  23, 110, 125,  86,   5,  85,  73,  44,
#         72, 128, 124,  87,  74,  14, 132,  78, 112,  98, 131,  10, 130,
#          1,  88, 104,   9,  94,  83,  80, 133,  24,   6,  71,  90, 121,
#         56, 117, 114,  75,  16,  69,  95, 107,  39, 135,  62, 134,  92,
#         59,  47, 109,  66,   8, 105, 108,  65,   7, 118,  13, 103,  52,
#         15,  67,  49, 101,  18,  33,  46,  96, 116,  77,  70,  37, 100,
#        113,  41, 111, 106,  79,  93,  40,  28,  48, 102,  29,  26,  63,
#         22,  91,  84,  57,  97,  35, 115, 127,  55,  61, 122,  12,   3,
#         32,  68,  20,   2, 120,  81,  43,  34, 136,  11,  54,  27,  17,
#         25,  19,  76, 129,   0,  42,  89,  36], dtype=int64)

# %%
combined_probs[36]
# Out:
# 0.053490778526089966

# %%
data_df = pd.read_csv("data.csv")
labels = data_df.keys()[2:]

# %%
data=[]
labels_lst = []
for i in indices[:8]:
    labels_lst.append(labels[i])
    data.append(combined_probs[i])

data, labels_lst
# Out:
# ([1.0,
#   0.9116239746249578,
#   0.8436857437873271,
#   0.8353954138790792,
#   0.8291759493139683,
#   0.8173883893687041,
#   0.8038509007105703,
#   0.7471598074280685],
#  ['herbal',
#   'woody',
#   'green',
#   'fruity',
#   'fresh',
#   'camphoreous',
#   'earthy',
#   'mint'])

# %%
from pycirclize import Circos
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_plot = pd.DataFrame(
    data=[
        data,
    ],
    index=["Pine"],
    columns=labels_lst,
)
df_plot
# Out:
#       herbal     woody     green    fruity     fresh  camphoreous    earthy  \
# Pine     1.0  0.911624  0.843686  0.835395  0.829176     0.817388  0.803851
#
#          mint
# Pine  0.74716

# %%
target_df = df.loc[1]

# %%
fig = plt.figure(figsize=(16, 16), dpi=100)
target_df = df.loc[1]
# Initialize Circos instance for radar chart plot
circos = Circos.radar_chart(
    df_plot,
    vmax=1,
    marker_size=6,
    cmap=dict(Pine="salmon"),
    grid_interval_ratio=0.2,
    line_kws_handler=lambda _: dict(lw=2, ls="solid"),
    marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
)

# Plot figure & set legend on upper right
circos.plotfig()
circos.ax.legend(loc="upper right", fontsize=10)

# %%
data=[]
labels_lst = []
for i in indices[-8:]:
    labels_lst.append(labels[i])
    data.append(combined_probs[i])

data, labels_lst
# Out:
# ([0.11176600858800427,
#   0.1076950788006572,
#   0.10667194417456177,
#   0.10373256630610647,
#   0.09767870041683852,
#   0.09219750783982789,
#   0.08067871686180358,
#   0.053490778526089966],
#  ['chamomile',
#   'buttery',
#   'malty',
#   'vanilla',
#   'alcoholic',
#   'cucumber',
#   'odorless',
#   'cognac'])

# %%
df_plot = pd.DataFrame(
    data=[
        data,
    ],
    index=["Pine"],
    columns=labels_lst,
)
df_plot
# Out:
#       chamomile   buttery     malty   vanilla  alcoholic  cucumber  odorless  \
# Pine   0.111766  0.107695  0.106672  0.103733   0.097679  0.092198  0.080679
#
#         cognac
# Pine  0.053491

# %%
fig = plt.figure(figsize=(16, 16), dpi=100)
target_df = df.loc[1]
# Initialize Circos instance for radar chart plot
circos = Circos.radar_chart(
    df_plot,
    vmax=1,
    marker_size=6,
    cmap=dict(Pine="salmon"),
    grid_interval_ratio=0.2,
    line_kws_handler=lambda _: dict(lw=2, ls="solid"),
    marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
)

# Plot figure & set legend on upper right
circos.plotfig()
circos.ax.legend(loc="upper right", fontsize=10)

# %%
data=[]
labels_lst = []
for i in indices:
    labels_lst.append(labels[i])
    data.append(combined_probs[i])

data, labels_lst
# Out:
# ([1.0,
#   0.9116239746249578,
#   0.8436857437873271,
#   0.8353954138790792,
#   0.8291759493139683,
#   0.8173883893687041,
#   0.8038509007105703,
#   0.7471598074280685,
#   0.7336221358041463,
#   0.7132968139962329,
#   0.576351517415057,
#   0.5650010883536962,
#   0.5522937959828704,
#   0.5457641714724338,
#   0.5204170608542602,
#   0.4970634631328254,
#   0.48984912026316396,
#   0.48108597748294196,
#   0.47894540400404967,
#   0.4600357104575472,
#   0.4513305879585121,
#   0.45013824382673795,
#   0.43570555113664716,
#   0.43045034921069947,
#   0.422701298887306,
#   0.42107716189850747,
#   0.4196199052609002,
#   0.4163615864615153,
#   0.3998807966910066,
#   0.39622285682401576,
#   0.3850147641681498,
#   0.38321145518648947,
#   0.3654303678096842,
#   0.3617342503012678,
#   0.35317703002701323,
#   0.35233856734538144,
#   0.35065541748599355,
#   0.34618586699648907,
#   0.34374966380036365,
#   'nutty',
#   'powdery',
#   'aromatic',
#   'orris',
#   'muguet',
#   'metallic',
#   'warm',
#   'celery',
#   'anisic',
#   'lavender',
#   'oily',
#   'sulfurous',
#   'geranium',
#   'solvent',
#   'sharp',
#   'lily',
#   'black currant',
#   'ketonic',
#   'ozone',
#   'raspberry',
#   'cortex',
#   'weedy',
#   'hay',
#   'waxy',
#   'orange',
#   'grassy',
#   'fatty',
#   'roasted',
#   'hyacinth',
#   'apricot',
#   'pungent',
#   'ripe',
#   'honey',
#   'apple',
#   'sour',
#   'bergamot',
#   'potato',
#   'fruit skin',
#   'bitter',
#   'jasmin',
#   'fishy',
#   'plum',
#   'burnt',
#   'cocoa',
#   'ethereal',
#   'peach',
#   'soapy',
#   'meaty',
#   'lactonic',
#   'cooked',
#   'pineapple',
#   'savory',
#   'creamy',
#   'rummy',
#   'radish',
#   'melon',
#   'orangeflower',
#   'coumarinic',
#   'chocolate',
#   'fermented',
#   'popcorn',
#   'cinnamon',
#   'cheesy',
#   'hazelnut',
#   'caramellic',
#   'onion',
#   'mushroom',
#   'grape',
#   'pear',
#   'coffee',
#   'smoky',
#   'tomato',
#   'gassy',
#   'hawthorn',
#   'sweaty',
#   'beefy',
#   'almond',
#   'clove',
#   'juicy',
#   'cabbage',
#   'alliaceous',
#   'strawberry',
#   'milky',
#   'dairy',
#   'coconut',
#   'winey',
#   'banana',
#   'garlic',
#   'cherry',
#   'brandy',
#   'chamomile',
#   'buttery',
#   'malty',
#   'vanilla',
#   'alcoholic',
#   'cucumber',
#   'odorless',
#   'cognac'])

# %%
df_plot = pd.DataFrame(
    data=[
        data,
    ],
    index=["Pine"],
    columns=labels_lst,
)
df_plot
# Out:
#       herbal     woody     green    fruity     fresh  camphoreous    earthy  \
# Pine     1.0  0.911624  0.843686  0.835395  0.829176     0.817388  0.803851
#
#          mint    floral     spicy  ...    cherry    brandy  chamomile  \
# Pine  0.74716  0.733622  0.713297  ...  0.116289  0.112798   0.111766
#
#        buttery     malty   vanilla  alcoholic  cucumber  odorless    cognac
# Pine  0.107695  0.106672  0.103733   0.097679  0.092198  0.080679  0.053491
#
# [1 rows x 138 columns]

# %%
fig = plt.figure(figsize=(16, 16), dpi=100)
target_df = df.loc[1]
# Initialize Circos instance for radar chart plot
circos = Circos.radar_chart(
    df_plot,
    vmax=1,
    marker_size=4,
    cmap=dict(Pine="salmon"),
    grid_interval_ratio=0.2,
    line_kws_handler=lambda _: dict(lw=2, ls="solid"),
    marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
)

# Plot figure & set legend on upper right
circos.plotfig()
circos.ax.legend(loc="upper right", fontsize=10)

# %%
import json

# %%
list(combined_probs)
# Out:
# [0.09767870041683852,
#  0.34041943853127477,
#  0.13537424940297899,
#  0.1434393086305416,
#  0.5457641714724338,
#  0.43570555113664716,
#  0.30385631283859377,
#  0.23049853105550783,
#  0.23462328526109724,
#  0.3261567082510823,
#  0.34618586699648907,
#  0.11805460952078142,
#  0.14445150922111713,
# %%
with open("pine_target.json", "w") as file:
    json.dump(list(combined_probs), file)

# %%
mol_dict = {}
for i, smiles in enumerate(top_5_df["smiles"]):
    probs = fragance_propabilities_from_smiles(smiles)[0]
    weight = list(top_5_df["OV [-]"])[i]
    mol = Chem.MolFromSmiles(smiles)
    
    data_cut=[]
    for j in indices[:8]:
        data_cut.append(probs[j])
    mol_dict[i] = {
        "probs":probs,
        "weight":weight,
        "mol": mol,
        "name": f"{list(top_5_df['name'])[i]} {int(weight)}",
        "probs_cut":data_cut
    }


mol_dict
# Out:
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# {0: {'probs': array([0.05670923, 0.1808126 , 0.08197895, 0.08702368, 0.368816  ,
#          0.28906935, 0.1939773 , 0.12383256, 0.13714284, 0.20857213,
#          0.21608219, 0.06222109, 0.0904218 , 0.11692098, 0.21969016,
#          0.13282096, 0.151262  , 0.06394777, 0.13178556, 0.05468661,
#          0.08635738, 0.5468689 , 0.09600006, 0.32499614, 0.18578288,
#          0.05791685, 0.09458174, 0.06483571, 0.10935425, 0.09815679,
#          0.28712583, 0.3117603 , 0.08703233, 0.12712975, 0.06545702,
#          0.09906447, 0.02921791, 0.12333379, 0.3650019 , 0.14245135,
#          0.11580265, 0.10129152, 0.04067011, 0.06503242, 0.25957048,
#          0.53182274, 0.1257142 , 0.12817447, 0.1106156 , 0.13208714,
#          0.41869864, 0.51095164, 0.12759477, 0.48822594, 0.0729863 ,
#          0.08150066, 0.1547815 , 0.08300035, 0.30056456, 0.13264032,
#          0.50306195, 0.08587615, 0.15309407, 0.10244449, 0.6213371 ,
#          0.13225503, 0.14059685, 0.11147289, 0.06884795, 0.15039413,
#          0.11304887, 0.16710012, 0.24790807, 0.2872062 , 0.22436385,
#          0.14929599, 0.05999453, 0.11562695, 0.23900862, 0.08689487,
#          0.17004652, 0.06830332, 0.47445235, 0.17522547, 0.08854731,
#          0.2878945 , 0.29320773, 0.23238058, 0.20386188, 0.04541319,
#          0.1715792 , 0.10031703, 0.1374667 , 0.10971474, 0.19199075,
#          0.14822702, 0.11211693, 0.06730878, 0.22421841, 0.3289247 ,
#          0.0960384 , 0.12080243, 0.11427949, 0.14119194, 0.20186126,
#          0.13749048, 0.11263106, 0.14804988, 0.146099  , 0.15296353,
#          0.26363835, 0.11522748, 0.23364066, 0.11874276, 0.16321573,
#          0.09637798, 0.11755318, 0.1736359 , 0.13582177, 0.44290167,
#          0.07306597, 0.18984765, 0.08057163, 0.32328132, 0.24964924,
#          0.2918614 , 0.3838446 , 0.08625522, 0.23110992, 0.06071883,
#          0.20753336, 0.22741692, 0.21568568, 0.18135533, 0.1251848 ,
#          0.13552064, 0.06946582, 0.58300173], dtype=float32),
#   'weight': 1348.3353521637716,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x29fbfe13a00>,
#   'name': 'alpha-Pinene 1348',
#   'probs_cut': [0.6213371,
#    0.58300173,
#    0.50306195,
#    0.48822594,
#    0.51095164,
#    0.5468689,
#    0.53182274,
#          0.11489595, 0.19668557, 0.19879518, 0.20233184, 0.21046261,
#          0.09325959, 0.0480958 , 0.09382258, 0.24569227, 0.07962624,
#          0.12715608, 0.06298478, 0.46452346, 0.09743774, 0.07061765,
#          0.35827285, 0.27295223, 0.2512622 , 0.18801682, 0.05772728,
#          0.17139485, 0.09410829, 0.10955343, 0.09595539, 0.22792809,
#          0.13146596, 0.11880168, 0.08585709, 0.20220874, 0.4021231 ,
#          0.10862465, 0.1182145 , 0.12762065, 0.1108755 , 0.255679  ,
#          0.1494114 , 0.11936843, 0.15721458, 0.12943421, 0.13219179,
#          0.19126293, 0.12130947, 0.2454341 , 0.11105014, 0.18479271,
#          0.06898931, 0.1377324 , 0.1797239 , 0.13748324, 0.42571083,
#          0.08514249, 0.17983203, 0.09879071, 0.34391478, 0.24874598,
#          0.3106595 , 0.41365615, 0.08765926, 0.23104861, 0.05883   ,
#          0.1625862 , 0.27287433, 0.20298389, 0.20033991, 0.11161856,
#          0.15211838, 0.06475326, 0.60762954], dtype=float32),
#   'weight': 247.0635282047529,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x29fbfe12d50>,
#   'name': 'Camphene 247',
#   'probs_cut': [0.5969991,
#    0.60762954,
#    0.46693695,
#    0.51508,
#    0.4828212,
#    0.59443384,
#    0.501646,
#    0.46452346]},
#  4: {'probs': array([0.04761142, 0.22593595, 0.05493448, 0.08495205, 0.39054266,
#          0.29784432, 0.2110854 , 0.14530428, 0.16355602, 0.212223  ,
#          0.2949481 , 0.07581291, 0.0721414 , 0.1685104 , 0.27191773,
#          0.14035556, 0.14639401, 0.06952481, 0.09627958, 0.06488188,
#          0.07329591, 0.4136098 , 0.09045044, 0.28088892, 0.20504248,
#          0.07124233, 0.07383524, 0.07823082, 0.09032244, 0.10990331,
#          0.3935062 , 0.32776397, 0.11741891, 0.09534122, 0.12039401,
#          0.07224132, 0.03874432, 0.08725591, 0.2595046 , 0.16423526,
#          0.13137826, 0.13692935, 0.06077463, 0.08653443, 0.30386394,
#          0.42435977, 0.08535668, 0.19754948, 0.09182584, 0.1035632 ,
#          0.54787034, 0.46835557, 0.14071693, 0.4807584 , 0.05477515,
#          0.07218964, 0.21495812, 0.09235065, 0.27382094, 0.11635036,
#          0.43958402, 0.10103417, 0.15621404, 0.07886742, 0.5729936 ,
#          0.15889038, 0.15732257, 0.1690349 , 0.07123837, 0.13183787,
#          0.14437374, 0.17621647, 0.26720947, 0.2718068 , 0.27483794,
#          0.20994976, 0.06588408, 0.08894715, 0.24882112, 0.12516738,
#          0.20348805, 0.08816664, 0.36494946, 0.23660615, 0.08403154,
#          0.30682176, 0.25310603, 0.27958977, 0.22261347, 0.06537858,
#          0.2355454 , 0.05905767, 0.14097975, 0.15067941, 0.25291014,
#          0.18045548, 0.14297876, 0.08153568, 0.2008404 , 0.31656283,
#          0.09683877, 0.13705975, 0.08791396, 0.08985931, 0.30335897,
#          0.11041522, 0.1136601 , 0.19594856, 0.1018568 , 0.10299747,
#          0.33411533, 0.10290346, 0.25546804, 0.10386468, 0.17589429,
#          0.09369574, 0.13202785, 0.13068748, 0.12893113, 0.4884094 ,
#          0.09348799, 0.08433118, 0.07673725, 0.38519278, 0.24033402,
#          0.2710856 , 0.35865298, 0.06969592, 0.21390972, 0.08191803,
#          0.13885507, 0.25623417, 0.2832614 , 0.24098763, 0.18763176,
#          0.14693543, 0.08159101, 0.61362207], dtype=float32),
#   'weight': 224.3444815806582,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x29fbfe13a70>,
#   'name': 'Terpinolene 224',
#   'probs_cut': [0.5729936,
#    0.61362207,
#    0.43958402,
#    0.4807584,
#    0.46835557,
#    0.4136098,
#    0.42435977,
#    0.36494946]}}

# %%
data=[]
labels_lst = []
for i in indices[:8]:
    labels_lst.append(labels[i])
    data.append(combined_probs[i])

data, labels_lst
# Out:
# ([1.0,
#   0.9116239746249578,
#   0.8436857437873271,
#   0.8353954138790792,
#   0.8291759493139683,
#   0.8173883893687041,
#   0.8038509007105703,
#   0.7471598074280685],
#  ['herbal',
#   'woody',
#   'green',
#   'fruity',
#   'fresh',
#   'camphoreous',
#   'earthy',
#   'mint'])

# %%
len(mol_dict.keys())
# Out:
# 5

# %%
[val["name"] for val in mol_dict.values()]
# Out:
# ['alpha-Pinene', 'delta-3-Carene', 'Myrcene', 'Camphene', 'Terpinolene']

# %%
df_plot = pd.DataFrame(
    data=[
        data] +[
        val["probs_cut"] for val in mol_dict.values()
    ],
    index=["Pine"] + [val["name"] for val in mol_dict.values()],
    columns=labels_lst,
)
df_plot
# Out:
#                        herbal     woody     green    fruity     fresh  \
# Pine                 1.000000  0.911624  0.843686  0.835395  0.829176
# alpha-Pinene 1348    0.621337  0.583002  0.503062  0.488226  0.510952
# delta-3-Carene 1251  0.641944  0.560214  0.531425  0.494507  0.524497
# Myrcene 313          0.533750  0.399887  0.642173  0.730840  0.506355
# Camphene 247         0.596999  0.607630  0.466937  0.515080  0.482821
# Terpinolene 224      0.572994  0.613622  0.439584  0.480758  0.468356
#
#                      camphoreous    earthy      mint
# Pine                    0.817388  0.803851  0.747160
# alpha-Pinene 1348       0.546869  0.531823  0.474452
# delta-3-Carene 1251     0.529645  0.514406  0.510373
# Myrcene 313             0.204269  0.305198  0.262815
# Camphene 247            0.594434  0.501646  0.464523
# Terpinolene 224         0.413610  0.424360  0.364949

# %%
fig = plt.figure(figsize=(16, 16), dpi=100)
target_df = df.loc[1]
# Initialize Circos instance for radar chart plot
circos = Circos.radar_chart(
    df_plot,
    vmax=1,
    marker_size=4,
    fill=False,
    #cmap=dict(Pine="salmon"),
    grid_interval_ratio=0.2,
    line_kws_handler=lambda _: dict(lw=2, ls="solid"),
    marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
)

# Plot figure & set legend on upper right
circos.plotfig()
circos.ax.legend(loc="upper right", fontsize=7)
