# %% [markdown]
# # Run Vanilla

# %%
import sys
import os
path_to_top_dir = "../"
# Dynamically add the `project` directory to the path
sys.path.append(os.path.abspath(path_to_top_dir))

# %%
os.path.abspath(path_to_top_dir)
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model'

# %%
# Print current working directory
os.getcwd()
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model\\runs'

# %%
# Import scent_gfn functions
from scent_gfn.fragments import FRAGMENTS, FRAGMENTS_OPENPOM_DATASET, FRAGMENTS_OPENPOM_VANILLA
from scent_gfn.molecule import MoleculeTrainer
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# Skipped loading some PyTorch models, missing a dependency. No module named 'tensorflow'
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)

# %% [markdown]
# | **Parameter**                | **Value**      |
# |------------------------------|----------------|
# | Reward function type         | OpenPOM        |
# | Similarity measure           | Cosine         |
# | Graph building               | Vanilla Fragments      |
# | Iterations                   | 500            |
# | Max number of nodes          | 6              |
# | Illegal action logreward     | -64           |
# | β                            | 1              |
# | Large molecule penalty       | Exponential           |

# %%
params = {
    "save_name": "vanilla3",
    "reward_func": "openpom", # structure, openpom
    "similarity": "cosine",
    "graph_building": FRAGMENTS_OPENPOM_VANILLA,#FRAGMENTS,
    "iterations": 500,
    "max_nodes": 6,
    "illegal_logreward": -64,
    "beta": 1.0,
    "large_mol_pen": ["exponential", 15]# ["exponential", 15] # ["exponential", 15] , ["hard", 15], [None,None]
}

# %%
# Utilities
import warnings
import random
import datetime

# Data processing and file management
import pathlib
import pandas as pd
import json
import numpy as np

# Machine learning
import torch
from gflownet.config import init_empty, Config
from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage, MolToImage


# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Run on cpu
dev = torch.device('cpu')

# %%
def get_pine_openpom_target():
    with open('../data/pine_target_2.json', 'r') as file:
        target = json.load(file)
    return [target]

# %%
def get_vanilla_test_and_training(split_ratio=0.7):
    df = pd.read_csv("../data/data.csv")
    vanilla_mols_df = df.loc[df['vanilla'] == 1]
    vanilla_smiles_trainig= list(vanilla_mols_df["nonStereoSMILES"])
    vanilla_smiles_trainig = random.sample(vanilla_smiles_trainig, round(len(vanilla_mols_df)*split_ratio))
    random.shuffle(vanilla_smiles_trainig)
    vanilla_smiles_test = []
    for i in vanilla_mols_df["nonStereoSMILES"]:
        if i not in vanilla_smiles_trainig:
            vanilla_smiles_test.append(i)
    return vanilla_smiles_trainig, vanilla_smiles_test

def get_vanillin():
    return ["COc1cc(C=O)ccc1O"]

# %%
target = get_vanillin()

# %%
# Initialize model
config = init_empty(Config())
config.print_every = 1
config.log_dir = f"{os.path.abspath(path_to_top_dir)}/results/{params['save_name']}_{datetime.datetime.now().strftime('%Y-%m-%d__%H_%M_%S')}"
config.device = dev
config.num_training_steps = params["iterations"]
config.num_workers = 0
config.num_validation_gen_steps = 1
config.overwrite_existing_exp=False
config.checkpoint_every = 100
config.algo.max_nodes = params["max_nodes"] #12 # 95 quantil
config.store_all_checkpoints = True
config.algo.illegal_action_logreward = params["illegal_logreward"]

if params["graph_building"] == None:
     trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]), print_config=True) #,fragments=FRAGMENTS, print_config=True)
else:
    trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]),fragments=params["graph_building"], print_config=True) #,fragments=FRAGMENTS, print_config=True)
# Out:
# SMILES input data detected ...
# Reward function: reward_function_openpom | Similarity measure: cosine_similarity | exp_penalty: True | max_mol=15
# Building molecules using fragments ...
#
#
# Hyperparameters:
#
# desc: noDesc
# log_dir: c:\Users\paulj\Desktop\prosjekt\pom_cpu-model/results/vanilla3_2024-12-03__22_12_54
# device: cpu
# seed: 0
# validate_every: 1000
# checkpoint_every: 100
# store_all_checkpoints: true
# print_every: 1
# start_at_step: 0
# num_final_gen_steps: null
# num_validation_gen_steps: 1
# num_training_steps: 500
# num_workers: 0
# hostname: null
# pickle_mp_messages: false
# git_hash: f106cde
# overwrite_existing_exp: false
# algo:
#   method: TB
#   num_from_policy: 64
#   num_from_dataset: 0
#   valid_num_from_policy: 64
#   valid_num_from_dataset: 0
#   max_len: 128
#   max_nodes: 6
#   max_edges: 128
#   illegal_action_logreward: -64.0
#   train_random_action_prob: 0.0
#   train_det_after: null
#   valid_random_action_prob: 0.0
#   sampling_tau: 0.9
#   tb:
#     bootstrap_own_reward: false
#     epsilon: null
#     reward_loss_multiplier: 1.0
#     variant: TB
#     do_correct_idempotent: false
#     do_parameterize_p_b: false
#     do_predict_n: false
#     do_sample_p_b: false
#     do_length_normalize: false
#     subtb_max_len: 128
#     Z_learning_rate: 0.0001
#     Z_lr_decay: 50000.0
#     cum_subtb: true
#     loss_fn: MSE
#     loss_fn_par: 1.0
#     n_loss: none
#     n_loss_multiplier: 1.0
#     backward_policy: Uniform
#   moql:
#     gamma: 1.0
#     num_omega_samples: 32
#     num_objectives: 2
#     lambda_decay: 10000
#     penalty: -10.0
#   a2c:
#     entropy: 0.01
#     gamma: 1.0
#     penalty: -10.0
#   fm:
#     epsilon: 1.0e-38
#     balanced_loss: false
#     leaf_coef: 10.0
#     correct_idempotent: false
#   sql:
#     alpha: 0.01
#     gamma: 1.0
#     penalty: -10.0
# model:
#   num_layers: 3
#   num_emb: 128
#   dropout: 0.0
#   graph_transformer:
#     num_heads: 2
#     ln_type: pre
#     num_mlp_layers: 0
#     concat_heads: true
#   seq_transformer:
#     num_heads: 2
#     posenc: Rotary
# opt:
#   opt: adam
#   learning_rate: 0.0001
#   lr_decay: 20000.0
#   weight_decay: 1.0e-08
#   momentum: 0.9
#   clip_grad_type: norm
#   clip_grad_param: 10.0
#   adam_eps: 1.0e-08
# replay:
#   use: false
#   capacity: null
#   warmup: null
#   hindsight_ratio: 0.0
#   num_from_replay: null
#   num_new_samples: null
# task:
#   qm9:
#     h5_path: ./data/qm9/qm9.h5
#     model_path: ./data/qm9/qm9_model.pt
#   qm9_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - gap
#     - qed
#     - sa
#     online_pareto_front: true
#   seh:
#     reduced_frag: false
#   seh_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - seh
#     - qed
#     - sa
#     - mw
#     log_topk: false
#     online_pareto_front: true
# cond:
#   valid_sample_cond_info: true
#   temperature:
#     sample_dist: uniform
#     dist_params:
#     - 0.5
#     - 32
#     num_thermometer_dim: 32
#   moo:
#     num_objectives: 2
#     num_thermometer_dim: 16
#   weighted_prefs:
#     preference_type: dirichlet
#     preference_param: 1.5
#   focus_region:
#     focus_type: centered
#     use_steer_thermomether: false
#     focus_cosim: 0.98
#     focus_limit_coef: 0.1
#     focus_model_training_limits:
#     - 0.25
#     - 0.75
#     focus_model_state_space_res: 30
#     max_train_it: 20000

# %%
trial.run()
# Out:
# 03/12/2024 22:12:55 - INFO - logger - Starting training
# 03/12/2024 22:13:04 - INFO - logger - iteration 1 : offline_loss:0.00 online_loss:620.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.09 loss:620.64 n_loss:0.00 tb_loss:620.64 batch_entropy:26.29 traj_lens:11.47 grad_norm:311.90 grad_norm_clip:67.74 sampled_reward_avg:0.46 train_time:1.53 time_spent:8.82
# 03/12/2024 22:13:12 - INFO - logger - iteration 2 : offline_loss:0.00 online_loss:674.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.04 loss:674.79 n_loss:0.00 tb_loss:674.79 batch_entropy:26.82 traj_lens:11.52 grad_norm:270.40 grad_norm_clip:67.98 sampled_reward_avg:0.46 train_time:1.44 time_spent:8.33
# 03/12/2024 22:13:21 - INFO - logger - iteration 3 : offline_loss:0.00 online_loss:591.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.00 loss:591.70 n_loss:0.00 tb_loss:591.70 batch_entropy:27.46 traj_lens:11.70 grad_norm:359.00 grad_norm_clip:68.44 sampled_reward_avg:0.49 train_time:1.30 time_spent:8.32
# 03/12/2024 22:13:30 - INFO - logger - iteration 4 : offline_loss:0.00 online_loss:607.39 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.05 loss:607.39 n_loss:0.00 tb_loss:607.39 batch_entropy:30.60 traj_lens:12.92 grad_norm:461.83 grad_norm_clip:70.07 sampled_reward_avg:0.44 train_time:1.73 time_spent:9.09
# 03/12/2024 22:13:37 - INFO - logger - iteration 5 : offline_loss:0.00 online_loss:656.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.09 loss:656.85 n_loss:0.00 tb_loss:656.85 batch_entropy:23.52 traj_lens:10.25 grad_norm:252.20 grad_norm_clip:66.34 sampled_reward_avg:0.48 train_time:1.21 time_spent:7.66
# 03/12/2024 22:13:45 - INFO - logger - iteration 6 : offline_loss:0.00 online_loss:711.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.14 loss:711.20 n_loss:0.00 tb_loss:711.20 batch_entropy:26.08 traj_lens:11.23 grad_norm:372.66 grad_norm_clip:67.40 sampled_reward_avg:0.47 train_time:1.34 time_spent:7.73
# 03/12/2024 22:13:53 - INFO - logger - iteration 7 : offline_loss:0.00 online_loss:590.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.18 loss:590.72 n_loss:0.00 tb_loss:590.72 batch_entropy:26.55 traj_lens:11.14 grad_norm:272.33 grad_norm_clip:66.33 sampled_reward_avg:0.47 train_time:1.30 time_spent:8.01
# 03/12/2024 22:14:02 - INFO - logger - iteration 8 : offline_loss:0.00 online_loss:512.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.22 loss:512.69 n_loss:0.00 tb_loss:512.69 batch_entropy:29.82 traj_lens:12.50 grad_norm:389.24 grad_norm_clip:68.62 sampled_reward_avg:0.45 train_time:1.49 time_spent:8.51
# 03/12/2024 22:14:11 - INFO - logger - iteration 9 : offline_loss:0.00 online_loss:430.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.27 loss:430.98 n_loss:0.00 tb_loss:430.98 batch_entropy:30.83 traj_lens:12.92 grad_norm:304.54 grad_norm_clip:66.81 sampled_reward_avg:0.46 train_time:1.68 time_spent:9.30
# 03/12/2024 22:14:20 - INFO - logger - iteration 10 : offline_loss:0.00 online_loss:416.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.31 loss:416.03 n_loss:0.00 tb_loss:416.03 batch_entropy:31.79 traj_lens:13.16 grad_norm:248.67 grad_norm_clip:65.59 sampled_reward_avg:0.44 train_time:1.70 time_spent:8.95
# 03/12/2024 22:14:29 - INFO - logger - iteration 11 : offline_loss:0.00 online_loss:478.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.35 loss:478.11 n_loss:0.00 tb_loss:478.11 batch_entropy:31.67 traj_lens:13.02 grad_norm:350.86 grad_norm_clip:68.07 sampled_reward_avg:0.45 train_time:1.69 time_spent:8.99
# 03/12/2024 22:14:38 - INFO - logger - iteration 12 : offline_loss:0.00 online_loss:489.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.40 loss:489.24 n_loss:0.00 tb_loss:489.24 batch_entropy:32.40 traj_lens:13.30 grad_norm:344.60 grad_norm_clip:66.94 sampled_reward_avg:0.45 train_time:1.67 time_spent:8.90
# 03/12/2024 22:14:47 - INFO - logger - iteration 13 : offline_loss:0.00 online_loss:557.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.44 loss:557.17 n_loss:0.00 tb_loss:557.17 batch_entropy:30.33 traj_lens:12.64 grad_norm:298.22 grad_norm_clip:66.14 sampled_reward_avg:0.44 train_time:1.64 time_spent:9.16
# 03/12/2024 22:14:56 - INFO - logger - iteration 14 : offline_loss:0.00 online_loss:331.37 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.49 loss:331.37 n_loss:0.00 tb_loss:331.37 batch_entropy:30.01 traj_lens:12.55 grad_norm:265.57 grad_norm_clip:65.31 sampled_reward_avg:0.48 train_time:1.59 time_spent:8.73
# 03/12/2024 22:15:06 - INFO - logger - iteration 15 : offline_loss:0.00 online_loss:485.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.53 loss:485.51 n_loss:0.00 tb_loss:485.51 batch_entropy:33.24 traj_lens:13.72 grad_norm:274.86 grad_norm_clip:65.63 sampled_reward_avg:0.43 train_time:1.79 time_spent:9.15
# 03/12/2024 22:15:16 - INFO - logger - iteration 16 : offline_loss:0.00 online_loss:460.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.57 loss:460.12 n_loss:0.00 tb_loss:460.12 batch_entropy:35.20 traj_lens:14.14 grad_norm:343.98 grad_norm_clip:67.18 sampled_reward_avg:0.41 train_time:1.84 time_spent:10.99
# 03/12/2024 22:15:29 - INFO - logger - iteration 17 : offline_loss:0.00 online_loss:295.58 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.62 loss:295.58 n_loss:0.00 tb_loss:295.58 batch_entropy:35.33 traj_lens:14.52 grad_norm:454.92 grad_norm_clip:68.69 sampled_reward_avg:0.42 train_time:2.01 time_spent:10.30
# 03/12/2024 22:15:39 - INFO - logger - iteration 18 : offline_loss:0.00 online_loss:372.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.67 loss:372.78 n_loss:0.00 tb_loss:372.78 batch_entropy:35.64 traj_lens:14.33 grad_norm:361.64 grad_norm_clip:67.39 sampled_reward_avg:0.42 train_time:1.89 time_spent:12.37
# 03/12/2024 22:15:48 - INFO - logger - iteration 19 : offline_loss:0.00 online_loss:458.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.71 loss:458.08 n_loss:0.00 tb_loss:458.08 batch_entropy:35.67 traj_lens:14.38 grad_norm:386.54 grad_norm_clip:67.74 sampled_reward_avg:0.38 train_time:2.15 time_spent:9.58
# 03/12/2024 22:15:59 - INFO - logger - iteration 20 : offline_loss:0.00 online_loss:371.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.76 loss:371.79 n_loss:0.00 tb_loss:371.79 batch_entropy:36.59 traj_lens:14.56 grad_norm:350.67 grad_norm_clip:66.87 sampled_reward_avg:0.43 train_time:2.08 time_spent:10.42
# 03/12/2024 22:16:08 - INFO - logger - iteration 21 : offline_loss:0.00 online_loss:353.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.80 loss:353.41 n_loss:0.00 tb_loss:353.41 batch_entropy:36.22 traj_lens:14.70 grad_norm:380.83 grad_norm_clip:67.61 sampled_reward_avg:0.43 train_time:1.98 time_spent:9.91
# 03/12/2024 22:16:18 - INFO - logger - iteration 22 : offline_loss:0.00 online_loss:518.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.85 loss:518.98 n_loss:0.00 tb_loss:518.98 batch_entropy:36.27 traj_lens:14.61 grad_norm:423.60 grad_norm_clip:67.69 sampled_reward_avg:0.37 train_time:1.97 time_spent:9.69
# 03/12/2024 22:16:30 - INFO - logger - iteration 23 : offline_loss:0.00 online_loss:515.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.90 loss:515.87 n_loss:0.00 tb_loss:515.87 batch_entropy:36.59 traj_lens:14.61 grad_norm:356.64 grad_norm_clip:67.72 sampled_reward_avg:0.36 train_time:2.08 time_spent:11.42
# 03/12/2024 22:16:43 - INFO - logger - iteration 24 : offline_loss:0.00 online_loss:384.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.95 loss:384.47 n_loss:0.00 tb_loss:384.47 batch_entropy:38.75 traj_lens:15.50 grad_norm:447.22 grad_norm_clip:68.48 sampled_reward_avg:0.37 train_time:1.98 time_spent:13.62
# 03/12/2024 22:16:53 - INFO - logger - iteration 25 : offline_loss:0.00 online_loss:342.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.00 loss:342.40 n_loss:0.00 tb_loss:342.40 batch_entropy:35.70 traj_lens:14.42 grad_norm:320.64 grad_norm_clip:66.32 sampled_reward_avg:0.44 train_time:1.84 time_spent:9.45
# 03/12/2024 22:17:02 - INFO - logger - iteration 26 : offline_loss:0.00 online_loss:406.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.04 loss:406.99 n_loss:0.00 tb_loss:406.99 batch_entropy:36.27 traj_lens:14.52 grad_norm:470.33 grad_norm_clip:68.32 sampled_reward_avg:0.41 train_time:2.02 time_spent:9.69
# 03/12/2024 22:17:12 - INFO - logger - iteration 27 : offline_loss:0.00 online_loss:355.92 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.09 loss:355.92 n_loss:0.00 tb_loss:355.92 batch_entropy:37.69 traj_lens:15.17 grad_norm:431.39 grad_norm_clip:68.10 sampled_reward_avg:0.40 train_time:2.16 time_spent:10.15
# 03/12/2024 22:17:23 - INFO - logger - iteration 28 : offline_loss:0.00 online_loss:304.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.14 loss:304.09 n_loss:0.00 tb_loss:304.09 batch_entropy:37.19 traj_lens:14.98 grad_norm:491.34 grad_norm_clip:68.18 sampled_reward_avg:0.39 train_time:2.00 time_spent:10.65
# 03/12/2024 22:17:33 - INFO - logger - iteration 29 : offline_loss:0.00 online_loss:367.73 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.19 loss:367.73 n_loss:0.00 tb_loss:367.73 batch_entropy:38.31 traj_lens:15.17 grad_norm:367.52 grad_norm_clip:67.06 sampled_reward_avg:0.37 train_time:1.96 time_spent:9.93
# 03/12/2024 22:17:43 - INFO - logger - iteration 30 : offline_loss:0.00 online_loss:310.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.24 loss:310.17 n_loss:0.00 tb_loss:310.17 batch_entropy:38.08 traj_lens:15.27 grad_norm:382.35 grad_norm_clip:67.50 sampled_reward_avg:0.42 train_time:2.06 time_spent:10.18
# 03/12/2024 22:17:55 - INFO - logger - iteration 31 : offline_loss:0.00 online_loss:461.50 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.29 loss:461.50 n_loss:0.00 tb_loss:461.50 batch_entropy:37.73 traj_lens:15.08 grad_norm:362.08 grad_norm_clip:66.97 sampled_reward_avg:0.38 train_time:2.83 time_spent:11.64
# 03/12/2024 22:18:07 - INFO - logger - iteration 32 : offline_loss:0.00 online_loss:387.91 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.34 loss:387.91 n_loss:0.00 tb_loss:387.91 batch_entropy:39.60 traj_lens:15.55 grad_norm:367.56 grad_norm_clip:66.63 sampled_reward_avg:0.35 train_time:2.52 time_spent:11.76
# 03/12/2024 22:18:18 - INFO - logger - iteration 33 : offline_loss:0.00 online_loss:336.89 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.39 loss:336.89 n_loss:0.00 tb_loss:336.89 batch_entropy:40.48 traj_lens:15.92 grad_norm:396.45 grad_norm_clip:68.06 sampled_reward_avg:0.35 train_time:2.63 time_spent:11.85
# 03/12/2024 22:18:31 - INFO - logger - iteration 34 : offline_loss:0.00 online_loss:412.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.44 loss:412.26 n_loss:0.00 tb_loss:412.26 batch_entropy:38.90 traj_lens:15.50 grad_norm:360.17 grad_norm_clip:67.00 sampled_reward_avg:0.37 train_time:2.65 time_spent:12.05
# 03/12/2024 22:18:43 - INFO - logger - iteration 35 : offline_loss:0.00 online_loss:409.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.50 loss:409.00 n_loss:0.00 tb_loss:409.00 batch_entropy:41.90 traj_lens:16.30 grad_norm:375.73 grad_norm_clip:66.73 sampled_reward_avg:0.34 train_time:2.78 time_spent:12.42
# 03/12/2024 22:18:54 - INFO - logger - iteration 36 : offline_loss:0.00 online_loss:459.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.55 loss:459.47 n_loss:0.00 tb_loss:459.47 batch_entropy:38.34 traj_lens:15.12 grad_norm:464.72 grad_norm_clip:67.98 sampled_reward_avg:0.38 train_time:2.36 time_spent:11.40
# 03/12/2024 22:19:06 - INFO - logger - iteration 37 : offline_loss:0.00 online_loss:355.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.60 loss:355.03 n_loss:0.00 tb_loss:355.03 batch_entropy:37.79 traj_lens:14.98 grad_norm:335.01 grad_norm_clip:66.04 sampled_reward_avg:0.38 train_time:2.53 time_spent:11.61
# 03/12/2024 22:19:19 - INFO - logger - iteration 38 : offline_loss:0.00 online_loss:329.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.66 loss:329.78 n_loss:0.00 tb_loss:329.78 batch_entropy:39.26 traj_lens:15.55 grad_norm:477.21 grad_norm_clip:69.14 sampled_reward_avg:0.36 train_time:2.69 time_spent:12.97
# 03/12/2024 22:19:33 - INFO - logger - iteration 39 : offline_loss:0.00 online_loss:382.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.71 loss:382.64 n_loss:0.00 tb_loss:382.64 batch_entropy:39.62 traj_lens:15.55 grad_norm:379.40 grad_norm_clip:67.83 sampled_reward_avg:0.37 train_time:2.13 time_spent:14.59
# 03/12/2024 22:19:44 - INFO - logger - iteration 40 : offline_loss:0.00 online_loss:335.06 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.77 loss:335.06 n_loss:0.00 tb_loss:335.06 batch_entropy:40.31 traj_lens:15.78 grad_norm:522.25 grad_norm_clip:69.65 sampled_reward_avg:0.35 train_time:2.56 time_spent:10.75
# 03/12/2024 22:19:55 - INFO - logger - iteration 41 : offline_loss:0.00 online_loss:368.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.82 loss:368.12 n_loss:0.00 tb_loss:368.12 batch_entropy:38.29 traj_lens:15.03 grad_norm:414.59 grad_norm_clip:68.59 sampled_reward_avg:0.38 train_time:2.17 time_spent:10.88
# 03/12/2024 22:20:06 - INFO - logger - iteration 42 : offline_loss:0.00 online_loss:397.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.87 loss:397.35 n_loss:0.00 tb_loss:397.35 batch_entropy:40.99 traj_lens:15.73 grad_norm:439.29 grad_norm_clip:68.36 sampled_reward_avg:0.33 train_time:2.43 time_spent:10.89
# 03/12/2024 22:20:22 - INFO - logger - iteration 43 : offline_loss:0.00 online_loss:372.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.93 loss:372.76 n_loss:0.00 tb_loss:372.76 batch_entropy:39.68 traj_lens:15.50 grad_norm:372.88 grad_norm_clip:66.99 sampled_reward_avg:0.35 train_time:2.06 time_spent:16.21
# 03/12/2024 22:20:32 - INFO - logger - iteration 44 : offline_loss:0.00 online_loss:356.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.99 loss:356.84 n_loss:0.00 tb_loss:356.84 batch_entropy:39.16 traj_lens:15.45 grad_norm:364.19 grad_norm_clip:66.74 sampled_reward_avg:0.36 train_time:1.93 time_spent:10.20
# 03/12/2024 22:20:42 - INFO - logger - iteration 45 : offline_loss:0.00 online_loss:327.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.04 loss:327.11 n_loss:0.00 tb_loss:327.11 batch_entropy:39.69 traj_lens:15.41 grad_norm:357.71 grad_norm_clip:65.24 sampled_reward_avg:0.34 train_time:2.13 time_spent:9.91
# 03/12/2024 22:20:54 - INFO - logger - iteration 46 : offline_loss:0.00 online_loss:371.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.10 loss:371.53 n_loss:0.00 tb_loss:371.53 batch_entropy:41.57 traj_lens:16.48 grad_norm:428.76 grad_norm_clip:68.34 sampled_reward_avg:0.36 train_time:2.65 time_spent:11.28
# 03/12/2024 22:21:05 - INFO - logger - iteration 47 : offline_loss:0.00 online_loss:332.96 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.15 loss:332.96 n_loss:0.00 tb_loss:332.96 batch_entropy:41.42 traj_lens:16.06 grad_norm:432.65 grad_norm_clip:68.24 sampled_reward_avg:0.33 train_time:2.49 time_spent:11.45
# 03/12/2024 22:21:17 - INFO - logger - iteration 48 : offline_loss:0.00 online_loss:361.01 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.21 loss:361.01 n_loss:0.00 tb_loss:361.01 batch_entropy:43.52 traj_lens:16.67 grad_norm:511.78 grad_norm_clip:68.84 sampled_reward_avg:0.30 train_time:2.60 time_spent:12.12
# 03/12/2024 22:21:29 - INFO - logger - iteration 49 : offline_loss:0.00 online_loss:408.39 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.27 loss:408.39 n_loss:0.00 tb_loss:408.39 batch_entropy:42.79 traj_lens:16.34 grad_norm:469.66 grad_norm_clip:69.42 sampled_reward_avg:0.29 train_time:2.82 time_spent:11.60
# 03/12/2024 22:21:40 - INFO - logger - iteration 50 : offline_loss:0.00 online_loss:349.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.33 loss:349.85 n_loss:0.00 tb_loss:349.85 batch_entropy:39.69 traj_lens:15.59 grad_norm:410.97 grad_norm_clip:68.54 sampled_reward_avg:0.33 train_time:2.46 time_spent:11.40
# 03/12/2024 22:21:52 - INFO - logger - iteration 51 : offline_loss:0.00 online_loss:311.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.39 loss:311.31 n_loss:0.00 tb_loss:311.31 batch_entropy:38.61 traj_lens:15.22 grad_norm:451.73 grad_norm_clip:68.82 sampled_reward_avg:0.41 train_time:2.32 time_spent:11.42
# 03/12/2024 22:22:04 - INFO - logger - iteration 52 : offline_loss:0.00 online_loss:341.80 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.45 loss:341.80 n_loss:0.00 tb_loss:341.80 batch_entropy:42.91 traj_lens:16.48 grad_norm:485.19 grad_norm_clip:68.43 sampled_reward_avg:0.30 train_time:2.83 time_spent:12.45
# 03/12/2024 22:22:16 - INFO - logger - iteration 53 : offline_loss:0.00 online_loss:390.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.50 loss:390.31 n_loss:0.00 tb_loss:390.31 batch_entropy:42.34 traj_lens:16.11 grad_norm:552.83 grad_norm_clip:70.75 sampled_reward_avg:0.29 train_time:2.45 time_spent:12.42
# 03/12/2024 22:22:29 - INFO - logger - iteration 54 : offline_loss:0.00 online_loss:342.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.57 loss:342.54 n_loss:0.00 tb_loss:342.54 batch_entropy:43.12 traj_lens:16.48 grad_norm:528.28 grad_norm_clip:69.04 sampled_reward_avg:0.31 train_time:2.65 time_spent:12.93
# 03/12/2024 22:22:41 - INFO - logger - iteration 55 : offline_loss:0.00 online_loss:340.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.63 loss:340.90 n_loss:0.00 tb_loss:340.90 batch_entropy:39.22 traj_lens:15.41 grad_norm:432.56 grad_norm_clip:69.93 sampled_reward_avg:0.33 train_time:2.34 time_spent:11.32
# 03/12/2024 22:22:53 - INFO - logger - iteration 56 : offline_loss:0.00 online_loss:342.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.69 loss:342.55 n_loss:0.00 tb_loss:342.55 batch_entropy:43.16 traj_lens:16.58 grad_norm:487.13 grad_norm_clip:69.27 sampled_reward_avg:0.30 train_time:2.60 time_spent:11.94
# 03/12/2024 22:23:05 - INFO - logger - iteration 57 : offline_loss:0.00 online_loss:318.91 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.75 loss:318.91 n_loss:0.00 tb_loss:318.91 batch_entropy:42.05 traj_lens:16.25 grad_norm:433.39 grad_norm_clip:67.71 sampled_reward_avg:0.35 train_time:2.53 time_spent:11.93
# 03/12/2024 22:23:17 - INFO - logger - iteration 58 : offline_loss:0.00 online_loss:381.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.81 loss:381.15 n_loss:0.00 tb_loss:381.15 batch_entropy:42.79 traj_lens:16.30 grad_norm:455.93 grad_norm_clip:67.98 sampled_reward_avg:0.30 train_time:2.55 time_spent:12.04
# 03/12/2024 22:23:29 - INFO - logger - iteration 59 : offline_loss:0.00 online_loss:341.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.87 loss:341.90 n_loss:0.00 tb_loss:341.90 batch_entropy:43.22 traj_lens:16.53 grad_norm:468.35 grad_norm_clip:68.59 sampled_reward_avg:0.30 train_time:2.60 time_spent:12.13
# 03/12/2024 22:23:41 - INFO - logger - iteration 60 : offline_loss:0.00 online_loss:309.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.94 loss:309.33 n_loss:0.00 tb_loss:309.33 batch_entropy:41.76 traj_lens:16.30 grad_norm:465.16 grad_norm_clip:68.74 sampled_reward_avg:0.33 train_time:2.65 time_spent:11.98
# 03/12/2024 22:23:53 - INFO - logger - iteration 61 : offline_loss:0.00 online_loss:372.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.00 loss:372.54 n_loss:0.00 tb_loss:372.54 batch_entropy:44.72 traj_lens:16.72 grad_norm:470.25 grad_norm_clip:67.58 sampled_reward_avg:0.28 train_time:2.63 time_spent:12.49
# 03/12/2024 22:24:05 - INFO - logger - iteration 62 : offline_loss:0.00 online_loss:312.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.06 loss:312.03 n_loss:0.00 tb_loss:312.03 batch_entropy:42.54 traj_lens:16.34 grad_norm:407.69 grad_norm_clip:65.19 sampled_reward_avg:0.31 train_time:2.60 time_spent:11.99
# 03/12/2024 22:24:17 - INFO - logger - iteration 63 : offline_loss:0.00 online_loss:317.58 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.13 loss:317.58 n_loss:0.00 tb_loss:317.58 batch_entropy:42.21 traj_lens:16.16 grad_norm:522.78 grad_norm_clip:68.68 sampled_reward_avg:0.31 train_time:2.66 time_spent:11.79
# 03/12/2024 22:24:30 - INFO - logger - iteration 64 : offline_loss:0.00 online_loss:302.67 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.19 loss:302.67 n_loss:0.00 tb_loss:302.67 batch_entropy:40.91 traj_lens:15.78 grad_norm:449.74 grad_norm_clip:67.73 sampled_reward_avg:0.32 train_time:2.77 time_spent:12.57
# 03/12/2024 22:24:45 - INFO - logger - iteration 65 : offline_loss:0.00 online_loss:343.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.26 loss:343.88 n_loss:0.00 tb_loss:343.88 batch_entropy:43.49 traj_lens:16.39 grad_norm:488.89 grad_norm_clip:67.82 sampled_reward_avg:0.27 train_time:2.75 time_spent:15.03
# 03/12/2024 22:24:57 - INFO - logger - iteration 66 : offline_loss:0.00 online_loss:323.01 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.32 loss:323.01 n_loss:0.00 tb_loss:323.01 batch_entropy:43.19 traj_lens:16.44 grad_norm:489.31 grad_norm_clip:69.18 sampled_reward_avg:0.29 train_time:2.71 time_spent:12.15
# 03/12/2024 22:25:09 - INFO - logger - iteration 67 : offline_loss:0.00 online_loss:338.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.39 loss:338.77 n_loss:0.00 tb_loss:338.77 batch_entropy:43.90 traj_lens:16.58 grad_norm:487.04 grad_norm_clip:67.72 sampled_reward_avg:0.31 train_time:2.55 time_spent:12.07
# 03/12/2024 22:25:21 - INFO - logger - iteration 68 : offline_loss:0.00 online_loss:339.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.46 loss:339.22 n_loss:0.00 tb_loss:339.22 batch_entropy:43.83 traj_lens:16.44 grad_norm:463.23 grad_norm_clip:66.90 sampled_reward_avg:0.28 train_time:2.58 time_spent:11.82
# 03/12/2024 22:25:33 - INFO - logger - iteration 69 : offline_loss:0.00 online_loss:327.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.52 loss:327.72 n_loss:0.00 tb_loss:327.72 batch_entropy:44.10 traj_lens:16.72 grad_norm:492.89 grad_norm_clip:68.00 sampled_reward_avg:0.30 train_time:2.61 time_spent:11.90
# 03/12/2024 22:25:44 - INFO - logger - iteration 70 : offline_loss:0.00 online_loss:324.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.59 loss:324.53 n_loss:0.00 tb_loss:324.53 batch_entropy:39.08 traj_lens:15.12 grad_norm:479.85 grad_norm_clip:68.69 sampled_reward_avg:0.33 train_time:2.19 time_spent:11.30
# 03/12/2024 22:25:55 - INFO - logger - iteration 71 : offline_loss:0.00 online_loss:368.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.66 loss:368.93 n_loss:0.00 tb_loss:368.93 batch_entropy:42.77 traj_lens:16.30 grad_norm:451.79 grad_norm_clip:67.40 sampled_reward_avg:0.30 train_time:2.55 time_spent:11.46
# 03/12/2024 22:26:07 - INFO - logger - iteration 72 : offline_loss:0.00 online_loss:325.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.72 loss:325.68 n_loss:0.00 tb_loss:325.68 batch_entropy:43.97 traj_lens:16.62 grad_norm:499.21 grad_norm_clip:68.19 sampled_reward_avg:0.30 train_time:2.52 time_spent:11.85
# 03/12/2024 22:26:19 - INFO - logger - iteration 73 : offline_loss:0.00 online_loss:390.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.79 loss:390.31 n_loss:0.00 tb_loss:390.31 batch_entropy:44.74 traj_lens:16.72 grad_norm:507.13 grad_norm_clip:68.81 sampled_reward_avg:0.27 train_time:2.94 time_spent:12.19
# 03/12/2024 22:26:32 - INFO - logger - iteration 74 : offline_loss:0.00 online_loss:328.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.86 loss:328.93 n_loss:0.00 tb_loss:328.93 batch_entropy:44.38 traj_lens:16.72 grad_norm:569.92 grad_norm_clip:68.62 sampled_reward_avg:0.29 train_time:2.54 time_spent:12.33
# 03/12/2024 22:26:43 - INFO - logger - iteration 75 : offline_loss:0.00 online_loss:311.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.93 loss:311.65 n_loss:0.00 tb_loss:311.65 batch_entropy:43.46 traj_lens:16.48 grad_norm:500.82 grad_norm_clip:67.67 sampled_reward_avg:0.29 train_time:2.58 time_spent:11.71
# 03/12/2024 22:26:55 - INFO - logger - iteration 76 : offline_loss:0.00 online_loss:366.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.00 loss:366.47 n_loss:0.00 tb_loss:366.47 batch_entropy:43.44 traj_lens:16.34 grad_norm:475.56 grad_norm_clip:66.94 sampled_reward_avg:0.28 train_time:2.55 time_spent:11.55
# 03/12/2024 22:27:07 - INFO - logger - iteration 77 : offline_loss:0.00 online_loss:375.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.06 loss:375.70 n_loss:0.00 tb_loss:375.70 batch_entropy:44.20 traj_lens:16.48 grad_norm:537.68 grad_norm_clip:68.48 sampled_reward_avg:0.24 train_time:2.51 time_spent:12.02
# 03/12/2024 22:27:19 - INFO - logger - iteration 78 : offline_loss:0.00 online_loss:319.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.13 loss:319.70 n_loss:0.00 tb_loss:319.70 batch_entropy:44.64 traj_lens:16.72 grad_norm:507.50 grad_norm_clip:67.31 sampled_reward_avg:0.28 train_time:2.54 time_spent:11.98
# 03/12/2024 22:27:31 - INFO - logger - iteration 79 : offline_loss:0.00 online_loss:324.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.20 loss:324.33 n_loss:0.00 tb_loss:324.33 batch_entropy:44.92 traj_lens:16.67 grad_norm:481.40 grad_norm_clip:65.32 sampled_reward_avg:0.28 train_time:2.75 time_spent:11.86
# 03/12/2024 22:27:42 - INFO - logger - iteration 80 : offline_loss:0.00 online_loss:392.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.27 loss:392.03 n_loss:0.00 tb_loss:392.03 batch_entropy:41.69 traj_lens:15.73 grad_norm:468.84 grad_norm_clip:67.87 sampled_reward_avg:0.30 train_time:2.34 time_spent:11.39
# 03/12/2024 22:27:54 - INFO - logger - iteration 81 : offline_loss:0.00 online_loss:310.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.34 loss:310.53 n_loss:0.00 tb_loss:310.53 batch_entropy:43.89 traj_lens:16.44 grad_norm:533.77 grad_norm_clip:68.96 sampled_reward_avg:0.29 train_time:2.51 time_spent:11.65
# 03/12/2024 22:28:05 - INFO - logger - iteration 82 : offline_loss:0.00 online_loss:348.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.42 loss:348.77 n_loss:0.00 tb_loss:348.77 batch_entropy:42.73 traj_lens:16.02 grad_norm:442.37 grad_norm_clip:65.16 sampled_reward_avg:0.31 train_time:2.44 time_spent:11.40
# 03/12/2024 22:28:17 - INFO - logger - iteration 83 : offline_loss:0.00 online_loss:284.96 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.49 loss:284.96 n_loss:0.00 tb_loss:284.96 batch_entropy:43.96 traj_lens:16.58 grad_norm:533.42 grad_norm_clip:67.50 sampled_reward_avg:0.29 train_time:2.63 time_spent:11.93
# 03/12/2024 22:28:29 - INFO - logger - iteration 84 : offline_loss:0.00 online_loss:309.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.56 loss:309.78 n_loss:0.00 tb_loss:309.78 batch_entropy:44.92 traj_lens:16.81 grad_norm:526.56 grad_norm_clip:67.05 sampled_reward_avg:0.27 train_time:2.68 time_spent:12.22
# 03/12/2024 22:28:41 - INFO - logger - iteration 85 : offline_loss:0.00 online_loss:327.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.63 loss:327.79 n_loss:0.00 tb_loss:327.79 batch_entropy:43.87 traj_lens:16.62 grad_norm:525.49 grad_norm_clip:68.11 sampled_reward_avg:0.28 train_time:2.63 time_spent:11.70
# 03/12/2024 22:28:53 - INFO - logger - iteration 86 : offline_loss:0.00 online_loss:269.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.70 loss:269.23 n_loss:0.00 tb_loss:269.23 batch_entropy:43.82 traj_lens:16.62 grad_norm:547.48 grad_norm_clip:67.82 sampled_reward_avg:0.26 train_time:2.57 time_spent:11.71
# 03/12/2024 22:29:05 - INFO - logger - iteration 87 : offline_loss:0.00 online_loss:267.48 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.77 loss:267.48 n_loss:0.00 tb_loss:267.48 batch_entropy:43.92 traj_lens:16.72 grad_norm:553.30 grad_norm_clip:68.83 sampled_reward_avg:0.25 train_time:2.65 time_spent:12.06
# 03/12/2024 22:29:17 - INFO - logger - iteration 88 : offline_loss:0.00 online_loss:280.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.85 loss:280.19 n_loss:0.00 tb_loss:280.19 batch_entropy:43.63 traj_lens:16.48 grad_norm:523.55 grad_norm_clip:68.91 sampled_reward_avg:0.30 train_time:2.49 time_spent:11.76
# 03/12/2024 22:29:29 - INFO - logger - iteration 89 : offline_loss:0.00 online_loss:294.28 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.92 loss:294.28 n_loss:0.00 tb_loss:294.28 batch_entropy:45.11 traj_lens:16.95 grad_norm:561.83 grad_norm_clip:68.99 sampled_reward_avg:0.26 train_time:2.67 time_spent:11.91
# 03/12/2024 22:29:41 - INFO - logger - iteration 90 : offline_loss:0.00 online_loss:281.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.00 loss:281.84 n_loss:0.00 tb_loss:281.84 batch_entropy:44.10 traj_lens:16.62 grad_norm:557.16 grad_norm_clip:68.56 sampled_reward_avg:0.26 train_time:2.63 time_spent:12.25
# 03/12/2024 22:29:53 - INFO - logger - iteration 91 : offline_loss:0.00 online_loss:313.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.07 loss:313.74 n_loss:0.00 tb_loss:313.74 batch_entropy:45.90 traj_lens:16.86 grad_norm:622.14 grad_norm_clip:68.62 sampled_reward_avg:0.26 train_time:2.60 time_spent:11.89
# 03/12/2024 22:30:05 - INFO - logger - iteration 92 : offline_loss:0.00 online_loss:303.43 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.14 loss:303.43 n_loss:0.00 tb_loss:303.43 batch_entropy:44.81 traj_lens:16.48 grad_norm:635.43 grad_norm_clip:68.90 sampled_reward_avg:0.25 train_time:2.74 time_spent:12.11
# 03/12/2024 22:30:17 - INFO - logger - iteration 93 : offline_loss:0.00 online_loss:286.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.22 loss:286.74 n_loss:0.00 tb_loss:286.74 batch_entropy:45.01 traj_lens:16.86 grad_norm:583.40 grad_norm_clip:69.96 sampled_reward_avg:0.27 train_time:2.54 time_spent:11.99
# 03/12/2024 22:30:28 - INFO - logger - iteration 94 : offline_loss:0.00 online_loss:317.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.29 loss:317.76 n_loss:0.00 tb_loss:317.76 batch_entropy:42.98 traj_lens:16.25 grad_norm:532.42 grad_norm_clip:68.53 sampled_reward_avg:0.28 train_time:2.49 time_spent:11.48
# 03/12/2024 22:30:41 - INFO - logger - iteration 95 : offline_loss:0.00 online_loss:275.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.37 loss:275.33 n_loss:0.00 tb_loss:275.33 batch_entropy:45.04 traj_lens:16.91 grad_norm:523.04 grad_norm_clip:66.84 sampled_reward_avg:0.27 train_time:2.59 time_spent:12.46
# 03/12/2024 22:30:53 - INFO - logger - iteration 96 : offline_loss:0.00 online_loss:276.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.45 loss:276.46 n_loss:0.00 tb_loss:276.46 batch_entropy:45.55 traj_lens:17.00 grad_norm:522.51 grad_norm_clip:66.41 sampled_reward_avg:0.26 train_time:2.66 time_spent:11.87
# 03/12/2024 22:31:05 - INFO - logger - iteration 97 : offline_loss:0.00 online_loss:284.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.52 loss:284.05 n_loss:0.00 tb_loss:284.05 batch_entropy:45.13 traj_lens:16.86 grad_norm:567.50 grad_norm_clip:67.90 sampled_reward_avg:0.28 train_time:2.82 time_spent:12.48
# 03/12/2024 22:31:17 - INFO - logger - iteration 98 : offline_loss:0.00 online_loss:328.66 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.60 loss:328.66 n_loss:0.00 tb_loss:328.66 batch_entropy:44.13 traj_lens:16.44 grad_norm:532.60 grad_norm_clip:69.66 sampled_reward_avg:0.27 train_time:2.54 time_spent:11.78
# 03/12/2024 22:31:30 - INFO - logger - iteration 99 : offline_loss:0.00 online_loss:257.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.68 loss:257.00 n_loss:0.00 tb_loss:257.00 batch_entropy:43.66 traj_lens:16.53 grad_norm:579.09 grad_norm_clip:67.97 sampled_reward_avg:0.30 train_time:3.25 time_spent:12.86
# 03/12/2024 22:31:45 - INFO - logger - iteration 100 : offline_loss:0.00 online_loss:272.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.75 loss:272.77 n_loss:0.00 tb_loss:272.77 batch_entropy:45.16 traj_lens:16.81 grad_norm:534.55 grad_norm_clip:65.92 sampled_reward_avg:0.25 train_time:3.38 time_spent:15.06
# 03/12/2024 22:31:57 - INFO - logger - iteration 101 : offline_loss:0.00 online_loss:249.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.83 loss:249.20 n_loss:0.00 tb_loss:249.20 batch_entropy:43.08 traj_lens:16.20 grad_norm:514.46 grad_norm_clip:66.77 sampled_reward_avg:0.29 train_time:2.53 time_spent:12.06
# 03/12/2024 22:32:09 - INFO - logger - iteration 102 : offline_loss:0.00 online_loss:242.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.91 loss:242.53 n_loss:0.00 tb_loss:242.53 batch_entropy:42.73 traj_lens:16.11 grad_norm:540.82 grad_norm_clip:67.79 sampled_reward_avg:0.31 train_time:2.48 time_spent:11.86
# 03/12/2024 22:32:21 - INFO - logger - iteration 103 : offline_loss:0.00 online_loss:264.67 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.99 loss:264.67 n_loss:0.00 tb_loss:264.67 batch_entropy:44.83 traj_lens:16.67 grad_norm:567.79 grad_norm_clip:67.91 sampled_reward_avg:0.27 train_time:2.62 time_spent:12.13
# 03/12/2024 22:32:32 - INFO - logger - iteration 104 : offline_loss:0.00 online_loss:248.89 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.07 loss:248.89 n_loss:0.00 tb_loss:248.89 batch_entropy:43.56 traj_lens:16.39 grad_norm:546.11 grad_norm_clip:67.12 sampled_reward_avg:0.31 train_time:2.44 time_spent:11.56
# 03/12/2024 22:32:44 - INFO - logger - iteration 105 : offline_loss:0.00 online_loss:243.96 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.14 loss:243.96 n_loss:0.00 tb_loss:243.96 batch_entropy:44.35 traj_lens:16.62 grad_norm:567.40 grad_norm_clip:67.95 sampled_reward_avg:0.27 train_time:2.55 time_spent:11.81
# 03/12/2024 22:32:56 - INFO - logger - iteration 106 : offline_loss:0.00 online_loss:248.67 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.22 loss:248.67 n_loss:0.00 tb_loss:248.67 batch_entropy:44.75 traj_lens:16.81 grad_norm:546.80 grad_norm_clip:67.25 sampled_reward_avg:0.26 train_time:2.65 time_spent:12.29
# 03/12/2024 22:33:08 - INFO - logger - iteration 107 : offline_loss:0.00 online_loss:247.43 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.30 loss:247.43 n_loss:0.00 tb_loss:247.43 batch_entropy:44.52 traj_lens:16.58 grad_norm:616.49 grad_norm_clip:68.50 sampled_reward_avg:0.27 train_time:2.69 time_spent:11.84
# 03/12/2024 22:33:20 - INFO - logger - iteration 108 : offline_loss:0.00 online_loss:309.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.38 loss:309.29 n_loss:0.00 tb_loss:309.29 batch_entropy:44.88 traj_lens:16.81 grad_norm:575.07 grad_norm_clip:68.27 sampled_reward_avg:0.27 train_time:2.89 time_spent:11.99
# 03/12/2024 22:33:33 - INFO - logger - iteration 109 : offline_loss:0.00 online_loss:254.44 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.46 loss:254.44 n_loss:0.00 tb_loss:254.44 batch_entropy:44.86 traj_lens:16.77 grad_norm:635.58 grad_norm_clip:68.60 sampled_reward_avg:0.27 train_time:2.68 time_spent:12.37
# 03/12/2024 22:33:45 - INFO - logger - iteration 110 : offline_loss:0.00 online_loss:263.50 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.55 loss:263.50 n_loss:0.00 tb_loss:263.50 batch_entropy:45.22 traj_lens:16.67 grad_norm:560.35 grad_norm_clip:66.69 sampled_reward_avg:0.25 train_time:2.57 time_spent:11.87
# 03/12/2024 22:33:57 - INFO - logger - iteration 111 : offline_loss:0.00 online_loss:263.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.63 loss:263.25 n_loss:0.00 tb_loss:263.25 batch_entropy:45.99 traj_lens:16.95 grad_norm:686.09 grad_norm_clip:69.64 sampled_reward_avg:0.23 train_time:2.68 time_spent:12.20
# 03/12/2024 22:34:09 - INFO - logger - iteration 112 : offline_loss:0.00 online_loss:265.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.71 loss:265.05 n_loss:0.00 tb_loss:265.05 batch_entropy:46.01 traj_lens:16.86 grad_norm:604.14 grad_norm_clip:67.80 sampled_reward_avg:0.26 train_time:2.52 time_spent:11.79
# 03/12/2024 22:34:21 - INFO - logger - iteration 113 : offline_loss:0.00 online_loss:227.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.79 loss:227.32 n_loss:0.00 tb_loss:227.32 batch_entropy:44.72 traj_lens:16.72 grad_norm:519.94 grad_norm_clip:62.50 sampled_reward_avg:0.26 train_time:2.57 time_spent:12.05
# 03/12/2024 22:34:32 - INFO - logger - iteration 114 : offline_loss:0.00 online_loss:238.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.87 loss:238.87 n_loss:0.00 tb_loss:238.87 batch_entropy:44.14 traj_lens:16.39 grad_norm:563.34 grad_norm_clip:66.96 sampled_reward_avg:0.28 train_time:2.55 time_spent:11.75
# 03/12/2024 22:34:44 - INFO - logger - iteration 115 : offline_loss:0.00 online_loss:243.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.95 loss:243.12 n_loss:0.00 tb_loss:243.12 batch_entropy:45.28 traj_lens:16.91 grad_norm:613.43 grad_norm_clip:67.85 sampled_reward_avg:0.25 train_time:2.65 time_spent:11.85
# 03/12/2024 22:34:56 - INFO - logger - iteration 116 : offline_loss:0.00 online_loss:223.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.04 loss:223.32 n_loss:0.00 tb_loss:223.32 batch_entropy:44.72 traj_lens:16.81 grad_norm:534.03 grad_norm_clip:64.65 sampled_reward_avg:0.28 train_time:2.68 time_spent:12.23
# 03/12/2024 22:35:08 - INFO - logger - iteration 117 : offline_loss:0.00 online_loss:233.07 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.12 loss:233.07 n_loss:0.00 tb_loss:233.07 batch_entropy:44.61 traj_lens:16.58 grad_norm:553.48 grad_norm_clip:65.45 sampled_reward_avg:0.29 train_time:2.74 time_spent:11.84
# 03/12/2024 22:35:20 - INFO - logger - iteration 118 : offline_loss:0.00 online_loss:229.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.21 loss:229.12 n_loss:0.00 tb_loss:229.12 batch_entropy:45.27 traj_lens:16.91 grad_norm:653.47 grad_norm_clip:69.37 sampled_reward_avg:0.25 train_time:2.59 time_spent:11.84
# 03/12/2024 22:35:32 - INFO - logger - iteration 119 : offline_loss:0.00 online_loss:223.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.29 loss:223.17 n_loss:0.00 tb_loss:223.17 batch_entropy:45.52 traj_lens:17.00 grad_norm:531.79 grad_norm_clip:61.00 sampled_reward_avg:0.25 train_time:2.63 time_spent:12.14
# 03/12/2024 22:35:44 - INFO - logger - iteration 120 : offline_loss:0.00 online_loss:234.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.37 loss:234.18 n_loss:0.00 tb_loss:234.18 batch_entropy:45.62 traj_lens:16.86 grad_norm:603.51 grad_norm_clip:67.73 sampled_reward_avg:0.24 train_time:2.56 time_spent:11.90
# 03/12/2024 22:35:56 - INFO - logger - iteration 121 : offline_loss:0.00 online_loss:224.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.46 loss:224.20 n_loss:0.00 tb_loss:224.20 batch_entropy:45.63 traj_lens:17.00 grad_norm:558.75 grad_norm_clip:64.09 sampled_reward_avg:0.25 train_time:2.57 time_spent:12.03
# 03/12/2024 22:36:08 - INFO - logger - iteration 122 : offline_loss:0.00 online_loss:224.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.54 loss:224.68 n_loss:0.00 tb_loss:224.68 batch_entropy:45.39 traj_lens:16.86 grad_norm:577.18 grad_norm_clip:67.21 sampled_reward_avg:0.25 train_time:2.66 time_spent:12.16
# 03/12/2024 22:36:20 - INFO - logger - iteration 123 : offline_loss:0.00 online_loss:217.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.63 loss:217.74 n_loss:0.00 tb_loss:217.74 batch_entropy:44.72 traj_lens:16.72 grad_norm:557.18 grad_norm_clip:65.40 sampled_reward_avg:0.29 train_time:2.51 time_spent:11.83
# 03/12/2024 22:36:32 - INFO - logger - iteration 124 : offline_loss:0.00 online_loss:212.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.71 loss:212.20 n_loss:0.00 tb_loss:212.20 batch_entropy:44.79 traj_lens:16.62 grad_norm:570.83 grad_norm_clip:66.64 sampled_reward_avg:0.25 train_time:2.60 time_spent:11.74
# 03/12/2024 22:36:45 - INFO - logger - iteration 125 : offline_loss:0.00 online_loss:208.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.80 loss:208.30 n_loss:0.00 tb_loss:208.30 batch_entropy:45.08 traj_lens:16.86 grad_norm:619.17 grad_norm_clip:68.17 sampled_reward_avg:0.27 train_time:2.98 time_spent:13.10
# 03/12/2024 22:36:58 - INFO - logger - iteration 126 : offline_loss:0.00 online_loss:202.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.89 loss:202.60 n_loss:0.00 tb_loss:202.60 batch_entropy:44.85 traj_lens:16.86 grad_norm:546.48 grad_norm_clip:63.96 sampled_reward_avg:0.27 train_time:2.65 time_spent:12.85
# 03/12/2024 22:37:10 - INFO - logger - iteration 127 : offline_loss:0.00 online_loss:209.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.97 loss:209.00 n_loss:0.00 tb_loss:209.00 batch_entropy:45.58 traj_lens:16.95 grad_norm:569.33 grad_norm_clip:65.99 sampled_reward_avg:0.25 train_time:2.62 time_spent:11.91
# ...
# 03/12/2024 23:43:46 - INFO - logger - iteration 458 : offline_loss:0.00 online_loss:1.56 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.12 loss:1.56 n_loss:0.00 tb_loss:1.56 batch_entropy:48.93 traj_lens:17.00 grad_norm:23.50 grad_norm_clip:21.96 sampled_reward_avg:0.19 train_time:2.60 time_spent:11.80
# 03/12/2024 23:43:57 - INFO - logger - iteration 459 : offline_loss:0.00 online_loss:1.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.09 loss:1.42 n_loss:0.00 tb_loss:1.42 batch_entropy:48.89 traj_lens:17.00 grad_norm:26.93 grad_norm_clip:25.96 sampled_reward_avg:0.20 train_time:2.58 time_spent:11.79
# 03/12/2024 23:44:10 - INFO - logger - iteration 460 : offline_loss:0.00 online_loss:1.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.06 loss:1.86 n_loss:0.00 tb_loss:1.86 batch_entropy:48.68 traj_lens:17.00 grad_norm:36.96 grad_norm_clip:31.61 sampled_reward_avg:0.23 train_time:2.57 time_spent:12.26
# 03/12/2024 23:44:22 - INFO - logger - iteration 461 : offline_loss:0.00 online_loss:1.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.04 loss:1.71 n_loss:0.00 tb_loss:1.71 batch_entropy:48.73 traj_lens:17.00 grad_norm:27.40 grad_norm_clip:25.47 sampled_reward_avg:0.20 train_time:2.65 time_spent:11.86
# 03/12/2024 23:44:34 - INFO - logger - iteration 462 : offline_loss:0.00 online_loss:1.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.01 loss:1.59 n_loss:0.00 tb_loss:1.59 batch_entropy:49.05 traj_lens:17.00 grad_norm:58.18 grad_norm_clip:43.79 sampled_reward_avg:0.20 train_time:2.72 time_spent:12.01
# 03/12/2024 23:44:46 - INFO - logger - iteration 463 : offline_loss:0.00 online_loss:1.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.00 loss:1.40 n_loss:0.00 tb_loss:1.40 batch_entropy:48.78 traj_lens:17.00 grad_norm:32.80 grad_norm_clip:31.47 sampled_reward_avg:0.22 train_time:2.55 time_spent:12.09
# 03/12/2024 23:44:57 - INFO - logger - iteration 464 : offline_loss:0.00 online_loss:1.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:24.98 loss:1.25 n_loss:0.00 tb_loss:1.25 batch_entropy:49.04 traj_lens:17.00 grad_norm:35.87 grad_norm_clip:34.03 sampled_reward_avg:0.20 train_time:2.54 time_spent:11.80
# 03/12/2024 23:45:09 - INFO - logger - iteration 465 : offline_loss:0.00 online_loss:1.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:24.98 loss:1.46 n_loss:0.00 tb_loss:1.46 batch_entropy:48.98 traj_lens:17.00 grad_norm:38.94 grad_norm_clip:29.68 sampled_reward_avg:0.21 train_time:2.53 time_spent:11.86
# 03/12/2024 23:45:21 - INFO - logger - iteration 466 : offline_loss:0.00 online_loss:1.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:24.98 loss:1.33 n_loss:0.00 tb_loss:1.33 batch_entropy:49.06 traj_lens:17.00 grad_norm:30.33 grad_norm_clip:25.96 sampled_reward_avg:0.21 train_time:2.56 time_spent:12.07
# 03/12/2024 23:45:33 - INFO - logger - iteration 467 : offline_loss:0.00 online_loss:1.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:24.99 loss:1.94 n_loss:0.00 tb_loss:1.94 batch_entropy:48.93 traj_lens:17.00 grad_norm:62.32 grad_norm_clip:45.87 sampled_reward_avg:0.20 train_time:2.80 time_spent:12.10
# 03/12/2024 23:45:45 - INFO - logger - iteration 468 : offline_loss:0.00 online_loss:1.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.01 loss:1.52 n_loss:0.00 tb_loss:1.52 batch_entropy:49.15 traj_lens:17.00 grad_norm:54.60 grad_norm_clip:40.52 sampled_reward_avg:0.19 train_time:2.58 time_spent:11.85
# 03/12/2024 23:45:57 - INFO - logger - iteration 469 : offline_loss:0.00 online_loss:2.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.04 loss:2.14 n_loss:0.00 tb_loss:2.14 batch_entropy:48.55 traj_lens:16.91 grad_norm:48.58 grad_norm_clip:40.43 sampled_reward_avg:0.21 train_time:2.58 time_spent:12.13
# 03/12/2024 23:46:09 - INFO - logger - iteration 470 : offline_loss:0.00 online_loss:1.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.07 loss:1.42 n_loss:0.00 tb_loss:1.42 batch_entropy:48.95 traj_lens:17.00 grad_norm:40.66 grad_norm_clip:29.71 sampled_reward_avg:0.22 train_time:2.53 time_spent:11.76
# 03/12/2024 23:46:21 - INFO - logger - iteration 471 : offline_loss:0.00 online_loss:1.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.11 loss:1.33 n_loss:0.00 tb_loss:1.33 batch_entropy:49.02 traj_lens:17.00 grad_norm:50.98 grad_norm_clip:41.52 sampled_reward_avg:0.19 train_time:2.55 time_spent:11.80
# 03/12/2024 23:46:33 - INFO - logger - iteration 472 : offline_loss:0.00 online_loss:1.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.15 loss:1.35 n_loss:0.00 tb_loss:1.35 batch_entropy:49.08 traj_lens:17.00 grad_norm:55.59 grad_norm_clip:42.79 sampled_reward_avg:0.22 train_time:2.65 time_spent:12.19
# 03/12/2024 23:46:45 - INFO - logger - iteration 473 : offline_loss:0.00 online_loss:1.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.20 loss:1.61 n_loss:0.00 tb_loss:1.61 batch_entropy:48.83 traj_lens:17.00 grad_norm:33.34 grad_norm_clip:32.34 sampled_reward_avg:0.20 train_time:2.54 time_spent:11.74
# 03/12/2024 23:46:57 - INFO - logger - iteration 474 : offline_loss:0.00 online_loss:1.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.23 loss:1.12 n_loss:0.00 tb_loss:1.12 batch_entropy:48.64 traj_lens:17.00 grad_norm:23.33 grad_norm_clip:21.63 sampled_reward_avg:0.23 train_time:2.57 time_spent:11.79
# 03/12/2024 23:47:09 - INFO - logger - iteration 475 : offline_loss:0.00 online_loss:2.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.27 loss:2.23 n_loss:0.00 tb_loss:2.23 batch_entropy:48.87 traj_lens:17.00 grad_norm:29.68 grad_norm_clip:27.75 sampled_reward_avg:0.21 train_time:2.59 time_spent:12.16
# 03/12/2024 23:47:21 - INFO - logger - iteration 476 : offline_loss:0.00 online_loss:3.67 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.29 loss:3.67 n_loss:0.00 tb_loss:3.67 batch_entropy:48.46 traj_lens:16.86 grad_norm:48.27 grad_norm_clip:40.07 sampled_reward_avg:0.23 train_time:2.51 time_spent:11.70
# 03/12/2024 23:47:33 - INFO - logger - iteration 477 : offline_loss:0.00 online_loss:4.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.30 loss:4.85 n_loss:0.00 tb_loss:4.85 batch_entropy:48.76 traj_lens:16.81 grad_norm:34.57 grad_norm_clip:26.48 sampled_reward_avg:0.21 train_time:3.07 time_spent:12.72
# 03/12/2024 23:47:46 - INFO - logger - iteration 478 : offline_loss:0.00 online_loss:5.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.31 loss:5.00 n_loss:0.00 tb_loss:5.00 batch_entropy:48.58 traj_lens:16.81 grad_norm:46.25 grad_norm_clip:33.87 sampled_reward_avg:0.20 train_time:2.39 time_spent:12.60
# 03/12/2024 23:47:58 - INFO - logger - iteration 479 : offline_loss:0.00 online_loss:0.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.30 loss:0.94 n_loss:0.00 tb_loss:0.94 batch_entropy:49.02 traj_lens:17.00 grad_norm:25.47 grad_norm_clip:22.15 sampled_reward_avg:0.20 train_time:2.46 time_spent:11.79
# 03/12/2024 23:48:10 - INFO - logger - iteration 480 : offline_loss:0.00 online_loss:1.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.29 loss:1.69 n_loss:0.00 tb_loss:1.69 batch_entropy:49.16 traj_lens:17.00 grad_norm:28.73 grad_norm_clip:26.82 sampled_reward_avg:0.20 train_time:2.53 time_spent:11.87
# 03/12/2024 23:48:22 - INFO - logger - iteration 481 : offline_loss:0.00 online_loss:2.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.28 loss:2.03 n_loss:0.00 tb_loss:2.03 batch_entropy:48.78 traj_lens:17.00 grad_norm:35.52 grad_norm_clip:29.87 sampled_reward_avg:0.20 train_time:2.56 time_spent:12.00
# 03/12/2024 23:48:33 - INFO - logger - iteration 482 : offline_loss:0.00 online_loss:4.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.28 loss:4.88 n_loss:0.00 tb_loss:4.88 batch_entropy:48.47 traj_lens:16.77 grad_norm:33.65 grad_norm_clip:30.22 sampled_reward_avg:0.22 train_time:2.46 time_spent:11.88
# 03/12/2024 23:48:45 - INFO - logger - iteration 483 : offline_loss:0.00 online_loss:1.81 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.27 loss:1.81 n_loss:0.00 tb_loss:1.81 batch_entropy:48.97 traj_lens:17.00 grad_norm:47.19 grad_norm_clip:40.26 sampled_reward_avg:0.22 train_time:2.56 time_spent:11.70
# 03/12/2024 23:48:57 - INFO - logger - iteration 484 : offline_loss:0.00 online_loss:1.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.27 loss:1.05 n_loss:0.00 tb_loss:1.05 batch_entropy:48.97 traj_lens:17.00 grad_norm:24.24 grad_norm_clip:23.87 sampled_reward_avg:0.20 train_time:2.66 time_spent:11.82
# 03/12/2024 23:49:09 - INFO - logger - iteration 485 : offline_loss:0.00 online_loss:0.83 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.26 loss:0.83 n_loss:0.00 tb_loss:0.83 batch_entropy:48.88 traj_lens:17.00 grad_norm:34.95 grad_norm_clip:33.94 sampled_reward_avg:0.22 train_time:2.55 time_spent:12.11
# 03/12/2024 23:49:21 - INFO - logger - iteration 486 : offline_loss:0.00 online_loss:1.58 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.26 loss:1.58 n_loss:0.00 tb_loss:1.58 batch_entropy:49.03 traj_lens:17.00 grad_norm:29.61 grad_norm_clip:27.55 sampled_reward_avg:0.20 train_time:2.49 time_spent:11.79
# 03/12/2024 23:49:33 - INFO - logger - iteration 487 : offline_loss:0.00 online_loss:1.43 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.25 loss:1.43 n_loss:0.00 tb_loss:1.43 batch_entropy:48.99 traj_lens:17.00 grad_norm:32.41 grad_norm_clip:29.41 sampled_reward_avg:0.21 train_time:2.69 time_spent:12.11
# 03/12/2024 23:49:45 - INFO - logger - iteration 488 : offline_loss:0.00 online_loss:2.92 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.24 loss:2.92 n_loss:0.00 tb_loss:2.92 batch_entropy:48.66 traj_lens:16.91 grad_norm:38.20 grad_norm_clip:32.10 sampled_reward_avg:0.21 train_time:2.51 time_spent:11.93
# 03/12/2024 23:49:57 - INFO - logger - iteration 489 : offline_loss:0.00 online_loss:1.44 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.22 loss:1.44 n_loss:0.00 tb_loss:1.44 batch_entropy:48.92 traj_lens:17.00 grad_norm:36.74 grad_norm_clip:33.32 sampled_reward_avg:0.21 train_time:2.67 time_spent:11.83
# 03/12/2024 23:50:09 - INFO - logger - iteration 490 : offline_loss:0.00 online_loss:1.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.19 loss:1.32 n_loss:0.00 tb_loss:1.32 batch_entropy:49.12 traj_lens:17.00 grad_norm:39.13 grad_norm_clip:36.86 sampled_reward_avg:0.19 train_time:2.58 time_spent:11.89
# 03/12/2024 23:50:21 - INFO - logger - iteration 491 : offline_loss:0.00 online_loss:1.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.18 loss:1.14 n_loss:0.00 tb_loss:1.14 batch_entropy:48.93 traj_lens:17.00 grad_norm:31.33 grad_norm_clip:28.70 sampled_reward_avg:0.23 train_time:2.52 time_spent:11.99
# 03/12/2024 23:50:33 - INFO - logger - iteration 492 : offline_loss:0.00 online_loss:1.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.18 loss:1.64 n_loss:0.00 tb_loss:1.64 batch_entropy:48.88 traj_lens:17.00 grad_norm:28.65 grad_norm_clip:27.64 sampled_reward_avg:0.21 train_time:2.56 time_spent:11.89
# 03/12/2024 23:50:44 - INFO - logger - iteration 493 : offline_loss:0.00 online_loss:2.91 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.17 loss:2.91 n_loss:0.00 tb_loss:2.91 batch_entropy:48.71 traj_lens:16.86 grad_norm:31.79 grad_norm_clip:28.23 sampled_reward_avg:0.21 train_time:2.53 time_spent:11.80
# 03/12/2024 23:50:56 - INFO - logger - iteration 494 : offline_loss:0.00 online_loss:91.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.16 loss:91.86 n_loss:0.00 tb_loss:91.86 batch_entropy:48.49 traj_lens:16.86 grad_norm:181.26 grad_norm_clip:58.09 sampled_reward_avg:0.21 train_time:2.55 time_spent:11.85
# 03/12/2024 23:51:08 - INFO - logger - iteration 495 : offline_loss:0.00 online_loss:1.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.13 loss:1.57 n_loss:0.00 tb_loss:1.57 batch_entropy:49.25 traj_lens:17.00 grad_norm:44.11 grad_norm_clip:35.47 sampled_reward_avg:0.21 train_time:2.59 time_spent:11.86
# 03/12/2024 23:51:20 - INFO - logger - iteration 496 : offline_loss:0.00 online_loss:1.63 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.11 loss:1.63 n_loss:0.00 tb_loss:1.63 batch_entropy:49.10 traj_lens:17.00 grad_norm:59.56 grad_norm_clip:39.29 sampled_reward_avg:0.21 train_time:2.50 time_spent:11.73
# 03/12/2024 23:51:32 - INFO - logger - iteration 497 : offline_loss:0.00 online_loss:1.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.11 loss:1.13 n_loss:0.00 tb_loss:1.13 batch_entropy:48.95 traj_lens:17.00 grad_norm:30.28 grad_norm_clip:27.79 sampled_reward_avg:0.22 train_time:2.63 time_spent:12.20
# 03/12/2024 23:51:44 - INFO - logger - iteration 498 : offline_loss:0.00 online_loss:1.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.12 loss:1.41 n_loss:0.00 tb_loss:1.41 batch_entropy:49.09 traj_lens:17.00 grad_norm:33.98 grad_norm_clip:32.80 sampled_reward_avg:0.19 train_time:2.54 time_spent:11.80
# 03/12/2024 23:51:55 - INFO - logger - iteration 499 : offline_loss:0.00 online_loss:1.45 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.13 loss:1.45 n_loss:0.00 tb_loss:1.45 batch_entropy:49.00 traj_lens:17.00 grad_norm:50.88 grad_norm_clip:39.95 sampled_reward_avg:0.20 train_time:2.51 time_spent:11.72
# 03/12/2024 23:52:08 - INFO - logger - iteration 500 : offline_loss:0.00 online_loss:1.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:25.15 loss:1.22 n_loss:0.00 tb_loss:1.22 batch_entropy:49.10 traj_lens:17.00 grad_norm:39.71 grad_norm_clip:36.40 sampled_reward_avg:0.20 train_time:2.52 time_spent:12.14

# %%
with open(os.path.join(config.log_dir, "params.json"), "w+") as file:
    json.dump(params,file)

with open(os.path.join(config.log_dir, "target.json"), "w+") as file:
    json.dump(target,file)

state = {
    "models_state_dict": [trial.model.state_dict()],
    "cfg": trial.cfg,
    "env_ctx": trial.model.env_ctx,
    #"model": trial.model,
}
if trial.sampling_model is not trial.model:
    state["sampling_model_state_dict"] = [trial.sampling_model.state_dict()]
fn = pathlib.Path(trial.cfg.log_dir) / "model_final_save.pt"
with open(fn, "wb") as fd:
    torch.save(
        state,
        fd,
    )

# %%
# Generate molecules
trajs = trial.algo.create_training_data_from_own_samples(trial.model, 25)
objs = [trial.ctx.graph_to_obj(i['result']) for i in trajs]
obj_props, is_valid = trial.task.compute_obj_properties(objs)
log_rewards = trial.task.cond_info_to_logreward({'beta': torch.ones(len(trajs))}, obj_props)
index = 0
rewards = []
for i in is_valid:
    if i:
        rewards.append(list(log_rewards)[index])
        index += 1 
    else:
        rewards.append(0)

MolsToGridImage(objs[:25], molsPerRow=5, subImgSize=(200, 120), legends=[f'reward: {r}' if r==0 else f'reward: {r.exp().item():.2f}' for r in rewards[:25]])

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')])
ax[0].set_yscale('log')
ax[1].set_ylabel('TB loss')
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')])
ax[1].set_ylabel('Average reward')
ax[2].plot([i.value for i in ea.Scalars('train_logZ')])
ax[2].set_ylabel('Predicted logZ')
pp.tight_layout()

# %%
tags = ea.Tags()
print("Available tags:", tags)

# %%
from pycirclize import Circos
import pandas as pd
import matplotlib.pyplot as plt
from pom_models.functions import fragance_propabilities_from_smiles
from rdkit import Chem
import numpy as np

# %%
indices = np.argsort(-np.array(target))
indices

# %%
labels = df.keys()[2:]
labels

# %%
data_lst  = []
for i, obj in enumerate(objs):
    smiles = Chem.MolToSmiles(obj)
    probs = fragance_propabilities_from_smiles(smiles)[0]

    data_lst.append( [smiles] + list(probs))
result_df = pd.DataFrame(
    data=data_lst,
    index=[i for i in range(len(data_lst))],
    columns=["smiles"]+list(labels)
    )
result_df.head()

# %%
target_df = pd.DataFrame(
    data=[["target"] + list(target)],
    columns=result_df.keys(),
    index=["Target"]
)
target_df

# %%
most_important_indicies = indices[:8]
most_important_keys = []
for i in most_important_indicies:
    most_important_keys.append(labels[i])
most_important_keys

# %%
rewards_plot = [f'{r}' if r==-1 else f'{r.exp().item():.2f}' for r in rewards[:25]]
rewards_plot

# %%
plot_df = result_df[most_important_keys].set_index(pd.Series([f"{i+1} r:{rewards_plot[i]}" for i in range(len(result_df["smiles"]))]))
plot_df

# %%
plot_target_df = target_df[most_important_keys]
plot_target_df

# %%
plot_df.loc["target"] = []

# %%
# Create 5 x 5 subplots
fig = plt.figure(figsize=(26, 16), dpi=100)
fig.subplots(5, 5, subplot_kw=dict(polar=True))
fig.subplots_adjust(wspace=1, hspace=0.25)

# Plot radar chart into subplots for each target
for target_name, ax in zip(plot_df.index, fig.axes):
    target_df = plot_df.loc[[target_name]]
    target_df = pd.concat([target_df, plot_target_df])
    # Initialize Circos instance for radar chart plot
    circos = Circos.radar_chart(
        target_df,
        vmax=1,
        marker_size=6,
        #cmap=dict(Hero="salmon", Warrior="skyblue", Wizard="lime", Assassin="magenta"),
        grid_interval_ratio=0.2,
        line_kws_handler=lambda _: dict(lw=2, ls="solid"),
        marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
    )

    # Plot figure & set legend on upper right
    circos.plotfig(ax=ax)
    circos.ax.legend(loc="upper right", fontsize=10,bbox_to_anchor=(1.7, 1.1))

# %%
np.array(result_df[labels].sum())/len(result_df[labels])

# %%
import seaborn as sns

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[0].set_yscale('log')
ax[0].set_ylabel('TB loss')
ax[0].grid()
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[1].set_ylabel('Average reward')
ax[1].set_xlabel('Iteration')
ax[1].grid()
ax[2].plot([i.value for i in ea.Scalars('train_logZ')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[2].set_ylabel('Predicted logZ')
ax[2].grid()
pp.tight_layout()
plt.savefig("images/pine_run_plots.pdf")
