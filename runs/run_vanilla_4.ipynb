# %% [markdown]
# # Run Vanilla

# %%
import sys
import os
path_to_top_dir = "../"
# Dynamically add the `project` directory to the path
sys.path.append(os.path.abspath(path_to_top_dir))

# %%
os.path.abspath(path_to_top_dir)
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model'

# %%
# Print current working directory
os.getcwd()
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model\\runs'

# %%
# Import scent_gfn functions
from scent_gfn.fragments import FRAGMENTS, FRAGMENTS_OPENPOM_DATASET, FRAGMENTS_OPENPOM_VANILLA
from scent_gfn.molecule import MoleculeTrainer
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# Skipped loading some PyTorch models, missing a dependency. No module named 'tensorflow'
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)

# %% [markdown]
# | **Parameter**                | **Value**      |
# |------------------------------|----------------|
# | Reward function type         | OpenPOM        |
# | Similarity measure           | Cosine         |
# | Graph building               | Vanilla Fragments      |
# | Iterations                   | 500            |
# | Max number of nodes          | 6              |
# | Illegal action logreward     | -64           |
# | β                            | 1              |
# | Large molecule penalty       | Hard           |

# %%
params = {
    "save_name": "vanilla4",
    "reward_func": "openpom", # structure, openpom
    "similarity": "cosine",
    "graph_building": FRAGMENTS_OPENPOM_VANILLA,#FRAGMENTS,
    "iterations": 500,
    "max_nodes": 6,
    "illegal_logreward": -64,
    "beta": 1.0,
    "large_mol_pen": ["hard", 23]# ["exponential", 15] # ["exponential", 15] , ["hard", 15], [None,None]
}

# %%
# Utilities
import warnings
import random
import datetime

# Data processing and file management
import pathlib
import pandas as pd
import json
import numpy as np

# Machine learning
import torch
from gflownet.config import init_empty, Config
from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage, MolToImage


# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Run on cpu
dev = torch.device('cpu')

# %%
def get_pine_openpom_target():
    with open('../data/pine_target_2.json', 'r') as file:
        target = json.load(file)
    return [target]

# %%
def get_vanilla_test_and_training(split_ratio=0.7):
    df = pd.read_csv("../data/data.csv")
    vanilla_mols_df = df.loc[df['vanilla'] == 1]
    vanilla_smiles_trainig= list(vanilla_mols_df["nonStereoSMILES"])
    vanilla_smiles_trainig = random.sample(vanilla_smiles_trainig, round(len(vanilla_mols_df)*split_ratio))
    random.shuffle(vanilla_smiles_trainig)
    vanilla_smiles_test = []
    for i in vanilla_mols_df["nonStereoSMILES"]:
        if i not in vanilla_smiles_trainig:
            vanilla_smiles_test.append(i)
    return vanilla_smiles_trainig, vanilla_smiles_test

def get_vanillin():
    return ["COc1cc(C=O)ccc1O"]

# %%
target = get_vanillin()

# %%
# Initialize model
config = init_empty(Config())
config.print_every = 1
config.log_dir = f"{os.path.abspath(path_to_top_dir)}/results/{params['save_name']}_{datetime.datetime.now().strftime('%Y-%m-%d__%H_%M_%S')}"
config.device = dev
config.num_training_steps = params["iterations"]
config.num_workers = 0
config.num_validation_gen_steps = 1
config.overwrite_existing_exp=False
config.checkpoint_every = 100
config.algo.max_nodes = params["max_nodes"] #12 # 95 quantil
config.store_all_checkpoints = True
config.algo.illegal_action_logreward = params["illegal_logreward"]

if params["graph_building"] == None:
     trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]), print_config=True) #,fragments=FRAGMENTS, print_config=True)
else:
    trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]),fragments=params["graph_building"], print_config=True) #,fragments=FRAGMENTS, print_config=True)
# Out:
# SMILES input data detected ...
# Reward function: reward_function_openpom | Similarity measure: cosine_similarity | exp_penalty: False | max_mol=23
# Building molecules using fragments ...
#
#
# Hyperparameters:
#
# desc: noDesc
# log_dir: c:\Users\paulj\Desktop\prosjekt\pom_cpu-model/results/vanilla4_2024-12-04__09_23_46
# device: cpu
# seed: 0
# validate_every: 1000
# checkpoint_every: 100
# store_all_checkpoints: true
# print_every: 1
# start_at_step: 0
# num_final_gen_steps: null
# num_validation_gen_steps: 1
# num_training_steps: 500
# num_workers: 0
# hostname: null
# pickle_mp_messages: false
# git_hash: f106cde
# overwrite_existing_exp: false
# algo:
#   method: TB
#   num_from_policy: 64
#   num_from_dataset: 0
#   valid_num_from_policy: 64
#   valid_num_from_dataset: 0
#   max_len: 128
#   max_nodes: 6
#   max_edges: 128
#   illegal_action_logreward: -64.0
#   train_random_action_prob: 0.0
#   train_det_after: null
#   valid_random_action_prob: 0.0
#   sampling_tau: 0.9
#   tb:
#     bootstrap_own_reward: false
#     epsilon: null
#     reward_loss_multiplier: 1.0
#     variant: TB
#     do_correct_idempotent: false
#     do_parameterize_p_b: false
#     do_predict_n: false
#     do_sample_p_b: false
#     do_length_normalize: false
#     subtb_max_len: 128
#     Z_learning_rate: 0.0001
#     Z_lr_decay: 50000.0
#     cum_subtb: true
#     loss_fn: MSE
#     loss_fn_par: 1.0
#     n_loss: none
#     n_loss_multiplier: 1.0
#     backward_policy: Uniform
#   moql:
#     gamma: 1.0
#     num_omega_samples: 32
#     num_objectives: 2
#     lambda_decay: 10000
#     penalty: -10.0
#   a2c:
#     entropy: 0.01
#     gamma: 1.0
#     penalty: -10.0
#   fm:
#     epsilon: 1.0e-38
#     balanced_loss: false
#     leaf_coef: 10.0
#     correct_idempotent: false
#   sql:
#     alpha: 0.01
#     gamma: 1.0
#     penalty: -10.0
# model:
#   num_layers: 3
#   num_emb: 128
#   dropout: 0.0
#   graph_transformer:
#     num_heads: 2
#     ln_type: pre
#     num_mlp_layers: 0
#     concat_heads: true
#   seq_transformer:
#     num_heads: 2
#     posenc: Rotary
# opt:
#   opt: adam
#   learning_rate: 0.0001
#   lr_decay: 20000.0
#   weight_decay: 1.0e-08
#   momentum: 0.9
#   clip_grad_type: norm
#   clip_grad_param: 10.0
#   adam_eps: 1.0e-08
# replay:
#   use: false
#   capacity: null
#   warmup: null
#   hindsight_ratio: 0.0
#   num_from_replay: null
#   num_new_samples: null
# task:
#   qm9:
#     h5_path: ./data/qm9/qm9.h5
#     model_path: ./data/qm9/qm9_model.pt
#   qm9_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - gap
#     - qed
#     - sa
#     online_pareto_front: true
#   seh:
#     reduced_frag: false
#   seh_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - seh
#     - qed
#     - sa
#     - mw
#     log_topk: false
#     online_pareto_front: true
# cond:
#   valid_sample_cond_info: true
#   temperature:
#     sample_dist: uniform
#     dist_params:
#     - 0.5
#     - 32
#     num_thermometer_dim: 32
#   moo:
#     num_objectives: 2
#     num_thermometer_dim: 16
#   weighted_prefs:
#     preference_type: dirichlet
#     preference_param: 1.5
#   focus_region:
#     focus_type: centered
#     use_steer_thermomether: false
#     focus_cosim: 0.98
#     focus_limit_coef: 0.1
#     focus_model_training_limits:
#     - 0.25
#     - 0.75
#     focus_model_state_space_res: 30
#     max_train_it: 20000

# %%
trial.run()
# Out:
# 04/12/2024 09:23:47 - INFO - logger - Starting training
# 04/12/2024 09:23:56 - INFO - logger - iteration 1 : offline_loss:0.00 online_loss:535.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.21 loss:535.76 n_loss:0.00 tb_loss:535.76 batch_entropy:24.13 traj_lens:10.91 grad_norm:244.82 grad_norm_clip:65.49 sampled_reward_avg:0.60 train_time:1.49 time_spent:8.79
# 04/12/2024 09:24:03 - INFO - logger - iteration 2 : offline_loss:0.00 online_loss:1041.80 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.25 loss:1041.80 n_loss:0.00 tb_loss:1041.80 batch_entropy:27.14 traj_lens:11.61 grad_norm:407.40 grad_norm_clip:68.23 sampled_reward_avg:0.46 train_time:1.47 time_spent:7.09
# 04/12/2024 09:24:10 - INFO - logger - iteration 3 : offline_loss:0.00 online_loss:668.45 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.24 loss:668.45 n_loss:0.00 tb_loss:668.45 batch_entropy:28.50 traj_lens:12.22 grad_norm:306.42 grad_norm_clip:65.04 sampled_reward_avg:0.56 train_time:1.49 time_spent:7.76
# 04/12/2024 09:24:17 - INFO - logger - iteration 4 : offline_loss:0.00 online_loss:672.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.23 loss:672.34 n_loss:0.00 tb_loss:672.34 batch_entropy:19.52 traj_lens:9.08 grad_norm:258.86 grad_norm_clip:66.04 sampled_reward_avg:0.54 train_time:1.00 time_spent:6.57
# 04/12/2024 09:24:25 - INFO - logger - iteration 5 : offline_loss:0.00 online_loss:572.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.21 loss:572.10 n_loss:0.00 tb_loss:572.10 batch_entropy:21.57 traj_lens:9.83 grad_norm:241.16 grad_norm_clip:62.90 sampled_reward_avg:0.55 train_time:1.19 time_spent:7.91
# 04/12/2024 09:24:33 - INFO - logger - iteration 6 : offline_loss:0.00 online_loss:725.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.19 loss:725.65 n_loss:0.00 tb_loss:725.65 batch_entropy:23.03 traj_lens:10.30 grad_norm:358.16 grad_norm_clip:67.13 sampled_reward_avg:0.49 train_time:1.31 time_spent:7.67
# 04/12/2024 09:24:40 - INFO - logger - iteration 7 : offline_loss:0.00 online_loss:867.63 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.17 loss:867.63 n_loss:0.00 tb_loss:867.63 batch_entropy:23.31 traj_lens:10.34 grad_norm:325.30 grad_norm_clip:67.20 sampled_reward_avg:0.48 train_time:1.26 time_spent:7.04
# 04/12/2024 09:24:47 - INFO - logger - iteration 8 : offline_loss:0.00 online_loss:672.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.14 loss:672.84 n_loss:0.00 tb_loss:672.84 batch_entropy:24.61 traj_lens:10.58 grad_norm:285.44 grad_norm_clip:65.23 sampled_reward_avg:0.55 train_time:1.27 time_spent:7.14
# 04/12/2024 09:24:54 - INFO - logger - iteration 9 : offline_loss:0.00 online_loss:632.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.11 loss:632.51 n_loss:0.00 tb_loss:632.51 batch_entropy:22.28 traj_lens:10.16 grad_norm:329.67 grad_norm_clip:66.20 sampled_reward_avg:0.53 train_time:1.20 time_spent:7.22
# 04/12/2024 09:25:01 - INFO - logger - iteration 10 : offline_loss:0.00 online_loss:727.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.08 loss:727.68 n_loss:0.00 tb_loss:727.68 batch_entropy:19.39 traj_lens:9.27 grad_norm:313.85 grad_norm_clip:65.97 sampled_reward_avg:0.55 train_time:1.04 time_spent:7.37
# 04/12/2024 09:25:08 - INFO - logger - iteration 11 : offline_loss:0.00 online_loss:642.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.04 loss:642.18 n_loss:0.00 tb_loss:642.18 batch_entropy:23.66 traj_lens:10.44 grad_norm:376.90 grad_norm_clip:66.38 sampled_reward_avg:0.53 train_time:1.24 time_spent:7.03
# 04/12/2024 09:25:16 - INFO - logger - iteration 12 : offline_loss:0.00 online_loss:566.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.01 loss:566.09 n_loss:0.00 tb_loss:566.09 batch_entropy:22.96 traj_lens:10.30 grad_norm:306.85 grad_norm_clip:66.04 sampled_reward_avg:0.58 train_time:1.15 time_spent:7.24
# 04/12/2024 09:25:23 - INFO - logger - iteration 13 : offline_loss:0.00 online_loss:640.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.02 loss:640.54 n_loss:0.00 tb_loss:640.54 batch_entropy:24.28 traj_lens:10.95 grad_norm:355.34 grad_norm_clip:64.38 sampled_reward_avg:0.58 train_time:1.26 time_spent:7.37
# 04/12/2024 09:25:30 - INFO - logger - iteration 14 : offline_loss:0.00 online_loss:565.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.03 loss:565.76 n_loss:0.00 tb_loss:565.76 batch_entropy:19.86 traj_lens:9.12 grad_norm:306.96 grad_norm_clip:65.05 sampled_reward_avg:0.59 train_time:1.05 time_spent:7.28
# 04/12/2024 09:25:38 - INFO - logger - iteration 15 : offline_loss:0.00 online_loss:399.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.04 loss:399.55 n_loss:0.00 tb_loss:399.55 batch_entropy:21.11 traj_lens:9.97 grad_norm:287.94 grad_norm_clip:63.98 sampled_reward_avg:0.57 train_time:1.09 time_spent:7.54
# 04/12/2024 09:25:45 - INFO - logger - iteration 16 : offline_loss:0.00 online_loss:626.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.05 loss:626.84 n_loss:0.00 tb_loss:626.84 batch_entropy:20.52 traj_lens:9.59 grad_norm:362.90 grad_norm_clip:65.61 sampled_reward_avg:0.54 train_time:1.04 time_spent:6.85
# 04/12/2024 09:25:52 - INFO - logger - iteration 17 : offline_loss:0.00 online_loss:421.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.06 loss:421.10 n_loss:0.00 tb_loss:421.10 batch_entropy:20.69 traj_lens:10.02 grad_norm:280.76 grad_norm_clip:63.86 sampled_reward_avg:0.57 train_time:1.16 time_spent:7.28
# 04/12/2024 09:25:59 - INFO - logger - iteration 18 : offline_loss:0.00 online_loss:192.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.06 loss:192.85 n_loss:0.00 tb_loss:192.85 batch_entropy:17.57 traj_lens:8.94 grad_norm:193.38 grad_norm_clip:58.22 sampled_reward_avg:0.66 train_time:0.89 time_spent:7.31
# 04/12/2024 09:26:07 - INFO - logger - iteration 19 : offline_loss:0.00 online_loss:195.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.06 loss:195.31 n_loss:0.00 tb_loss:195.31 batch_entropy:20.71 traj_lens:10.11 grad_norm:268.24 grad_norm_clip:63.94 sampled_reward_avg:0.65 train_time:1.15 time_spent:8.04
# 04/12/2024 09:26:16 - INFO - logger - iteration 20 : offline_loss:0.00 online_loss:355.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.06 loss:355.55 n_loss:0.00 tb_loss:355.55 batch_entropy:19.30 traj_lens:9.78 grad_norm:424.11 grad_norm_clip:65.03 sampled_reward_avg:0.58 train_time:1.08 time_spent:8.46
# 04/12/2024 09:26:23 - INFO - logger - iteration 21 : offline_loss:0.00 online_loss:418.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.05 loss:418.14 n_loss:0.00 tb_loss:418.14 batch_entropy:19.70 traj_lens:9.69 grad_norm:254.57 grad_norm_clip:64.45 sampled_reward_avg:0.60 train_time:1.05 time_spent:7.46
# 04/12/2024 09:26:30 - INFO - logger - iteration 22 : offline_loss:0.00 online_loss:177.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.03 loss:177.36 n_loss:0.00 tb_loss:177.36 batch_entropy:16.00 traj_lens:8.47 grad_norm:178.88 grad_norm_clip:59.25 sampled_reward_avg:0.64 train_time:0.81 time_spent:6.88
# 04/12/2024 09:26:38 - INFO - logger - iteration 23 : offline_loss:0.00 online_loss:353.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.01 loss:353.20 n_loss:0.00 tb_loss:353.20 batch_entropy:19.28 traj_lens:9.55 grad_norm:234.53 grad_norm_clip:62.53 sampled_reward_avg:0.63 train_time:1.07 time_spent:7.33
# 04/12/2024 09:26:45 - INFO - logger - iteration 24 : offline_loss:0.00 online_loss:227.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.01 loss:227.35 n_loss:0.00 tb_loss:227.35 batch_entropy:18.07 traj_lens:9.55 grad_norm:149.88 grad_norm_clip:55.65 sampled_reward_avg:0.63 train_time:1.09 time_spent:7.45
# 04/12/2024 09:26:52 - INFO - logger - iteration 25 : offline_loss:0.00 online_loss:529.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.03 loss:529.04 n_loss:0.00 tb_loss:529.04 batch_entropy:18.72 traj_lens:9.50 grad_norm:276.51 grad_norm_clip:62.66 sampled_reward_avg:0.57 train_time:1.00 time_spent:6.99
# 04/12/2024 09:27:00 - INFO - logger - iteration 26 : offline_loss:0.00 online_loss:262.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.05 loss:262.41 n_loss:0.00 tb_loss:262.41 batch_entropy:17.70 traj_lens:9.50 grad_norm:205.43 grad_norm_clip:61.05 sampled_reward_avg:0.62 train_time:0.99 time_spent:7.89
# 04/12/2024 09:27:08 - INFO - logger - iteration 27 : offline_loss:0.00 online_loss:196.58 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.07 loss:196.58 n_loss:0.00 tb_loss:196.58 batch_entropy:19.38 traj_lens:9.97 grad_norm:214.79 grad_norm_clip:61.25 sampled_reward_avg:0.66 train_time:1.19 time_spent:8.62
# 04/12/2024 09:27:16 - INFO - logger - iteration 28 : offline_loss:0.00 online_loss:240.01 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.09 loss:240.01 n_loss:0.00 tb_loss:240.01 batch_entropy:15.99 traj_lens:8.70 grad_norm:244.22 grad_norm_clip:63.24 sampled_reward_avg:0.63 train_time:0.83 time_spent:7.25
# 04/12/2024 09:27:23 - INFO - logger - iteration 29 : offline_loss:0.00 online_loss:337.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.12 loss:337.74 n_loss:0.00 tb_loss:337.74 batch_entropy:21.31 traj_lens:10.72 grad_norm:265.70 grad_norm_clip:63.89 sampled_reward_avg:0.57 train_time:1.13 time_spent:7.23
# 04/12/2024 09:27:31 - INFO - logger - iteration 30 : offline_loss:0.00 online_loss:146.63 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.14 loss:146.63 n_loss:0.00 tb_loss:146.63 batch_entropy:20.23 traj_lens:10.30 grad_norm:212.53 grad_norm_clip:60.18 sampled_reward_avg:0.68 train_time:1.27 time_spent:8.56
# 04/12/2024 09:27:40 - INFO - logger - iteration 31 : offline_loss:0.00 online_loss:238.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.17 loss:238.69 n_loss:0.00 tb_loss:238.69 batch_entropy:19.68 traj_lens:10.06 grad_norm:172.40 grad_norm_clip:56.21 sampled_reward_avg:0.63 train_time:1.13 time_spent:8.12
# 04/12/2024 09:27:47 - INFO - logger - iteration 32 : offline_loss:0.00 online_loss:363.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.20 loss:363.94 n_loss:0.00 tb_loss:363.94 batch_entropy:19.63 traj_lens:10.16 grad_norm:317.07 grad_norm_clip:64.40 sampled_reward_avg:0.59 train_time:1.08 time_spent:7.21
# 04/12/2024 09:27:54 - INFO - logger - iteration 33 : offline_loss:0.00 online_loss:371.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.23 loss:371.57 n_loss:0.00 tb_loss:371.57 batch_entropy:18.38 traj_lens:9.41 grad_norm:285.48 grad_norm_clip:64.31 sampled_reward_avg:0.63 train_time:1.09 time_spent:7.43
# 04/12/2024 09:28:02 - INFO - logger - iteration 34 : offline_loss:0.00 online_loss:200.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.27 loss:200.87 n_loss:0.00 tb_loss:200.87 batch_entropy:20.04 traj_lens:10.58 grad_norm:294.80 grad_norm_clip:64.58 sampled_reward_avg:0.63 train_time:1.11 time_spent:7.44
# 04/12/2024 09:28:09 - INFO - logger - iteration 35 : offline_loss:0.00 online_loss:220.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.30 loss:220.32 n_loss:0.00 tb_loss:220.32 batch_entropy:19.91 traj_lens:10.44 grad_norm:195.52 grad_norm_clip:59.27 sampled_reward_avg:0.65 train_time:1.12 time_spent:7.52
# 04/12/2024 09:28:17 - INFO - logger - iteration 36 : offline_loss:0.00 online_loss:96.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.33 loss:96.05 n_loss:0.00 tb_loss:96.05 batch_entropy:17.78 traj_lens:9.64 grad_norm:229.32 grad_norm_clip:61.29 sampled_reward_avg:0.67 train_time:0.96 time_spent:7.93
# 04/12/2024 09:28:25 - INFO - logger - iteration 37 : offline_loss:0.00 online_loss:268.95 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.37 loss:268.95 n_loss:0.00 tb_loss:268.95 batch_entropy:21.37 traj_lens:10.91 grad_norm:239.39 grad_norm_clip:63.08 sampled_reward_avg:0.63 train_time:1.19 time_spent:7.72
# 04/12/2024 09:28:33 - INFO - logger - iteration 38 : offline_loss:0.00 online_loss:145.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.40 loss:145.09 n_loss:0.00 tb_loss:145.09 batch_entropy:20.76 traj_lens:10.81 grad_norm:276.68 grad_norm_clip:64.20 sampled_reward_avg:0.67 train_time:1.20 time_spent:7.92
# 04/12/2024 09:28:41 - INFO - logger - iteration 39 : offline_loss:0.00 online_loss:116.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.44 loss:116.93 n_loss:0.00 tb_loss:116.93 batch_entropy:21.03 traj_lens:10.77 grad_norm:184.83 grad_norm_clip:55.60 sampled_reward_avg:0.67 train_time:1.12 time_spent:7.78
# 04/12/2024 09:28:48 - INFO - logger - iteration 40 : offline_loss:0.00 online_loss:306.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.47 loss:306.85 n_loss:0.00 tb_loss:306.85 batch_entropy:23.38 traj_lens:11.61 grad_norm:389.91 grad_norm_clip:66.37 sampled_reward_avg:0.61 train_time:1.26 time_spent:7.81
# 04/12/2024 09:28:57 - INFO - logger - iteration 41 : offline_loss:0.00 online_loss:151.45 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.51 loss:151.45 n_loss:0.00 tb_loss:151.45 batch_entropy:20.34 traj_lens:10.77 grad_norm:237.18 grad_norm_clip:62.39 sampled_reward_avg:0.63 train_time:1.37 time_spent:8.31
# 04/12/2024 09:29:04 - INFO - logger - iteration 42 : offline_loss:0.00 online_loss:367.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.55 loss:367.54 n_loss:0.00 tb_loss:367.54 batch_entropy:20.38 traj_lens:10.67 grad_norm:272.33 grad_norm_clip:63.15 sampled_reward_avg:0.59 train_time:1.29 time_spent:7.80
# 04/12/2024 09:29:13 - INFO - logger - iteration 43 : offline_loss:0.00 online_loss:152.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.58 loss:152.47 n_loss:0.00 tb_loss:152.47 batch_entropy:21.14 traj_lens:10.95 grad_norm:178.80 grad_norm_clip:55.23 sampled_reward_avg:0.66 train_time:1.40 time_spent:8.84
# 04/12/2024 09:29:22 - INFO - logger - iteration 44 : offline_loss:0.00 online_loss:311.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.62 loss:311.29 n_loss:0.00 tb_loss:311.29 batch_entropy:23.06 traj_lens:11.05 grad_norm:315.95 grad_norm_clip:65.02 sampled_reward_avg:0.63 train_time:1.32 time_spent:8.29
# 04/12/2024 09:29:31 - INFO - logger - iteration 45 : offline_loss:0.00 online_loss:233.44 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.66 loss:233.44 n_loss:0.00 tb_loss:233.44 batch_entropy:22.45 traj_lens:11.28 grad_norm:211.95 grad_norm_clip:60.56 sampled_reward_avg:0.66 train_time:1.47 time_spent:8.93
# 04/12/2024 09:29:39 - INFO - logger - iteration 46 : offline_loss:0.00 online_loss:192.58 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.70 loss:192.58 n_loss:0.00 tb_loss:192.58 batch_entropy:22.68 traj_lens:11.38 grad_norm:242.40 grad_norm_clip:61.38 sampled_reward_avg:0.64 train_time:1.63 time_spent:8.82
# 04/12/2024 09:29:48 - INFO - logger - iteration 47 : offline_loss:0.00 online_loss:200.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.74 loss:200.10 n_loss:0.00 tb_loss:200.10 batch_entropy:22.31 traj_lens:11.70 grad_norm:159.54 grad_norm_clip:51.29 sampled_reward_avg:0.63 train_time:1.50 time_spent:8.84
# 04/12/2024 09:29:57 - INFO - logger - iteration 48 : offline_loss:0.00 online_loss:277.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.77 loss:277.51 n_loss:0.00 tb_loss:277.51 batch_entropy:23.50 traj_lens:12.17 grad_norm:259.49 grad_norm_clip:62.60 sampled_reward_avg:0.61 train_time:1.70 time_spent:8.83
# 04/12/2024 09:30:06 - INFO - logger - iteration 49 : offline_loss:0.00 online_loss:253.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.82 loss:253.29 n_loss:0.00 tb_loss:253.29 batch_entropy:22.96 traj_lens:11.61 grad_norm:241.87 grad_norm_clip:62.17 sampled_reward_avg:0.61 train_time:1.47 time_spent:8.75
# 04/12/2024 09:30:15 - INFO - logger - iteration 50 : offline_loss:0.00 online_loss:204.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.86 loss:204.61 n_loss:0.00 tb_loss:204.61 batch_entropy:22.24 traj_lens:11.66 grad_norm:183.22 grad_norm_clip:55.68 sampled_reward_avg:0.63 train_time:1.50 time_spent:9.42
# 04/12/2024 09:30:24 - INFO - logger - iteration 51 : offline_loss:0.00 online_loss:149.96 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.90 loss:149.96 n_loss:0.00 tb_loss:149.96 batch_entropy:24.67 traj_lens:12.41 grad_norm:247.09 grad_norm_clip:61.58 sampled_reward_avg:0.62 train_time:1.79 time_spent:9.04
# 04/12/2024 09:30:33 - INFO - logger - iteration 52 : offline_loss:0.00 online_loss:117.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.94 loss:117.11 n_loss:0.00 tb_loss:117.11 batch_entropy:23.06 traj_lens:11.94 grad_norm:314.59 grad_norm_clip:63.67 sampled_reward_avg:0.63 train_time:1.42 time_spent:8.66
# 04/12/2024 09:30:42 - INFO - logger - iteration 53 : offline_loss:0.00 online_loss:115.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.99 loss:115.74 n_loss:0.00 tb_loss:115.74 batch_entropy:22.07 traj_lens:11.70 grad_norm:175.58 grad_norm_clip:53.72 sampled_reward_avg:0.66 train_time:1.42 time_spent:8.99
# 04/12/2024 09:30:51 - INFO - logger - iteration 54 : offline_loss:0.00 online_loss:254.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.03 loss:254.77 n_loss:0.00 tb_loss:254.77 batch_entropy:26.15 traj_lens:12.92 grad_norm:245.17 grad_norm_clip:61.34 sampled_reward_avg:0.65 train_time:1.89 time_spent:9.52
# 04/12/2024 09:31:01 - INFO - logger - iteration 55 : offline_loss:0.00 online_loss:204.75 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.07 loss:204.75 n_loss:0.00 tb_loss:204.75 batch_entropy:25.82 traj_lens:13.34 grad_norm:194.97 grad_norm_clip:56.19 sampled_reward_avg:0.62 train_time:1.80 time_spent:9.22
# 04/12/2024 09:31:10 - INFO - logger - iteration 56 : offline_loss:0.00 online_loss:108.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.12 loss:108.99 n_loss:0.00 tb_loss:108.99 batch_entropy:23.71 traj_lens:12.50 grad_norm:184.80 grad_norm_clip:54.85 sampled_reward_avg:0.63 train_time:1.62 time_spent:9.23
# 04/12/2024 09:31:19 - INFO - logger - iteration 57 : offline_loss:0.00 online_loss:187.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.17 loss:187.53 n_loss:0.00 tb_loss:187.53 batch_entropy:26.22 traj_lens:13.30 grad_norm:197.02 grad_norm_clip:57.01 sampled_reward_avg:0.63 train_time:1.87 time_spent:9.56
# 04/12/2024 09:31:29 - INFO - logger - iteration 58 : offline_loss:0.00 online_loss:135.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.21 loss:135.24 n_loss:0.00 tb_loss:135.24 batch_entropy:24.22 traj_lens:12.50 grad_norm:225.91 grad_norm_clip:59.60 sampled_reward_avg:0.64 train_time:1.86 time_spent:9.65
# 04/12/2024 09:31:39 - INFO - logger - iteration 59 : offline_loss:0.00 online_loss:149.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.26 loss:149.85 n_loss:0.00 tb_loss:149.85 batch_entropy:26.26 traj_lens:13.25 grad_norm:208.73 grad_norm_clip:56.55 sampled_reward_avg:0.64 train_time:1.74 time_spent:9.81
# 04/12/2024 09:31:48 - INFO - logger - iteration 60 : offline_loss:0.00 online_loss:158.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.31 loss:158.65 n_loss:0.00 tb_loss:158.65 batch_entropy:24.54 traj_lens:12.92 grad_norm:210.85 grad_norm_clip:59.15 sampled_reward_avg:0.63 train_time:1.87 time_spent:9.44
# 04/12/2024 09:31:57 - INFO - logger - iteration 61 : offline_loss:0.00 online_loss:111.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.36 loss:111.23 n_loss:0.00 tb_loss:111.23 batch_entropy:24.81 traj_lens:12.69 grad_norm:186.32 grad_norm_clip:53.82 sampled_reward_avg:0.67 train_time:1.59 time_spent:9.09
# 04/12/2024 09:32:07 - INFO - logger - iteration 62 : offline_loss:0.00 online_loss:155.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.41 loss:155.55 n_loss:0.00 tb_loss:155.55 batch_entropy:24.76 traj_lens:12.92 grad_norm:215.19 grad_norm_clip:58.78 sampled_reward_avg:0.65 train_time:1.59 time_spent:9.59
# 04/12/2024 09:32:16 - INFO - logger - iteration 63 : offline_loss:0.00 online_loss:228.39 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.46 loss:228.39 n_loss:0.00 tb_loss:228.39 batch_entropy:25.91 traj_lens:12.92 grad_norm:228.33 grad_norm_clip:60.74 sampled_reward_avg:0.62 train_time:1.83 time_spent:9.36
# 04/12/2024 09:32:27 - INFO - logger - iteration 64 : offline_loss:0.00 online_loss:150.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.51 loss:150.74 n_loss:0.00 tb_loss:150.74 batch_entropy:28.25 traj_lens:13.91 grad_norm:206.99 grad_norm_clip:55.51 sampled_reward_avg:0.64 train_time:2.53 time_spent:10.62
# 04/12/2024 09:32:38 - INFO - logger - iteration 65 : offline_loss:0.00 online_loss:212.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.56 loss:212.30 n_loss:0.00 tb_loss:212.30 batch_entropy:27.75 traj_lens:13.77 grad_norm:236.49 grad_norm_clip:59.65 sampled_reward_avg:0.64 train_time:2.30 time_spent:11.27
# 04/12/2024 09:32:50 - INFO - logger - iteration 66 : offline_loss:0.00 online_loss:125.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.61 loss:125.03 n_loss:0.00 tb_loss:125.03 batch_entropy:26.42 traj_lens:13.16 grad_norm:249.61 grad_norm_clip:59.53 sampled_reward_avg:0.63 train_time:1.88 time_spent:11.34
# 04/12/2024 09:32:59 - INFO - logger - iteration 67 : offline_loss:0.00 online_loss:124.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.66 loss:124.24 n_loss:0.00 tb_loss:124.24 batch_entropy:27.99 traj_lens:14.00 grad_norm:245.49 grad_norm_clip:59.43 sampled_reward_avg:0.67 train_time:1.86 time_spent:9.84
# 04/12/2024 09:33:09 - INFO - logger - iteration 68 : offline_loss:0.00 online_loss:157.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.72 loss:157.54 n_loss:0.00 tb_loss:157.54 batch_entropy:27.19 traj_lens:13.67 grad_norm:184.88 grad_norm_clip:53.17 sampled_reward_avg:0.65 train_time:1.83 time_spent:9.72
# 04/12/2024 09:33:19 - INFO - logger - iteration 69 : offline_loss:0.00 online_loss:141.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.77 loss:141.53 n_loss:0.00 tb_loss:141.53 batch_entropy:27.44 traj_lens:13.67 grad_norm:244.90 grad_norm_clip:60.41 sampled_reward_avg:0.64 train_time:2.04 time_spent:9.70
# 04/12/2024 09:33:29 - INFO - logger - iteration 70 : offline_loss:0.00 online_loss:94.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.82 loss:94.10 n_loss:0.00 tb_loss:94.10 batch_entropy:26.22 traj_lens:13.48 grad_norm:393.56 grad_norm_clip:65.30 sampled_reward_avg:0.64 train_time:1.96 time_spent:9.99
# 04/12/2024 09:33:38 - INFO - logger - iteration 71 : offline_loss:0.00 online_loss:97.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.88 loss:97.53 n_loss:0.00 tb_loss:97.53 batch_entropy:27.02 traj_lens:13.95 grad_norm:183.38 grad_norm_clip:50.16 sampled_reward_avg:0.62 train_time:1.86 time_spent:9.42
# 04/12/2024 09:33:48 - INFO - logger - iteration 72 : offline_loss:0.00 online_loss:126.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.93 loss:126.31 n_loss:0.00 tb_loss:126.31 batch_entropy:29.38 traj_lens:14.47 grad_norm:229.66 grad_norm_clip:57.49 sampled_reward_avg:0.65 train_time:2.16 time_spent:10.17
# 04/12/2024 09:33:58 - INFO - logger - iteration 73 : offline_loss:0.00 online_loss:200.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.99 loss:200.20 n_loss:0.00 tb_loss:200.20 batch_entropy:26.68 traj_lens:13.53 grad_norm:233.33 grad_norm_clip:59.97 sampled_reward_avg:0.61 train_time:1.95 time_spent:9.23
# 04/12/2024 09:34:08 - INFO - logger - iteration 74 : offline_loss:0.00 online_loss:113.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.04 loss:113.40 n_loss:0.00 tb_loss:113.40 batch_entropy:28.03 traj_lens:13.95 grad_norm:326.84 grad_norm_clip:63.24 sampled_reward_avg:0.63 train_time:2.11 time_spent:10.33
# 04/12/2024 09:34:17 - INFO - logger - iteration 75 : offline_loss:0.00 online_loss:167.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.10 loss:167.22 n_loss:0.00 tb_loss:167.22 batch_entropy:29.31 traj_lens:14.42 grad_norm:427.87 grad_norm_clip:66.31 sampled_reward_avg:0.62 train_time:1.91 time_spent:9.41
# 04/12/2024 09:34:27 - INFO - logger - iteration 76 : offline_loss:0.00 online_loss:128.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.15 loss:128.18 n_loss:0.00 tb_loss:128.18 batch_entropy:27.70 traj_lens:13.91 grad_norm:240.99 grad_norm_clip:58.06 sampled_reward_avg:0.64 train_time:1.89 time_spent:9.83
# 04/12/2024 09:34:37 - INFO - logger - iteration 77 : offline_loss:0.00 online_loss:113.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.21 loss:113.47 n_loss:0.00 tb_loss:113.47 batch_entropy:27.53 traj_lens:13.67 grad_norm:225.20 grad_norm_clip:54.63 sampled_reward_avg:0.66 train_time:1.75 time_spent:9.77
# 04/12/2024 09:34:47 - INFO - logger - iteration 78 : offline_loss:0.00 online_loss:115.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.27 loss:115.54 n_loss:0.00 tb_loss:115.54 batch_entropy:28.39 traj_lens:14.14 grad_norm:372.12 grad_norm_clip:64.86 sampled_reward_avg:0.65 train_time:2.12 time_spent:10.01
# 04/12/2024 09:34:57 - INFO - logger - iteration 79 : offline_loss:0.00 online_loss:202.38 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.33 loss:202.38 n_loss:0.00 tb_loss:202.38 batch_entropy:31.33 traj_lens:14.98 grad_norm:263.64 grad_norm_clip:60.71 sampled_reward_avg:0.62 train_time:2.16 time_spent:9.98
# 04/12/2024 09:35:07 - INFO - logger - iteration 80 : offline_loss:0.00 online_loss:125.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.39 loss:125.19 n_loss:0.00 tb_loss:125.19 batch_entropy:28.63 traj_lens:14.52 grad_norm:208.49 grad_norm_clip:53.35 sampled_reward_avg:0.64 train_time:1.97 time_spent:9.88
# 04/12/2024 09:35:19 - INFO - logger - iteration 81 : offline_loss:0.00 online_loss:150.01 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.45 loss:150.01 n_loss:0.00 tb_loss:150.01 batch_entropy:27.96 traj_lens:13.91 grad_norm:270.58 grad_norm_clip:62.58 sampled_reward_avg:0.64 train_time:2.40 time_spent:11.81
# 04/12/2024 09:35:30 - INFO - logger - iteration 82 : offline_loss:0.00 online_loss:122.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.51 loss:122.57 n_loss:0.00 tb_loss:122.57 batch_entropy:27.74 traj_lens:13.91 grad_norm:261.65 grad_norm_clip:60.50 sampled_reward_avg:0.62 train_time:2.05 time_spent:10.92
# 04/12/2024 09:35:40 - INFO - logger - iteration 83 : offline_loss:0.00 online_loss:88.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.57 loss:88.15 n_loss:0.00 tb_loss:88.15 batch_entropy:26.62 traj_lens:13.44 grad_norm:251.23 grad_norm_clip:58.89 sampled_reward_avg:0.63 train_time:1.91 time_spent:10.57
# 04/12/2024 09:35:51 - INFO - logger - iteration 84 : offline_loss:0.00 online_loss:98.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.63 loss:98.12 n_loss:0.00 tb_loss:98.12 batch_entropy:29.78 traj_lens:14.98 grad_norm:246.66 grad_norm_clip:58.66 sampled_reward_avg:0.63 train_time:2.18 time_spent:10.43
# 04/12/2024 09:36:01 - INFO - logger - iteration 85 : offline_loss:0.00 online_loss:98.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.69 loss:98.23 n_loss:0.00 tb_loss:98.23 batch_entropy:29.12 traj_lens:14.52 grad_norm:244.06 grad_norm_clip:56.08 sampled_reward_avg:0.65 train_time:2.07 time_spent:10.34
# 04/12/2024 09:36:11 - INFO - logger - iteration 86 : offline_loss:0.00 online_loss:131.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.75 loss:131.93 n_loss:0.00 tb_loss:131.93 batch_entropy:29.96 traj_lens:14.80 grad_norm:261.96 grad_norm_clip:60.33 sampled_reward_avg:0.65 train_time:2.23 time_spent:9.92
# 04/12/2024 09:36:21 - INFO - logger - iteration 87 : offline_loss:0.00 online_loss:133.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.82 loss:133.79 n_loss:0.00 tb_loss:133.79 batch_entropy:30.73 traj_lens:15.03 grad_norm:245.06 grad_norm_clip:58.57 sampled_reward_avg:0.63 train_time:2.29 time_spent:10.22
# 04/12/2024 09:36:31 - INFO - logger - iteration 88 : offline_loss:0.00 online_loss:131.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.88 loss:131.59 n_loss:0.00 tb_loss:131.59 batch_entropy:30.03 traj_lens:14.70 grad_norm:295.72 grad_norm_clip:62.44 sampled_reward_avg:0.63 train_time:1.93 time_spent:9.71
# 04/12/2024 09:36:41 - INFO - logger - iteration 89 : offline_loss:0.00 online_loss:204.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.95 loss:204.24 n_loss:0.00 tb_loss:204.24 batch_entropy:31.68 traj_lens:14.94 grad_norm:421.41 grad_norm_clip:65.59 sampled_reward_avg:0.62 train_time:2.15 time_spent:10.29
# 04/12/2024 09:36:51 - INFO - logger - iteration 90 : offline_loss:0.00 online_loss:133.96 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.01 loss:133.96 n_loss:0.00 tb_loss:133.96 batch_entropy:30.94 traj_lens:14.89 grad_norm:314.88 grad_norm_clip:63.72 sampled_reward_avg:0.64 train_time:2.39 time_spent:10.36
# 04/12/2024 09:37:02 - INFO - logger - iteration 91 : offline_loss:0.00 online_loss:129.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.08 loss:129.36 n_loss:0.00 tb_loss:129.36 batch_entropy:33.03 traj_lens:15.78 grad_norm:275.80 grad_norm_clip:59.93 sampled_reward_avg:0.65 train_time:2.53 time_spent:10.62
# 04/12/2024 09:37:13 - INFO - logger - iteration 92 : offline_loss:0.00 online_loss:123.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.14 loss:123.74 n_loss:0.00 tb_loss:123.74 batch_entropy:32.03 traj_lens:15.41 grad_norm:313.90 grad_norm_clip:61.36 sampled_reward_avg:0.66 train_time:2.51 time_spent:10.85
# 04/12/2024 09:37:23 - INFO - logger - iteration 93 : offline_loss:0.00 online_loss:96.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.21 loss:96.42 n_loss:0.00 tb_loss:96.42 batch_entropy:29.22 traj_lens:14.52 grad_norm:250.85 grad_norm_clip:56.46 sampled_reward_avg:0.64 train_time:2.04 time_spent:9.75
# 04/12/2024 09:37:33 - INFO - logger - iteration 94 : offline_loss:0.00 online_loss:151.06 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.28 loss:151.06 n_loss:0.00 tb_loss:151.06 batch_entropy:29.95 traj_lens:14.61 grad_norm:266.24 grad_norm_clip:60.76 sampled_reward_avg:0.61 train_time:2.10 time_spent:10.02
# 04/12/2024 09:37:43 - INFO - logger - iteration 95 : offline_loss:0.00 online_loss:117.37 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.34 loss:117.37 n_loss:0.00 tb_loss:117.37 batch_entropy:30.87 traj_lens:14.80 grad_norm:352.71 grad_norm_clip:65.24 sampled_reward_avg:0.68 train_time:2.09 time_spent:10.44
# 04/12/2024 09:37:54 - INFO - logger - iteration 96 : offline_loss:0.00 online_loss:102.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.41 loss:102.08 n_loss:0.00 tb_loss:102.08 batch_entropy:31.42 traj_lens:15.36 grad_norm:253.58 grad_norm_clip:54.52 sampled_reward_avg:0.64 train_time:2.46 time_spent:10.53
# 04/12/2024 09:38:04 - INFO - logger - iteration 97 : offline_loss:0.00 online_loss:100.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.48 loss:100.70 n_loss:0.00 tb_loss:100.70 batch_entropy:29.46 traj_lens:14.33 grad_norm:309.48 grad_norm_clip:63.59 sampled_reward_avg:0.66 train_time:2.22 time_spent:9.93
# 04/12/2024 09:38:14 - INFO - logger - iteration 98 : offline_loss:0.00 online_loss:106.01 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.55 loss:106.01 n_loss:0.00 tb_loss:106.01 batch_entropy:31.11 traj_lens:15.12 grad_norm:267.72 grad_norm_clip:58.43 sampled_reward_avg:0.64 train_time:2.27 time_spent:10.02
# 04/12/2024 09:38:24 - INFO - logger - iteration 99 : offline_loss:0.00 online_loss:105.27 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.62 loss:105.27 n_loss:0.00 tb_loss:105.27 batch_entropy:31.81 traj_lens:15.31 grad_norm:265.71 grad_norm_clip:57.64 sampled_reward_avg:0.65 train_time:2.25 time_spent:10.69
# 04/12/2024 09:38:35 - INFO - logger - iteration 100 : offline_loss:0.00 online_loss:174.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.69 loss:174.40 n_loss:0.00 tb_loss:174.40 batch_entropy:32.54 traj_lens:15.27 grad_norm:272.36 grad_norm_clip:59.58 sampled_reward_avg:0.63 train_time:2.19 time_spent:10.29
# 04/12/2024 09:38:45 - INFO - logger - iteration 101 : offline_loss:0.00 online_loss:112.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.76 loss:112.42 n_loss:0.00 tb_loss:112.42 batch_entropy:32.90 traj_lens:15.73 grad_norm:283.63 grad_norm_clip:58.60 sampled_reward_avg:0.65 train_time:2.23 time_spent:10.58
# 04/12/2024 09:38:56 - INFO - logger - iteration 102 : offline_loss:0.00 online_loss:146.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.83 loss:146.98 n_loss:0.00 tb_loss:146.98 batch_entropy:31.56 traj_lens:14.98 grad_norm:258.88 grad_norm_clip:58.50 sampled_reward_avg:0.61 train_time:2.32 time_spent:10.50
# 04/12/2024 09:39:06 - INFO - logger - iteration 103 : offline_loss:0.00 online_loss:128.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.90 loss:128.61 n_loss:0.00 tb_loss:128.61 batch_entropy:32.54 traj_lens:15.55 grad_norm:392.47 grad_norm_clip:64.93 sampled_reward_avg:0.63 train_time:2.27 time_spent:10.55
# 04/12/2024 09:39:17 - INFO - logger - iteration 104 : offline_loss:0.00 online_loss:155.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.97 loss:155.94 n_loss:0.00 tb_loss:155.94 batch_entropy:33.77 traj_lens:15.92 grad_norm:382.37 grad_norm_clip:66.43 sampled_reward_avg:0.65 train_time:2.51 time_spent:10.46
# 04/12/2024 09:39:27 - INFO - logger - iteration 105 : offline_loss:0.00 online_loss:87.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.05 loss:87.08 n_loss:0.00 tb_loss:87.08 batch_entropy:30.99 traj_lens:15.08 grad_norm:281.08 grad_norm_clip:58.78 sampled_reward_avg:0.64 train_time:2.27 time_spent:10.06
# 04/12/2024 09:39:37 - INFO - logger - iteration 106 : offline_loss:0.00 online_loss:87.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.12 loss:87.19 n_loss:0.00 tb_loss:87.19 batch_entropy:29.82 traj_lens:14.66 grad_norm:240.27 grad_norm_clip:54.65 sampled_reward_avg:0.64 train_time:2.11 time_spent:10.47
# 04/12/2024 09:39:48 - INFO - logger - iteration 107 : offline_loss:0.00 online_loss:121.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.19 loss:121.18 n_loss:0.00 tb_loss:121.18 batch_entropy:34.01 traj_lens:16.02 grad_norm:347.49 grad_norm_clip:64.57 sampled_reward_avg:0.66 train_time:2.34 time_spent:10.70
# 04/12/2024 09:39:58 - INFO - logger - iteration 108 : offline_loss:0.00 online_loss:176.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.26 loss:176.23 n_loss:0.00 tb_loss:176.23 batch_entropy:32.96 traj_lens:15.59 grad_norm:264.74 grad_norm_clip:59.10 sampled_reward_avg:0.63 train_time:2.26 time_spent:10.32
# 04/12/2024 09:40:09 - INFO - logger - iteration 109 : offline_loss:0.00 online_loss:115.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.34 loss:115.26 n_loss:0.00 tb_loss:115.26 batch_entropy:34.08 traj_lens:15.88 grad_norm:282.78 grad_norm_clip:54.58 sampled_reward_avg:0.65 train_time:2.37 time_spent:11.17
# 04/12/2024 09:40:20 - INFO - logger - iteration 110 : offline_loss:0.00 online_loss:126.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.41 loss:126.64 n_loss:0.00 tb_loss:126.64 batch_entropy:32.90 traj_lens:15.64 grad_norm:323.80 grad_norm_clip:64.20 sampled_reward_avg:0.64 train_time:2.30 time_spent:10.43
# 04/12/2024 09:40:30 - INFO - logger - iteration 111 : offline_loss:0.00 online_loss:183.38 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.49 loss:183.38 n_loss:0.00 tb_loss:183.38 batch_entropy:34.11 traj_lens:15.83 grad_norm:293.04 grad_norm_clip:62.30 sampled_reward_avg:0.61 train_time:2.38 time_spent:10.56
# 04/12/2024 09:40:41 - INFO - logger - iteration 112 : offline_loss:0.00 online_loss:201.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.56 loss:201.18 n_loss:0.00 tb_loss:201.18 batch_entropy:32.90 traj_lens:15.27 grad_norm:245.82 grad_norm_clip:56.61 sampled_reward_avg:0.64 train_time:2.70 time_spent:10.79
# 04/12/2024 09:40:52 - INFO - logger - iteration 113 : offline_loss:0.00 online_loss:201.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.64 loss:201.21 n_loss:0.00 tb_loss:201.21 batch_entropy:33.51 traj_lens:15.36 grad_norm:262.50 grad_norm_clip:57.39 sampled_reward_avg:0.66 train_time:2.37 time_spent:10.57
# 04/12/2024 09:41:02 - INFO - logger - iteration 114 : offline_loss:0.00 online_loss:137.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.71 loss:137.85 n_loss:0.00 tb_loss:137.85 batch_entropy:33.74 traj_lens:15.50 grad_norm:346.69 grad_norm_clip:64.40 sampled_reward_avg:0.63 train_time:2.66 time_spent:10.56
# 04/12/2024 09:41:13 - INFO - logger - iteration 115 : offline_loss:0.00 online_loss:114.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.79 loss:114.55 n_loss:0.00 tb_loss:114.55 batch_entropy:32.36 traj_lens:15.31 grad_norm:343.45 grad_norm_clip:64.44 sampled_reward_avg:0.66 train_time:2.49 time_spent:10.81
# 04/12/2024 09:41:24 - INFO - logger - iteration 116 : offline_loss:0.00 online_loss:170.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.87 loss:170.90 n_loss:0.00 tb_loss:170.90 batch_entropy:33.19 traj_lens:15.31 grad_norm:307.32 grad_norm_clip:61.60 sampled_reward_avg:0.66 train_time:2.20 time_spent:10.67
# 04/12/2024 09:41:34 - INFO - logger - iteration 117 : offline_loss:0.00 online_loss:123.80 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.95 loss:123.80 n_loss:0.00 tb_loss:123.80 batch_entropy:32.27 traj_lens:15.03 grad_norm:318.57 grad_norm_clip:64.38 sampled_reward_avg:0.64 train_time:2.08 time_spent:10.18
# 04/12/2024 09:41:45 - INFO - logger - iteration 118 : offline_loss:0.00 online_loss:135.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.02 loss:135.35 n_loss:0.00 tb_loss:135.35 batch_entropy:34.18 traj_lens:16.02 grad_norm:304.04 grad_norm_clip:59.81 sampled_reward_avg:0.64 train_time:2.39 time_spent:10.68
# 04/12/2024 09:41:56 - INFO - logger - iteration 119 : offline_loss:0.00 online_loss:98.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.10 loss:98.51 n_loss:0.00 tb_loss:98.51 batch_entropy:34.48 traj_lens:16.20 grad_norm:299.25 grad_norm_clip:58.01 sampled_reward_avg:0.66 train_time:2.34 time_spent:11.08
# 04/12/2024 09:42:06 - INFO - logger - iteration 120 : offline_loss:0.00 online_loss:115.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:115.87 n_loss:0.00 tb_loss:115.87 batch_entropy:32.52 traj_lens:15.45 grad_norm:267.31 grad_norm_clip:57.63 sampled_reward_avg:0.63 train_time:2.20 time_spent:10.24
# 04/12/2024 09:42:16 - INFO - logger - iteration 121 : offline_loss:0.00 online_loss:91.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.26 loss:91.09 n_loss:0.00 tb_loss:91.09 batch_entropy:33.74 traj_lens:15.92 grad_norm:273.81 grad_norm_clip:54.11 sampled_reward_avg:0.63 train_time:2.51 time_spent:10.52
# 04/12/2024 09:42:27 - INFO - logger - iteration 122 : offline_loss:0.00 online_loss:146.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.34 loss:146.12 n_loss:0.00 tb_loss:146.12 batch_entropy:31.95 traj_lens:15.03 grad_norm:306.58 grad_norm_clip:63.09 sampled_reward_avg:0.65 train_time:2.30 time_spent:10.26
# 04/12/2024 09:42:38 - INFO - logger - iteration 123 : offline_loss:0.00 online_loss:84.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.42 loss:84.69 n_loss:0.00 tb_loss:84.69 batch_entropy:33.75 traj_lens:15.97 grad_norm:295.44 grad_norm_clip:59.74 sampled_reward_avg:0.65 train_time:2.42 time_spent:10.83
# 04/12/2024 09:42:48 - INFO - logger - iteration 124 : offline_loss:0.00 online_loss:236.48 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.51 loss:236.48 n_loss:0.00 tb_loss:236.48 batch_entropy:33.86 traj_lens:15.50 grad_norm:368.32 grad_norm_clip:66.40 sampled_reward_avg:0.63 train_time:2.27 time_spent:10.50
# 04/12/2024 09:42:59 - INFO - logger - iteration 125 : offline_loss:0.00 online_loss:127.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.59 loss:127.70 n_loss:0.00 tb_loss:127.70 batch_entropy:33.24 traj_lens:15.27 grad_norm:268.34 grad_norm_clip:56.14 sampled_reward_avg:0.64 train_time:2.25 time_spent:10.65
# 04/12/2024 09:43:09 - INFO - logger - iteration 126 : offline_loss:0.00 online_loss:143.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.67 loss:143.54 n_loss:0.00 tb_loss:143.54 batch_entropy:33.10 traj_lens:15.69 grad_norm:308.45 grad_norm_clip:63.26 sampled_reward_avg:0.65 train_time:2.32 time_spent:10.60
# 04/12/2024 09:43:20 - INFO - logger - iteration 127 : offline_loss:0.00 online_loss:133.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.75 loss:133.29 n_loss:0.00 tb_loss:133.29 batch_entropy:32.24 traj_lens:15.17 grad_norm:297.01 grad_norm_clip:60.32 sampled_reward_avg:0.63 train_time:2.08 time_spent:10.41
# ...
# 04/12/2024 10:44:00 - INFO - logger - iteration 459 : offline_loss:0.00 online_loss:16.49 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.39 loss:16.49 n_loss:0.00 tb_loss:16.49 batch_entropy:41.61 traj_lens:16.86 grad_norm:218.71 grad_norm_clip:59.55 sampled_reward_avg:0.74 train_time:3.13 time_spent:12.68
# 04/12/2024 10:44:13 - INFO - logger - iteration 460 : offline_loss:0.00 online_loss:156.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.43 loss:156.31 n_loss:0.00 tb_loss:156.31 batch_entropy:41.08 traj_lens:16.81 grad_norm:306.68 grad_norm_clip:65.23 sampled_reward_avg:0.70 train_time:3.11 time_spent:13.03
# 04/12/2024 10:44:25 - INFO - logger - iteration 461 : offline_loss:0.00 online_loss:62.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.45 loss:62.79 n_loss:0.00 tb_loss:62.79 batch_entropy:40.91 traj_lens:17.00 grad_norm:148.11 grad_norm_clip:55.73 sampled_reward_avg:0.72 train_time:2.89 time_spent:11.94
# 04/12/2024 10:44:37 - INFO - logger - iteration 462 : offline_loss:0.00 online_loss:14.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.47 loss:14.76 n_loss:0.00 tb_loss:14.76 batch_entropy:40.98 traj_lens:16.72 grad_norm:194.24 grad_norm_clip:59.57 sampled_reward_avg:0.73 train_time:3.00 time_spent:12.63
# 04/12/2024 10:44:50 - INFO - logger - iteration 463 : offline_loss:0.00 online_loss:9.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.51 loss:9.72 n_loss:0.00 tb_loss:9.72 batch_entropy:40.92 traj_lens:16.95 grad_norm:124.85 grad_norm_clip:55.74 sampled_reward_avg:0.74 train_time:3.27 time_spent:12.84
# 04/12/2024 10:45:03 - INFO - logger - iteration 464 : offline_loss:0.00 online_loss:54.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.55 loss:54.20 n_loss:0.00 tb_loss:54.20 batch_entropy:40.96 traj_lens:17.00 grad_norm:147.63 grad_norm_clip:50.66 sampled_reward_avg:0.73 train_time:3.36 time_spent:13.13
# 04/12/2024 10:45:17 - INFO - logger - iteration 465 : offline_loss:0.00 online_loss:12.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.59 loss:12.22 n_loss:0.00 tb_loss:12.22 batch_entropy:40.98 traj_lens:16.62 grad_norm:148.59 grad_norm_clip:55.99 sampled_reward_avg:0.75 train_time:3.28 time_spent:13.93
# 04/12/2024 10:45:30 - INFO - logger - iteration 466 : offline_loss:0.00 online_loss:79.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.63 loss:79.88 n_loss:0.00 tb_loss:79.88 batch_entropy:40.99 traj_lens:16.95 grad_norm:226.83 grad_norm_clip:60.57 sampled_reward_avg:0.73 train_time:3.03 time_spent:12.98
# 04/12/2024 10:45:42 - INFO - logger - iteration 467 : offline_loss:0.00 online_loss:9.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.67 loss:9.30 n_loss:0.00 tb_loss:9.30 batch_entropy:40.52 traj_lens:16.86 grad_norm:128.92 grad_norm_clip:53.62 sampled_reward_avg:0.75 train_time:2.58 time_spent:11.55
# 04/12/2024 10:45:54 - INFO - logger - iteration 468 : offline_loss:0.00 online_loss:103.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.71 loss:103.86 n_loss:0.00 tb_loss:103.86 batch_entropy:41.54 traj_lens:17.00 grad_norm:240.47 grad_norm_clip:62.26 sampled_reward_avg:0.72 train_time:2.98 time_spent:12.26
# 04/12/2024 10:46:05 - INFO - logger - iteration 469 : offline_loss:0.00 online_loss:57.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.74 loss:57.74 n_loss:0.00 tb_loss:57.74 batch_entropy:40.78 traj_lens:16.81 grad_norm:191.45 grad_norm_clip:56.80 sampled_reward_avg:0.75 train_time:2.80 time_spent:11.37
# 04/12/2024 10:46:17 - INFO - logger - iteration 470 : offline_loss:0.00 online_loss:114.01 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.77 loss:114.01 n_loss:0.00 tb_loss:114.01 batch_entropy:42.53 traj_lens:16.91 grad_norm:228.47 grad_norm_clip:60.70 sampled_reward_avg:0.73 train_time:2.66 time_spent:11.48
# 04/12/2024 10:46:28 - INFO - logger - iteration 471 : offline_loss:0.00 online_loss:144.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.80 loss:144.78 n_loss:0.00 tb_loss:144.78 batch_entropy:41.82 traj_lens:16.95 grad_norm:333.54 grad_norm_clip:66.05 sampled_reward_avg:0.72 train_time:2.84 time_spent:11.38
# 04/12/2024 10:46:40 - INFO - logger - iteration 472 : offline_loss:0.00 online_loss:160.07 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.82 loss:160.07 n_loss:0.00 tb_loss:160.07 batch_entropy:41.97 traj_lens:16.91 grad_norm:381.58 grad_norm_clip:67.59 sampled_reward_avg:0.73 train_time:3.24 time_spent:12.28
# 04/12/2024 10:46:53 - INFO - logger - iteration 473 : offline_loss:0.00 online_loss:63.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.82 loss:63.53 n_loss:0.00 tb_loss:63.53 batch_entropy:41.83 traj_lens:17.00 grad_norm:201.38 grad_norm_clip:59.23 sampled_reward_avg:0.73 train_time:2.60 time_spent:12.55
# 04/12/2024 10:47:05 - INFO - logger - iteration 474 : offline_loss:0.00 online_loss:64.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.84 loss:64.36 n_loss:0.00 tb_loss:64.36 batch_entropy:42.27 traj_lens:17.00 grad_norm:171.21 grad_norm_clip:58.28 sampled_reward_avg:0.72 train_time:2.82 time_spent:11.62
# 04/12/2024 10:47:16 - INFO - logger - iteration 475 : offline_loss:0.00 online_loss:58.37 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.86 loss:58.37 n_loss:0.00 tb_loss:58.37 batch_entropy:41.93 traj_lens:16.86 grad_norm:167.54 grad_norm_clip:56.87 sampled_reward_avg:0.73 train_time:2.83 time_spent:11.59
# 04/12/2024 10:47:28 - INFO - logger - iteration 476 : offline_loss:0.00 online_loss:98.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.89 loss:98.68 n_loss:0.00 tb_loss:98.68 batch_entropy:41.73 traj_lens:17.00 grad_norm:282.00 grad_norm_clip:63.20 sampled_reward_avg:0.74 train_time:2.79 time_spent:11.57
# 04/12/2024 10:47:39 - INFO - logger - iteration 477 : offline_loss:0.00 online_loss:57.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.91 loss:57.68 n_loss:0.00 tb_loss:57.68 batch_entropy:41.85 traj_lens:16.95 grad_norm:133.15 grad_norm_clip:54.20 sampled_reward_avg:0.77 train_time:2.79 time_spent:11.59
# 04/12/2024 10:47:50 - INFO - logger - iteration 478 : offline_loss:0.00 online_loss:130.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.93 loss:130.77 n_loss:0.00 tb_loss:130.77 batch_entropy:41.46 traj_lens:16.86 grad_norm:214.28 grad_norm_clip:60.66 sampled_reward_avg:0.73 train_time:2.69 time_spent:11.17
# 04/12/2024 10:48:02 - INFO - logger - iteration 479 : offline_loss:0.00 online_loss:88.83 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.94 loss:88.83 n_loss:0.00 tb_loss:88.83 batch_entropy:42.62 traj_lens:17.00 grad_norm:232.00 grad_norm_clip:60.06 sampled_reward_avg:0.75 train_time:2.62 time_spent:11.60
# 04/12/2024 10:48:14 - INFO - logger - iteration 480 : offline_loss:0.00 online_loss:53.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.96 loss:53.77 n_loss:0.00 tb_loss:53.77 batch_entropy:41.13 traj_lens:16.72 grad_norm:156.45 grad_norm_clip:56.53 sampled_reward_avg:0.75 train_time:2.75 time_spent:11.45
# 04/12/2024 10:48:25 - INFO - logger - iteration 481 : offline_loss:0.00 online_loss:10.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:17.98 loss:10.20 n_loss:0.00 tb_loss:10.20 batch_entropy:41.65 traj_lens:17.00 grad_norm:163.58 grad_norm_clip:56.15 sampled_reward_avg:0.76 train_time:2.91 time_spent:11.64
# 04/12/2024 10:48:37 - INFO - logger - iteration 482 : offline_loss:0.00 online_loss:10.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.01 loss:10.17 n_loss:0.00 tb_loss:10.17 batch_entropy:41.91 traj_lens:17.00 grad_norm:163.16 grad_norm_clip:56.58 sampled_reward_avg:0.76 train_time:2.59 time_spent:11.70
# 04/12/2024 10:48:48 - INFO - logger - iteration 483 : offline_loss:0.00 online_loss:6.38 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.04 loss:6.38 n_loss:0.00 tb_loss:6.38 batch_entropy:41.07 traj_lens:16.95 grad_norm:97.68 grad_norm_clip:48.46 sampled_reward_avg:0.77 train_time:2.75 time_spent:11.59
# 04/12/2024 10:49:00 - INFO - logger - iteration 484 : offline_loss:0.00 online_loss:249.45 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.09 loss:249.45 n_loss:0.00 tb_loss:249.45 batch_entropy:41.34 traj_lens:16.67 grad_norm:429.36 grad_norm_clip:69.25 sampled_reward_avg:0.72 train_time:2.70 time_spent:11.13
# 04/12/2024 10:49:11 - INFO - logger - iteration 485 : offline_loss:0.00 online_loss:78.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.12 loss:78.36 n_loss:0.00 tb_loss:78.36 batch_entropy:41.01 traj_lens:16.77 grad_norm:321.82 grad_norm_clip:63.58 sampled_reward_avg:0.74 train_time:2.63 time_spent:11.62
# 04/12/2024 10:49:23 - INFO - logger - iteration 486 : offline_loss:0.00 online_loss:125.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.14 loss:125.17 n_loss:0.00 tb_loss:125.17 batch_entropy:40.97 traj_lens:16.53 grad_norm:200.04 grad_norm_clip:57.95 sampled_reward_avg:0.75 train_time:2.73 time_spent:11.92
# 04/12/2024 10:49:35 - INFO - logger - iteration 487 : offline_loss:0.00 online_loss:63.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.15 loss:63.22 n_loss:0.00 tb_loss:63.22 batch_entropy:41.14 traj_lens:16.58 grad_norm:142.58 grad_norm_clip:53.73 sampled_reward_avg:0.76 train_time:2.68 time_spent:11.45
# 04/12/2024 10:49:46 - INFO - logger - iteration 488 : offline_loss:0.00 online_loss:59.66 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.16 loss:59.66 n_loss:0.00 tb_loss:59.66 batch_entropy:41.00 traj_lens:16.77 grad_norm:171.23 grad_norm_clip:55.69 sampled_reward_avg:0.76 train_time:2.68 time_spent:11.30
# 04/12/2024 10:49:58 - INFO - logger - iteration 489 : offline_loss:0.00 online_loss:116.38 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.17 loss:116.38 n_loss:0.00 tb_loss:116.38 batch_entropy:41.08 traj_lens:16.86 grad_norm:273.33 grad_norm_clip:61.82 sampled_reward_avg:0.74 train_time:2.89 time_spent:11.76
# 04/12/2024 10:50:09 - INFO - logger - iteration 490 : offline_loss:0.00 online_loss:53.83 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.16 loss:53.83 n_loss:0.00 tb_loss:53.83 batch_entropy:41.42 traj_lens:16.86 grad_norm:174.91 grad_norm_clip:52.28 sampled_reward_avg:0.75 train_time:2.73 time_spent:11.42
# 04/12/2024 10:50:21 - INFO - logger - iteration 491 : offline_loss:0.00 online_loss:7.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.16 loss:7.34 n_loss:0.00 tb_loss:7.34 batch_entropy:41.40 traj_lens:17.00 grad_norm:115.97 grad_norm_clip:50.16 sampled_reward_avg:0.78 train_time:2.79 time_spent:11.50
# 04/12/2024 10:50:32 - INFO - logger - iteration 492 : offline_loss:0.00 online_loss:106.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.18 loss:106.71 n_loss:0.00 tb_loss:106.71 batch_entropy:42.12 traj_lens:17.00 grad_norm:327.39 grad_norm_clip:65.13 sampled_reward_avg:0.75 train_time:2.80 time_spent:11.80
# 04/12/2024 10:50:44 - INFO - logger - iteration 493 : offline_loss:0.00 online_loss:72.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.18 loss:72.00 n_loss:0.00 tb_loss:72.00 batch_entropy:42.05 traj_lens:16.91 grad_norm:260.59 grad_norm_clip:63.70 sampled_reward_avg:0.77 train_time:2.65 time_spent:11.41
# 04/12/2024 10:50:55 - INFO - logger - iteration 494 : offline_loss:0.00 online_loss:7.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.20 loss:7.17 n_loss:0.00 tb_loss:7.17 batch_entropy:41.78 traj_lens:16.95 grad_norm:87.10 grad_norm_clip:39.31 sampled_reward_avg:0.78 train_time:2.75 time_spent:11.53
# 04/12/2024 10:51:07 - INFO - logger - iteration 495 : offline_loss:0.00 online_loss:121.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.22 loss:121.42 n_loss:0.00 tb_loss:121.42 batch_entropy:40.96 traj_lens:16.58 grad_norm:245.92 grad_norm_clip:63.34 sampled_reward_avg:0.73 train_time:2.69 time_spent:11.66
# 04/12/2024 10:51:18 - INFO - logger - iteration 496 : offline_loss:0.00 online_loss:198.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.23 loss:198.12 n_loss:0.00 tb_loss:198.12 batch_entropy:42.47 traj_lens:17.00 grad_norm:443.83 grad_norm_clip:69.20 sampled_reward_avg:0.72 train_time:2.74 time_spent:11.20
# 04/12/2024 10:51:29 - INFO - logger - iteration 497 : offline_loss:0.00 online_loss:107.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.23 loss:107.17 n_loss:0.00 tb_loss:107.17 batch_entropy:42.41 traj_lens:16.91 grad_norm:267.99 grad_norm_clip:62.66 sampled_reward_avg:0.74 train_time:2.87 time_spent:11.32
# 04/12/2024 10:51:41 - INFO - logger - iteration 498 : offline_loss:0.00 online_loss:51.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.22 loss:51.16 n_loss:0.00 tb_loss:51.16 batch_entropy:42.03 traj_lens:17.00 grad_norm:168.79 grad_norm_clip:58.09 sampled_reward_avg:0.76 train_time:2.81 time_spent:11.71
# 04/12/2024 10:51:52 - INFO - logger - iteration 499 : offline_loss:0.00 online_loss:135.06 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.22 loss:135.06 n_loss:0.00 tb_loss:135.06 batch_entropy:41.65 traj_lens:16.77 grad_norm:190.03 grad_norm_clip:58.69 sampled_reward_avg:0.76 train_time:2.74 time_spent:11.33
# 04/12/2024 10:52:04 - INFO - logger - iteration 500 : offline_loss:0.00 online_loss:61.50 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:18.21 loss:61.50 n_loss:0.00 tb_loss:61.50 batch_entropy:42.28 traj_lens:17.00 grad_norm:192.49 grad_norm_clip:57.35 sampled_reward_avg:0.78 train_time:2.86 time_spent:11.68

# %%
with open(os.path.join(config.log_dir, "params.json"), "w+") as file:
    json.dump(params,file)

with open(os.path.join(config.log_dir, "target.json"), "w+") as file:
    json.dump(target,file)

state = {
    "models_state_dict": [trial.model.state_dict()],
    "cfg": trial.cfg,
    "env_ctx": trial.model.env_ctx,
    #"model": trial.model,
}
if trial.sampling_model is not trial.model:
    state["sampling_model_state_dict"] = [trial.sampling_model.state_dict()]
fn = pathlib.Path(trial.cfg.log_dir) / "model_final_save.pt"
with open(fn, "wb") as fd:
    torch.save(
        state,
        fd,
    )

# %%
# Generate molecules
trajs = trial.algo.create_training_data_from_own_samples(trial.model, 25)
objs = [trial.ctx.graph_to_obj(i['result']) for i in trajs]
obj_props, is_valid = trial.task.compute_obj_properties(objs)
log_rewards = trial.task.cond_info_to_logreward({'beta': torch.ones(len(trajs))}, obj_props)
index = 0
rewards = []
for i in is_valid:
    if i:
        rewards.append(list(log_rewards)[index])
        index += 1 
    else:
        rewards.append(0)

MolsToGridImage(objs[:25], molsPerRow=5, subImgSize=(200, 120), legends=[f'reward: {r}' if r==0 else f'reward: {r.exp().item():.2f}' for r in rewards[:25]])

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')])
ax[0].set_yscale('log')
ax[1].set_ylabel('TB loss')
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')])
ax[1].set_ylabel('Average reward')
ax[2].plot([i.value for i in ea.Scalars('train_logZ')])
ax[2].set_ylabel('Predicted logZ')
pp.tight_layout()

# %%
tags = ea.Tags()
print("Available tags:", tags)

# %%
from pycirclize import Circos
import pandas as pd
import matplotlib.pyplot as plt
from pom_models.functions import fragance_propabilities_from_smiles
from rdkit import Chem
import numpy as np

# %%
indices = np.argsort(-np.array(target))
indices

# %%
labels = df.keys()[2:]
labels

# %%
data_lst  = []
for i, obj in enumerate(objs):
    smiles = Chem.MolToSmiles(obj)
    probs = fragance_propabilities_from_smiles(smiles)[0]

    data_lst.append( [smiles] + list(probs))
result_df = pd.DataFrame(
    data=data_lst,
    index=[i for i in range(len(data_lst))],
    columns=["smiles"]+list(labels)
    )
result_df.head()

# %%
target_df = pd.DataFrame(
    data=[["target"] + list(target)],
    columns=result_df.keys(),
    index=["Target"]
)
target_df

# %%
most_important_indicies = indices[:8]
most_important_keys = []
for i in most_important_indicies:
    most_important_keys.append(labels[i])
most_important_keys

# %%
rewards_plot = [f'{r}' if r==-1 else f'{r.exp().item():.2f}' for r in rewards[:25]]
rewards_plot

# %%
plot_df = result_df[most_important_keys].set_index(pd.Series([f"{i+1} r:{rewards_plot[i]}" for i in range(len(result_df["smiles"]))]))
plot_df

# %%
plot_target_df = target_df[most_important_keys]
plot_target_df

# %%
plot_df.loc["target"] = []

# %%
# Create 5 x 5 subplots
fig = plt.figure(figsize=(26, 16), dpi=100)
fig.subplots(5, 5, subplot_kw=dict(polar=True))
fig.subplots_adjust(wspace=1, hspace=0.25)

# Plot radar chart into subplots for each target
for target_name, ax in zip(plot_df.index, fig.axes):
    target_df = plot_df.loc[[target_name]]
    target_df = pd.concat([target_df, plot_target_df])
    # Initialize Circos instance for radar chart plot
    circos = Circos.radar_chart(
        target_df,
        vmax=1,
        marker_size=6,
        #cmap=dict(Hero="salmon", Warrior="skyblue", Wizard="lime", Assassin="magenta"),
        grid_interval_ratio=0.2,
        line_kws_handler=lambda _: dict(lw=2, ls="solid"),
        marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
    )

    # Plot figure & set legend on upper right
    circos.plotfig(ax=ax)
    circos.ax.legend(loc="upper right", fontsize=10,bbox_to_anchor=(1.7, 1.1))

# %%
np.array(result_df[labels].sum())/len(result_df[labels])

# %%
import seaborn as sns

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[0].set_yscale('log')
ax[0].set_ylabel('TB loss')
ax[0].grid()
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[1].set_ylabel('Average reward')
ax[1].set_xlabel('Iteration')
ax[1].grid()
ax[2].plot([i.value for i in ea.Scalars('train_logZ')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[2].set_ylabel('Predicted logZ')
ax[2].grid()
pp.tight_layout()
plt.savefig("images/pine_run_plots.pdf")
