# %% [markdown]
# # Load Save (Vanilla)

# %%
savename = "c:/Users/paulj/Desktop/prosjekt/pom_cpu-model/results/vanilla12_2025-01-29__09_16_18"
number=12

# %% [markdown]
# | **Parameter**                | **Value**      |
# |------------------------------|----------------|
# | Reward function type         | OpenPOM        |
# | Similarity measure           | Cosine         |
# | Graph building               | Fragments Vanilla      |
# | Iterations                   | 500            |
# | Max number of nodes          | 6              |
# | Illegal action logreward     | -100           |
# | β                            | 1             |
# | Large molecule penalty       | None           |

# %% [markdown]
# ## Imports

# %%
import sys
import os
path_to_top_dir = "../"
# Dynamically add the `project` directory to the path
sys.path.append(os.path.abspath(path_to_top_dir))

# %%
# Utils
import warnings

# Plotting
from rdkit.Chem.Draw import MolsToGridImage
import matplotlib.pyplot as plt
import seaborn as sns
from pycirclize import Circos

# File management
import json
import numpy as np
import pandas as pd


# GFlowNET
import gflownet
from gflownet.algo.trajectory_balance import TrajectoryBalance
from gflownet.envs.graph_building_env import GraphBuildingEnv
from gflownet.config import init_empty, Config
from scent_gfn.molecule import MoleculeTask

# OpenPOM
from pom_models.functions import fragance_propabilities_from_smiles

# Others
from tensorboard.backend.event_processing import event_accumulator
import torch
from rdkit import Chem
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# Skipped loading some PyTorch models, missing a dependency. No module named 'tensorflow'
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)

# %% [markdown]
# ## Functions

# %%
def get_fragrance_notes():
    return list(pd.read_csv("../data/data.csv").keys()[2:])

# %%
def get_sorted_targed_scent_indicies(target):
    return np.argsort(-np.array(target))

# %%
def get_evaluated_objs_notes_df(objs):
    labels= get_fragrance_notes()
    data_lst  = []
    for i, obj in enumerate(objs):
        smiles = Chem.MolToSmiles(obj)
        probs = fragance_propabilities_from_smiles(smiles)[0]

        data_lst.append( [smiles] + list(probs))
    result_df = pd.DataFrame(
        data=data_lst,
        index=[i for i in range(len(data_lst))],
        columns=["smiles"]+list(labels)
        )
    return result_df

# %%
def get_target_notes_df(target):
    labels= get_fragrance_notes()
    target_df = pd.DataFrame(
        data=[["target"] + list(target)],
        columns=["smiles"]+list(labels),
        index=["Target"]
    )
    return target_df

# %%
def get_most_important_indicies(number,target):
    labels= get_fragrance_notes()
    indices=get_sorted_targed_scent_indicies(target)
    most_important_indicies = indices[:number]
    most_important_keys = []
    for i in most_important_indicies:
        most_important_keys.append(labels[i])
    return most_important_keys

# %%
def get_plot_df(objs,target, number,rewards):
    result_df = get_evaluated_objs_notes_df(objs)
    most_important_keys = get_most_important_indicies(number,target)
    return result_df[most_important_keys].set_index(pd.Series([f"{i+1} r:{rewards[i]:.2f}" for i in range(len(result_df["smiles"]))]))

# %%
def create_radar_grid_plot(objs,target, number,rewards,dim=[5,5], space=[1,0.25]):
    
    plot_df = get_plot_df(objs,target, number,rewards)
    plot_target_df= get_target_notes_df(target)[get_most_important_indicies(number,target)]
    #print(plot_df)
    #print(plot_target_df)
    # Create 5 x 5 subplots
    fig = plt.figure(figsize=(26, 16), dpi=100)
    fig.subplots(dim[0], dim[1], subplot_kw=dict(polar=True))
    fig.subplots_adjust(wspace=space[0], hspace=space[1])
    # Plot radar chart into subplots for each target
    for target_name, ax in zip(plot_df.index, fig.axes):
        target_df = plot_df.loc[[target_name]]
        target_df = pd.concat([target_df, plot_target_df])
        # Initialize Circos instance for radar chart plot
        circos = Circos.radar_chart(
            target_df,
            vmax=1,
            marker_size=6,
            #cmap=dict(Hero="salmon", Warrior="skyblue", Wizard="lime", Assassin="magenta"),
            grid_interval_ratio=0.2,
            line_kws_handler=lambda _: dict(lw=2, ls="solid"),
            marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
        )

        # Plot figure & set legend on upper right
        circos.plotfig(ax=ax)
        circos.ax.legend(loc="upper right", fontsize=10,bbox_to_anchor=(1.7, 1.1))
    return fig

# %%
def read_pine_smiles():
    return list(pd.read_csv("../data/intensities.csv")["smiles"])

# %%
def read_vanilla_smiles():
    df = pd.read_csv("../data/data.csv")
    vanilla_mols_df = df.loc[df['vanilla'] == 1]
    vanilla_smiles_trainig= list(vanilla_mols_df["nonStereoSMILES"])
    
    return vanilla_smiles_trainig

# %%
cfg = init_empty(Config())

cfg.log_dir = savename
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()


f, ax = plt.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')], color=sns.color_palette("Set2")[2])
ax[0].set_yscale('log')
ax[0].set_ylabel('TB loss')
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')], color=sns.color_palette("Set2")[2])
ax[1].set_ylabel('Average reward')
ax[1].set_xlabel('Iteration')
ax[2].plot([i.value for i in ea.Scalars('train_logZ')], color=sns.color_palette("Set2")[2])
ax[2].set_ylabel('Predicted logZ')
plt.tight_layout()

# %%
f, ax = plt.subplots(1, 2, figsize=(4*2,2))
ax[0].plot([i.value for i in ea.Scalars('train_loss')], color=sns.color_palette("Set2")[0], linewidth=1.5)
ax[0].set_yscale('log')
ax[0].set_ylabel('TB loss')
ax[0].grid()
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')], color=sns.color_palette("Set2")[0], linewidth=1.5)
ax[1].set_ylabel('Average reward')
ax[1].grid()
#ax[1].set_xlabel('Iteration')
plt.tight_layout()
plt.savefig(f"../images/vanilla_{number}_plots.pdf", bbox_inches="tight")

# %%
# Model class must be defined somewhere
state = torch.load(os.path.join(cfg.log_dir, "model_final_save.pt"), weights_only=False)
#model = statemodel.eval()
#state["models_state_dict"]
config = state["cfg"]
env_ctx = state["env_ctx"]

# %%
with open(os.path.join(cfg.log_dir, "params.json"), "r") as file:
    params = json.load(file)

with open(os.path.join(cfg.log_dir, "target.json"), "r") as file:
    target = json.load(file)

# %%
model = gflownet.models.graph_transformer.GraphTransformerGFN(state["env_ctx"],state["cfg"])
model.load_state_dict(state["models_state_dict"][0])
model.eval()
1
# Out:
# 1

# %%
#D:\Dokumenter\Skole\Prosjektoppgave\gflownet\src\gflownet\algo\trajectory_balance.py


algo = TrajectoryBalance(GraphBuildingEnv(),state["env_ctx"],state["cfg"])

# %%
task = MoleculeTask(data_tuple=(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]))
# Out:
# SMILES input data detected ...
# Reward function: reward_function_openpom | Similarity measure: cosine_similarity | exp_penalty: False | max_mol=17

# %%
trajs = algo.create_training_data_from_own_samples(model, 12)

# %%
objs = [env_ctx.graph_to_obj(i['result']) for i in trajs]
obj_props, is_valid = task.compute_obj_properties(objs)
print(is_valid)
log_rewards = task.cond_info_to_logreward({'beta': torch.ones(len(obj_props))*params["beta"]}, obj_props)
index = 0
rewards = []

for i in is_valid:
    if i:
        rewards.append(list(log_rewards)[index].exp().item())
        index += 1 
    else:
        rewards.append(0.0)

MolsToGridImage(objs, molsPerRow=3, subImgSize=(200, 120), legends=[f'R(x) = {r:.2f}' for r in rewards])
# Out:
# tensor([True, True, True, True, True, True, True, True, True, True, True, True])

# %%
fig = create_radar_grid_plot(objs,fragance_propabilities_from_smiles(target[0])[0], 8,rewards,dim=[4,3],space=[0.25,0.25])

# %%
smiles = [Chem.MolToSmiles(m) for m in objs]

# %%
smiles
# Out:
# ['CC(=O)CCC(C)=O',
#  'CC(C)C',
#  'CC(=O)C=C(C)C(C)(C)C',
#  'CC(C=CC(C)(C)C)=CC(C)(C)C',
#  'CC(C)(O)CCC1CC1',
#  'CC(C)(C)C(C)(C)O',
#  'CC=O',
#  'CC(C)=CC1CC1',
#  'CC(=O)CCCCCCC=C(C)C',
#  'CC(=O)c1c[nH]c(C(C)(C)C)c1',
#  'CC(=O)CCC(C)=O',
#  'CC(=CC(C)O)C(C)O']

# %%
#objs = [Chem.MolFromSmiles(s) for s in smiles]

# %%
obj_props, is_valid = task.compute_obj_properties(objs)
rewards=[task.reward_function(o) for o in objs]

MolsToGridImage(objs, molsPerRow=3, subImgSize=(200, 120), legends=[f'R(x) = {r:.2f}' for r in rewards])

# %%
largest_indices = np.argsort(np.array(rewards))[-4:][::-1]
reduced_mols =[]
reduced_rewards = []
for i in largest_indices:
    reduced_mols.append(objs[i])
    reduced_rewards.append(rewards[i])
reduced_mols,reduced_rewards
# Out:
# ([<rdkit.Chem.rdchem.Mol at 0x213b0dbe340>,
#   <rdkit.Chem.rdchem.Mol at 0x213b0dbe180>,
#   <rdkit.Chem.rdchem.Mol at 0x213b0dbe3b0>,
#   <rdkit.Chem.rdchem.Mol at 0x213b0dbdcb0>],
#  [0.8649241, 0.77632385, 0.760876, 0.760876])

# %%
smiles_list = [Chem.MolToSmiles(m) for m in reduced_mols]
smiles_list
# Out:
# ['CC(=O)c1c[nH]c(C(C)(C)C)c1',
#  'CC(=CC(C)O)C(C)O',
#  'CC(=O)CCC(C)=O',
#  'CC(=O)CCC(C)=O']

# %% [markdown]
# gen_mol_images("van8", smiles_list8, rewards8, size=(7*200,7*120), bond_width=6)

# %%
def create_radar_plots_set(objs,target, number,rewards,dirname, space=[1,0.25], bbox=[1.7,1.1], fsize=10,grid_label_formatter=None,label_kws_handler=None,grid_label_kws = None):
    
    plot_df = get_plot_df(objs,target, number,rewards)
    plot_target_df= get_target_notes_df(target)[get_most_important_indicies(number,target)]
    #print(plot_df)
    #print(plot_df)
    #print(plot_target_df)
    # Create 5 x 5 subplots
    #fig = plt.figure(figsize=(26, 16), dpi=100)
    #fig.subplots(dim[0], dim[1], subplot_kw=dict(polar=True))
    #fig.subplots_adjust(wspace=space[0], hspace=space[1])
    # Plot radar chart into subplots for each target
    for i, target_name in enumerate(plot_df.index):
        target_df = plot_df.loc[[target_name]]
        reward_val=target_df.index[0].split(":")[1]
        target_df.index = ["Molecule"]
        target_df = pd.concat([target_df, plot_target_df])
        # Initialize Circos instance for radar chart plot
        circos = Circos.radar_chart(
            target_df,
            vmax=1,
            marker_size=6,
            #cmap=dict(Hero="salmon", Warrior="skyblue", Wizard="lime", Assassin="magenta"),
            grid_interval_ratio=0.2,
            line_kws_handler=lambda _: dict(lw=2, ls="solid"),
            marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
            grid_label_formatter=grid_label_formatter,
            label_kws_handler=label_kws_handler,
            grid_label_kws = grid_label_kws,
        )

        # Plot figure & set legend on upper right
        fig = circos.plotfig(figsize=(13, 8), dpi=100)
        circos.ax.legend(loc="upper right", fontsize=fsize,bbox_to_anchor=(bbox[0], bbox[1]))
        plt.savefig(f"../images/{dirname}/radar{i}r{reward_val}.pdf", bbox_inches="tight")
    return fig

# %%
fsize=30
fig = create_radar_plots_set(
    reduced_mols,
    fragance_propabilities_from_smiles(target[0])[0], 
    8,
    reduced_rewards,
    f"van{number}",
    space=[0.01,0.4], 
    fsize=fsize, 
    bbox=[1.5,1.1], 
    label_kws_handler=lambda _: dict(size=fsize),
    grid_label_kws=dict(size=fsize),
    )

# %%
trajs1000 = algo.create_training_data_from_own_samples(model, 1000)

# %%
objs1000 = [env_ctx.graph_to_obj(i['result']) for i in trajs1000]

# %%
rewards1000 = [task.reward_function(o) for o in objs1000]

# %%
vanilla_data = [Chem.MolFromSmiles(s) for s in read_vanilla_smiles()]

# Generate canonical SMILES for comparison
objs1000_smiles_canon = [Chem.MolToSmiles(mol, canonical=True) for mol in objs1000]
vanilla_smiles_canon = [Chem.MolToSmiles(mol, canonical=True) for mol in vanilla_data]

# Check if molecules in list1 are in list2
contained_in_both = []
for smiles in vanilla_smiles_canon:
        if smiles in objs1000_smiles_canon:
            contained_in_both.append(smiles)

contained_in_both
# Out:
# []

# %%
indiciestop20= []
for i in sorted(rewards1000, reverse=True)[:20]:
    indiciestop20.append(rewards1000.index(i))
indiciestop20
# Out:
# [319,
#  440,
#  492,
#  430,
#  556,
#  216,
#  291,
#  527,
#  244,
#  224,
#  408,
#  498,
#  818,
#  611,
#  594,
#  614,
#  253,
#  973,
#  255,
#  255]

# %%
smilestop20 = []
for i in indiciestop20:
    smilestop20.append(objs1000_smiles_canon[i])
smilestop20
# Out:
# ['CCc1c[nH]c(C(C)=O)c1',
#  'C=Cc1c[nH]c(C(C)=O)c1',
#  'CC(=O)c1c[nH]c(C(C)O)c1',
#  'CC(=O)C=Cc1cc(C(C)=O)c[nH]1',
#  'CC(=O)c1c[nH]c(-c2cc(C=C(C)C)c[nH]2)c1',
#  'CC(=O)C=C(C)c1cc(C(C)O)c[nH]1',
#  'CC(=O)CCc1cc(C(C)=O)c[nH]1',
#  'CC(=O)c1cc(CCC(C)O)c[nH]1',
#  'CC(=O)C(C)=Cc1cc(C(C)=O)c[nH]1',
#  'CC(=O)c1cc(CCc2cc(C(C)O)c[nH]2)c[nH]1',
#  'CC(C)=Cc1cc(C(C)O)c[nH]1',
#  'CC=Cc1ccc[nH]1',
#  'CC(C)=Cc1cc(C=CC(C)O)c[nH]1',
#  'CC(=O)c1c[nH]c(C2CC2)c1',
#  'CC(C)(O)c1c[nH]c(C=O)c1',
#  'CC(=O)C=CC=O',
#  'CCc1cc[nH]c1',
#  'CC(=O)C=C(C)c1c[nH]c(C2CC2)c1',
#  'CC(=O)C=CC(C)=O',
#  'CC(=O)C=CC(C)=O']

# %%
rewards1000
# Out:
# [0.7364088,
#  0.66841143,
#  0.6398073,
#  0.8034371,
#  0.63333017,
#  0.8064093,
#  0.6612006,
#  0.7024846,
#  0.6395563,
#  0.6548089,
#  0.7364088,
#  0.8159037,
#  0.6344056,
#  0.62485355,
#  0.81234443,
#  0.5997207,
#  0.69207704,
#  0.6614258,
#  0.650696,
#  0.65342844,
#  0.6616291,
#  0.636308,
#  0.7510574,
#  0.6612006,
#  0.6300068,
#  0.7575056,
#  0.65538824,
#  0.712935,
#  0.651473,
#  0.84384656,
#  0.7441299,
#  0.6398073,
#  0.7425937,
#  0.81234443,
#  0.7878818,
#  0.8398003,
#  0.78874403,
#  0.64590204,
#  0.71707475,
#  0.6684185,
#  0.67514586,
#  0.5997207,
#  0.6785962,
#  0.69787514,
#  0.5300307,
#  0.6288166,
#  0.61644834,
#  0.64590204,
#  0.59811497,
#  0.63333017,
#  0.65761536,
#  0.78610533,
#  0.63505036,
#  0.6795182,
#  0.7024846,
#  0.6570255,
#  0.6958158,
#  0.72593665,
#  0.78610533,
#  0.81265503,
#  0.6612006,
#  0.6612006,
#  0.7046734,
#  0.72165895,
#  0.6594859,
#  0.75306755,
#  0.6809917,
#  0.68269396,
#  0.7107172,
#  0.53996336,
#  0.8331633,
#  0.6288893,
#  0.6956203,
#  0.6331545,
#  0.7013184,
#  0.8064093,
#  0.6895756,
#  0.64590204,
#  0.6086283,
#  0.8064093,
#  0.75173026,
#  0.6751092,
#  0.8306732,
#  0.7647955,
#  0.61727,
#  0.5997207,
#  0.81234443,
#  0.6632227,
#  0.85119456,
#  0.6520576,
#  0.70194465,
#  0.8306732,
#  0.7554176,
#  0.69760007,
#  0.8306732,
#  0.6840824,
#  0.6875489,
#  0.63392913,
#  0.651473,
#  0.7413026,
#  0.5892904,
#  0.66519326,
#  0.6203047,
#  0.5892904,
#  0.8064093,
#  0.74824655,
#  0.6956203,
#  0.81234443,
#  0.85811466,
#  0.62485355,
#  0.655255,
#  0.72165895,
#  0.63505036,
#  0.84384656,
#  0.7369935,
#  0.651473,
#  0.751744,
#  0.6634301,
#  0.65342844,
#  0.818014,
#  0.6907469,
#  0.64243066,
#  0.82290375,
#  0.78610533,
#  0.8064093,
#  0.6785962,
#  0.6797048,
#  0.6467648,
#  0.74941,
#  0.8527821,
#  0.61220104,
#  0.6612006,
#  0.6886556,
#  0.7413026,
#  0.65342844,
#  0.6155653,
#  0.65342844,
#  0.7364088,
#  0.6432194,
#  0.7861401,
#  0.61727,
#  0.62199455,
#  0.6086246,
#  0.6612006,
#  0.84200543,
#  0.8064093,
#  0.5981392,
#  0.62485355,
#  0.6809917,
#  0.67704296,
#  0.627164,
#  0.8064093,
#  0.712935,
#  0.6507469,
#  0.57807493,
#  0.67339456,
#  0.67339456,
#  0.64590204,
#  0.82919294,
#  0.6445388,
#  0.61397606,
#  0.71300375,
#  0.60314405,
#  0.7554176,
#  0.72354144,
#  0.64590204,
#  0.6507469,
#  0.6915551,
#  0.85718787,
#  0.655255,
#  0.67666143,
#  0.81888336,
#  0.64590204,
#  0.62485355,
#  0.6612006,
#  0.7554176,
#  0.6785962,
#  0.7121912,
#  0.7425937,
#  0.78666675,
#  0.75306755,
#  0.67616034,
#  0.66519326,
#  0.627164,
#  0.6655397,
#  0.7311838,
#  0.69760007,
#  0.62485355,
#  0.72165895,
#  0.67339456,
#  0.8306732,
#  0.82290375,
#  0.6545455,
#  0.7320988,
#  0.7239265,
#  0.64393485,
#  0.68313575,
#  0.6570255,
#  0.6688703,
#  0.71928596,
#  0.57554674,
#  0.72165895,
#  0.69787514,
#  0.7364088,
#  0.6179792,
#  0.6655397,
#  0.7144611,
#  0.663574,
#  0.7107172,
#  0.8556014,
#  0.65342844,
#  0.67339456,
#  0.6655397,
#  0.7765471,
#  0.6634301,
#  0.7325972,
#  0.906866,
#  0.74277884,
#  0.6430438,
#  0.5997207,
#  0.62485355,
#  0.61339694,
#  0.7486534,
#  0.63076276,
#  0.8954514,
#  0.64679,
#  0.6086283,
#  0.7080783,
#  0.82919294,
#  0.5300307,
#  0.71034235,
#  0.7425937,
#  0.69613427,
#  0.61582285,
#  0.6807147,
#  0.6655397,
#  0.7479485,
#  0.6968944,
#  0.6344056,
#  0.68313575,
#  0.8064093,
#  0.6968944,
#  0.7046734,
#  0.651473,
#  0.8955333,
#  0.6217012,
#  0.8159037,
#  0.6634301,
#  0.6958158,
#  0.7441299,
#  0.8156752,
#  0.62764925,
#  0.7107172,
#  0.87447584,
#  0.655098,
#  0.85881126,
#  0.8034371,
#  0.7107172,
#  0.72593665,
#  0.5997207,
#  0.53996336,
#  0.57807493,
#  0.6688703,
#  0.7249276,
#  0.818014,
#  0.7024846,
#  0.6887027,
#  0.7554176,
#  0.636308,
#  0.6636529,
#  0.80195636,
#  0.8034371,
#  0.68269396,
#  0.68511176,
#  0.71624696,
#  0.8086141,
#  0.67075,
#  0.7465405,
#  0.7358675,
#  0.6100307,
#  0.64590204,
#  0.5997207,
#  0.6432194,
#  0.6833738,
#  0.62764925,
#  0.6655397,
#  0.53996336,
#  0.7364088,
#  0.64393485,
#  0.7649607,
#  0.7369935,
#  0.9056152,
#  0.6626721,
#  0.6114903,
#  0.64590204,
#  0.5938538,
#  0.6531144,
#  0.64825606,
#  0.72165895,
#  0.5997207,
#  0.6507469,
#  0.6093452,
#  0.68313575,
#  0.66453075,
#  0.674311,
#  0.7591274,
#  0.6111549,
#  0.6958158,
#  0.6809917,
#  0.62764925,
#  0.7107172,
#  0.7320988,
#  0.8034371,
#  0.6795182,
#  0.6679689,
#  0.7554176,
#  0.71034235,
#  0.655255,
#  0.6634301,
#  0.92849785,
#  0.65342844,
#  0.7548477,
#  0.7107172,
#  0.65538824,
#  0.6643976,
#  0.6785962,
#  0.63360256,
#  0.7249276,
#  0.5997207,
#  0.6887027,
#  0.7861401,
#  0.7591274,
#  0.71034235,
#  0.6612006,
#  0.72957855,
#  0.8034371,
#  0.8306732,
#  0.8064093,
#  0.6612006,
#  0.78610533,
#  0.70160496,
#  0.72001964,
#  0.61727,
#  0.7024846,
#  0.6929244,
#  0.62485355,
#  0.7024846,
#  0.69613427,
#  0.53996336,
#  0.72165895,
#  0.7452994,
#  0.5997207,
#  0.8034371,
#  0.61727,
#  0.5975633,
#  0.8064093,
#  0.8159037,
#  0.6358405,
#  0.651473,
#  0.71707475,
#  0.818014,
#  0.651473,
#  0.5997207,
#  0.7046734,
#  0.7320988,
#  0.7014426,
#  0.72354144,
#  0.64590204,
#  0.67514586,
#  0.5997207,
#  0.75823104,
#  0.8306732,
#  0.6030072,
#  0.7618902,
#  0.75823104,
#  0.72593665,
#  0.5978905,
#  0.64590204,
#  0.750175,
#  0.6785962,
#  0.67616034,
#  0.81234443,
#  0.73397136,
#  0.71300375,
#  0.6548089,
#  0.65761536,
#  0.66749656,
#  0.818014,
#  0.8034371,
#  0.6655397,
#  0.6218151,
#  0.6809917,
#  0.69939065,
#  0.70160496,
#  0.6101366,
#  0.72354144,
#  0.7861401,
#  0.67666143,
#  0.651473,
#  0.65837795,
#  0.6612006,
#  0.61727,
#  0.6886674,
#  0.7425937,
#  0.655098,
#  0.64590204,
#  0.6809917,
#  0.71300375,
#  0.8934381,
#  0.7249276,
#  0.81234443,
#  0.723835,
#  0.7024846,
#  0.85881126,
#  0.65342844,
#  0.6399319,
#  0.7239265,
#  0.6467648,
#  0.6968944,
#  0.8086141,
#  0.67450434,
#  0.6241588,
#  0.78610533,
#  0.7082582,
#  0.6958158,
#  0.64825606,
#  0.6612006,
#  0.73397136,
#  0.67360485,
#  0.73834044,
#  0.9247612,
#  0.72180134,
#  0.68858576,
#  0.71034235,
#  0.7116623,
#  0.6679689,
#  0.7203691,
#  0.68991566,
#  0.70051175,
#  0.8556014,
#  0.9275421,
#  0.7046734,
#  0.64679,
#  0.6573722,
#  0.74941,
#  0.62485355,
#  0.85881126,
#  0.7441299,
#  0.64393485,
#  0.61712307,
#  0.636308,
#  0.67666143,
#  0.6236928,
#  0.76885766,
#  0.8556014,
#  0.61727,
#  0.81234443,
#  0.65342844,
#  0.6100307,
#  0.5997207,
#  0.6655397,
#  0.7121912,
#  0.63505036,
#  0.65342844,
#  0.5981392,
#  0.5946618,
#  0.6154866,
#  0.8306732,
#  0.72165895,
#  0.7046734,
#  0.806644,
#  0.7173286,
#  0.7554176,
#  0.5762406,
#  0.6333083,
#  0.74431574,
#  0.6276383,
#  0.7441299,
#  0.636308,
#  0.66009974,
#  0.6309268,
#  0.7425937,
#  0.5300307,
#  0.8159037,
#  0.7024846,
#  0.6286249,
#  0.7861401,
#  0.6785962,
#  0.6785962,
#  0.7554176,
#  0.6086283,
#  0.61339694,
#  0.9273844,
#  0.84384656,
#  0.72354144,
#  0.64590204,
#  0.5300307,
#  0.73253727,
#  0.8892077,
#  0.73193294,
#  0.7554176,
#  0.6612006,
#  0.6577126,
#  0.6986868,
#  0.61727,
#  0.6655397,
#  0.7107172,
#  0.6577253,
#  0.73397136,
#  0.7144611,
#  0.66519326,
#  0.66519326,
#  0.53996336,
#  0.627164,
#  0.806644,
#  0.7441299,
#  0.6809917,
#  0.6655397,
#  0.69873357,
#  0.53996336,
#  0.5999712,
#  0.8043768,
#  0.6444014,
#  0.7121912,
#  0.65538824,
#  0.7024846,
#  0.69812214,
#  0.90007704,
#  0.7554176,
#  0.7107172,
#  0.7239265,
#  0.76171696,
#  0.57143795,
#  0.627164,
#  0.7286252,
#  0.77632385,
#  0.7861401,
#  0.8556014,
#  0.67514586,
#  0.6612006,
#  0.67489827,
#  0.8064093,
#  0.627164,
#  0.57807493,
#  0.6288166,
#  0.6545455,
#  0.6634301,
#  0.7249276,
#  0.8306732,
#  0.7364088,
#  0.67339456,
#  0.6086318,
#  0.5300307,
#  0.6612006,
#  0.5997207,
#  0.63315445,
#  0.906945,
#  0.71300375,
#  0.8064093,
#  0.78874403,
#  0.6395563,
#  0.8034371,
#  0.6915551,
#  0.7249276,
#  0.7107172,
#  0.7369935,
#  0.7358675,
#  0.66841143,
#  0.818014,
#  0.818014,
#  0.62485355,
#  0.6180084,
#  0.67228496,
#  0.700525,
#  0.8543896,
#  0.75823104,
#  0.70543003,
#  0.6612006,
#  0.62764925,
#  0.651473,
#  0.6679689,
#  0.70194465,
#  0.81234443,
#  0.7425937,
#  0.71300375,
#  0.71034235,
#  0.7364088,
#  0.66453075,
#  0.72593665,
#  0.651473,
#  0.82290375,
#  0.7819764,
#  0.6785962,
#  0.5997207,
#  0.8760075,
#  0.8306732,
#  0.6634301,
#  0.7425937,
#  0.8159037,
#  0.6588911,
#  0.71988875,
#  0.787195,
#  0.6634301,
#  0.61727,
#  0.65342844,
#  0.6508728,
#  0.7853941,
#  0.7249276,
#  0.7249276,
#  0.7024846,
#  0.7441299,
#  0.88397723,
#  0.62341195,
#  0.7435002,
#  0.8746009,
#  0.6101366,
#  0.67360485,
#  0.5997207,
#  0.651473,
#  0.6094679,
#  0.6614258,
#  0.8306732,
#  0.62485355,
#  0.7861401,
#  0.7896937,
#  0,
#  0.5997207,
#  0.67666143,
#  0.71707475,
#  0.7286252,
#  0.6179792,
#  0.65761536,
#  0.70766926,
#  0.7024846,
#  0.7024846,
#  0.73834044,
#  0.5969301,
#  0.6884302,
#  0.655255,
#  0.7364088,
#  0.8306732,
#  0.818014,
#  0.67514586,
#  0.60314405,
#  0.8549404,
#  0.6612006,
#  0.700525,
#  0.67375094,
#  0.5997207,
#  0.78610533,
#  0.651473,
#  0.7554176,
#  0.83514917,
#  0.6634301,
#  0.57807493,
#  0.6372473,
#  0.6884302,
#  0.71300375,
#  0.61727,
#  0.7107172,
#  0.5300307,
#  0.71034235,
#  0.8306732,
#  0.8034371,
#  0.82306755,
#  0.6968944,
#  0.72354144,
#  0.7425937,
#  0.7592342,
#  0.6913408,
#  0.63505036,
#  0.76063365,
#  0.76063365,
#  0.61397606,
#  0.6432194,
#  0.7483675,
#  0.6526024,
#  0.7338392,
#  0.85523003,
#  0.657581,
#  0.71034235,
#  0.6086283,
#  0.5798086,
#  0.7861401,
#  0.636308,
#  0.7425937,
#  0.6609139,
#  0.6987193,
#  0.7107172,
#  0.6577126,
#  0.6634301,
#  0.7441299,
#  0.80883,
#  0.6795182,
#  0.5300307,
#  0.650693,
#  0.73834044,
#  0.65538824,
#  0.71034235,
#  0.65668917,
#  0.8159037,
#  0.651473,
#  0.7107172,
#  0.651473,
#  0.67360485,
#  0.67999333,
#  0.651473,
#  0.65342844,
#  0.72001964,
#  0.8064093,
#  0.71034235,
#  0.65538824,
#  0.78610533,
#  0.7435002,
#  0.73834044,
#  0.67131597,
#  0.72354144,
#  0.82290375,
#  0.6310371,
#  0.66519326,
#  0.7107172,
#  0.83449763,
#  0.6288166,
#  0.7425937,
#  0.62855333,
#  0.8159037,
#  0.61450714,
#  0.82208705,
#  0.5997207,
#  0.7441299,
#  0.6577253,
#  0.6809917,
#  0.7592342,
#  0.7364088,
#  0.6236928,
#  0.82290375,
#  0.71034235,
#  0.5997207,
#  0.8556014,
#  0.6785962,
#  0.7554176,
#  0.6459941,
#  0.700525,
#  0.6887027,
#  0.6217012,
#  0.6501519,
#  0.8064093,
#  0.61209655,
#  0.5941141,
#  0.6086283,
#  0.5300307,
#  0.58551913,
#  0.627164,
#  0.6497386,
#  0.67514586,
#  0.7554176,
#  0.660391,
#  0.7649607,
#  0.71034235,
#  0.78610533,
#  0.5997207,
#  0.81234443,
#  0.75823104,
#  0.8306732,
#  0.81846607,
#  0.79811156,
#  0.67489827,
#  0.72354144,
#  0.6526024,
#  0.723835,
#  0.6432194,
#  0.6817242,
#  0.6593025,
#  0.7861401,
#  0.73834044,
#  0.6958158,
#  0.5300307,
#  0.6317994,
#  0.6655397,
#  0.5997207,
#  0.65342844,
#  0.74363863,
#  0.61818475,
#  0.67616034,
#  0.7649607,
#  0.79811156,
#  0.66280794,
#  0.65342844,
#  0.65254694,
#  0.7209758,
#  0.8064093,
#  0.760876,
#  0.68269396,
#  0.6577253,
#  0.651473,
#  0.6546371,
#  0.7554176,
#  0.8064093,
#  0.8306732,
#  0.7107172,
#  0.5997207,
#  0.651473,
#  0.6809917,
#  0.7107172,
#  0.67666143,
#  0.84653944,
#  0.74277884,
#  0.68858576,
#  0.7479485,
#  0.73397136,
#  0.66519326,
#  0.5300307,
#  0.81234443,
#  0.72593665,
#  0.7320988,
#  0.62485355,
#  0.6809917,
#  0.5786946,
#  0.8853072,
#  0.5300307,
#  0.655255,
#  0.7841139,
#  0.8397183,
#  0.7592342,
#  0.67339456,
#  0.76885766,
#  0.6612006,
#  0.7338392,
#  0.69787514,
#  0.6612006,
#  0.65704733,
#  0.8306732,
#  0.67360485,
#  0.700525,
#  0.53996336,
#  0.6468282,
#  0.6293248,
#  0.61460435,
#  0.73885006,
#  0.68269396,
#  0.72593665,
#  0.6548089,
#  0.5997207,
#  0.627164,
#  0.64590204,
#  0.7006398,
#  0.63171613,
#  0.65499103,
#  0.58853143,
#  0.760876,
#  0.7554176,
#  0.62485355,
#  0.6612006,
#  0.7249276,
#  0.66738385,
#  0.6958158,
#  0.84384656,
#  0.7024846,
#  0.818014,
#  0.81234443,
#  0.79696417,
#  0.8034371,
#  0.8306732,
#  0.68313575,
#  0.7024846,
#  0.73397136,
#  0.78610533,
#  0.6634301,
#  0.67131597,
#  0.6968944,
#  0.64393485,
#  0.5300307,
#  0.6894086,
#  0.5300307,
#  0.71034235,
#  0.712935,
#  0.66841143,
#  0.71988875,
#  0.65668917,
#  0.75517136,
#  0.6809917,
#  0.6577126,
#  0.66519326,
#  0.64590204,
#  0.72593665,
#  0.6317994,
#  0.6286249,
#  0.72593665,
#  0.7083494,
#  0.61339694,
#  0.655255,
#  0.7425937,
#  0.70194465,
#  0.62485355,
#  0.7554176,
#  0.818014,
#  0.61727,
#  0.71928596,
#  0.6785962,
#  0.6430438,
#  0.69873357,
#  0.71300375,
#  0.7861401,
#  0.7369935,
#  0.80883,
#  0.57807493,
#  0.53996336,
#  0.7861401,
#  0.7441299,
#  0.5997207,
#  0.7311838,
#  0.8159037,
#  0.627164,
#  0.64590204,
#  0.72341526,
#  0.5981392,
#  0.67966753,
#  0.6797048,
#  0.818014,
#  0.8159037,
#  0.7861401,
#  0.7118057,
#  0.60200965,
#  0.6419144,
#  0.78610533,
#  0.6655397,
#  0.66519326,
#  0.5969301,
#  0.6634301,
#  0.6233001,
#  0.61209655,
#  0.62582374,
#  0.6655397,
#  0.6662117,
#  0.6283907,
#  0.7780295,
#  0.8016819,
#  0.6507469,
#  0.82290375,
#  0.69760007,
#  0.8473868,
#  0.700525,
#  0.6776084,
#  0.78354704,
#  0.5997207,
#  0.7441299,
#  0.722837,
#  0.75173026,
#  0.71737486,
#  0.6809917,
#  0.81234443,
#  0.71034235,
#  0.5938538,
#  0.62764925,
#  0.78610533,
#  0.72165895,
#  0.6691383,
#  0.5997207,
#  0.8237463,
#  0.65538824,
#  0.7364088,
#  0.700525,
#  0.71034235,
#  0.7024846,
#  0.7554176,
#  0.6655397,
#  0.6309268,
#  0.76526916,
#  0.6100307,
#  0.67339456,
#  0.72957855,
#  0.760876,
#  0.7483675,
#  0.8621438,
#  0.81234443,
#  0.8543896,
#  0.6795182,
#  0.655255,
#  0.63505036,
#  0.6612006,
#  0.5997207,
#  0.6958158,
#  0.62771,
#  0.7554176,
#  0.8049123,
#  0.67514586,
#  0.6222226,
#  0.7425937,
#  0.7413026,
#  0.72433776,
#  0.6817242,
#  0.6264901,
#  0.8034371,
#  0.7121912,
#  0.6360304,
#  0.6655397,
#  0.655255,
#  0.57283014,
#  0.6520576,
#  0.6482696]

# %%
objs1000_smiles_canon
# Out:
# ['CC(O)C(C)(C)O',
#  'CCC1CC1',
#  'CC(C)=CC(C)=CC(C)(C)C',
#  'CC(=O)CCC(C)O',
#  'CC(=O)C=CC=CCCC=C(C)C',
#  'CC(=O)C1CC1',
#  'CC(C)=CC(C)(C)C',
#  'CC(=O)CCC=C(C)C',
#  'CC(=CC(C)(C)C)C1CC1',
#  'CC(=O)CCCCC=C(C)C',
#  'CC(O)C(C)(C)O',
#  'CC(=O)C=CC(C)(C)O',
#  'CC(=CCCC(C)(C)O)C(C)(C)C',
#  'CC(C)=CC1CC1',
#  'CC(C)=CC(C)O',
#  'CC',
#  'CC(=O)C=C(C)C=CC(C)=CC=C(C)C',
#  'CC(=O)CCC=CC=C(C)C',
#  'C=C(C)C=C(C)C(C)(C)C',
#  'CC(C)(C)C(C)(C)C',
#  'CC(C)(O)C=CCCC=CC(C)(C)O',
#  'CC(C)=CCCC(C)(C)C',
#  'CC(=O)C=CC=C(C)CCC(C)=O',
#  'CC(C)=CC(C)(C)C',
#  'CC(C)(O)C=CCCC1CC1',
#  'CC(=O)C=CC(C)=CC(C)(C)O',
#  'CC(C)=CCCC(C)(C)O',
#  'CC(O)C=CC(C)(C)C',
#  'CC(C)C',
#  'C=CC(C)=O',
#  'CC=O',
#  'CC(C)=CC(C)=CC(C)(C)C',
#  'CC(O)C1CC1',
#  'CC(C)=CC(C)O',
#  'CC(=O)CCC=CC(C)O',
#  'CC(=O)C=CC(C)=CC(C)O',
#  'CC(=O)C=CCCC(C)=O',
#  'CC(C)(C)C1CC1',
#  'CCC(C)O',
#  'CC(C)=CC=CC=CC(C)O',
#  'CC(C)=CC=C(C)C',
#  'CC',
#  'CC(C)(O)C1CC1',
#  'CC(=O)CCCCC(C)(C)O',
#  'C=C',
#  'CCCC',
#  'CC(C=CC(C)(C)C)=CC(C)(C)C',
#  'CC(C)(C)C1CC1',
#  'CC(C)=CC=C(C)C=CCCC(C)(C)C',
#  'CC(=O)C=CC=CCCC=C(C)C',
#  'C=C(C)C(C)(C)C',
#  'CC(=O)C=CC=C(C)C',
#  'CC(C)(C)C=CC(C)(C)C',
#  'CCC(C)(C)C',
#  'CC(=O)CCC=C(C)C',
#  'CC(=O)CCC(C)=CC1CC1',
#  'CC(=O)C=CC(C)(C)C',
#  'C=C(C)C',
#  'CC(=O)C=CC=C(C)C',
#  'c1c[nH]c(C2CC2)c1',
#  'CC(C)=CC(C)(C)C',
#  'CC(C)=CC(C)(C)C',
#  'CC(C)(O)C(C)(C)O',
#  'CCO',
#  'CC(=O)CCC(C)=CC=C(C)C',
#  'CC(=O)CCC=C(C)C(C)=O',
#  'CC(=O)CCC(C)(C)C',
#  'CC(=O)C(C)=CC(C)(C)C',
#  'CC(C)=CC(C)(C)O',
#  'C1CC1',
#  'CC(C)=Cc1c[nH]c(C=C(C)C)c1',
#  'CC(C)=CC(C)=CCCC(C)(C)O',
#  'CC(=O)C=C(C)CCC=C(C)C',
#  'CC(C)=CC=C(C)C=C(C)C(C)(C)C',
#  'CC(=O)C(C)=CCCC(C)(C)O',
#  'CC(=O)C1CC1',
#  'CC(=CC(C)O)CCC(C)(C)C',
#  'CC(C)(C)C1CC1',
#  'CC(C)=CCCC1CC1',
#  'CC(=O)C1CC1',
#  'CC(C)=CC(C)=CC(C)O',
#  'CC(O)C=CCCCCC(C)(C)C',
#  'CC(=O)C=C(C)C',
#  'CC(=O)C(C)=CC(C)(C)O',
#  'C=CC',
#  'CC',
#  'CC(C)=CC(C)O',
#  'CC(C)=CC(C)=CC(C)(C)O',
#  'CC(=O)C(C)=CC=O',
#  'CC(C)=CC=C(C)C=C(C)C',
#  'CC(=O)CCC(C)=CC(C)(C)O',
#  'CC(=O)C=C(C)C',
#  'CC(=O)C(C)(C)O',
#  'CC(=CC(C)O)C(C)(C)C',
#  'CC(=O)C=C(C)C',
#  'CC(C)=CC=C(C)C=CC(C)O',
#  'CC(C)(O)C=CCCC(C)(C)O',
#  'CC(C)(N)O',
#  'CC(C)C',
#  'CC(O)CCCCC(C)O',
#  'CC(C)=CC=CCCC=C(C)C',
#  'CC(C)(C)CCC(C)(C)O',
#  'CC(C)=CC(C)=CCCC(C)(C)C',
#  'CC(C)=CC=CCCC=C(C)C',
#  'CC(=O)C1CC1',
#  'CC(C)=Cc1c[nH]c(C=C(C)C(C)(C)C)c1',
#  'CC(=O)C=C(C)CCC=C(C)C',
#  'CC(C)=CC(C)O',
#  'CC(=O)c1cc(C2CC2)c[nH]1',
#  'CC(C)=CC1CC1',
#  'CC(C)(C)C=CC(C)(C)O',
#  'CCO',
#  'CC(C)(C)C=CC(C)(C)C',
#  'C=CC(C)=O',
#  'CC(=O)C(C)=CC=C(C)C',
#  'CC(C)C',
#  'CC(C=CC(C)O)=CC(C)(C)O',
#  'CC(=O)C(C)(C)C',
#  'CC(C)(C)C(C)(C)C',
#  'CC(=O)C(C)=O',
#  'CC(=O)CCCCCCC(C)(C)O',
#  'CC(=CC1CC1)C(C)(C)C',
#  'CC(=O)C=C(C)C(C)=O',
#  'CC(=O)C=CC=C(C)C',
#  'CC(=O)C1CC1',
#  'CC(C)(O)C1CC1',
#  'C=C(C)C(C)(C)O',
#  'CC(=CC(C)(C)O)C(C)(C)C',
#  'CC(=O)C=C(C)C1CC1',
#  'CC(O)CCc1cc(C(C)(C)O)c[nH]1',
#  'CC(C)=CCCCCC(C)=CC(C)(C)O',
#  'CC(C)=CC(C)(C)C',
#  'CC(=CC(C)(C)O)C(C)(C)O',
#  'CC(O)CCCCC(C)O',
#  'CC(C)(C)C(C)(C)C',
#  'CC(=CC1CC1)C=C(C)CCC(C)(C)O',
#  'CC(C)(C)C(C)(C)C',
#  'CC(O)C(C)(C)O',
#  'C=CC(C)(C)C',
#  'CC(=O)C(C)O',
#  'C=CC',
#  'CC(C)=CCCCCC(C)(C)C',
#  'CC(C=CC(C)(C)C)=CC1CC1',
#  'CC(C)=CC(C)(C)C',
#  'CC(=O)C=C(C)C=CC(C)O',
#  'CC(=O)C1CC1',
#  'C1CC1C1CC1',
#  'CC(C)=CC1CC1',
#  'CC(=O)CCC(C)(C)C',
#  'CC(C)=CCCCCC(C)O',
#  'CC(C)=CC=CC=C(C)C',
#  'CC(=O)C1CC1',
#  'CC(O)C=CC(C)(C)C',
#  'CC(C)(O)C=CC1CC1',
#  'C=CCC',
#  'CC(C)=CC=CC(C)(C)O',
#  'CC(C)=CC=CC(C)(C)O',
#  'CC(C)(C)C1CC1',
#  'CC(=O)C=CCCC(C)O',
#  'CC(=CCCC(C)(C)O)CCC(C)(C)O',
#  'C=CC1CC1',
#  'CC(=O)CCC1CC1',
#  'CC(C)=CC=CC1CC1',
#  'CC(=O)C(C)(C)O',
#  'CCC(C)=O',
#  'CC(C)(C)C1CC1',
#  'CC(C)(O)C=CC1CC1',
#  'CC(=O)C=CC=CC1CC1',
#  'CC(=O)CCCCc1cc(C(C)O)c[nH]1',
#  'CC(C)(C)C=CC(C)(C)O',
#  'CC(O)C(C)(C)C',
#  'CC(C)=Cc1cc(C=CC(C)(C)O)c[nH]1',
#  'CC(C)(C)C1CC1',
#  'CC(C)=CC1CC1',
#  'CC(C)=CC(C)(C)C',
#  'CC(=O)C(C)(C)O',
#  'CC(C)(O)C1CC1',
#  'CC(=O)C(C)=CC1CC1',
#  'CC(O)C1CC1',
#  'CC(C=O)=CC(C)(C)O',
#  'CC(=O)CCC=C(C)C(C)=O',
#  'CCC=C(C)C',
#  'CC(C)(C)CCC(C)(C)O',
#  'CC(C)=CC=CC=C(C)C',
#  'CC(C)(C)C(C)(C)O',
#  'CC(=CC(C)O)CCC(C)(C)O',
#  'CC(=CC(C)O)C(C)(C)C',
#  'CC(C)=CC1CC1',
#  'CCO',
#  'CC(C)=CC=CC(C)(C)O',
#  'CC(=O)C=C(C)C',
#  'CC(=O)C=C(C)C(C)=O',
#  'CCC(C)(C)O',
#  'CC(O)CCC(C)(C)O',
#  'CC(=O)CCC=CC(C)(C)O',
#  'CC(=CC(C)(C)C)C(C)(C)C',
#  'CC(=O)CCCCC(C)(C)C',
#  'CC(=O)CCC(C)=CC1CC1',
#  'CC(C)=CCCC=CC(C)O',
#  'CC(=O)C=CC=CC=C(C)C',
#  'CCC=CC1CC1',
#  'CCO',
#  'CC(=O)CCCCC(C)(C)O',
#  'CC(O)C(C)(C)O',
#  'CC(C)=CC=C(C)CCC(C)(C)C',
#  'CC(C)(C)C(C)(C)O',
#  'C=CC(C)(C)O',
#  'CC(C)(O)CCCCCCC(C)(C)O',
#  'CC(C)=CC(C)(C)O',
#  'CC(=O)C=CC(C)O',
#  'CC(C)(C)C(C)(C)C',
#  'CC(C)=CC=CC(C)(C)O',
#  'CC(C)(C)C(C)(C)O',
#  'CC(C)=Cc1cc(CCC(C)(C)O)c[nH]1',
#  'CC(=O)C(C)(C)C',
#  'C=C(C)CCC(C)O',
#  'CC(=O)C=C(C)c1cc(C(C)O)c[nH]1',
#  'CC(=CC=CC(C)(C)O)C(C)O',
#  'CC(C)(O)CCCCC1CC1',
#  'CC',
#  'CC(C)=CC1CC1',
#  'CC(C)=CC=CC(C)(C)C',
#  'CC(=O)C(C)=CC=CC(C)(C)O',
#  'CC(C)(C)C=CCCC(C)(C)O',
#  'CC(=O)c1cc(CCc2cc(C(C)O)c[nH]2)c[nH]1',
#  'CC(=CC(C)(C)C)C(C)(C)O',
#  'CC(C)=CCCC1CC1',
#  'CC(=O)C=C(C)C(C)=CC=C(C)C',
#  'CC(=O)C=CCCC(C)O',
#  'C=C',
#  'CC(=O)CCC(C)(C)O',
#  'CC(O)C1CC1',
#  'CC(O)CCCCC(C)(C)C',
#  'CC(C)=CC=C(C)CCC=C(C)C(C)(C)C',
#  'CC(=O)C=CCCC(C)(C)C',
#  'CC(C)(C)C(C)(C)O',
#  'CC(C)=CC=CC(C)O',
#  'CC(=O)C=C(C)C(C)(C)C',
#  'CC(=CCCC(C)(C)O)C(C)(C)C',
#  'CC(=O)CCCCC(C)(C)C',
#  'CC(=O)C1CC1',
#  'CC(=O)C=C(C)C(C)(C)C',
#  'CC(C)(O)C(C)(C)O',
#  'CC(C)C',
#  'CC(=O)C(C)=Cc1cc(C(C)=O)c[nH]1',
#  'CC(C)(C)C=CC1CC1',
#  'CC(=O)C=CC(C)(C)O',
#  'CC(=O)C(C)(C)C',
#  'CC(=O)C=CC(C)(C)C',
#  'CC=O',
#  'CC(C)=Cc1c[nH]c(CCCCC(C)O)c1',
#  'CC(C)=CC=C(C)C1CC1',
#  'CC(C)=CC(C)(C)O',
#  'CCc1cc[nH]c1',
#  'C=C(C)C1CC1',
#  'CC(=O)C=CC(C)=O',
#  'CC(=O)CCC(C)O',
#  'CC(C)=CC(C)(C)O',
#  'C=C(C)C',
#  'CC',
#  'C1CC1',
#  'C=CCC',
#  'CC(C)=CCCC=CC(C)O',
#  'CC(C)O',
#  'CC(=O)C(C)=O',
#  'CC(=O)CCC=C(C)C',
#  'CC(=O)CCC=C(C)C(C)(C)O',
#  'CC(=O)C(C)(C)O',
#  'CC(C)=CCCC(C)(C)C',
#  'CC(=CC(C)(C)O)CCC(C)(C)O',
#  'CC(C)(O)CCc1c[nH]c(C(C)(C)O)c1',
#  'CC(=O)CCC(C)O',
#  'CC(=O)C(C)=CC(C)(C)C',
#  'CC(=CC(C)(C)C)C(C)O',
#  'CC(=O)CCC=CC=CC(C)O',
#  'CC(C)=CCCc1cc(C(C)O)c[nH]1',
#  'CC=CCCC(C)=O',
#  'CC(C)=CC=C(C)CCc1c[nH]c(C(C)O)c1',
#  'CC(C)(C)c1ccc[nH]1',
#  'CC(C)=CCCC=C(C)C',
#  'CC(C)(C)C1CC1',
#  'CC',
#  'C=CC(C)(C)C',
#  'CC(=O)C=CCCC1CC1',
#  'CC(C)=CC=C(C)C1CC1',
#  'CC(C)(C)C(C)(C)O',
#  'C1CC1',
#  'CC(O)C(C)(C)O',
#  'CC(=CC(C)(C)C)C(C)(C)C',
#  'CC(=O)C=CC1CC1',
#  'CC(=O)C(C)=CC=C(C)C',
#  'CC(=O)CCc1cc(C(C)=O)c[nH]1',
#  'CC(=CC(C)(C)C)CCC(C)O',
#  'CC(C)(O)C=CC=CCCC(C)(C)C',
#  'CC(C)(C)C1CC1',
#  'CC=CCC',
#  'CC(=O)C=C(C)CCCCC=C(C)C',
#  'CC(C)=CC=C(C)C=C(C)C=C(C)C',
#  'CCO',
#  'CC',
#  'CC(C)(O)C=CC1CC1',
#  'CC(=O)CCC=CC=CC(C)(C)C',
#  'CC(=O)CCCCC(C)(C)C',
#  'CC(O)CCC=CC1CC1',
#  'CC(C=CC(C)O)=CC(C)(C)C',
#  'CC(=O)C=C(C)C(C)(C)O',
#  'CC(C)=CC=CCCC=CC(C)O',
#  'CC(=O)C=CC(C)(C)C',
#  'CC(=O)CCC(C)(C)C',
#  'CC(C)=CC=C(C)C1CC1',
#  'CC(C)=CC(C)(C)O',
#  'CC(O)CCC(C)(C)O',
#  'CC(=O)CCC(C)O',
#  'CCC(C)(C)C',
#  'CC(C)=CC=C(C)C=C(C)C(C)O',
#  'CC(=O)C(C)(C)O',
#  'CC(=O)CCC(C)(C)O',
#  'CC(C)(C)C=CC(C)(C)O',
#  'CC(=O)C(C)(C)C',
#  'CCc1c[nH]c(C(C)=O)c1',
#  'CC(C)(C)C(C)(C)C',
#  'CC(=CC(C)O)C(C)(C)O',
#  'CC(C)=CC(C)(C)O',
#  'CC(C)=CCCC(C)(C)O',
#  'C=C(C)CCC(C)(C)O',
#  'CC(C)(O)C1CC1',
#  'CCC=CC=CC(C)O',
#  'CC(C)O',
#  'CC',
#  'CC(=O)CCC=C(C)C(C)(C)O',
#  'CC(=O)C(C)O',
#  'CC(=O)C=C(C)C(C)(C)O',
#  'CC(=O)CCC(C)(C)O',
#  'CC(C)=CC(C)(C)C',
#  'CC(=O)C=C(C)C=C(C)C(C)(C)O',
#  'CC(=O)CCC(C)O',
#  'CC(=O)C=C(C)C',
#  'CC(=O)C1CC1',
#  'CC(C)=CC(C)(C)C',
#  'CC(=O)C=CC=C(C)C',
#  'CC(O)CCCCCCC(C)(C)O',
#  'CC(O)C=CC1CC1',
#  'C=CC',
#  'CC(=O)CCC=C(C)C',
#  'CC(O)C=CC(=O)O',
#  'CC(C)=CC1CC1',
#  'CC(=O)CCC=C(C)C',
#  'CC(O)CCCCC(C)(C)C',
#  'C1CC1',
#  'CCO',
#  'CC(=Cc1cc(C(C)(C)C)c[nH]1)CCc1c[nH]c(C(C)(C)O)c1',
#  'CC',
#  'CC(=O)CCC(C)O',
#  'C=CC',
#  'CC(C)=CC=CC=C(C)CCC(C)(C)C',
#  'CC(=O)C1CC1',
#  'CC(=O)C=CC(C)(C)O',
#  'CC(C)=CC=C(C)C(C)(C)C',
#  'CC(C)C',
#  'CCC(C)O',
#  'CC(=O)C(C)=O',
#  'CC(C)C',
#  'CC',
#  'CC(C)(O)C(C)(C)O',
#  'CC(O)CCC(C)(C)O',
#  'CCCC(C)=O',
#  'CCC(C)=O',
#  'CC(C)(C)C1CC1',
#  'CC(C)=CC=C(C)C',
#  'CC',
#  'CC(O)CCC(C)O',
#  'CC(=O)C=C(C)C',
#  'CC(C)=CCCCCC1CC1',
#  'CC(=O)C=C(C)CCCCC(C)O',
#  'CC(O)CCC(C)O',
#  'C=C(C)C',
#  'CC(C)=CC=CC=CC=C(C)C',
#  'CC(C)(C)C1CC1',
#  'CC(O)c1c[nH]c(CCC=CC=CC(C)(C)O)c1',
#  'CC(C)(O)C1CC1',
#  'CCC=C(C)C',
#  'CC(C)=CC(C)O',
#  'CC(C)=CCCC(C)O',
#  'CC(=O)CCC1CC1',
#  'CC(=O)CCCCC=C(C)C',
#  'C=C(C)C(C)(C)C',
#  'CC(C)C(C)(C)O',
#  'CC(=O)C(C)=O',
#  'CC(=O)CCC(C)O',
#  'CC(C)(C)C(C)(C)O',
#  'CC(C=CC1CC1)=CC(C)(C)O',
#  'CC(=O)CCC(C)(C)C',
#  'CC(=CC=Cc1cc(CCC(C)(C)O)c[nH]1)C(C)(C)C',
#  'CC(O)CCCCCCC(C)(C)O',
#  'CC(C=CCCC(C)(C)C)=CC(C)(C)C',
#  'CCC(C)=O',
#  'CC(=O)C(C)O',
#  'CC(O)C(C)(C)C',
#  'CC(C)C',
#  'CC(=O)C(C)=CC=CC(C)(C)C',
#  'CC(C)=CC(C)(C)C',
#  'C=CC',
#  'CC(=O)CCCCC=CC(C)(C)O',
#  'CC(O)C1CC1',
#  'C=C(C)C1CC1',
#  'CC(C)(C)C1CC1',
#  'CC(=O)CCC(C)(C)C',
#  'CC(=O)CCC1CC1',
#  'CC(C)=Cc1cc(C(C)O)c[nH]1',
#  'CC(C)O',
#  'CC(C)=CC(C)O',
#  'CC(O)CCC1CC1',
#  'CC(=O)CCC=C(C)C',
#  'CC(=O)C=CC(C)=O',
#  'CC(C)(C)C(C)(C)C',
#  'CC(C)(C)CCCCC1CC1',
#  'CC(=O)CCC=CC(C)(C)O',
#  'CC(=CC(C)(C)O)C(C)(C)C',
#  'CC(=O)C=C(C)C(C)(C)C',
#  'CC(C)=CCCc1cc(C(C)O)c[nH]1',
#  'CC(=O)C=CC=CC(C)(C)C',
#  'CC(C)=CC=C(C)CCC(C)(C)O',
#  'CC(=O)C=CC=C(C)C',
#  'CC(C)(C)CCc1cc(C(C)(C)C)c[nH]1',
#  'CC(=O)C=CC(C)(C)C',
#  'CC(C)=CC=C(C)C=C(C)C=C(C)C',
#  'CC(C)=CC(C)(C)C',
#  'CC(C)=CCCC(C)O',
#  'C=C(C)CC',
#  'CC(=O)C=CCCC(C)(C)O',
#  'CC(=O)C=Cc1cc(C(C)=O)c[nH]1',
#  'CC(C)(C)c1c[nH]c(C=CC2CC2)c1',
#  'CC(=O)C=CCCC=C(C)C',
#  'CC(=O)CCC(C)(C)O',
#  'CC(=O)C=C(C)C(C)=CC(C)=CCCC(C)=O',
#  'CC(C)=CC=C(C)C=C(C)C(C)O',
#  'CC(=O)C=CC(C)=CC=C(C)C',
#  'CC(=CC=O)C(C)(C)C',
#  'C=C(C)C=C(C)C',
#  'CC(=O)C=CC(C)O',
#  'C=Cc1c[nH]c(C(C)=O)c1',
#  'CC(C)(O)C(C)(C)O',
#  'CC(=CC(C)(C)C)C(C)(C)O',
#  'CC(C)(C)CCCCC(C)(C)O',
#  'CC(=O)C=C(C)C1CC1',
#  'CC(C)=CC1CC1',
#  'CC(=O)C=CC(C)=O',
#  'CC=O',
#  'CC(=CC(C)(C)C)C(C)(C)C',
#  'CC(C)=CCCCCCCC(C)(C)C',
#  'CC(C)=CCCC(C)(C)C',
#  'CC(O)C(C)(C)C',
#  'CC(C=CC(C)(C)C)=CC(C)(C)O',
#  'CC(C)=Cc1c[nH]c(C(C)(C)C)c1',
#  'CC(=O)C=CC(C)O',
#  'C=CC',
#  'CC(C)=CC(C)O',
#  'CC(C)(C)C(C)(C)C',
#  'CC(C)=CCCC=C(C)C',
#  'CC',
#  'CC(C)(C)C(C)(C)O',
#  'CC(=O)C(C)=CC1CC1',
#  'CC(C)(C)C=CC(C)(C)C',
#  'CC(C)(C)C(C)(C)C',
#  'C1CC1C1CC1',
#  'CC(C)=CCCC(C)=CC=CC(C)(C)C',
#  'CC(C)=CC(C)=CCCC1CC1',
#  'CC(=O)C=C(C)C',
#  'CCO',
#  'CC(C)(O)C(C)(C)O',
#  'CCCCc1ccc[nH]1',
#  'CC(O)CCCCC(C)(C)O',
#  'CC(=O)C(C)(C)O',
#  'C=CC=CC1CC1',
#  'CC(C)=CCCC(C)C',
#  'C=C(C)C=C(C)C(C)O',
#  'CC(=O)C=CC=CC=CC(C)(C)C',
#  'CC=O',
#  'CC(C)=CCCC(C)(C)C',
#  'C=CC=C(C)C=C(C)C',
#  'CCC=CC(C)(C)C',
#  'CC(O)C1CC1',
#  'C=C',
#  'CC(=O)C=CC(C)(C)O',
#  'CC(=O)CCC=C(C)C',
#  'CC(=O)CCC=CCCC(C)(C)C',
#  'CC(=O)C(C)O',
#  'CC(C)(O)C1CC1',
#  'CC(C)(O)C1CC1',
#  'CC(=O)C(C)(C)O',
#  'CC(C)=CCCC1CC1',
#  'CC(C)=CC=CC(C)(C)C',
#  'CC(=O)c1c[nH]c(C(C)O)c1',
#  'C=CC(C)=O',
#  'CCC(C)=O',
#  'CC(C)(C)C1CC1',
#  'C=C',
#  'CC(=O)C=CC=C(C)C=C(C)C',
#  'CC=Cc1ccc[nH]1',
#  'CC(=CC(C)(C)O)CCC(C)O',
#  'CC(=O)C(C)(C)O',
#  'CC(C)=CC(C)(C)C',
#  'CC(C)(C)CCC(C)(C)C',
#  'CC(O)CCCCC1CC1',
#  'C=CC',
#  'CC(C)(C)C(C)(C)O',
#  'CC(C)=CC(C)(C)O',
#  'CC(C)(O)CCC1CC1',
#  'CC(C)=CCCC(C)O',
#  'C=CC(C)(C)O',
#  'CC(C)(C)CCC(C)(C)O',
#  'CC(C)(C)CCC(C)(C)O',
#  'C1CC1',
#  'CC(C)=CC=CC=C(C)C',
#  'CCCCc1ccc[nH]1',
#  'CC=O',
#  'CC(=O)CCC(C)(C)C',
#  'CC(C)(C)C(C)(C)O',
#  'CC(O)C(C)O',
#  'C1CC1',
#  'CC(C)(C)C=CCCC=CC(C)(C)O',
#  'CC(=O)CCc1cc(C(C)(C)C)c[nH]1',
#  'CC(=CC(C)(C)O)C1CC1',
#  'CC(=O)C(C)=CC1CC1',
#  'CC(C)=CCCC(C)(C)O',
#  'CC(=O)CCC=C(C)C',
#  'CC(=O)C=CC(C)=CC1CC1',
#  'CC(=O)c1cc(CCC(C)O)c[nH]1',
#  'CC(=O)C(C)(C)O',
#  'CC(C)=CC(C)(C)O',
#  'CC(=O)CCC=CC(C)(C)O',
#  'CC(C)(C)C=Cc1c[nH]c(C(C)(C)O)c1',
#  'CC(C)=CC=CC=CCCC=C(C)C',
#  'CC(C)=CC=CC=C(C)C',
#  'CC(=O)C=C(C)C=CC=C(C)C',
#  'CC(=CC(C)O)C(C)O',
#  'CC(=O)C(C)O',
#  'CC(=O)C=CC(C)O',
#  'CC(C)=CC=C(C)C',
#  'CC(C)=CC(C)(C)C',
#  'CC(C)=CC(C)=CCCC(C)O',
#  'CC(=O)C1CC1',
#  'CC(C)=CC=CC=C(C)C',
#  'C=CCC',
#  'CCCC',
#  'CCC(C)(C)O',
#  'CC(=O)C(C)(C)C',
#  'CC(C)O',
#  'CC(=O)C=C(C)C',
#  'CC(O)C(C)(C)O',
#  'CC(C)=CC=CC(C)(C)O',
#  'CC(C)=CC=CCCC(C)=CC(C)=CC(C)(C)O',
#  'C=C',
#  'CC(C)=CC(C)(C)C',
#  'CC',
#  'CC(=CC(C)(C)C)C=C(C)C(C)(C)O',
#  'CC(=O)c1c[nH]c(-c2cc(C=C(C)C)c[nH]2)c1',
#  'CC(=O)CCC1CC1',
#  'CC(=O)C1CC1',
#  'CC(=O)C=CCCC(C)=O',
#  'CC(=CC(C)(C)C)C1CC1',
#  'CC(=O)CCC(C)O',
#  'CC(=O)C=CC=CC1CC1',
#  'CC(C)O',
#  'CC(C)=CC(C)(C)O',
#  'CC(=O)C(C)=CC=C(C)C',
#  'CC(C)(C)c1ccc[nH]1',
#  'CCC1CC1',
#  'CC(=O)C(C)=O',
#  'CC(=O)C(C)=O',
#  'CC(C)=CC1CC1',
#  'CC(C)=CC=C(C)CCC(C)=CC(C)(C)O',
#  'C=CC=C(C)C',
#  'CC(O)CCC(C)(C)C',
#  'CC(O)c1c[nH]c(C(C)(C)O)c1',
#  'CC(O)CCC(C)O',
#  'CC(=CC1CC1)C(C)O',
#  'CC(C)=CC(C)(C)C',
#  'CC(C)=CC=C(C)C1CC1',
#  'CC(C)C',
#  'CC(C)=CC=C(C)C=C(C)C(C)O',
#  'CC(=O)CCC(C)=CC(C)(C)O',
#  'CC(C)=CC(C)O',
#  'CC(O)C1CC1',
#  'CC(=O)CCC1CC1',
#  'CC(=O)CCC(C)(C)O',
#  'CC(O)C(C)(C)O',
#  'CC(O)CCC=CC1CC1',
#  'C=C(C)C',
#  'CC(C)C',
#  'CC(=O)C=C(C)C(C)=O',
#  'CC(C)=CC(C)=CC=O',
#  'CC(C)(O)C1CC1',
#  'CC',
#  'CC(C)(O)c1c[nH]c(C=O)c1',
#  'CC(=O)C=C(C)C',
#  'CC(=O)C(C)(C)C',
#  'CC(O)C1CC1',
#  'CC(=O)C=CC(C)(C)O',
#  'CC(=CC(C)(C)O)C(C)=CC(C)(C)O',
#  'CC(=O)CCCCC(C)=O',
#  'CC(C)=CC=Cc1cc(C=C(C)C)c[nH]1',
#  'CC(=O)C(C)(C)C',
#  'C=CC',
#  'CC(C)(C)C(C)(C)C',
#  'CC(=O)CCC(C)=CC(C)(C)C',
#  'CC(O)C=CC=O',
#  'CC(C)O',
#  'CC(C)O',
#  'CC(=O)CCC=C(C)C',
#  'CC=O',
#  'CC(=O)c1c[nH]c(C2CC2)c1',
#  'C(=CC1CC1)CCC1CC1',
#  'CC(=O)CCCCC(C)O',
#  'CC(=O)C=CC=O',
#  'CC(C=CCCC(C)(C)C)=CC(C)(C)C',
#  'C=C(C)CC',
#  'CC',
#  'CC(C)C',
#  'CC(=O)C(C)=CCCC=CC=CC(C)(C)C',
#  'CC(=O)CCC=CC=C(C)C',
#  'CC(=O)C=C(C)C',
#  'CC(C)=CC1CC1',
#  'CC(=O)C(C)O',
#  'CC(=O)C=CC=CC(C)(C)O',
#  'C',
#  'CC',
#  'CC(O)C(C)(C)C',
#  'CCC(C)O',
#  'CC(=O)C=C(C)C=CC=C(C)C',
#  'CC(C)=CC=C(C)CCC(C)(C)C',
#  'C=C(C)C(C)(C)C',
#  'CC(C=CC(C)(C)C)=CC(C)=Cc1cc(C(C)O)c[nH]1',
#  'CC(=O)CCC=C(C)C',
#  'CC(=O)CCC=C(C)C',
#  'CC(=O)C=CCCC(C)(C)O',
#  'CC(C)=CC=CCCC(C)(C)C',
#  'CC(C)(O)CCC(C)(C)O',
#  'CC(C)(C)C=CC(C)(C)O',
#  'CC(O)C(C)(C)O',
#  'CC(=O)C=C(C)C',
#  'CC(=O)C(C)=O',
#  'CC(C)=CC=C(C)C',
#  'CC(C)=CC=CC1CC1',
#  'CC(=O)C=CC=CCCc1cc(C(C)=O)c[nH]1',
#  'CC(C)=CC(C)(C)C',
#  'CC(O)CCC(C)(C)C',
#  'CC(O)C=CC=CC(C)(C)C',
#  'CC',
#  'CC(=O)C=CC=C(C)C',
#  'CC(C)C',
#  'CC(=O)C(C)(C)O',
#  'CC(=O)C=C(C)C(C)O',
#  'CC(=O)C(C)(C)C',
#  'C=CCC',
#  'CC(=O)C=CCCC=CC=C(C)C',
#  'CC(C)(O)CCC(C)(C)O',
#  'CC(=O)CCC1CC1',
#  'C=CC',
#  'CC(C)=CC(C)(C)O',
#  'C=C',
#  'CC(=O)CCC(C)(C)O',
#  'CC(=O)C=C(C)C',
#  'CC(=O)CCC(C)O',
#  'O=C(O)c1cc(C2CC2)c[nH]1',
#  'CC(=O)C=C(C)C(C)(C)C',
#  'CCC(C)=O',
#  'CC(O)C1CC1',
#  'C=C(C)C(C)O',
#  'CC(=O)C(C)=CC(C)=CC=C(C)C',
#  'CC(C)(C)C=CC(C)(C)C',
#  'CC(=CC(C)(C)O)C(C)O',
#  'CC(=CC(C)(C)O)C(C)O',
#  'C=CC1CC1',
#  'C=CC(C)(C)C',
#  'CC(O)C=CC(C)O',
#  'CC(C)(C)CCCCC(C)(C)C',
#  'CC(C)(O)C=CC(C)(C)O',
#  'CC(=O)CCc1cc(C(C)(C)O)c[nH]1',
#  'CCC=CC(C)(C)O',
#  'CC(=O)CCC(C)(C)O',
#  'CC(C)=CCCC1CC1',
#  'CC=CC=CCCC(C)(C)C',
#  'CC(=O)C(C)O',
#  'CC(C)=CCCC(C)(C)C',
#  'CC(O)C1CC1',
#  'CC(O)C=CC=CC1CC1',
#  'CC(=O)C(C)=CC=CC=C(C)C',
#  'CC(C)=CC(C)(C)O',
#  'CC(C)(C)CCC(C)(C)C',
#  'CC(=O)C(C)(C)C',
#  'CC=O',
#  'CC(=O)C=C(C)CCC(C)O',
#  'CCC(C)(C)C',
#  'C=C',
#  'CC(C)=CCCC=C(C)C=O',
#  'CC(=O)C=CCCC(C)(C)O',
#  'CC(C)=CCCC(C)(C)O',
#  'CC(=O)CCC(C)(C)O',
#  'CC(C)=CC=CCCC(C)O',
#  'CC(=O)C=CC(C)(C)O',
#  'CC(C)C',
#  'CC(C)=CC(C)(C)O',
#  'CC(C)C',
#  'C=C(C)CC',
#  'CC(C=CC(C)(C)O)=CC(C)(C)O',
#  'CC(C)C',
#  'CC(C)(C)C(C)(C)C',
#  'CC(O)C=CC1CC1',
#  'CC(=O)C1CC1',
#  'CC(=O)CCC(C)(C)O',
#  'CC(C)=CCCC(C)(C)O',
#  'CC(=O)C=CC=C(C)C',
#  'CC(=O)CCCCC(C)O',
#  'CC(=O)C=CCCC(C)(C)O',
#  'C=C(C)C=CC',
#  'CCC(C)=O',
#  'CC(=O)C=C(C)C(C)=O',
#  'CC(C)=CCCCCC(C)(C)O',
#  'CC(C)(C)CCC(C)(C)O',
#  'CC(C)=CC(C)(C)O',
#  'CC(=O)C(C)=CC(C)O',
#  'CCCC',
#  'CC(O)C1CC1',
#  'C(CCC1CC1)CC1CC1',
#  'CC(=O)C=CC(C)(C)O',
#  'CC(C)=CCCC(C)=CC(C)(C)C',
#  'CC(C)=Cc1c[nH]c(C=CC(C)(C)O)c1',
#  'CC',
#  'CC=O',
#  'CC(C)(O)CCC1CC1',
#  'CC(=O)CCC(C)(C)C',
#  'C=C(C)C(C)O',
#  'CC(O)C(C)(C)O',
#  'CC(C=CC(C)(C)C)=CC(C)(C)O',
#  'CC(=O)C=C(C)C(C)=O',
#  'CC(=O)CCC(C)(C)O',
#  'CC',
#  'CC(=O)C=CC(C)O',
#  'CC(C)(O)C1CC1',
#  'CC(=O)C(C)(C)O',
#  'CCC=C(C)C(C)(C)C',
#  'CC(O)CCC(C)(C)C',
#  'CC(=O)CCC=C(C)C(C)(C)O',
#  'CC(C)(C)C=CC1CC1',
#  'CC(=O)CCC=CC(C)(C)C',
#  'CC(=O)C1CC1',
#  'CC(C)=CC=CC(C)=CC(C)(C)C',
#  'CC(C)=CCCCCC=C(C)C',
#  'CC(C)=CCCC1CC1',
#  'C=C',
#  'CC(C)=CCCC=CC1CC1',
#  'CC(C)=CC=CC=C(C)C',
#  'CC(=O)CCC=CC1CC1',
#  'CC(C)=CC=C(C)C',
#  'CC(=O)C(C)(C)O',
#  'C=C(C)C=C(C)C=CC',
#  'CC(=O)C=CC1CC1',
#  'CC(=O)CCC(C)(C)O',
#  'CC(=O)C=CC=C(C)C',
#  'CC',
#  'CC(C)=CC(C)O',
#  'CC(O)CCC(C)O',
#  'CC(=O)C=C(C)C',
#  'CC(=O)C(C)=CC=CC(C)O',
#  'CC(=O)C=C(C)C=C(C)C(C)=O',
#  'CC(C)=CC(C)=CCCC(C)O',
#  'CCC(C)=O',
#  'CC(C)(C)CCCCC(C)(C)C',
#  'CC(O)CCC1CC1',
#  'C=CC(C)(C)C',
#  'CC(C)=CC=CC(C)=CC(C)O',
#  'CC(=O)C=C(C)CCC(C)=CC=C(C)C',
#  'CC(=O)C(C)O',
#  'CC(=O)C=CCCC(C)(C)O',
#  'CC(=O)C=CC(C)(C)C',
#  'C=C',
#  'CC(C)=CC(C)=CC1CC1',
#  'CC(C)(C)C(C)(C)O',
#  'CC',
#  'CC(C)(C)C(C)(C)C',
#  'CC(C)(C)C=Cc1cc(C(C)(C)O)c[nH]1',
#  'CC(C)=CC=CCCC(C)(C)O',
#  'CCC=C(C)C',
#  'CC(=O)C=CC1CC1',
#  'CC(=O)C=C(C)C=C(C)C(C)=O',
#  'CC(C)(O)C=CCCCCC(C)(C)O',
#  'CC(C)(C)C(C)(C)C',
#  'CC(C)=CC(C)=CC(C)=CC(C)(C)O',
#  'CC(C)=CC=C(C)CCc1cc(C(C)(C)O)c[nH]1',
#  'CC(=O)C1CC1',
#  'CC(=O)CCC(C)=O',
#  'CC(=O)C(C)=CC(C)(C)C',
#  'CC(C)(O)CCC1CC1',
#  'CC(C)C',
#  'CC(=CC=CC(C)(C)C)C(C)O',
#  'CC(=O)C(C)(C)O',
#  'CC(=O)C1CC1',
#  'CC(=O)C=C(C)C',
#  'CC(C)=CC(C)(C)O',
#  'CC',
#  'CC(C)C',
#  'CC(=O)CCC(C)(C)C',
#  'CC(C)=CC(C)(C)O',
#  'CC(O)C(C)(C)C',
#  'CC(=O)c1c[nH]c(C=C(C)C=C(C)C)c1',
#  'CC(=CC=CC(C)(C)O)C(C)O',
#  'CC(=O)C=CCCC=C(C)C',
#  'CC(C)=CC=CC(C)O',
#  'CC(C)=CCCC(C)O',
#  'CC(C)(C)CCC(C)(C)O',
#  'C=C',
#  'CC(C)=CC(C)O',
#  'C=C(C)C',
#  'CC(O)CCC(C)(C)O',
#  'CC(C)=CC1CC1',
#  'CC(=O)CCC(C)(C)C',
#  'CC(C)=CC=CC=CCCC(C)(C)C',
#  'CC(C)=Cc1cc(C=CC(C)O)c[nH]1',
#  'C=C',
#  'CC(C)(C)C=CC(C)(C)O',
#  'CC(C)(C)c1c[nH]c(C(C)(C)O)c1',
#  'CC(=O)c1cc(C(C)(C)C)c[nH]1',
#  'C=C(C)C(C)O',
#  'CC(C)=CC=CC(C)(C)O',
#  'CC(C)=Cc1c[nH]c(C(C)(C)C)c1',
#  'CC(C)=CC(C)(C)C',
#  'CC(C)(O)C=CC(C)(C)O',
#  'CC(=O)CCCCC(C)(C)O',
#  'CC(C)=CC(C)(C)C',
#  'CC(C)=CC=C(C)CCC(C)O',
#  'CC(=O)C=C(C)C',
#  'C=C(C)CC',
#  'CC(O)CCC(C)(C)C',
#  'C1CC1',
#  'CC(C)=CC=C(C)C(C)(C)O',
#  'CC(C)=CC=CC(C)=CCCC(C)O',
#  'CC(C)=CCCC(C)=CC(C)=CC(C)(C)C',
#  'CC(=O)CCC(C)=CC(C)=CC(C)O',
#  'CC(=O)C(C)=CC(C)(C)C',
#  'C=C(C)C',
#  'CC(=O)CCCCC=C(C)C',
#  'CC',
#  'CC(C)=CC=CC=C(C)C',
#  'CC(C)(C)C1CC1',
#  'CC(=O)C=C(C)C=C(C)C1CC1',
#  'CC(=CC1CC1)C=C(C)C(C)(C)O',
#  'C=C(C)C=C(C)C=C(C)C=CC',
#  'CC(C)=CC=CCCC1CC1',
#  'CC(=O)CCC(C)=O',
#  'CC(=O)C(C)(C)O',
#  'CC(C)=CC1CC1',
#  'CC(C)=CC(C)(C)C',
#  'CC(C)O',
#  'CC(=O)C=CCCCCCCC(C)=O',
#  'CC(=O)C=CC(C)(C)C',
#  'C=CC(C)=O',
#  'CC(=O)CCC=C(C)C',
#  'CC(=O)C(C)=O',
#  'CC(C)=CC(C)O',
#  'CC(C)=CC=C(C)c1c[nH]c(C(C)(C)O)c1',
#  'CC(=O)CCC(C)O',
#  'CC(=O)C=C(C)C',
#  'CC(=O)CCCCC(C)(C)C',
#  'CC(=O)CCC=C(C)C',
#  'CC(C)=CCCC(C)O',
#  'CC(=O)C=CC=C(C)C',
#  'CC(=O)C(C)(C)C',
#  'C=C(C)C=CC',
#  'CC(=O)C=C(C)C(C)(C)C',
#  'CC(=CC(C)(C)C)C(C)(C)C',
#  'C=C',
#  'CC(=O)C=CCCC=C(C)C(C)(C)O',
#  'C=C',
#  'CC(=O)CCC(C)(C)O',
#  'CC(O)C=CC(C)(C)C',
#  'CCC1CC1',
#  'CC(=O)CCCCC(C)=O',
#  'CC(C)=CC=CCCC(C)O',
#  'CC(C)(O)C=O',
#  'CC(=O)CCC(C)(C)C',
#  'CC(C)(C)CCC(C)(C)C',
#  'CC(C)(C)CCC(C)(C)O',
#  'CC(C)(C)C1CC1',
#  'C=C(C)C',
#  'CC(C)=CC(C)=CC1CC1',
#  'CC(=O)CCC=CCCC(C)(C)C',
#  'C=C(C)C',
#  'CC(=CC(C)(C)O)CCC=CC(C)O',
#  'CC(C)=CC=CC(C)(C)C',
#  'CC(C)(C)C=CC(C)(C)O',
#  'CC(O)C1CC1',
#  'CC(=O)CCC(C)=CC(C)(C)O',
#  'CC(C)=CC1CC1',
#  'CC(=O)C(C)(C)O',
#  'CC(=O)C(C)=O',
#  'C=CC',
#  'CC(=O)C=CC=CC=C(C)C',
#  'CC(C)(O)C1CC1',
#  'CC(C)(O)CCCCC1CC1',
#  'CC(O)C(C)O',
#  'CC(=O)CCC1CC1',
#  'CC(=O)C(C)O',
#  'CC(=O)C(C)=CC=C(C)C',
#  'CC(=O)C=C(C)CCC(C)O',
#  'C=CCC',
#  'C1CC1',
#  'CC(=O)C(C)O',
#  'CC=O',
#  'CC',
#  'CC(=CC(C)O)CCC(C)(C)O',
#  'CC(=O)C=CC(C)(C)O',
#  'CC(C)=CC=CC=C(C)C',
#  'CC(C)(C)C1CC1',
#  'CC(=O)C=CCCCCC(C)=O',
#  'C1CC1C1CC1',
#  'CC(C)(C)C1C(C(C)(C)C)C(C(C)(C)O)C(C(C)(C)C)C(C(C)(C)O)C1C(C)(C)C',
#  'C=C(C)C(C)(C)O',
#  'CC(=O)C(C)=O',
#  'CC(=O)C=CC(C)(C)O',
#  'CC(=O)C(C)O',
#  'CC(C)=CC=Cc1cc(C=CC(C)(C)C)c[nH]1',
#  'CC(C)(C)CCC=CCCC1CC1',
#  'CC(C)(C)CCC1CC1',
#  'CC(=O)C=CC=C(C)C',
#  'CC(C)(C)C(C)(C)O',
#  'CC(C)(C)CCC(C)(C)O',
#  'CC(C)=CC=CCCC(C)(C)C',
#  'CC(=O)C(C)(C)C',
#  'CC(C)=CCCC=CC(C)(C)O',
#  'CC(C)=CC=CC(C)=CC(C)(C)C',
#  'CC(=CCCC(C)(C)C)C(C)=CC(C)(C)C',
#  'CC(C)(C)C(C)(C)O',
#  'CC(=CC(C)O)CCCCC=CC(C)(C)O',
#  'CC(C)=CC=CC(C)=CC=C(C)C',
#  'CC(C)=CC=Cc1cc(C(C)(C)O)c[nH]1',
#  'CC(=O)c1c[nH]c(C(C)=CC(C)(C)C)c1',
#  'CC(C)(O)C=CC1CC1',
#  'CC(=O)C=C(C)C(C)=O',
#  'CC(=CC(C)O)C(C)(C)C',
#  'CC(=CC(C)O)c1cc(C(C)(C)O)c[nH]1',
#  'CC(O)CCC(C)(C)C',
#  'CC(=O)C=C(C)C=C(C)C(C)(C)C',
#  'CC(C)(C)c1cc(-c2ccc[nH]2)c[nH]1',
#  'CC',
#  'CC=O',
#  'CC(=CC(C)O)C1CC1',
#  'CC(C)=CC(C)=CC(C)O',
#  'CC(=O)C(C)=CC(C)=CC(C)(C)O',
#  'CC(=O)CCC(C)(C)C',
#  'CC(C)=CC(C)O',
#  'CC(=O)CCC(C)(C)O',
#  'CC=CCC',
#  'CC(C)=CC=C(C)C1CC1',
#  'CC(=O)C=CC=C(C)C',
#  'CCO',
#  'CC(=O)CCCCC1CC1',
#  'CC',
#  'CC(C)=Cc1cc(C(C)(C)O)c[nH]1',
#  'CC(C)=CCCC(C)(C)O',
#  'CC(O)C(C)(C)O',
#  'CC(O)CCC(C)(C)C',
#  'CC(=O)CCC(C)(C)O',
#  'CC(=O)CCC=C(C)C',
#  'CC(=O)C(C)(C)O',
#  'CC(C)(C)C(C)(C)O',
#  'CCC=CC(C)(C)C',
#  'CC(O)C=CC(C)(C)O',
#  'CC(C)=CCCC=C(C)C',
#  'CC(C)=CC=CC(C)(C)O',
#  'CC(=O)C=C(C)C=C(C)C(C)(C)O',
#  'CC(=O)CCC(C)=O',
#  'CC(O)C=CC(C)O',
#  'CC(=O)C=C(C)c1c[nH]c(C2CC2)c1',
#  'CC(C)=CC(C)O',
#  'CC(O)c1c[nH]c(C(C)(C)O)c1',
#  'CCC(C)(C)C',
#  'CC(C)(C)C=CC(C)(C)O',
#  'CC(C)(C)C=CC(C)(C)C',
#  'CC(C)=CC(C)(C)C',
#  'CC',
#  'CC(=O)C=CC(C)(C)C',
#  'CC(C)=CCCC(C)=CCCC(C)O',
#  'CC(=O)C(C)(C)O',
#  'CC(O)c1cc(CCC=CC(C)(C)O)c[nH]1',
#  'CC(C)=CC=C(C)C',
#  'CC(C=CC(C)(C)O)=CC1CC1',
#  'CC(O)C1CC1',
#  'CC(O)CCCCC(C)O',
#  'CC(C)(C)CCC=Cc1cc(C(C)(C)O)c[nH]1',
#  'CC(C)=CC=CC(C)=CC(C)O',
#  'CCCCC=C(C)C',
#  'CC(=O)CCC(C)O',
#  'CC(=O)C(C)=CC1CC1',
#  'CC(=O)C=CC=CCCC(C)(C)C',
#  'CC(C)(C)C(C)(C)O',
#  'CC(C)(C)C=CC(C)(C)O',
#  'CC(C)=CC=CC=CC=CC(C)(C)C',
#  'CC(C)=CC=C(C)C=C(C)C',
#  'CC(C)(C)C(=O)[O-]']
