# %% [markdown]
# # Run Vanilla

# %%
import sys
import os
path_to_top_dir = "../"
# Dynamically add the `project` directory to the path
sys.path.append(os.path.abspath(path_to_top_dir))

# %%
os.path.abspath(path_to_top_dir)
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model'

# %%
# Print current working directory
os.getcwd()
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model\\runs'

# %%
# Import scent_gfn functions
from scent_gfn.fragments import FRAGMENTS, FRAGMENTS_OPENPOM_DATASET, FRAGMENTS_OPENPOM_VANILLA
from scent_gfn.molecule import MoleculeTrainer
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# Skipped loading some PyTorch models, missing a dependency. No module named 'tensorflow'
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)

# %% [markdown]
# | **Parameter**                | **Value**      |
# |------------------------------|----------------|
# | Reward function type         | OpenPOM        |
# | Similarity measure           | Cosine         |
# | Graph building               | Vanilla Fragments      |
# | Iterations                   | 500            |
# | Max number of nodes          | 6              |
# | Illegal action logreward     | -100           |
# | β                            | 1              |
# | Large molecule penalty       | None           |

# %%
params = {
    "save_name": "vanilla1",
    "reward_func": "openpom", # structure, openpom
    "similarity": "cosine",
    "graph_building": FRAGMENTS_OPENPOM_VANILLA,#FRAGMENTS,
    "iterations": 500,
    "max_nodes": 6,
    "illegal_logreward": -100,
    "beta": 1.0,
    "large_mol_pen": [None,None]# ["exponential", 15] # ["exponential", 15] , ["hard", 15], [None,None]
}

# %%
# Utilities
import warnings
import random
import datetime

# Data processing and file management
import pathlib
import pandas as pd
import json
import numpy as np

# Machine learning
import torch
from gflownet.config import init_empty, Config
from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage, MolToImage


# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Run on cpu
dev = torch.device('cpu')

# %%
def get_pine_openpom_target():
    with open('../data/pine_target_2.json', 'r') as file:
        target = json.load(file)
    return [target]

# %%
def get_vanilla_test_and_training(split_ratio=0.7):
    df = pd.read_csv("../data/data.csv")
    vanilla_mols_df = df.loc[df['vanilla'] == 1]
    vanilla_smiles_trainig= list(vanilla_mols_df["nonStereoSMILES"])
    vanilla_smiles_trainig = random.sample(vanilla_smiles_trainig, round(len(vanilla_mols_df)*split_ratio))
    random.shuffle(vanilla_smiles_trainig)
    vanilla_smiles_test = []
    for i in vanilla_mols_df["nonStereoSMILES"]:
        if i not in vanilla_smiles_trainig:
            vanilla_smiles_test.append(i)
    return vanilla_smiles_trainig, vanilla_smiles_test

def get_vanillin():
    return ["COc1cc(C=O)ccc1O"]

# %%
target = get_vanillin()

# %%
# Initialize model
config = init_empty(Config())
config.print_every = 1
config.log_dir = f"{os.path.abspath(path_to_top_dir)}/results/{params['save_name']}_{datetime.datetime.now().strftime('%Y-%m-%d__%H_%M_%S')}"
config.device = dev
config.num_training_steps = params["iterations"]
config.num_workers = 0
config.num_validation_gen_steps = 1
config.overwrite_existing_exp=False
config.checkpoint_every = 100
config.algo.max_nodes = params["max_nodes"] #12 # 95 quantil
config.store_all_checkpoints = True
config.algo.illegal_action_logreward = params["illegal_logreward"]

if params["graph_building"] == None:
     trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]), print_config=True) #,fragments=FRAGMENTS, print_config=True)
else:
    trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]),fragments=params["graph_building"], print_config=True) #,fragments=FRAGMENTS, print_config=True)
# Out:
# SMILES input data detected ...
# Reward function: reward_function_openpom | Similarity measure: cosine_similarity | exp_penalty: False | max_mol=None
# Building molecules using fragments ...
#
#
# Hyperparameters:
#
# desc: noDesc
# log_dir: c:\Users\paulj\Desktop\prosjekt\pom_cpu-model/results/vanilla1_2024-12-03__18_44_11
# device: cpu
# seed: 0
# validate_every: 1000
# checkpoint_every: 100
# store_all_checkpoints: true
# print_every: 1
# start_at_step: 0
# num_final_gen_steps: null
# num_validation_gen_steps: 1
# num_training_steps: 500
# num_workers: 0
# hostname: null
# pickle_mp_messages: false
# git_hash: f106cde
# overwrite_existing_exp: false
# algo:
#   method: TB
#   num_from_policy: 64
#   num_from_dataset: 0
#   valid_num_from_policy: 64
#   valid_num_from_dataset: 0
#   max_len: 128
#   max_nodes: 6
#   max_edges: 128
#   illegal_action_logreward: -100.0
#   train_random_action_prob: 0.0
#   train_det_after: null
#   valid_random_action_prob: 0.0
#   sampling_tau: 0.9
#   tb:
#     bootstrap_own_reward: false
#     epsilon: null
#     reward_loss_multiplier: 1.0
#     variant: TB
#     do_correct_idempotent: false
#     do_parameterize_p_b: false
#     do_predict_n: false
#     do_sample_p_b: false
#     do_length_normalize: false
#     subtb_max_len: 128
#     Z_learning_rate: 0.0001
#     Z_lr_decay: 50000.0
#     cum_subtb: true
#     loss_fn: MSE
#     loss_fn_par: 1.0
#     n_loss: none
#     n_loss_multiplier: 1.0
#     backward_policy: Uniform
#   moql:
#     gamma: 1.0
#     num_omega_samples: 32
#     num_objectives: 2
#     lambda_decay: 10000
#     penalty: -10.0
#   a2c:
#     entropy: 0.01
#     gamma: 1.0
#     penalty: -10.0
#   fm:
#     epsilon: 1.0e-38
#     balanced_loss: false
#     leaf_coef: 10.0
#     correct_idempotent: false
#   sql:
#     alpha: 0.01
#     gamma: 1.0
#     penalty: -10.0
# model:
#   num_layers: 3
#   num_emb: 128
#   dropout: 0.0
#   graph_transformer:
#     num_heads: 2
#     ln_type: pre
#     num_mlp_layers: 0
#     concat_heads: true
#   seq_transformer:
#     num_heads: 2
#     posenc: Rotary
# opt:
#   opt: adam
#   learning_rate: 0.0001
#   lr_decay: 20000.0
#   weight_decay: 1.0e-08
#   momentum: 0.9
#   clip_grad_type: norm
#   clip_grad_param: 10.0
#   adam_eps: 1.0e-08
# replay:
#   use: false
#   capacity: null
#   warmup: null
#   hindsight_ratio: 0.0
#   num_from_replay: null
#   num_new_samples: null
# task:
#   qm9:
#     h5_path: ./data/qm9/qm9.h5
#     model_path: ./data/qm9/qm9_model.pt
#   qm9_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - gap
#     - qed
#     - sa
#     online_pareto_front: true
#   seh:
#     reduced_frag: false
#   seh_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - seh
#     - qed
#     - sa
#     - mw
#     log_topk: false
#     online_pareto_front: true
# cond:
#   valid_sample_cond_info: true
#   temperature:
#     sample_dist: uniform
#     dist_params:
#     - 0.5
#     - 32
#     num_thermometer_dim: 32
#   moo:
#     num_objectives: 2
#     num_thermometer_dim: 16
#   weighted_prefs:
#     preference_type: dirichlet
#     preference_param: 1.5
#   focus_region:
#     focus_type: centered
#     use_steer_thermomether: false
#     focus_cosim: 0.98
#     focus_limit_coef: 0.1
#     focus_model_training_limits:
#     - 0.25
#     - 0.75
#     focus_model_state_space_res: 30
#     max_train_it: 20000

# %%
trial.run()
# Out:
# 03/12/2024 18:44:25 - INFO - logger - Starting training
# 03/12/2024 18:44:34 - INFO - logger - iteration 1 : offline_loss:0.00 online_loss:675.38 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.19 loss:675.38 n_loss:0.00 tb_loss:675.38 batch_entropy:23.34 traj_lens:10.77 grad_norm:212.60 grad_norm_clip:64.07 sampled_reward_avg:0.65 train_time:1.65 time_spent:9.30
# 03/12/2024 18:44:46 - INFO - logger - iteration 2 : offline_loss:0.00 online_loss:710.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.16 loss:710.68 n_loss:0.00 tb_loss:710.68 batch_entropy:28.84 traj_lens:12.17 grad_norm:411.99 grad_norm_clip:68.38 sampled_reward_avg:0.68 train_time:1.98 time_spent:11.46
# 03/12/2024 18:44:55 - INFO - logger - iteration 3 : offline_loss:0.00 online_loss:851.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.12 loss:851.34 n_loss:0.00 tb_loss:851.34 batch_entropy:23.80 traj_lens:10.77 grad_norm:269.39 grad_norm_clip:63.97 sampled_reward_avg:0.62 train_time:1.42 time_spent:9.33
# 03/12/2024 18:45:04 - INFO - logger - iteration 4 : offline_loss:0.00 online_loss:687.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.09 loss:687.60 n_loss:0.00 tb_loss:687.60 batch_entropy:26.05 traj_lens:11.28 grad_norm:234.31 grad_norm_clip:65.74 sampled_reward_avg:0.65 train_time:1.49 time_spent:9.20
# 03/12/2024 18:45:13 - INFO - logger - iteration 5 : offline_loss:0.00 online_loss:799.49 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.05 loss:799.49 n_loss:0.00 tb_loss:799.49 batch_entropy:23.83 traj_lens:10.67 grad_norm:319.97 grad_norm_clip:66.74 sampled_reward_avg:0.62 train_time:1.44 time_spent:9.12
# 03/12/2024 18:45:23 - INFO - logger - iteration 6 : offline_loss:0.00 online_loss:566.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.02 loss:566.33 n_loss:0.00 tb_loss:566.33 batch_entropy:24.94 traj_lens:11.05 grad_norm:270.79 grad_norm_clip:66.47 sampled_reward_avg:0.68 train_time:1.53 time_spent:9.34
# 03/12/2024 18:45:32 - INFO - logger - iteration 7 : offline_loss:0.00 online_loss:576.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.02 loss:576.71 n_loss:0.00 tb_loss:576.71 batch_entropy:23.77 traj_lens:10.39 grad_norm:262.96 grad_norm_clip:66.42 sampled_reward_avg:0.66 train_time:1.51 time_spent:8.95
# 03/12/2024 18:45:42 - INFO - logger - iteration 8 : offline_loss:0.00 online_loss:636.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.05 loss:636.71 n_loss:0.00 tb_loss:636.71 batch_entropy:26.57 traj_lens:11.66 grad_norm:245.76 grad_norm_clip:65.75 sampled_reward_avg:0.66 train_time:1.85 time_spent:10.04
# 03/12/2024 18:45:51 - INFO - logger - iteration 9 : offline_loss:0.00 online_loss:547.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.09 loss:547.64 n_loss:0.00 tb_loss:547.64 batch_entropy:23.75 traj_lens:10.62 grad_norm:253.35 grad_norm_clip:66.02 sampled_reward_avg:0.66 train_time:1.37 time_spent:8.96
# 03/12/2024 18:45:59 - INFO - logger - iteration 10 : offline_loss:0.00 online_loss:611.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.12 loss:611.16 n_loss:0.00 tb_loss:611.16 batch_entropy:22.52 traj_lens:10.02 grad_norm:312.27 grad_norm_clip:66.20 sampled_reward_avg:0.66 train_time:1.16 time_spent:8.21
# 03/12/2024 18:46:07 - INFO - logger - iteration 11 : offline_loss:0.00 online_loss:502.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.16 loss:502.99 n_loss:0.00 tb_loss:502.99 batch_entropy:25.36 traj_lens:11.19 grad_norm:342.32 grad_norm_clip:66.54 sampled_reward_avg:0.68 train_time:1.39 time_spent:8.29
# 03/12/2024 18:46:16 - INFO - logger - iteration 12 : offline_loss:0.00 online_loss:322.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.19 loss:322.25 n_loss:0.00 tb_loss:322.25 batch_entropy:27.79 traj_lens:12.08 grad_norm:280.15 grad_norm_clip:65.68 sampled_reward_avg:0.74 train_time:1.81 time_spent:9.01
# 03/12/2024 18:46:26 - INFO - logger - iteration 13 : offline_loss:0.00 online_loss:425.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.23 loss:425.55 n_loss:0.00 tb_loss:425.55 batch_entropy:31.74 traj_lens:13.02 grad_norm:380.50 grad_norm_clip:68.20 sampled_reward_avg:0.73 train_time:1.74 time_spent:9.32
# 03/12/2024 18:46:35 - INFO - logger - iteration 14 : offline_loss:0.00 online_loss:517.38 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.26 loss:517.38 n_loss:0.00 tb_loss:517.38 batch_entropy:31.42 traj_lens:13.02 grad_norm:381.34 grad_norm_clip:67.97 sampled_reward_avg:0.71 train_time:1.67 time_spent:9.26
# 03/12/2024 18:46:44 - INFO - logger - iteration 15 : offline_loss:0.00 online_loss:375.97 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.30 loss:375.97 n_loss:0.00 tb_loss:375.97 batch_entropy:30.27 traj_lens:12.73 grad_norm:298.52 grad_norm_clip:66.44 sampled_reward_avg:0.74 train_time:1.61 time_spent:9.17
# 03/12/2024 18:46:54 - INFO - logger - iteration 16 : offline_loss:0.00 online_loss:440.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.33 loss:440.29 n_loss:0.00 tb_loss:440.29 batch_entropy:34.09 traj_lens:13.86 grad_norm:300.87 grad_norm_clip:67.05 sampled_reward_avg:0.74 train_time:1.97 time_spent:9.89
# 03/12/2024 18:47:03 - INFO - logger - iteration 17 : offline_loss:0.00 online_loss:361.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.37 loss:361.70 n_loss:0.00 tb_loss:361.70 batch_entropy:32.74 traj_lens:13.53 grad_norm:363.79 grad_norm_clip:67.13 sampled_reward_avg:0.77 train_time:1.85 time_spent:9.49
# 03/12/2024 18:47:13 - INFO - logger - iteration 18 : offline_loss:0.00 online_loss:399.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.40 loss:399.29 n_loss:0.00 tb_loss:399.29 batch_entropy:30.63 traj_lens:12.88 grad_norm:272.55 grad_norm_clip:65.62 sampled_reward_avg:0.73 train_time:1.66 time_spent:9.66
# 03/12/2024 18:47:23 - INFO - logger - iteration 19 : offline_loss:0.00 online_loss:375.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.44 loss:375.31 n_loss:0.00 tb_loss:375.31 batch_entropy:33.44 traj_lens:13.67 grad_norm:315.87 grad_norm_clip:66.29 sampled_reward_avg:0.75 train_time:1.94 time_spent:9.70
# 03/12/2024 18:47:32 - INFO - logger - iteration 20 : offline_loss:0.00 online_loss:502.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.48 loss:502.32 n_loss:0.00 tb_loss:502.32 batch_entropy:30.80 traj_lens:12.92 grad_norm:401.38 grad_norm_clip:67.03 sampled_reward_avg:0.70 train_time:1.86 time_spent:9.16
# 03/12/2024 18:47:41 - INFO - logger - iteration 21 : offline_loss:0.00 online_loss:437.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.51 loss:437.88 n_loss:0.00 tb_loss:437.88 batch_entropy:30.22 traj_lens:12.73 grad_norm:347.73 grad_norm_clip:68.07 sampled_reward_avg:0.71 train_time:1.65 time_spent:8.96
# 03/12/2024 18:47:51 - INFO - logger - iteration 22 : offline_loss:0.00 online_loss:505.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.55 loss:505.76 n_loss:0.00 tb_loss:505.76 batch_entropy:32.67 traj_lens:13.16 grad_norm:367.87 grad_norm_clip:68.23 sampled_reward_avg:0.73 train_time:1.79 time_spent:9.74
# 03/12/2024 18:48:00 - INFO - logger - iteration 23 : offline_loss:0.00 online_loss:621.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.59 loss:621.11 n_loss:0.00 tb_loss:621.11 batch_entropy:34.45 traj_lens:13.86 grad_norm:341.82 grad_norm_clip:67.51 sampled_reward_avg:0.73 train_time:1.90 time_spent:9.39
# 03/12/2024 18:48:09 - INFO - logger - iteration 24 : offline_loss:0.00 online_loss:535.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.63 loss:535.99 n_loss:0.00 tb_loss:535.99 batch_entropy:32.70 traj_lens:13.48 grad_norm:368.94 grad_norm_clip:66.61 sampled_reward_avg:0.71 train_time:1.84 time_spent:9.30
# 03/12/2024 18:48:19 - INFO - logger - iteration 25 : offline_loss:0.00 online_loss:548.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.66 loss:548.05 n_loss:0.00 tb_loss:548.05 batch_entropy:33.73 traj_lens:13.62 grad_norm:408.49 grad_norm_clip:67.31 sampled_reward_avg:0.72 train_time:1.86 time_spent:9.82
# 03/12/2024 18:48:29 - INFO - logger - iteration 26 : offline_loss:0.00 online_loss:372.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.70 loss:372.68 n_loss:0.00 tb_loss:372.68 batch_entropy:33.21 traj_lens:13.58 grad_norm:346.92 grad_norm_clip:66.53 sampled_reward_avg:0.75 train_time:1.90 time_spent:9.60
# 03/12/2024 18:48:38 - INFO - logger - iteration 27 : offline_loss:0.00 online_loss:288.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.74 loss:288.32 n_loss:0.00 tb_loss:288.32 batch_entropy:33.09 traj_lens:13.67 grad_norm:311.49 grad_norm_clip:66.24 sampled_reward_avg:0.76 train_time:1.87 time_spent:9.66
# 03/12/2024 18:48:48 - INFO - logger - iteration 28 : offline_loss:0.00 online_loss:322.91 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.78 loss:322.91 n_loss:0.00 tb_loss:322.91 batch_entropy:34.34 traj_lens:14.05 grad_norm:424.50 grad_norm_clip:67.61 sampled_reward_avg:0.75 train_time:1.95 time_spent:9.95
# 03/12/2024 18:48:59 - INFO - logger - iteration 29 : offline_loss:0.00 online_loss:459.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.82 loss:459.29 n_loss:0.00 tb_loss:459.29 batch_entropy:36.05 traj_lens:14.28 grad_norm:492.06 grad_norm_clip:70.00 sampled_reward_avg:0.76 train_time:2.02 time_spent:10.28
# 03/12/2024 18:49:08 - INFO - logger - iteration 30 : offline_loss:0.00 online_loss:463.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.85 loss:463.15 n_loss:0.00 tb_loss:463.15 batch_entropy:33.69 traj_lens:13.91 grad_norm:308.66 grad_norm_clip:65.98 sampled_reward_avg:0.75 train_time:1.95 time_spent:9.56
# 03/12/2024 18:49:18 - INFO - logger - iteration 31 : offline_loss:0.00 online_loss:435.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.89 loss:435.71 n_loss:0.00 tb_loss:435.71 batch_entropy:34.96 traj_lens:14.14 grad_norm:350.85 grad_norm_clip:67.09 sampled_reward_avg:0.75 train_time:2.03 time_spent:9.91
# 03/12/2024 18:49:29 - INFO - logger - iteration 32 : offline_loss:0.00 online_loss:518.66 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.93 loss:518.66 n_loss:0.00 tb_loss:518.66 batch_entropy:36.64 traj_lens:14.47 grad_norm:324.81 grad_norm_clip:66.26 sampled_reward_avg:0.73 train_time:2.27 time_spent:10.52
# 03/12/2024 18:49:41 - INFO - logger - iteration 33 : offline_loss:0.00 online_loss:353.91 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.97 loss:353.91 n_loss:0.00 tb_loss:353.91 batch_entropy:37.71 traj_lens:15.03 grad_norm:350.54 grad_norm_clip:66.95 sampled_reward_avg:0.76 train_time:2.46 time_spent:12.26
# 03/12/2024 18:49:52 - INFO - logger - iteration 34 : offline_loss:0.00 online_loss:444.43 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.01 loss:444.43 n_loss:0.00 tb_loss:444.43 batch_entropy:35.17 traj_lens:14.14 grad_norm:360.71 grad_norm_clip:67.46 sampled_reward_avg:0.75 train_time:1.91 time_spent:10.78
# 03/12/2024 18:50:02 - INFO - logger - iteration 35 : offline_loss:0.00 online_loss:382.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.05 loss:382.26 n_loss:0.00 tb_loss:382.26 batch_entropy:38.76 traj_lens:15.17 grad_norm:345.12 grad_norm_clip:66.33 sampled_reward_avg:0.78 train_time:2.11 time_spent:10.43
# 03/12/2024 18:50:12 - INFO - logger - iteration 36 : offline_loss:0.00 online_loss:412.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.09 loss:412.40 n_loss:0.00 tb_loss:412.40 batch_entropy:37.91 traj_lens:14.94 grad_norm:334.78 grad_norm_clip:66.93 sampled_reward_avg:0.76 train_time:2.02 time_spent:10.10
# 03/12/2024 18:50:22 - INFO - logger - iteration 37 : offline_loss:0.00 online_loss:424.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.12 loss:424.93 n_loss:0.00 tb_loss:424.93 batch_entropy:32.53 traj_lens:13.02 grad_norm:367.54 grad_norm_clip:67.58 sampled_reward_avg:0.75 train_time:1.74 time_spent:9.90
# 03/12/2024 18:50:33 - INFO - logger - iteration 38 : offline_loss:0.00 online_loss:366.73 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.16 loss:366.73 n_loss:0.00 tb_loss:366.73 batch_entropy:37.92 traj_lens:14.94 grad_norm:385.32 grad_norm_clip:67.73 sampled_reward_avg:0.78 train_time:2.40 time_spent:10.51
# 03/12/2024 18:50:43 - INFO - logger - iteration 39 : offline_loss:0.00 online_loss:409.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.20 loss:409.77 n_loss:0.00 tb_loss:409.77 batch_entropy:37.43 traj_lens:14.80 grad_norm:351.10 grad_norm_clip:66.22 sampled_reward_avg:0.75 train_time:2.09 time_spent:10.70
# 03/12/2024 18:50:56 - INFO - logger - iteration 40 : offline_loss:0.00 online_loss:355.89 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.24 loss:355.89 n_loss:0.00 tb_loss:355.89 batch_entropy:37.66 traj_lens:14.84 grad_norm:393.98 grad_norm_clip:67.83 sampled_reward_avg:0.75 train_time:2.51 time_spent:12.35
# 03/12/2024 18:51:08 - INFO - logger - iteration 41 : offline_loss:0.00 online_loss:411.73 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.28 loss:411.73 n_loss:0.00 tb_loss:411.73 batch_entropy:41.75 traj_lens:16.06 grad_norm:436.53 grad_norm_clip:68.18 sampled_reward_avg:0.79 train_time:2.53 time_spent:12.16
# 03/12/2024 18:51:18 - INFO - logger - iteration 42 : offline_loss:0.00 online_loss:387.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.33 loss:387.08 n_loss:0.00 tb_loss:387.08 batch_entropy:40.21 traj_lens:15.64 grad_norm:385.19 grad_norm_clip:67.13 sampled_reward_avg:0.77 train_time:2.32 time_spent:10.60
# 03/12/2024 18:51:28 - INFO - logger - iteration 43 : offline_loss:0.00 online_loss:424.43 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.37 loss:424.43 n_loss:0.00 tb_loss:424.43 batch_entropy:37.78 traj_lens:14.80 grad_norm:403.15 grad_norm_clip:67.48 sampled_reward_avg:0.75 train_time:2.03 time_spent:10.06
# 03/12/2024 18:51:39 - INFO - logger - iteration 44 : offline_loss:0.00 online_loss:491.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.41 loss:491.79 n_loss:0.00 tb_loss:491.79 batch_entropy:38.44 traj_lens:14.89 grad_norm:405.37 grad_norm_clip:67.45 sampled_reward_avg:0.75 train_time:2.09 time_spent:10.47
# 03/12/2024 18:51:49 - INFO - logger - iteration 45 : offline_loss:0.00 online_loss:372.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.45 loss:372.79 n_loss:0.00 tb_loss:372.79 batch_entropy:39.29 traj_lens:15.36 grad_norm:458.15 grad_norm_clip:68.11 sampled_reward_avg:0.78 train_time:2.23 time_spent:10.48
# 03/12/2024 18:52:00 - INFO - logger - iteration 46 : offline_loss:0.00 online_loss:399.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.50 loss:399.69 n_loss:0.00 tb_loss:399.69 batch_entropy:40.79 traj_lens:15.64 grad_norm:507.88 grad_norm_clip:69.01 sampled_reward_avg:0.76 train_time:2.35 time_spent:10.64
# 03/12/2024 18:52:11 - INFO - logger - iteration 47 : offline_loss:0.00 online_loss:402.62 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.54 loss:402.62 n_loss:0.00 tb_loss:402.62 batch_entropy:41.12 traj_lens:15.83 grad_norm:418.61 grad_norm_clip:67.58 sampled_reward_avg:0.77 train_time:2.17 time_spent:11.03
# 03/12/2024 18:52:21 - INFO - logger - iteration 48 : offline_loss:0.00 online_loss:498.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.58 loss:498.87 n_loss:0.00 tb_loss:498.87 batch_entropy:39.33 traj_lens:15.12 grad_norm:372.85 grad_norm_clip:67.46 sampled_reward_avg:0.76 train_time:2.23 time_spent:10.20
# 03/12/2024 18:52:32 - INFO - logger - iteration 49 : offline_loss:0.00 online_loss:408.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.63 loss:408.25 n_loss:0.00 tb_loss:408.25 batch_entropy:41.49 traj_lens:15.88 grad_norm:478.12 grad_norm_clip:68.26 sampled_reward_avg:0.78 train_time:2.18 time_spent:10.63
# 03/12/2024 18:52:42 - INFO - logger - iteration 50 : offline_loss:0.00 online_loss:403.95 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.67 loss:403.95 n_loss:0.00 tb_loss:403.95 batch_entropy:41.39 traj_lens:15.83 grad_norm:436.54 grad_norm_clip:68.26 sampled_reward_avg:0.77 train_time:2.20 time_spent:10.52
# 03/12/2024 18:52:54 - INFO - logger - iteration 51 : offline_loss:0.00 online_loss:411.02 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.72 loss:411.02 n_loss:0.00 tb_loss:411.02 batch_entropy:42.13 traj_lens:16.11 grad_norm:421.13 grad_norm_clip:68.57 sampled_reward_avg:0.76 train_time:2.35 time_spent:11.32
# 03/12/2024 18:53:04 - INFO - logger - iteration 52 : offline_loss:0.00 online_loss:526.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.76 loss:526.41 n_loss:0.00 tb_loss:526.41 batch_entropy:42.22 traj_lens:15.97 grad_norm:437.12 grad_norm_clip:68.18 sampled_reward_avg:0.75 train_time:2.38 time_spent:10.62
# 03/12/2024 18:53:15 - INFO - logger - iteration 53 : offline_loss:0.00 online_loss:378.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.81 loss:378.13 n_loss:0.00 tb_loss:378.13 batch_entropy:40.47 traj_lens:15.59 grad_norm:366.78 grad_norm_clip:66.89 sampled_reward_avg:0.78 train_time:2.24 time_spent:10.65
# 03/12/2024 18:53:26 - INFO - logger - iteration 54 : offline_loss:0.00 online_loss:407.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.86 loss:407.60 n_loss:0.00 tb_loss:407.60 batch_entropy:42.63 traj_lens:16.16 grad_norm:490.54 grad_norm_clip:70.41 sampled_reward_avg:0.78 train_time:2.36 time_spent:11.07
# 03/12/2024 18:53:37 - INFO - logger - iteration 55 : offline_loss:0.00 online_loss:384.06 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.90 loss:384.06 n_loss:0.00 tb_loss:384.06 batch_entropy:41.65 traj_lens:16.06 grad_norm:443.78 grad_norm_clip:68.79 sampled_reward_avg:0.78 train_time:2.37 time_spent:10.92
# 03/12/2024 18:53:48 - INFO - logger - iteration 56 : offline_loss:0.00 online_loss:408.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.95 loss:408.69 n_loss:0.00 tb_loss:408.69 batch_entropy:42.41 traj_lens:16.11 grad_norm:449.66 grad_norm_clip:69.01 sampled_reward_avg:0.79 train_time:2.41 time_spent:10.69
# 03/12/2024 18:53:58 - INFO - logger - iteration 57 : offline_loss:0.00 online_loss:469.38 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.00 loss:469.38 n_loss:0.00 tb_loss:469.38 batch_entropy:42.45 traj_lens:16.11 grad_norm:454.92 grad_norm_clip:68.71 sampled_reward_avg:0.77 train_time:2.41 time_spent:10.69
# 03/12/2024 18:54:10 - INFO - logger - iteration 58 : offline_loss:0.00 online_loss:404.27 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.04 loss:404.27 n_loss:0.00 tb_loss:404.27 batch_entropy:42.71 traj_lens:16.34 grad_norm:433.52 grad_norm_clip:67.54 sampled_reward_avg:0.78 train_time:2.39 time_spent:11.36
# 03/12/2024 18:54:20 - INFO - logger - iteration 59 : offline_loss:0.00 online_loss:511.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.09 loss:511.19 n_loss:0.00 tb_loss:511.19 batch_entropy:42.43 traj_lens:16.11 grad_norm:539.81 grad_norm_clip:70.07 sampled_reward_avg:0.75 train_time:2.41 time_spent:10.67
# 03/12/2024 18:54:31 - INFO - logger - iteration 60 : offline_loss:0.00 online_loss:376.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.14 loss:376.10 n_loss:0.00 tb_loss:376.10 batch_entropy:39.65 traj_lens:15.17 grad_norm:393.82 grad_norm_clip:67.26 sampled_reward_avg:0.78 train_time:2.24 time_spent:10.53
# 03/12/2024 18:54:43 - INFO - logger - iteration 61 : offline_loss:0.00 online_loss:425.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.19 loss:425.69 n_loss:0.00 tb_loss:425.69 batch_entropy:44.32 traj_lens:16.72 grad_norm:457.43 grad_norm_clip:68.66 sampled_reward_avg:0.80 train_time:2.75 time_spent:11.90
# 03/12/2024 18:54:54 - INFO - logger - iteration 62 : offline_loss:0.00 online_loss:396.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.24 loss:396.14 n_loss:0.00 tb_loss:396.14 batch_entropy:42.58 traj_lens:16.20 grad_norm:468.50 grad_norm_clip:68.77 sampled_reward_avg:0.78 train_time:2.34 time_spent:10.70
# 03/12/2024 18:55:05 - INFO - logger - iteration 63 : offline_loss:0.00 online_loss:451.80 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.29 loss:451.80 n_loss:0.00 tb_loss:451.80 batch_entropy:42.04 traj_lens:15.92 grad_norm:408.94 grad_norm_clip:67.42 sampled_reward_avg:0.75 train_time:2.47 time_spent:11.54
# 03/12/2024 18:55:17 - INFO - logger - iteration 64 : offline_loss:0.00 online_loss:399.28 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.34 loss:399.28 n_loss:0.00 tb_loss:399.28 batch_entropy:43.63 traj_lens:16.58 grad_norm:584.49 grad_norm_clip:69.65 sampled_reward_avg:0.78 train_time:2.73 time_spent:12.35
# 03/12/2024 18:55:30 - INFO - logger - iteration 65 : offline_loss:0.00 online_loss:406.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.39 loss:406.87 n_loss:0.00 tb_loss:406.87 batch_entropy:43.10 traj_lens:16.39 grad_norm:476.92 grad_norm_clip:68.61 sampled_reward_avg:0.79 train_time:2.64 time_spent:12.14
# 03/12/2024 18:55:41 - INFO - logger - iteration 66 : offline_loss:0.00 online_loss:456.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.44 loss:456.84 n_loss:0.00 tb_loss:456.84 batch_entropy:42.94 traj_lens:16.30 grad_norm:471.51 grad_norm_clip:68.27 sampled_reward_avg:0.78 train_time:2.77 time_spent:11.70
# 03/12/2024 18:55:53 - INFO - logger - iteration 67 : offline_loss:0.00 online_loss:452.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.49 loss:452.98 n_loss:0.00 tb_loss:452.98 batch_entropy:42.50 traj_lens:16.11 grad_norm:430.08 grad_norm_clip:67.55 sampled_reward_avg:0.77 train_time:2.52 time_spent:11.47
# 03/12/2024 18:56:04 - INFO - logger - iteration 68 : offline_loss:0.00 online_loss:452.66 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.54 loss:452.66 n_loss:0.00 tb_loss:452.66 batch_entropy:42.77 traj_lens:16.20 grad_norm:449.39 grad_norm_clip:67.21 sampled_reward_avg:0.78 train_time:2.60 time_spent:11.36
# 03/12/2024 18:56:15 - INFO - logger - iteration 69 : offline_loss:0.00 online_loss:373.73 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.59 loss:373.73 n_loss:0.00 tb_loss:373.73 batch_entropy:41.35 traj_lens:15.69 grad_norm:506.59 grad_norm_clip:68.17 sampled_reward_avg:0.79 train_time:2.43 time_spent:10.78
# 03/12/2024 18:56:26 - INFO - logger - iteration 70 : offline_loss:0.00 online_loss:408.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.65 loss:408.36 n_loss:0.00 tb_loss:408.36 batch_entropy:43.38 traj_lens:16.25 grad_norm:615.11 grad_norm_clip:69.72 sampled_reward_avg:0.79 train_time:2.43 time_spent:11.13
# 03/12/2024 18:56:37 - INFO - logger - iteration 71 : offline_loss:0.00 online_loss:392.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.70 loss:392.26 n_loss:0.00 tb_loss:392.26 batch_entropy:42.37 traj_lens:16.06 grad_norm:707.27 grad_norm_clip:72.13 sampled_reward_avg:0.79 train_time:2.29 time_spent:10.86
# 03/12/2024 18:56:48 - INFO - logger - iteration 72 : offline_loss:0.00 online_loss:386.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.75 loss:386.72 n_loss:0.00 tb_loss:386.72 batch_entropy:43.56 traj_lens:16.58 grad_norm:524.35 grad_norm_clip:69.31 sampled_reward_avg:0.79 train_time:2.61 time_spent:11.01
# 03/12/2024 18:56:59 - INFO - logger - iteration 73 : offline_loss:0.00 online_loss:499.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.80 loss:499.40 n_loss:0.00 tb_loss:499.40 batch_entropy:43.62 traj_lens:16.39 grad_norm:446.00 grad_norm_clip:68.28 sampled_reward_avg:0.77 train_time:2.57 time_spent:10.76
# 03/12/2024 18:57:10 - INFO - logger - iteration 74 : offline_loss:0.00 online_loss:434.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.85 loss:434.19 n_loss:0.00 tb_loss:434.19 batch_entropy:42.77 traj_lens:15.97 grad_norm:447.27 grad_norm_clip:67.38 sampled_reward_avg:0.77 train_time:2.43 time_spent:11.04
# 03/12/2024 18:57:20 - INFO - logger - iteration 75 : offline_loss:0.00 online_loss:461.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.91 loss:461.09 n_loss:0.00 tb_loss:461.09 batch_entropy:43.80 traj_lens:16.39 grad_norm:487.81 grad_norm_clip:69.24 sampled_reward_avg:0.78 train_time:2.47 time_spent:10.71
# 03/12/2024 18:57:31 - INFO - logger - iteration 76 : offline_loss:0.00 online_loss:393.67 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.96 loss:393.67 n_loss:0.00 tb_loss:393.67 batch_entropy:43.37 traj_lens:16.25 grad_norm:458.19 grad_norm_clip:67.61 sampled_reward_avg:0.78 train_time:2.40 time_spent:10.71
# 03/12/2024 18:57:42 - INFO - logger - iteration 77 : offline_loss:0.00 online_loss:400.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.01 loss:400.78 n_loss:0.00 tb_loss:400.78 batch_entropy:43.08 traj_lens:16.06 grad_norm:546.56 grad_norm_clip:68.61 sampled_reward_avg:0.78 train_time:2.31 time_spent:11.03
# 03/12/2024 18:57:53 - INFO - logger - iteration 78 : offline_loss:0.00 online_loss:403.97 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.07 loss:403.97 n_loss:0.00 tb_loss:403.97 batch_entropy:45.01 traj_lens:16.81 grad_norm:582.35 grad_norm_clip:69.01 sampled_reward_avg:0.77 train_time:2.45 time_spent:10.90
# 03/12/2024 18:58:04 - INFO - logger - iteration 79 : offline_loss:0.00 online_loss:402.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.12 loss:402.84 n_loss:0.00 tb_loss:402.84 batch_entropy:43.46 traj_lens:16.16 grad_norm:511.33 grad_norm_clip:68.06 sampled_reward_avg:0.78 train_time:2.40 time_spent:10.80
# 03/12/2024 18:58:14 - INFO - logger - iteration 80 : offline_loss:0.00 online_loss:353.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.17 loss:353.82 n_loss:0.00 tb_loss:353.82 batch_entropy:40.83 traj_lens:15.50 grad_norm:485.81 grad_norm_clip:68.98 sampled_reward_avg:0.77 train_time:2.25 time_spent:10.44
# 03/12/2024 18:58:26 - INFO - logger - iteration 81 : offline_loss:0.00 online_loss:430.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.23 loss:430.93 n_loss:0.00 tb_loss:430.93 batch_entropy:45.84 traj_lens:16.86 grad_norm:537.91 grad_norm_clip:69.41 sampled_reward_avg:0.77 train_time:2.65 time_spent:11.56
# 03/12/2024 18:58:37 - INFO - logger - iteration 82 : offline_loss:0.00 online_loss:448.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.28 loss:448.87 n_loss:0.00 tb_loss:448.87 batch_entropy:43.78 traj_lens:16.34 grad_norm:441.95 grad_norm_clip:66.88 sampled_reward_avg:0.77 train_time:2.50 time_spent:10.92
# 03/12/2024 18:58:48 - INFO - logger - iteration 83 : offline_loss:0.00 online_loss:397.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.34 loss:397.77 n_loss:0.00 tb_loss:397.77 batch_entropy:44.23 traj_lens:16.58 grad_norm:591.88 grad_norm_clip:70.73 sampled_reward_avg:0.79 train_time:2.63 time_spent:11.09
# 03/12/2024 18:58:59 - INFO - logger - iteration 84 : offline_loss:0.00 online_loss:390.49 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.39 loss:390.49 n_loss:0.00 tb_loss:390.49 batch_entropy:44.87 traj_lens:16.86 grad_norm:515.87 grad_norm_clip:68.80 sampled_reward_avg:0.78 train_time:2.47 time_spent:11.33
# 03/12/2024 18:59:10 - INFO - logger - iteration 85 : offline_loss:0.00 online_loss:465.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.45 loss:465.69 n_loss:0.00 tb_loss:465.69 batch_entropy:45.24 traj_lens:16.67 grad_norm:507.27 grad_norm_clip:68.13 sampled_reward_avg:0.77 train_time:2.60 time_spent:10.99
# 03/12/2024 18:59:21 - INFO - logger - iteration 86 : offline_loss:0.00 online_loss:351.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.50 loss:351.90 n_loss:0.00 tb_loss:351.90 batch_entropy:43.00 traj_lens:16.30 grad_norm:564.70 grad_norm_clip:70.30 sampled_reward_avg:0.78 train_time:2.44 time_spent:10.77
# 03/12/2024 18:59:32 - INFO - logger - iteration 87 : offline_loss:0.00 online_loss:441.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.56 loss:441.99 n_loss:0.00 tb_loss:441.99 batch_entropy:44.70 traj_lens:16.72 grad_norm:453.74 grad_norm_clip:66.67 sampled_reward_avg:0.78 train_time:2.53 time_spent:11.19
# 03/12/2024 18:59:43 - INFO - logger - iteration 88 : offline_loss:0.00 online_loss:384.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.62 loss:384.24 n_loss:0.00 tb_loss:384.24 batch_entropy:43.20 traj_lens:15.97 grad_norm:676.42 grad_norm_clip:71.81 sampled_reward_avg:0.79 train_time:2.37 time_spent:10.63
# 03/12/2024 18:59:54 - INFO - logger - iteration 89 : offline_loss:0.00 online_loss:369.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.67 loss:369.30 n_loss:0.00 tb_loss:369.30 batch_entropy:44.23 traj_lens:16.58 grad_norm:518.50 grad_norm_clip:68.31 sampled_reward_avg:0.78 train_time:2.52 time_spent:11.13
# 03/12/2024 19:00:05 - INFO - logger - iteration 90 : offline_loss:0.00 online_loss:373.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.73 loss:373.09 n_loss:0.00 tb_loss:373.09 batch_entropy:44.80 traj_lens:16.81 grad_norm:518.18 grad_norm_clip:67.51 sampled_reward_avg:0.79 train_time:2.58 time_spent:11.44
# 03/12/2024 19:00:16 - INFO - logger - iteration 91 : offline_loss:0.00 online_loss:364.81 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.79 loss:364.81 n_loss:0.00 tb_loss:364.81 batch_entropy:44.00 traj_lens:16.48 grad_norm:535.46 grad_norm_clip:68.19 sampled_reward_avg:0.79 train_time:2.41 time_spent:10.74
# 03/12/2024 19:00:27 - INFO - logger - iteration 92 : offline_loss:0.00 online_loss:371.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.84 loss:371.46 n_loss:0.00 tb_loss:371.46 batch_entropy:44.31 traj_lens:16.53 grad_norm:481.96 grad_norm_clip:66.02 sampled_reward_avg:0.78 train_time:2.55 time_spent:11.03
# 03/12/2024 19:00:38 - INFO - logger - iteration 93 : offline_loss:0.00 online_loss:358.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.90 loss:358.53 n_loss:0.00 tb_loss:358.53 batch_entropy:43.53 traj_lens:16.34 grad_norm:539.28 grad_norm_clip:70.25 sampled_reward_avg:0.80 train_time:2.43 time_spent:11.20
# 03/12/2024 19:00:50 - INFO - logger - iteration 94 : offline_loss:0.00 online_loss:372.89 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.96 loss:372.89 n_loss:0.00 tb_loss:372.89 batch_entropy:45.51 traj_lens:17.00 grad_norm:549.28 grad_norm_clip:67.94 sampled_reward_avg:0.78 train_time:2.75 time_spent:11.60
# 03/12/2024 19:01:02 - INFO - logger - iteration 95 : offline_loss:0.00 online_loss:385.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.02 loss:385.36 n_loss:0.00 tb_loss:385.36 batch_entropy:44.98 traj_lens:16.62 grad_norm:629.14 grad_norm_clip:68.98 sampled_reward_avg:0.78 train_time:2.50 time_spent:12.02
# 03/12/2024 19:01:13 - INFO - logger - iteration 96 : offline_loss:0.00 online_loss:398.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.08 loss:398.31 n_loss:0.00 tb_loss:398.31 batch_entropy:45.52 traj_lens:16.81 grad_norm:555.70 grad_norm_clip:67.74 sampled_reward_avg:0.78 train_time:2.56 time_spent:11.08
# 03/12/2024 19:01:24 - INFO - logger - iteration 97 : offline_loss:0.00 online_loss:364.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.14 loss:364.86 n_loss:0.00 tb_loss:364.86 batch_entropy:43.74 traj_lens:16.30 grad_norm:580.07 grad_norm_clip:68.62 sampled_reward_avg:0.80 train_time:2.38 time_spent:11.31
# 03/12/2024 19:01:35 - INFO - logger - iteration 98 : offline_loss:0.00 online_loss:371.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.19 loss:371.59 n_loss:0.00 tb_loss:371.59 batch_entropy:44.50 traj_lens:16.53 grad_norm:505.39 grad_norm_clip:66.90 sampled_reward_avg:0.78 train_time:2.42 time_spent:10.80
# 03/12/2024 19:01:46 - INFO - logger - iteration 99 : offline_loss:0.00 online_loss:348.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.25 loss:348.11 n_loss:0.00 tb_loss:348.11 batch_entropy:44.30 traj_lens:16.58 grad_norm:522.13 grad_norm_clip:67.88 sampled_reward_avg:0.79 train_time:2.52 time_spent:11.03
# 03/12/2024 19:01:58 - INFO - logger - iteration 100 : offline_loss:0.00 online_loss:378.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.31 loss:378.05 n_loss:0.00 tb_loss:378.05 batch_entropy:45.41 traj_lens:16.81 grad_norm:560.89 grad_norm_clip:68.55 sampled_reward_avg:0.78 train_time:2.47 time_spent:11.43
# 03/12/2024 19:02:10 - INFO - logger - iteration 101 : offline_loss:0.00 online_loss:350.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.37 loss:350.19 n_loss:0.00 tb_loss:350.19 batch_entropy:44.39 traj_lens:16.67 grad_norm:606.53 grad_norm_clip:68.91 sampled_reward_avg:0.78 train_time:3.66 time_spent:12.29
# 03/12/2024 19:02:21 - INFO - logger - iteration 102 : offline_loss:0.00 online_loss:333.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.43 loss:333.54 n_loss:0.00 tb_loss:333.54 batch_entropy:44.82 traj_lens:16.91 grad_norm:566.81 grad_norm_clip:68.48 sampled_reward_avg:0.78 train_time:2.54 time_spent:11.00
# 03/12/2024 19:02:32 - INFO - logger - iteration 103 : offline_loss:0.00 online_loss:368.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.49 loss:368.88 n_loss:0.00 tb_loss:368.88 batch_entropy:45.90 traj_lens:16.95 grad_norm:652.69 grad_norm_clip:69.09 sampled_reward_avg:0.81 train_time:2.57 time_spent:11.31
# 03/12/2024 19:02:43 - INFO - logger - iteration 104 : offline_loss:0.00 online_loss:356.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.55 loss:356.00 n_loss:0.00 tb_loss:356.00 batch_entropy:45.36 traj_lens:16.81 grad_norm:629.00 grad_norm_clip:70.45 sampled_reward_avg:0.80 train_time:2.57 time_spent:10.89
# 03/12/2024 19:02:54 - INFO - logger - iteration 105 : offline_loss:0.00 online_loss:358.02 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.62 loss:358.02 n_loss:0.00 tb_loss:358.02 batch_entropy:45.48 traj_lens:16.86 grad_norm:534.95 grad_norm_clip:67.14 sampled_reward_avg:0.79 train_time:2.56 time_spent:10.88
# 03/12/2024 19:03:05 - INFO - logger - iteration 106 : offline_loss:0.00 online_loss:361.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.68 loss:361.71 n_loss:0.00 tb_loss:361.71 batch_entropy:45.61 traj_lens:16.81 grad_norm:564.98 grad_norm_clip:69.21 sampled_reward_avg:0.78 train_time:2.70 time_spent:11.37
# 03/12/2024 19:03:16 - INFO - logger - iteration 107 : offline_loss:0.00 online_loss:378.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.74 loss:378.72 n_loss:0.00 tb_loss:378.72 batch_entropy:45.99 traj_lens:16.81 grad_norm:609.51 grad_norm_clip:69.84 sampled_reward_avg:0.79 train_time:2.44 time_spent:10.92
# 03/12/2024 19:03:27 - INFO - logger - iteration 108 : offline_loss:0.00 online_loss:348.27 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.80 loss:348.27 n_loss:0.00 tb_loss:348.27 batch_entropy:45.35 traj_lens:16.86 grad_norm:523.88 grad_norm_clip:67.31 sampled_reward_avg:0.80 train_time:2.49 time_spent:10.88
# 03/12/2024 19:03:38 - INFO - logger - iteration 109 : offline_loss:0.00 online_loss:335.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.86 loss:335.21 n_loss:0.00 tb_loss:335.21 batch_entropy:44.09 traj_lens:16.44 grad_norm:582.61 grad_norm_clip:69.26 sampled_reward_avg:0.77 train_time:2.54 time_spent:11.22
# 03/12/2024 19:03:49 - INFO - logger - iteration 110 : offline_loss:0.00 online_loss:345.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.92 loss:345.40 n_loss:0.00 tb_loss:345.40 batch_entropy:45.29 traj_lens:16.81 grad_norm:603.48 grad_norm_clip:70.38 sampled_reward_avg:0.79 train_time:2.53 time_spent:11.06
# 03/12/2024 19:04:00 - INFO - logger - iteration 111 : offline_loss:0.00 online_loss:356.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.99 loss:356.59 n_loss:0.00 tb_loss:356.59 batch_entropy:45.33 traj_lens:16.72 grad_norm:533.57 grad_norm_clip:66.07 sampled_reward_avg:0.78 train_time:2.48 time_spent:10.91
# 03/12/2024 19:04:12 - INFO - logger - iteration 112 : offline_loss:0.00 online_loss:339.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.05 loss:339.64 n_loss:0.00 tb_loss:339.64 batch_entropy:45.52 traj_lens:17.00 grad_norm:629.28 grad_norm_clip:68.52 sampled_reward_avg:0.80 train_time:2.49 time_spent:11.27
# 03/12/2024 19:04:22 - INFO - logger - iteration 113 : offline_loss:0.00 online_loss:329.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.11 loss:329.34 n_loss:0.00 tb_loss:329.34 batch_entropy:44.71 traj_lens:16.62 grad_norm:607.23 grad_norm_clip:68.04 sampled_reward_avg:0.80 train_time:2.32 time_spent:10.72
# 03/12/2024 19:04:33 - INFO - logger - iteration 114 : offline_loss:0.00 online_loss:352.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:352.55 n_loss:0.00 tb_loss:352.55 batch_entropy:45.52 traj_lens:16.67 grad_norm:624.69 grad_norm_clip:69.12 sampled_reward_avg:0.79 train_time:2.52 time_spent:10.86
# 03/12/2024 19:04:45 - INFO - logger - iteration 115 : offline_loss:0.00 online_loss:398.28 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.24 loss:398.28 n_loss:0.00 tb_loss:398.28 batch_entropy:45.14 traj_lens:16.67 grad_norm:563.41 grad_norm_clip:69.35 sampled_reward_avg:0.77 train_time:2.54 time_spent:11.39
# 03/12/2024 19:04:56 - INFO - logger - iteration 116 : offline_loss:0.00 online_loss:355.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.30 loss:355.14 n_loss:0.00 tb_loss:355.14 batch_entropy:45.84 traj_lens:16.81 grad_norm:651.86 grad_norm_clip:69.79 sampled_reward_avg:0.77 train_time:2.54 time_spent:10.95
# 03/12/2024 19:05:06 - INFO - logger - iteration 117 : offline_loss:0.00 online_loss:337.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.37 loss:337.94 n_loss:0.00 tb_loss:337.94 batch_entropy:45.69 traj_lens:16.77 grad_norm:573.98 grad_norm_clip:67.59 sampled_reward_avg:0.80 train_time:2.52 time_spent:10.93
# 03/12/2024 19:05:17 - INFO - logger - iteration 118 : offline_loss:0.00 online_loss:346.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.43 loss:346.88 n_loss:0.00 tb_loss:346.88 batch_entropy:45.82 traj_lens:16.81 grad_norm:615.42 grad_norm_clip:68.30 sampled_reward_avg:0.79 train_time:2.48 time_spent:10.91
# 03/12/2024 19:05:29 - INFO - logger - iteration 119 : offline_loss:0.00 online_loss:309.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.50 loss:309.69 n_loss:0.00 tb_loss:309.69 batch_entropy:43.61 traj_lens:16.20 grad_norm:592.10 grad_norm_clip:68.71 sampled_reward_avg:0.80 train_time:2.42 time_spent:11.14
# 03/12/2024 19:05:40 - INFO - logger - iteration 120 : offline_loss:0.00 online_loss:351.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.56 loss:351.87 n_loss:0.00 tb_loss:351.87 batch_entropy:46.13 traj_lens:16.91 grad_norm:626.95 grad_norm_clip:70.02 sampled_reward_avg:0.79 train_time:2.60 time_spent:11.06
# 03/12/2024 19:05:51 - INFO - logger - iteration 121 : offline_loss:0.00 online_loss:334.28 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.63 loss:334.28 n_loss:0.00 tb_loss:334.28 batch_entropy:46.01 traj_lens:17.00 grad_norm:590.28 grad_norm_clip:68.29 sampled_reward_avg:0.81 train_time:2.44 time_spent:10.97
# 03/12/2024 19:06:02 - INFO - logger - iteration 122 : offline_loss:0.00 online_loss:338.50 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.69 loss:338.50 n_loss:0.00 tb_loss:338.50 batch_entropy:45.24 traj_lens:16.62 grad_norm:559.87 grad_norm_clip:66.60 sampled_reward_avg:0.79 train_time:2.46 time_spent:11.24
# 03/12/2024 19:06:13 - INFO - logger - iteration 123 : offline_loss:0.00 online_loss:348.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.76 loss:348.13 n_loss:0.00 tb_loss:348.13 batch_entropy:46.68 traj_lens:17.00 grad_norm:630.71 grad_norm_clip:68.98 sampled_reward_avg:0.79 train_time:2.74 time_spent:11.30
# 03/12/2024 19:06:24 - INFO - logger - iteration 124 : offline_loss:0.00 online_loss:327.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.82 loss:327.57 n_loss:0.00 tb_loss:327.57 batch_entropy:45.50 traj_lens:16.67 grad_norm:565.08 grad_norm_clip:66.88 sampled_reward_avg:0.78 train_time:2.50 time_spent:11.40
# 03/12/2024 19:06:36 - INFO - logger - iteration 125 : offline_loss:0.00 online_loss:383.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.89 loss:383.59 n_loss:0.00 tb_loss:383.59 batch_entropy:45.45 traj_lens:16.81 grad_norm:567.11 grad_norm_clip:67.66 sampled_reward_avg:0.79 train_time:2.47 time_spent:11.32
# 03/12/2024 19:06:46 - INFO - logger - iteration 126 : offline_loss:0.00 online_loss:304.37 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.96 loss:304.37 n_loss:0.00 tb_loss:304.37 batch_entropy:45.23 traj_lens:16.86 grad_norm:599.86 grad_norm_clip:67.57 sampled_reward_avg:0.81 train_time:2.35 time_spent:10.67
# 03/12/2024 19:06:58 - INFO - logger - iteration 127 : offline_loss:0.00 online_loss:333.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.02 loss:333.42 n_loss:0.00 tb_loss:333.42 batch_entropy:46.64 traj_lens:17.00 grad_norm:629.87 grad_norm_clip:68.15 sampled_reward_avg:0.80 train_time:2.68 time_spent:11.26
# ...
# 03/12/2024 20:08:14 - INFO - logger - iteration 458 : offline_loss:0.00 online_loss:1.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.32 loss:1.53 n_loss:0.00 tb_loss:1.53 batch_entropy:48.64 traj_lens:17.00 grad_norm:42.30 grad_norm_clip:34.83 sampled_reward_avg:0.78 train_time:2.51 time_spent:10.91
# 03/12/2024 20:08:25 - INFO - logger - iteration 459 : offline_loss:0.00 online_loss:2.06 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.34 loss:2.06 n_loss:0.00 tb_loss:2.06 batch_entropy:48.47 traj_lens:17.00 grad_norm:34.56 grad_norm_clip:30.80 sampled_reward_avg:0.78 train_time:2.55 time_spent:10.95
# 03/12/2024 20:08:36 - INFO - logger - iteration 460 : offline_loss:0.00 online_loss:1.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.34 loss:1.46 n_loss:0.00 tb_loss:1.46 batch_entropy:48.61 traj_lens:17.00 grad_norm:27.67 grad_norm_clip:23.61 sampled_reward_avg:0.77 train_time:2.54 time_spent:11.34
# 03/12/2024 20:08:47 - INFO - logger - iteration 461 : offline_loss:0.00 online_loss:2.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.35 loss:2.40 n_loss:0.00 tb_loss:2.40 batch_entropy:48.55 traj_lens:17.00 grad_norm:26.24 grad_norm_clip:23.61 sampled_reward_avg:0.78 train_time:2.47 time_spent:10.95
# 03/12/2024 20:08:58 - INFO - logger - iteration 462 : offline_loss:0.00 online_loss:4.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.36 loss:4.12 n_loss:0.00 tb_loss:4.12 batch_entropy:48.13 traj_lens:16.86 grad_norm:35.12 grad_norm_clip:26.62 sampled_reward_avg:0.77 train_time:2.44 time_spent:10.77
# 03/12/2024 20:09:09 - INFO - logger - iteration 463 : offline_loss:0.00 online_loss:1.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.36 loss:1.90 n_loss:0.00 tb_loss:1.90 batch_entropy:48.57 traj_lens:17.00 grad_norm:32.67 grad_norm_clip:28.30 sampled_reward_avg:0.78 train_time:2.50 time_spent:11.34
# 03/12/2024 20:09:20 - INFO - logger - iteration 464 : offline_loss:0.00 online_loss:1.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.35 loss:1.54 n_loss:0.00 tb_loss:1.54 batch_entropy:48.88 traj_lens:17.00 grad_norm:28.72 grad_norm_clip:27.32 sampled_reward_avg:0.76 train_time:2.42 time_spent:10.78
# 03/12/2024 20:09:31 - INFO - logger - iteration 465 : offline_loss:0.00 online_loss:1.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.35 loss:1.57 n_loss:0.00 tb_loss:1.57 batch_entropy:48.43 traj_lens:17.00 grad_norm:26.05 grad_norm_clip:24.83 sampled_reward_avg:0.79 train_time:2.45 time_spent:10.97
# 03/12/2024 20:09:42 - INFO - logger - iteration 466 : offline_loss:0.00 online_loss:1.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.35 loss:1.78 n_loss:0.00 tb_loss:1.78 batch_entropy:48.50 traj_lens:17.00 grad_norm:26.20 grad_norm_clip:25.68 sampled_reward_avg:0.77 train_time:2.32 time_spent:10.77
# 03/12/2024 20:09:53 - INFO - logger - iteration 467 : offline_loss:0.00 online_loss:1.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.34 loss:1.85 n_loss:0.00 tb_loss:1.85 batch_entropy:48.82 traj_lens:17.00 grad_norm:31.77 grad_norm_clip:29.61 sampled_reward_avg:0.77 train_time:2.44 time_spent:11.33
# 03/12/2024 20:10:04 - INFO - logger - iteration 468 : offline_loss:0.00 online_loss:1.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.34 loss:1.76 n_loss:0.00 tb_loss:1.76 batch_entropy:48.63 traj_lens:17.00 grad_norm:33.67 grad_norm_clip:29.34 sampled_reward_avg:0.77 train_time:2.67 time_spent:11.15
# 03/12/2024 20:10:16 - INFO - logger - iteration 469 : offline_loss:0.00 online_loss:1.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.33 loss:1.79 n_loss:0.00 tb_loss:1.79 batch_entropy:48.87 traj_lens:17.00 grad_norm:43.92 grad_norm_clip:35.26 sampled_reward_avg:0.78 train_time:2.56 time_spent:11.55
# 03/12/2024 20:10:27 - INFO - logger - iteration 470 : offline_loss:0.00 online_loss:2.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.33 loss:2.34 n_loss:0.00 tb_loss:2.34 batch_entropy:48.70 traj_lens:17.00 grad_norm:40.33 grad_norm_clip:33.64 sampled_reward_avg:0.77 train_time:2.48 time_spent:11.39
# 03/12/2024 20:10:38 - INFO - logger - iteration 471 : offline_loss:0.00 online_loss:1.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.34 loss:1.99 n_loss:0.00 tb_loss:1.99 batch_entropy:48.58 traj_lens:17.00 grad_norm:29.91 grad_norm_clip:26.01 sampled_reward_avg:0.77 train_time:2.48 time_spent:11.00
# 03/12/2024 20:10:49 - INFO - logger - iteration 472 : offline_loss:0.00 online_loss:2.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.34 loss:2.79 n_loss:0.00 tb_loss:2.79 batch_entropy:48.64 traj_lens:17.00 grad_norm:42.17 grad_norm_clip:30.38 sampled_reward_avg:0.77 train_time:2.52 time_spent:10.98
# 03/12/2024 20:11:00 - INFO - logger - iteration 473 : offline_loss:0.00 online_loss:2.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.36 loss:2.59 n_loss:0.00 tb_loss:2.59 batch_entropy:48.80 traj_lens:17.00 grad_norm:53.33 grad_norm_clip:39.72 sampled_reward_avg:0.78 train_time:2.51 time_spent:11.41
# 03/12/2024 20:11:11 - INFO - logger - iteration 474 : offline_loss:0.00 online_loss:1.63 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.38 loss:1.63 n_loss:0.00 tb_loss:1.63 batch_entropy:48.37 traj_lens:17.00 grad_norm:36.48 grad_norm_clip:34.55 sampled_reward_avg:0.77 train_time:2.53 time_spent:10.96
# 03/12/2024 20:11:22 - INFO - logger - iteration 475 : offline_loss:0.00 online_loss:1.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.40 loss:1.14 n_loss:0.00 tb_loss:1.14 batch_entropy:48.80 traj_lens:17.00 grad_norm:25.49 grad_norm_clip:24.97 sampled_reward_avg:0.77 train_time:2.42 time_spent:10.81
# 03/12/2024 20:11:33 - INFO - logger - iteration 476 : offline_loss:0.00 online_loss:5.63 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.41 loss:5.63 n_loss:0.00 tb_loss:5.63 batch_entropy:47.96 traj_lens:16.81 grad_norm:49.76 grad_norm_clip:30.04 sampled_reward_avg:0.77 train_time:2.35 time_spent:11.15
# 03/12/2024 20:11:44 - INFO - logger - iteration 477 : offline_loss:0.00 online_loss:1.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.42 loss:1.57 n_loss:0.00 tb_loss:1.57 batch_entropy:48.90 traj_lens:17.00 grad_norm:37.65 grad_norm_clip:33.98 sampled_reward_avg:0.78 train_time:2.49 time_spent:10.89
# 03/12/2024 20:11:55 - INFO - logger - iteration 478 : offline_loss:0.00 online_loss:1.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.43 loss:1.60 n_loss:0.00 tb_loss:1.60 batch_entropy:48.74 traj_lens:17.00 grad_norm:27.56 grad_norm_clip:27.31 sampled_reward_avg:0.77 train_time:2.48 time_spent:10.91
# 03/12/2024 20:12:06 - INFO - logger - iteration 479 : offline_loss:0.00 online_loss:2.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.45 loss:2.25 n_loss:0.00 tb_loss:2.25 batch_entropy:48.81 traj_lens:17.00 grad_norm:43.98 grad_norm_clip:33.88 sampled_reward_avg:0.77 train_time:2.48 time_spent:11.30
# 03/12/2024 20:12:17 - INFO - logger - iteration 480 : offline_loss:0.00 online_loss:111.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.46 loss:111.69 n_loss:0.00 tb_loss:111.69 batch_entropy:48.02 traj_lens:16.81 grad_norm:182.99 grad_norm_clip:51.05 sampled_reward_avg:0.76 train_time:2.51 time_spent:10.83
# 03/12/2024 20:12:28 - INFO - logger - iteration 481 : offline_loss:0.00 online_loss:2.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.46 loss:2.05 n_loss:0.00 tb_loss:2.05 batch_entropy:48.79 traj_lens:17.00 grad_norm:41.32 grad_norm_clip:33.92 sampled_reward_avg:0.78 train_time:2.48 time_spent:10.86
# 03/12/2024 20:12:40 - INFO - logger - iteration 482 : offline_loss:0.00 online_loss:1.80 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.46 loss:1.80 n_loss:0.00 tb_loss:1.80 batch_entropy:48.58 traj_lens:17.00 grad_norm:37.32 grad_norm_clip:30.43 sampled_reward_avg:0.77 train_time:2.56 time_spent:11.36
# 03/12/2024 20:12:50 - INFO - logger - iteration 483 : offline_loss:0.00 online_loss:1.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.44 loss:1.84 n_loss:0.00 tb_loss:1.84 batch_entropy:48.64 traj_lens:17.00 grad_norm:31.27 grad_norm_clip:29.20 sampled_reward_avg:0.77 train_time:2.46 time_spent:10.89
# 03/12/2024 20:13:01 - INFO - logger - iteration 484 : offline_loss:0.00 online_loss:1.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.43 loss:1.61 n_loss:0.00 tb_loss:1.61 batch_entropy:48.63 traj_lens:17.00 grad_norm:24.31 grad_norm_clip:24.31 sampled_reward_avg:0.77 train_time:2.57 time_spent:10.95
# 03/12/2024 20:13:13 - INFO - logger - iteration 485 : offline_loss:0.00 online_loss:1.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.41 loss:1.13 n_loss:0.00 tb_loss:1.13 batch_entropy:48.71 traj_lens:17.00 grad_norm:25.15 grad_norm_clip:24.13 sampled_reward_avg:0.77 train_time:2.37 time_spent:11.24
# 03/12/2024 20:13:23 - INFO - logger - iteration 486 : offline_loss:0.00 online_loss:2.07 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.39 loss:2.07 n_loss:0.00 tb_loss:2.07 batch_entropy:48.72 traj_lens:17.00 grad_norm:47.91 grad_norm_clip:39.84 sampled_reward_avg:0.78 train_time:2.43 time_spent:10.83
# 03/12/2024 20:13:34 - INFO - logger - iteration 487 : offline_loss:0.00 online_loss:1.83 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.38 loss:1.83 n_loss:0.00 tb_loss:1.83 batch_entropy:48.72 traj_lens:17.00 grad_norm:30.59 grad_norm_clip:26.88 sampled_reward_avg:0.78 train_time:2.49 time_spent:10.85
# 03/12/2024 20:13:46 - INFO - logger - iteration 488 : offline_loss:0.00 online_loss:1.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.36 loss:1.69 n_loss:0.00 tb_loss:1.69 batch_entropy:48.62 traj_lens:17.00 grad_norm:36.69 grad_norm_clip:33.60 sampled_reward_avg:0.78 train_time:2.36 time_spent:11.25
# 03/12/2024 20:13:56 - INFO - logger - iteration 489 : offline_loss:0.00 online_loss:1.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.34 loss:1.74 n_loss:0.00 tb_loss:1.74 batch_entropy:48.80 traj_lens:17.00 grad_norm:42.65 grad_norm_clip:30.46 sampled_reward_avg:0.78 train_time:2.40 time_spent:10.89
# 03/12/2024 20:14:07 - INFO - logger - iteration 490 : offline_loss:0.00 online_loss:1.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.33 loss:1.55 n_loss:0.00 tb_loss:1.55 batch_entropy:48.71 traj_lens:17.00 grad_norm:42.91 grad_norm_clip:37.54 sampled_reward_avg:0.76 train_time:2.58 time_spent:11.03
# 03/12/2024 20:14:19 - INFO - logger - iteration 491 : offline_loss:0.00 online_loss:1.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.32 loss:1.46 n_loss:0.00 tb_loss:1.46 batch_entropy:48.82 traj_lens:17.00 grad_norm:31.33 grad_norm_clip:23.10 sampled_reward_avg:0.76 train_time:2.49 time_spent:11.41
# 03/12/2024 20:14:30 - INFO - logger - iteration 492 : offline_loss:0.00 online_loss:1.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.32 loss:1.30 n_loss:0.00 tb_loss:1.30 batch_entropy:48.55 traj_lens:17.00 grad_norm:23.55 grad_norm_clip:21.16 sampled_reward_avg:0.77 train_time:2.43 time_spent:10.90
# 03/12/2024 20:14:40 - INFO - logger - iteration 493 : offline_loss:0.00 online_loss:1.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.32 loss:1.71 n_loss:0.00 tb_loss:1.71 batch_entropy:48.85 traj_lens:17.00 grad_norm:45.12 grad_norm_clip:37.64 sampled_reward_avg:0.77 train_time:2.28 time_spent:10.70
# 03/12/2024 20:14:52 - INFO - logger - iteration 494 : offline_loss:0.00 online_loss:1.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.33 loss:1.23 n_loss:0.00 tb_loss:1.23 batch_entropy:48.69 traj_lens:17.00 grad_norm:29.97 grad_norm_clip:26.35 sampled_reward_avg:0.76 train_time:2.66 time_spent:11.39
# 03/12/2024 20:15:03 - INFO - logger - iteration 495 : offline_loss:0.00 online_loss:1.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.34 loss:1.88 n_loss:0.00 tb_loss:1.88 batch_entropy:48.86 traj_lens:17.00 grad_norm:38.70 grad_norm_clip:31.55 sampled_reward_avg:0.76 train_time:2.39 time_spent:10.82
# 03/12/2024 20:15:14 - INFO - logger - iteration 496 : offline_loss:0.00 online_loss:1.67 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.35 loss:1.67 n_loss:0.00 tb_loss:1.67 batch_entropy:48.71 traj_lens:17.00 grad_norm:38.23 grad_norm_clip:28.20 sampled_reward_avg:0.78 train_time:2.56 time_spent:10.91
# 03/12/2024 20:15:24 - INFO - logger - iteration 497 : offline_loss:0.00 online_loss:1.44 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.37 loss:1.44 n_loss:0.00 tb_loss:1.44 batch_entropy:48.57 traj_lens:17.00 grad_norm:31.34 grad_norm_clip:27.83 sampled_reward_avg:0.78 train_time:2.39 time_spent:10.84
# 03/12/2024 20:15:36 - INFO - logger - iteration 498 : offline_loss:0.00 online_loss:1.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.40 loss:1.70 n_loss:0.00 tb_loss:1.70 batch_entropy:48.94 traj_lens:17.00 grad_norm:37.74 grad_norm_clip:28.37 sampled_reward_avg:0.77 train_time:2.53 time_spent:11.37
# 03/12/2024 20:15:47 - INFO - logger - iteration 499 : offline_loss:0.00 online_loss:1.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.42 loss:1.23 n_loss:0.00 tb_loss:1.23 batch_entropy:48.58 traj_lens:17.00 grad_norm:26.36 grad_norm_clip:26.29 sampled_reward_avg:0.77 train_time:2.48 time_spent:10.95
# 03/12/2024 20:15:58 - INFO - logger - iteration 500 : offline_loss:0.00 online_loss:4.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.44 loss:4.22 n_loss:0.00 tb_loss:4.22 batch_entropy:48.42 traj_lens:16.86 grad_norm:39.60 grad_norm_clip:34.44 sampled_reward_avg:0.78 train_time:2.51 time_spent:10.89

# %%
# Generate molecules
trajs = trial.algo.create_training_data_from_own_samples(trial.model, 25)
objs = [trial.ctx.graph_to_obj(i['result']) for i in trajs]
obj_props, is_valid = trial.task.compute_obj_properties(objs)
log_rewards = trial.task.cond_info_to_logreward({'beta': torch.ones(len(trajs))}, obj_props)
index = 0
rewards = []
for i in is_valid:
    if i:
        rewards.append(list(log_rewards)[index])
        index += 1 
    else:
        rewards.append(0)

MolsToGridImage(objs[:25], molsPerRow=5, subImgSize=(200, 120), legends=[f'reward: {r}' if r==0 else f'reward: {r.exp().item():.2f}' for r in rewards[:25]])

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')])
ax[0].set_yscale('log')
ax[1].set_ylabel('TB loss')
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')])
ax[1].set_ylabel('Average reward')
ax[2].plot([i.value for i in ea.Scalars('train_logZ')])
ax[2].set_ylabel('Predicted logZ')
pp.tight_layout()

# %%
with open(os.path.join(config.log_dir, "params.json"), "w+") as file:
    json.dump(params,file)

with open(os.path.join(config.log_dir, "target.json"), "w+") as file:
    json.dump(target,file)

state = {
    "models_state_dict": [trial.model.state_dict()],
    "cfg": trial.cfg,
    "env_ctx": trial.model.env_ctx,
    #"model": trial.model,
}
if trial.sampling_model is not trial.model:
    state["sampling_model_state_dict"] = [trial.sampling_model.state_dict()]
fn = pathlib.Path(trial.cfg.log_dir) / "model_final_save.pt"
with open(fn, "wb") as fd:
    torch.save(
        state,
        fd,
    )

# %%
tags = ea.Tags()
print("Available tags:", tags)
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['train_offline_loss', 'train_online_loss', 'train_reward_loss', 'train_invalid_trajectories', 'train_invalid_logprob', 'train_invalid_losses', 'train_backward_vs_unif', 'train_logZ', 'train_loss', 'train_n_loss', 'train_tb_loss', 'train_batch_entropy', 'train_traj_lens', 'train_grad_norm', 'train_grad_norm_clip', 'train_sampled_reward_avg', 'train_train_time', 'train_time_spent'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
from pycirclize import Circos
import pandas as pd
import matplotlib.pyplot as plt
from pom_models.functions import fragance_propabilities_from_smiles
from rdkit import Chem
import numpy as np

# %%
indices = np.argsort(-np.array(target))
indices
# Out:
# array([ 64, 137,  60,  53,  51,  21,  45,  82,  50, 119, 126,  38, 123,
#          4,  30,  99,  31,  58,  23, 110, 125,  86,   5,  85,  73,  44,
#         72, 128, 124,  87,  74,  14, 132,  78, 112,  98, 131,  10, 130,
#          1,  88, 104,   9,  94,  83,  80, 133,  24,   6,  71,  90, 121,
#         56, 117, 114,  75,  16,  69,  95, 107,  39, 135,  62, 134,  92,
#         59,  47, 109,  66,   8, 105, 108,  65,   7, 118,  13, 103,  52,
#         15,  67,  49, 101,  18,  33,  46,  96, 116,  77,  70,  37, 100,
#        113,  41, 111, 106,  79,  93,  40,  28,  48, 102,  29,  26,  63,
#         22,  91,  84,  57,  97,  35, 115, 127,  55,  61, 122,  12,   3,
#         32,  68,  20,   2, 120,  81,  43,  34, 136,  11,  54,  27,  17,
#         25,  19,  76, 129,   0,  42,  89,  36], dtype=int64)

# %%
labels = df.keys()[2:]
labels
# Out:
# Index(['alcoholic', 'aldehydic', 'alliaceous', 'almond', 'amber', 'animal',
#        'anisic', 'apple', 'apricot', 'aromatic',
#        ...
#        'tropical', 'vanilla', 'vegetable', 'vetiver', 'violet', 'warm', 'waxy',
#        'weedy', 'winey', 'woody'],
#       dtype='object', length=138)

# %%
data_lst  = []
for i, obj in enumerate(objs):
    smiles = Chem.MolToSmiles(obj)
    probs = fragance_propabilities_from_smiles(smiles)[0]

    data_lst.append( [smiles] + list(probs))
result_df = pd.DataFrame(
    data=data_lst,
    index=[i for i in range(len(data_lst))],
    columns=["smiles"]+list(labels)
    )
result_df.head()
# Out:
#                                               smiles  alcoholic  aldehydic  \
# 0  CC=Cc1ccc(-c2ccccc2)nc1-c1ccncc1C1CCC(c2ncccn2...   0.069776   0.153556
# 1  C1=CNC=C(c2ccc(-c3cc(C4CCCCO4)ccc3C3COCC3c3ccc...   0.061807   0.138917
# 2  NC(=O)n1cnc2c(C3CC(c4cc[nH]c4)OC(c4ccccn4)C3c3...   0.073982   0.152314
# 3  [NH3+]Cc1nc(-c2cscn2)ncc1-c1cccc(-c2cccc(C3CCC...   0.071527   0.139928
# 4  O=c1[nH]c(-c2cccc(-c3cccc(-c4ccc(C5CCCCC5C5CCC...   0.066674   0.139203
#
#    alliaceous    almond     amber    animal    anisic     apple   apricot  \
# 0    0.099827  0.402382  0.146904  0.439994  0.269701  0.069901  0.102523
# 1    0.124202  0.366594  0.171433  0.492144  0.179461  0.060116  0.099165
# 2    0.145837  0.444088  0.125184  0.408273  0.186333  0.074473  0.098976
# 3    0.113312  0.363613  0.194153  0.484348  0.241197  0.071331  0.123056
# 4    0.149508  0.381778  0.153466  0.466547  0.176261  0.062686  0.093575
#
#    ...  tropical   vanilla  vegetable   vetiver    violet      warm      waxy  \
# 0  ...  0.175588  0.242265   0.143761  0.104901  0.078149  0.258849  0.196291
# 1  ...  0.149967  0.171135   0.157905  0.100572  0.074436  0.241837  0.186080
# 2  ...  0.179454  0.264533   0.154011  0.103656  0.058125  0.254636  0.147292
# 3  ...  0.179949  0.174847   0.166743  0.112877  0.088852  0.229042  0.239815
# 4  ...  0.170937  0.201472   0.193817  0.102865  0.067999  0.226404  0.163439
#
#       weedy     winey     woody
# 0  0.134099  0.126378  0.330897
# 1  0.134500  0.104646  0.308324
# 2  0.145878  0.148205  0.328596
# 3  0.137551  0.136907  0.318456
# 4  0.134856  0.116684  0.330685
#
# [5 rows x 139 columns]

# %%
target_df = pd.DataFrame(
    data=[["target"] + list(target)],
    columns=result_df.keys(),
    index=["Target"]
)
target_df
# Out:
#         smiles  alcoholic  aldehydic  alliaceous    almond     amber  \
# Target  target   0.060157   0.209652    0.083372  0.088339  0.336117
#
#           animal    anisic     apple   apricot  ...  tropical   vanilla  \
# Target  0.268335  0.187134  0.141956  0.144496  ...  0.256422  0.063885
#
#         vegetable   vetiver    violet      warm      waxy     weedy     winey  \
# Target   0.211703  0.215956  0.225055  0.188657  0.149626  0.152026  0.074805
#
#            woody
# Target  0.561436
#
# [1 rows x 139 columns]

# %%
most_important_indicies = indices[:8]
most_important_keys = []
for i in most_important_indicies:
    most_important_keys.append(labels[i])
most_important_keys
# Out:
# ['herbal',
#  'woody',
#  'green',
#  'fruity',
#  'fresh',
#  'camphoreous',
#  'earthy',
#  'mint']

# %%
rewards_plot = [f'{r}' if r==-1 else f'{r.exp().item():.2f}' for r in rewards[:25]]
rewards_plot
# Out:
# ['0.70',
#  '0.73',
#  '0.74',
#  '0.72',
#  '0.75',
#  '0.78',
#  '0.74',
#  '0.73',
#  '0.73',
#  '0.76',
#  '0.74',
#  '0.79',
#  '0.72',
#  '0.80',
#  '0.76',
#  '0.75',
#  '0.73',
#  '-1',
#  '0.72',
#  '0.68',
#  '0.78',
#  '0.75',
#  '0.74',
#  '0.71',
#  '0.76']

# %%
plot_df = result_df[most_important_keys].set_index(pd.Series([f"{i+1} r:{rewards_plot[i]}" for i in range(len(result_df["smiles"]))]))
plot_df
# Out:
#              herbal     woody     green    fruity     fresh  camphoreous  \
# 1 r:0.70   0.368094  0.330897  0.425910  0.443748  0.267390     0.169610
# 2 r:0.73   0.294593  0.308324  0.322688  0.410055  0.213210     0.166270
# 3 r:0.74   0.290509  0.328596  0.285294  0.421802  0.205202     0.155920
# 4 r:0.72   0.358809  0.318456  0.468388  0.432952  0.271824     0.206908
# 5 r:0.75   0.287300  0.330685  0.311546  0.412037  0.208565     0.172571
# 6 r:0.78   0.182618  0.203277  0.165164  0.235379  0.100871     0.091571
# 7 r:0.74   0.275967  0.296983  0.258811  0.400231  0.221381     0.160613
# 8 r:0.73   0.326077  0.303185  0.382644  0.417231  0.253960     0.192523
# 9 r:0.73   0.310999  0.304116  0.349419  0.413104  0.237467     0.186510
# 10 r:0.76  0.253020  0.347671  0.213475  0.381569  0.169357     0.134993
# 11 r:0.74  0.198602  0.308167  0.300016  0.337904  0.128329     0.118076
# 12 r:0.79  0.143668  0.257713  0.150923  0.314463  0.112767     0.077271
# 13 r:0.72  0.301320  0.326540  0.354685  0.406240  0.251264     0.179504
# 14 r:0.80  0.211331  0.331121  0.233339  0.350115  0.176412     0.160793
# 15 r:0.76  0.227407  0.307530  0.220036  0.344294  0.152955     0.172492
# 16 r:0.75  0.297689  0.326757  0.258348  0.340328  0.220759     0.185199
# 17 r:0.73  0.289932  0.306849  0.337943  0.434554  0.252221     0.181258
# 18 r:-1    0.123548  0.158362  0.119637  0.219423  0.086070     0.051814
# 19 r:0.72  0.182281  0.314394  0.173218  0.243396  0.085447     0.084501
# 20 r:0.68  0.320848  0.272693  0.424277  0.430092  0.227365     0.157252
# 21 r:0.78  0.238534  0.334504  0.257013  0.374431  0.178583     0.140218
# 22 r:0.75  0.176416  0.318134  0.210015  0.330937  0.115485     0.100866
# 23 r:0.74  0.264973  0.306655  0.311559  0.403515  0.214938     0.173023
# 24 r:0.71  0.338862  0.318522  0.332845  0.426389  0.239368     0.184573
# 25 r:0.76  0.195005  0.290134  0.173161  0.252996  0.110642     0.110815
#
#              earthy      mint
# 1 r:0.70   0.353724  0.178364
# 2 r:0.73   0.292193  0.181642
# 3 r:0.74   0.271813  0.160209
# 4 r:0.72   0.414255  0.195107
# 5 r:0.75   0.313930  0.193488
# 6 r:0.78   0.176723  0.161200
# 7 r:0.74   0.215575  0.227584
# 8 r:0.73   0.345738  0.208983
# 9 r:0.73   0.310535  0.218014
# 10 r:0.76  0.257461  0.165206
# 11 r:0.74  0.478390  0.122739
# 12 r:0.79  0.278956  0.124404
# 13 r:0.72  0.319612  0.233586
# 14 r:0.80  0.321676  0.204743
# 15 r:0.76  0.308910  0.254658
# 16 r:0.75  0.242084  0.308225
# 17 r:0.73  0.272369  0.225847
# 18 r:-1    0.141139  0.082083
# 19 r:0.72  0.300377  0.102483
# 20 r:0.68  0.324674  0.137788
# 21 r:0.78  0.332839  0.190959
# 22 r:0.75  0.331477  0.119101
# 23 r:0.74  0.308567  0.155132
# 24 r:0.71  0.285873  0.188249
# 25 r:0.76  0.264889  0.196687

# %%
plot_target_df = target_df[most_important_keys]
plot_target_df
# Out:
#           herbal     woody     green   fruity    fresh  camphoreous    earthy  \
# Target  0.615864  0.561436  0.519596  0.51449  0.51066       0.5034  0.495063
#
#             mint
# Target  0.460149

# %%
plot_df.loc["target"] = []

# %%
# Create 5 x 5 subplots
fig = plt.figure(figsize=(26, 16), dpi=100)
fig.subplots(5, 5, subplot_kw=dict(polar=True))
fig.subplots_adjust(wspace=1, hspace=0.25)

# Plot radar chart into subplots for each target
for target_name, ax in zip(plot_df.index, fig.axes):
    target_df = plot_df.loc[[target_name]]
    target_df = pd.concat([target_df, plot_target_df])
    # Initialize Circos instance for radar chart plot
    circos = Circos.radar_chart(
        target_df,
        vmax=1,
        marker_size=6,
        #cmap=dict(Hero="salmon", Warrior="skyblue", Wizard="lime", Assassin="magenta"),
        grid_interval_ratio=0.2,
        line_kws_handler=lambda _: dict(lw=2, ls="solid"),
        marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
    )

    # Plot figure & set legend on upper right
    circos.plotfig(ax=ax)
    circos.ax.legend(loc="upper right", fontsize=10,bbox_to_anchor=(1.7, 1.1))

# %%
np.array(result_df[labels].sum())/len(result_df[labels])
# Out:
# array([0.05995543, 0.11770916, 0.15727852, 0.31326059, 0.12783672,
#        0.3747793 , 0.16163549, 0.05580204, 0.08372282, 0.24644029,
#        0.2505292 , 0.05264592, 0.17609397, 0.06224182, 0.13956971,
#        0.24895823, 0.09086286, 0.08057499, 0.3823027 , 0.1737732 ,
#        0.12967977, 0.14860569, 0.25545275, 0.07475504, 0.13512743,
#        0.06313413, 0.15046977, 0.18489482, 0.20927325, 0.20088501,
#        0.10334121, 0.14020291, 0.1273722 , 0.21772644, 0.17441086,
#        0.30895635, 0.04945072, 0.17386217, 0.15681252, 0.1290583 ,
#        0.33909127, 0.18139683, 0.04622186, 0.13549076, 0.20057446,
#        0.29855117, 0.13621598, 0.16909724, 0.12709749, 0.21577373,
#        0.33544526, 0.1880733 , 0.09973023, 0.36708736, 0.16353609,
#        0.09104607, 0.15215756, 0.13582535, 0.1128882 , 0.13432352,
#        0.28161418, 0.17359337, 0.18758734, 0.20311867, 0.25833598,
#        0.25197047, 0.1435107 , 0.10136159, 0.04503134, 0.10612095,
#        0.11025929, 0.07581776, 0.13877815, 0.18894821, 0.06013056,
#        0.07995119, 0.07771552, 0.28569695, 0.20228025, 0.08993534,
#        0.21938802, 0.15152822, 0.18145923, 0.05444064, 0.19866957,
#        0.16157049, 0.33344504, 0.11656775, 0.49465367, 0.17112602,
#        0.13731928, 0.13425602, 0.14000855, 0.1577076 , 0.10538497,
#        0.10250922, 0.10695944, 0.0564326 , 0.24436444, 0.05643884,
#        0.11188348, 0.11374471, 0.28699082, 0.19696714, 0.24330935,
#        0.2897364 , 0.17456959, 0.09922338, 0.10810912, 0.44322902,
#        0.17489824, 0.07321169, 0.07889949, 0.26218846, 0.16814665,
#        0.25269756, 0.09107039, 0.17896123, 0.13353877, 0.28961003,
#        0.11430747, 0.23380655, 0.08721501, 0.4772395 , 0.18102673,
#        0.08746423, 0.28916484, 0.14565593, 0.15690601, 0.17116238,
#        0.18922386, 0.08926415, 0.05736238, 0.18025963, 0.14159097,
#        0.11112495, 0.10840479, 0.3020105 ], dtype=float32)

# %%
import seaborn as sns

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[0].set_yscale('log')
ax[0].set_ylabel('TB loss')
ax[0].grid()
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[1].set_ylabel('Average reward')
ax[1].set_xlabel('Iteration')
ax[1].grid()
ax[2].plot([i.value for i in ea.Scalars('train_logZ')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[2].set_ylabel('Predicted logZ')
ax[2].grid()
pp.tight_layout()
plt.savefig("images/pine_run_plots.pdf")
