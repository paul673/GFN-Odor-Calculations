# %% [markdown]
# # Run Vanilla (beta fix)

# %%
import sys
import os
path_to_top_dir = "../"
# Dynamically add the `project` directory to the path
sys.path.append(os.path.abspath(path_to_top_dir))

# %%
os.path.abspath(path_to_top_dir)
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model'

# %%
# Print current working directory
os.getcwd()
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model\\runs'

# %%
# Import scent_gfn functions
from scent_gfn.fragments import FRAGMENTS, FRAGMENTS_OPENPOM_DATASET, FRAGMENTS_OPENPOM_VANILLA
from scent_gfn.molecule import MoleculeTrainer
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# Skipped loading some PyTorch models, missing a dependency. No module named 'tensorflow'
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)

# %% [markdown]
# | **Parameter**                | **Value**      |
# |------------------------------|----------------|
# | Reward function type         | Structue        |
# | Similarity measure           | Cosine         |
# | Graph building               | Atoms      |
# | Iterations                   | 500            |
# | Max number of nodes          | 20              |
# | Illegal action logreward     | -100           |
# | β                            | 1              |
# | Large molecule penalty       | None           |

# %%
params = {
    "save_name": "vanilla9",
    "reward_func": "structure", # structure, openpom
    "similarity": "cosine",
    "graph_building": None,#FRAGMENTS,
    "iterations": 500,
    "max_nodes": 20,
    "illegal_logreward": -100,
    "beta": 1.0,
    "large_mol_pen": [None,None]# ["hard", 23]# ["exponential", 15] # ["exponential", 15] , ["hard", 15], [None,None]
}

# %%
# Utilities
import warnings
import random
import datetime

# Data processing and file management
import pathlib
import pandas as pd
import json
import numpy as np

# Machine learning
import torch
from gflownet.config import init_empty, Config
from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage, MolToImage


# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Run on cpu
dev = torch.device('cpu')

# %%
def get_pine_openpom_target():
    with open('../data/pine_target_2.json', 'r') as file:
        target = json.load(file)
    return [target]

# %%
def get_vanilla_test_and_training(split_ratio=0.7):
    df = pd.read_csv("../data/data.csv")
    vanilla_mols_df = df.loc[df['vanilla'] == 1]
    vanilla_smiles_trainig= list(vanilla_mols_df["nonStereoSMILES"])
    vanilla_smiles_trainig = random.sample(vanilla_smiles_trainig, round(len(vanilla_mols_df)*split_ratio))
    random.shuffle(vanilla_smiles_trainig)
    vanilla_smiles_test = []
    for i in vanilla_mols_df["nonStereoSMILES"]:
        if i not in vanilla_smiles_trainig:
            vanilla_smiles_test.append(i)
    return vanilla_smiles_trainig, vanilla_smiles_test

def get_vanillin():
    return ["COc1cc(C=O)ccc1O"]

# %%
target = get_vanillin()

# %%
# Initialize model
config = init_empty(Config())
config.print_every = 1
config.log_dir = f"{os.path.abspath(path_to_top_dir)}/results/{params['save_name']}_{datetime.datetime.now().strftime('%Y-%m-%d__%H_%M_%S')}"
config.device = dev
config.num_training_steps = params["iterations"]
config.num_workers = 0
config.num_validation_gen_steps = 1
config.overwrite_existing_exp=False
config.checkpoint_every = 100
config.algo.max_nodes = params["max_nodes"] #12 # 95 quantil
config.store_all_checkpoints = True
config.algo.illegal_action_logreward = params["illegal_logreward"]

if params["graph_building"] == None:
     trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]), print_config=True) #,fragments=FRAGMENTS, print_config=True)
else:
    trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]),fragments=params["graph_building"], print_config=True) #,fragments=FRAGMENTS, print_config=True)
# Out:
# SMILES input data detected ...
# Reward function: reward_function_structure | Similarity measure: CosineSimilarity | exp_penalty: False | max_mol=None
# Building molecules using atoms ...
#
#
# Hyperparameters:
#
# desc: noDesc
# log_dir: c:\Users\paulj\Desktop\prosjekt\pom_cpu-model/results/vanilla9_2024-12-06__20_41_11
# device: cpu
# seed: 0
# validate_every: 1000
# checkpoint_every: 100
# store_all_checkpoints: true
# print_every: 1
# start_at_step: 0
# num_final_gen_steps: null
# num_validation_gen_steps: 1
# num_training_steps: 500
# num_workers: 0
# hostname: null
# pickle_mp_messages: false
# git_hash: f106cde
# overwrite_existing_exp: false
# algo:
#   method: TB
#   num_from_policy: 64
#   num_from_dataset: 0
#   valid_num_from_policy: 64
#   valid_num_from_dataset: 0
#   max_len: 128
#   max_nodes: 20
#   max_edges: 128
#   illegal_action_logreward: -100.0
#   train_random_action_prob: 0.0
#   train_det_after: null
#   valid_random_action_prob: 0.0
#   sampling_tau: 0.9
#   tb:
#     bootstrap_own_reward: false
#     epsilon: null
#     reward_loss_multiplier: 1.0
#     variant: TB
#     do_correct_idempotent: false
#     do_parameterize_p_b: false
#     do_predict_n: false
#     do_sample_p_b: false
#     do_length_normalize: false
#     subtb_max_len: 128
#     Z_learning_rate: 0.0001
#     Z_lr_decay: 50000.0
#     cum_subtb: true
#     loss_fn: MSE
#     loss_fn_par: 1.0
#     n_loss: none
#     n_loss_multiplier: 1.0
#     backward_policy: Uniform
#   moql:
#     gamma: 1.0
#     num_omega_samples: 32
#     num_objectives: 2
#     lambda_decay: 10000
#     penalty: -10.0
#   a2c:
#     entropy: 0.01
#     gamma: 1.0
#     penalty: -10.0
#   fm:
#     epsilon: 1.0e-38
#     balanced_loss: false
#     leaf_coef: 10.0
#     correct_idempotent: false
#   sql:
#     alpha: 0.01
#     gamma: 1.0
#     penalty: -10.0
# model:
#   num_layers: 3
#   num_emb: 128
#   dropout: 0.0
#   graph_transformer:
#     num_heads: 2
#     ln_type: pre
#     num_mlp_layers: 0
#     concat_heads: true
#   seq_transformer:
#     num_heads: 2
#     posenc: Rotary
# opt:
#   opt: adam
#   learning_rate: 0.0001
#   lr_decay: 20000.0
#   weight_decay: 1.0e-08
#   momentum: 0.9
#   clip_grad_type: norm
#   clip_grad_param: 10.0
#   adam_eps: 1.0e-08
# replay:
#   use: false
#   capacity: null
#   warmup: null
#   hindsight_ratio: 0.0
#   num_from_replay: null
#   num_new_samples: null
# task:
#   qm9:
#     h5_path: ./data/qm9/qm9.h5
#     model_path: ./data/qm9/qm9_model.pt
#   qm9_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - gap
#     - qed
#     - sa
#     online_pareto_front: true
#   seh:
#     reduced_frag: false
#   seh_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - seh
#     - qed
#     - sa
#     - mw
#     log_topk: false
#     online_pareto_front: true
# cond:
#   valid_sample_cond_info: true
#   temperature:
#     sample_dist: uniform
#     dist_params:
#     - 0.5
#     - 32
#     num_thermometer_dim: 32
#   moo:
#     num_objectives: 2
#     num_thermometer_dim: 16
#   weighted_prefs:
#     preference_type: dirichlet
#     preference_param: 1.5
#   focus_region:
#     focus_type: centered
#     use_steer_thermomether: false
#     focus_cosim: 0.98
#     focus_limit_coef: 0.1
#     focus_model_training_limits:
#     - 0.25
#     - 0.75
#     focus_model_state_space_res: 30
#     max_train_it: 20000

# %%
trial.run()
# Out:
# 06/12/2024 20:41:11 - INFO - logger - Starting training
# 06/12/2024 20:41:29 - INFO - logger - iteration 1 : offline_loss:0.00 online_loss:2548.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.21 loss:2548.14 n_loss:0.00 tb_loss:2548.14 batch_entropy:59.90 traj_lens:18.56 grad_norm:723.64 grad_norm_clip:78.80 sampled_reward_avg:0.00 train_time:6.31 time_spent:17.82
# 06/12/2024 20:41:46 - INFO - logger - iteration 2 : offline_loss:0.00 online_loss:2297.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.24 loss:2297.24 n_loss:0.00 tb_loss:2297.24 batch_entropy:60.43 traj_lens:18.56 grad_norm:1346.75 grad_norm_clip:82.92 sampled_reward_avg:0.00 train_time:6.40 time_spent:17.32
# 06/12/2024 20:42:10 - INFO - logger - iteration 3 : offline_loss:0.00 online_loss:1905.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.28 loss:1905.46 n_loss:0.00 tb_loss:1905.46 batch_entropy:83.01 traj_lens:24.34 grad_norm:3057.72 grad_norm_clip:87.43 sampled_reward_avg:0.00 train_time:9.83 time_spent:23.77
# 06/12/2024 20:42:31 - INFO - logger - iteration 4 : offline_loss:0.00 online_loss:1844.27 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.32 loss:1844.27 n_loss:0.00 tb_loss:1844.27 batch_entropy:75.57 traj_lens:22.09 grad_norm:3205.23 grad_norm_clip:87.21 sampled_reward_avg:0.00 train_time:7.97 time_spent:21.20
# 06/12/2024 20:43:05 - INFO - logger - iteration 5 : offline_loss:0.00 online_loss:1511.56 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.35 loss:1511.56 n_loss:0.00 tb_loss:1511.56 batch_entropy:107.99 traj_lens:29.70 grad_norm:3317.83 grad_norm_clip:88.19 sampled_reward_avg:0.00 train_time:16.32 time_spent:33.59
# 06/12/2024 20:43:30 - INFO - logger - iteration 6 : offline_loss:0.00 online_loss:1445.75 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.39 loss:1445.75 n_loss:0.00 tb_loss:1445.75 batch_entropy:96.51 traj_lens:26.27 grad_norm:2491.15 grad_norm_clip:86.46 sampled_reward_avg:0.00 train_time:9.64 time_spent:24.81
# 06/12/2024 20:44:00 - INFO - logger - iteration 7 : offline_loss:0.00 online_loss:1339.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.43 loss:1339.08 n_loss:0.00 tb_loss:1339.08 batch_entropy:108.02 traj_lens:28.39 grad_norm:1386.08 grad_norm_clip:82.26 sampled_reward_avg:0.00 train_time:14.07 time_spent:30.53
# 06/12/2024 20:44:38 - INFO - logger - iteration 8 : offline_loss:0.00 online_loss:1027.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.46 loss:1027.03 n_loss:0.00 tb_loss:1027.03 batch_entropy:125.11 traj_lens:33.17 grad_norm:1495.73 grad_norm_clip:82.05 sampled_reward_avg:0.00 train_time:19.80 time_spent:37.70
# 06/12/2024 20:45:11 - INFO - logger - iteration 9 : offline_loss:0.00 online_loss:1157.38 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.50 loss:1157.38 n_loss:0.00 tb_loss:1157.38 batch_entropy:116.72 traj_lens:31.38 grad_norm:1643.17 grad_norm_clip:82.82 sampled_reward_avg:0.00 train_time:13.76 time_spent:33.46
# 06/12/2024 20:45:46 - INFO - logger - iteration 10 : offline_loss:0.00 online_loss:770.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.53 loss:770.16 n_loss:0.00 tb_loss:770.16 batch_entropy:135.51 traj_lens:35.17 grad_norm:2009.59 grad_norm_clip:82.84 sampled_reward_avg:0.00 train_time:14.73 time_spent:34.06
# 06/12/2024 20:46:17 - INFO - logger - iteration 11 : offline_loss:0.00 online_loss:804.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.57 loss:804.08 n_loss:0.00 tb_loss:804.08 batch_entropy:121.61 traj_lens:33.09 grad_norm:2111.75 grad_norm_clip:83.89 sampled_reward_avg:0.00 train_time:13.27 time_spent:31.35
# 06/12/2024 20:47:05 - INFO - logger - iteration 12 : offline_loss:0.00 online_loss:459.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.61 loss:459.17 n_loss:0.00 tb_loss:459.17 batch_entropy:151.30 traj_lens:40.92 grad_norm:3229.09 grad_norm_clip:86.82 sampled_reward_avg:0.00 train_time:25.25 time_spent:47.38
# 06/12/2024 20:48:32 - INFO - logger - iteration 13 : offline_loss:0.00 online_loss:367.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.64 loss:367.35 n_loss:0.00 tb_loss:367.35 batch_entropy:163.68 traj_lens:45.22 grad_norm:5059.39 grad_norm_clip:88.81 sampled_reward_avg:0.00 train_time:39.39 time_spent:80.17
# 06/12/2024 20:49:43 - INFO - logger - iteration 14 : offline_loss:0.00 online_loss:517.02 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.68 loss:517.02 n_loss:0.00 tb_loss:517.02 batch_entropy:156.45 traj_lens:43.25 grad_norm:4891.90 grad_norm_clip:88.40 sampled_reward_avg:0.00 train_time:28.00 time_spent:78.31
# 06/12/2024 20:50:40 - INFO - logger - iteration 15 : offline_loss:0.00 online_loss:610.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.71 loss:610.86 n_loss:0.00 tb_loss:610.86 batch_entropy:163.37 traj_lens:44.59 grad_norm:2427.79 grad_norm_clip:83.50 sampled_reward_avg:0.00 train_time:21.47 time_spent:57.57
# 06/12/2024 20:51:39 - INFO - logger - iteration 16 : offline_loss:0.00 online_loss:529.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.75 loss:529.11 n_loss:0.00 tb_loss:529.11 batch_entropy:176.01 traj_lens:49.17 grad_norm:5741.76 grad_norm_clip:87.66 sampled_reward_avg:0.00 train_time:29.41 time_spent:58.79
# 06/12/2024 20:52:52 - INFO - logger - iteration 17 : offline_loss:0.00 online_loss:554.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.78 loss:554.74 n_loss:0.00 tb_loss:554.74 batch_entropy:172.19 traj_lens:47.56 grad_norm:2473.16 grad_norm_clip:82.72 sampled_reward_avg:0.00 train_time:24.09 time_spent:72.51
# 06/12/2024 20:54:34 - INFO - logger - iteration 18 : offline_loss:0.00 online_loss:517.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.82 loss:517.70 n_loss:0.00 tb_loss:517.70 batch_entropy:189.13 traj_lens:52.02 grad_norm:2256.72 grad_norm_clip:81.71 sampled_reward_avg:0.00 train_time:59.75 time_spent:98.21
# 06/12/2024 20:57:39 - INFO - logger - iteration 19 : offline_loss:0.00 online_loss:530.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.85 loss:530.25 n_loss:0.00 tb_loss:530.25 batch_entropy:192.52 traj_lens:54.70 grad_norm:11844.42 grad_norm_clip:88.96 sampled_reward_avg:0.00 train_time:56.78 time_spent:187.97
# 06/12/2024 21:00:31 - INFO - logger - iteration 20 : offline_loss:0.00 online_loss:556.48 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.89 loss:556.48 n_loss:0.00 tb_loss:556.48 batch_entropy:194.58 traj_lens:56.48 grad_norm:18721.17 grad_norm_clip:89.46 sampled_reward_avg:0.00 train_time:61.84 time_spent:165.86
# 06/12/2024 21:17:13 - INFO - logger - iteration 21 : offline_loss:0.00 online_loss:714.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.92 loss:714.87 n_loss:0.00 tb_loss:714.87 batch_entropy:198.92 traj_lens:58.27 grad_norm:22043.21 grad_norm_clip:89.58 sampled_reward_avg:0.00 train_time:781.60 time_spent:953.71
# 06/12/2024 21:31:14 - INFO - logger - iteration 22 : offline_loss:0.00 online_loss:1054.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.96 loss:1054.03 n_loss:0.00 tb_loss:1054.03 batch_entropy:200.81 traj_lens:59.95 grad_norm:26284.91 grad_norm_clip:89.79 sampled_reward_avg:0.00 train_time:512.97 time_spent:809.49
# 06/12/2024 21:59:48 - INFO - logger - iteration 23 : offline_loss:0.00 online_loss:1464.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.00 loss:1464.41 n_loss:0.00 tb_loss:1464.41 batch_entropy:194.06 traj_lens:61.11 grad_norm:37593.09 grad_norm_clip:90.65 sampled_reward_avg:0.00 train_time:1406.84 time_spent:1710.35
# 06/12/2024 22:16:17 - INFO - logger - iteration 24 : offline_loss:0.00 online_loss:2230.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.03 loss:2230.12 n_loss:0.00 tb_loss:2230.12 batch_entropy:184.41 traj_lens:62.70 grad_norm:56646.95 grad_norm_clip:90.63 sampled_reward_avg:0.00 train_time:599.18 time_spent:1010.04
# 06/12/2024 22:53:16 - INFO - logger - iteration 25 : offline_loss:0.00 online_loss:2866.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.07 loss:2866.86 n_loss:0.00 tb_loss:2866.86 batch_entropy:188.61 traj_lens:65.44 grad_norm:70063.72 grad_norm_clip:90.60 sampled_reward_avg:0.00 train_time:1914.51 time_spent:2267.03
# 06/12/2024 23:27:29 - INFO - logger - iteration 26 : offline_loss:0.00 online_loss:4975.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.11 loss:4975.82 n_loss:0.00 tb_loss:4975.82 batch_entropy:161.25 traj_lens:63.53 grad_norm:88497.58 grad_norm_clip:90.59 sampled_reward_avg:0.00 train_time:1437.66 time_spent:2029.22
# 07/12/2024 00:09:54 - INFO - logger - iteration 27 : offline_loss:0.00 online_loss:5712.27 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.15 loss:5712.27 n_loss:0.00 tb_loss:5712.27 batch_entropy:163.90 traj_lens:66.25 grad_norm:111075.48 grad_norm_clip:90.61 sampled_reward_avg:0.00 train_time:2004.48 time_spent:2576.30
# 07/12/2024 00:40:09 - INFO - logger - iteration 28 : offline_loss:0.00 online_loss:7318.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.19 loss:7318.54 n_loss:0.00 tb_loss:7318.54 batch_entropy:154.53 traj_lens:66.56 grad_norm:113953.26 grad_norm_clip:90.10 sampled_reward_avg:0.00 train_time:1357.23 time_spent:1826.56
# 07/12/2024 01:56:39 - INFO - logger - iteration 29 : offline_loss:0.00 online_loss:7053.44 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.23 loss:7053.44 n_loss:0.00 tb_loss:7053.44 batch_entropy:155.75 traj_lens:66.58 grad_norm:113710.44 grad_norm_clip:90.64 sampled_reward_avg:0.00 train_time:4131.81 time_spent:4540.75
# 07/12/2024 02:33:24 - INFO - logger - iteration 30 : offline_loss:0.00 online_loss:8163.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.27 loss:8163.42 n_loss:0.00 tb_loss:8163.42 batch_entropy:143.77 traj_lens:65.20 grad_norm:120211.43 grad_norm_clip:90.69 sampled_reward_avg:0.00 train_time:1476.44 time_spent:2215.33
# 07/12/2024 03:13:41 - INFO - logger - iteration 31 : offline_loss:0.00 online_loss:6750.66 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.31 loss:6750.66 n_loss:0.00 tb_loss:6750.66 batch_entropy:148.77 traj_lens:63.86 grad_norm:117468.02 grad_norm_clip:90.68 sampled_reward_avg:0.00 train_time:2094.14 time_spent:2440.96
# 07/12/2024 03:43:52 - INFO - logger - iteration 32 : offline_loss:0.00 online_loss:6392.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.35 loss:6392.72 n_loss:0.00 tb_loss:6392.72 batch_entropy:149.81 traj_lens:64.39 grad_norm:126078.44 grad_norm_clip:90.75 sampled_reward_avg:0.00 train_time:1427.15 time_spent:1775.99
# 07/12/2024 03:56:05 - INFO - logger - iteration 33 : offline_loss:0.00 online_loss:3999.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.39 loss:3999.17 n_loss:0.00 tb_loss:3999.17 batch_entropy:155.37 traj_lens:61.16 grad_norm:103854.59 grad_norm_clip:90.29 sampled_reward_avg:0.00 train_time:464.52 time_spent:759.46
# 07/12/2024 04:02:49 - INFO - logger - iteration 34 : offline_loss:0.00 online_loss:3127.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.43 loss:3127.22 n_loss:0.00 tb_loss:3127.22 batch_entropy:163.15 traj_lens:61.27 grad_norm:95170.77 grad_norm_clip:90.27 sampled_reward_avg:0.00 train_time:103.51 time_spent:420.52
# 07/12/2024 04:35:22 - INFO - logger - iteration 35 : offline_loss:0.00 online_loss:1906.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.47 loss:1906.17 n_loss:0.00 tb_loss:1906.17 batch_entropy:173.13 traj_lens:60.47 grad_norm:77501.20 grad_norm_clip:90.79 sampled_reward_avg:0.00 train_time:1672.62 time_spent:1905.89
# 07/12/2024 04:40:44 - INFO - logger - iteration 36 : offline_loss:0.00 online_loss:1565.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.52 loss:1565.09 n_loss:0.00 tb_loss:1565.09 batch_entropy:169.83 traj_lens:57.16 grad_norm:55178.34 grad_norm_clip:90.78 sampled_reward_avg:0.00 train_time:38.05 time_spent:373.57
# 07/12/2024 04:44:11 - INFO - logger - iteration 37 : offline_loss:0.00 online_loss:3457.80 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.56 loss:3457.80 n_loss:0.00 tb_loss:3457.80 batch_entropy:131.57 traj_lens:50.92 grad_norm:62645.52 grad_norm_clip:91.04 sampled_reward_avg:0.00 train_time:20.93 time_spent:211.38
# 07/12/2024 04:45:08 - INFO - logger - iteration 38 : offline_loss:0.00 online_loss:4942.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.60 loss:4942.21 n_loss:0.00 tb_loss:4942.21 batch_entropy:99.58 traj_lens:44.56 grad_norm:61941.47 grad_norm_clip:91.11 sampled_reward_avg:0.00 train_time:14.57 time_spent:57.91
# 07/12/2024 04:45:45 - INFO - logger - iteration 39 : offline_loss:0.00 online_loss:5996.62 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.65 loss:5996.62 n_loss:0.00 tb_loss:5996.62 batch_entropy:74.18 traj_lens:38.31 grad_norm:57276.15 grad_norm_clip:90.87 sampled_reward_avg:0.00 train_time:12.14 time_spent:37.13
# 07/12/2024 04:46:13 - INFO - logger - iteration 40 : offline_loss:0.00 online_loss:5356.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.69 loss:5356.31 n_loss:0.00 tb_loss:5356.31 batch_entropy:59.50 traj_lens:32.41 grad_norm:53681.89 grad_norm_clip:90.80 sampled_reward_avg:0.00 train_time:9.54 time_spent:27.52
# 07/12/2024 04:46:39 - INFO - logger - iteration 41 : offline_loss:0.00 online_loss:5434.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.74 loss:5434.51 n_loss:0.00 tb_loss:5434.51 batch_entropy:46.80 traj_lens:28.42 grad_norm:51870.07 grad_norm_clip:90.66 sampled_reward_avg:0.00 train_time:8.53 time_spent:26.44
# 07/12/2024 04:46:53 - INFO - logger - iteration 42 : offline_loss:0.00 online_loss:4321.06 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.78 loss:4321.06 n_loss:0.00 tb_loss:4321.06 batch_entropy:38.25 traj_lens:22.12 grad_norm:35256.25 grad_norm_clip:90.64 sampled_reward_avg:0.00 train_time:4.86 time_spent:13.73
# 07/12/2024 04:47:05 - INFO - logger - iteration 43 : offline_loss:0.00 online_loss:3229.45 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.83 loss:3229.45 n_loss:0.00 tb_loss:3229.45 batch_entropy:43.74 traj_lens:21.45 grad_norm:28415.34 grad_norm_clip:90.62 sampled_reward_avg:0.00 train_time:4.53 time_spent:12.31
# 07/12/2024 04:47:15 - INFO - logger - iteration 44 : offline_loss:0.00 online_loss:3011.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.88 loss:3011.36 n_loss:0.00 tb_loss:3011.36 batch_entropy:33.62 traj_lens:16.72 grad_norm:18274.19 grad_norm_clip:89.96 sampled_reward_avg:0.00 train_time:3.05 time_spent:9.40
# 07/12/2024 04:47:22 - INFO - logger - iteration 45 : offline_loss:0.00 online_loss:2984.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.93 loss:2984.86 n_loss:0.00 tb_loss:2984.86 batch_entropy:30.84 traj_lens:14.78 grad_norm:13096.43 grad_norm_clip:89.79 sampled_reward_avg:0.00 train_time:2.68 time_spent:7.66
# 07/12/2024 04:47:27 - INFO - logger - iteration 46 : offline_loss:0.00 online_loss:3140.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.98 loss:3140.42 n_loss:0.00 tb_loss:3140.42 batch_entropy:21.93 traj_lens:10.52 grad_norm:8406.01 grad_norm_clip:89.52 sampled_reward_avg:0.00 train_time:1.56 time_spent:5.11
# 07/12/2024 04:47:32 - INFO - logger - iteration 47 : offline_loss:0.00 online_loss:3174.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.03 loss:3174.20 n_loss:0.00 tb_loss:3174.20 batch_entropy:20.99 traj_lens:10.28 grad_norm:8611.04 grad_norm_clip:89.43 sampled_reward_avg:0.00 train_time:1.42 time_spent:4.88
# 07/12/2024 04:47:36 - INFO - logger - iteration 48 : offline_loss:0.00 online_loss:3303.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.08 loss:3303.21 n_loss:0.00 tb_loss:3303.21 batch_entropy:17.41 traj_lens:9.19 grad_norm:9212.56 grad_norm_clip:89.28 sampled_reward_avg:0.00 train_time:1.26 time_spent:4.13
# 07/12/2024 04:47:40 - INFO - logger - iteration 49 : offline_loss:0.00 online_loss:3460.95 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.13 loss:3460.95 n_loss:0.00 tb_loss:3460.95 batch_entropy:14.09 traj_lens:7.58 grad_norm:10787.37 grad_norm_clip:88.34 sampled_reward_avg:0.00 train_time:0.96 time_spent:3.19
# 07/12/2024 04:47:42 - INFO - logger - iteration 50 : offline_loss:0.00 online_loss:3396.44 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.18 loss:3396.44 n_loss:0.00 tb_loss:3396.44 batch_entropy:11.90 traj_lens:6.27 grad_norm:9620.87 grad_norm_clip:87.12 sampled_reward_avg:0.00 train_time:0.66 time_spent:2.54
# 07/12/2024 04:47:45 - INFO - logger - iteration 51 : offline_loss:0.00 online_loss:3432.81 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.24 loss:3432.81 n_loss:0.00 tb_loss:3432.81 batch_entropy:11.60 traj_lens:6.25 grad_norm:8911.40 grad_norm_clip:86.10 sampled_reward_avg:0.00 train_time:0.70 time_spent:2.85
# 07/12/2024 04:47:48 - INFO - logger - iteration 52 : offline_loss:0.00 online_loss:3346.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.29 loss:3346.68 n_loss:0.00 tb_loss:3346.68 batch_entropy:11.15 traj_lens:5.48 grad_norm:7463.76 grad_norm_clip:85.18 sampled_reward_avg:0.00 train_time:0.63 time_spent:2.57
# 07/12/2024 04:47:50 - INFO - logger - iteration 53 : offline_loss:0.00 online_loss:3392.27 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.34 loss:3392.27 n_loss:0.00 tb_loss:3392.27 batch_entropy:11.31 traj_lens:5.23 grad_norm:6305.52 grad_norm_clip:84.63 sampled_reward_avg:0.00 train_time:0.49 time_spent:1.94
# 07/12/2024 04:47:52 - INFO - logger - iteration 54 : offline_loss:0.00 online_loss:3598.48 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.40 loss:3598.48 n_loss:0.00 tb_loss:3598.48 batch_entropy:8.74 traj_lens:4.84 grad_norm:4628.90 grad_norm_clip:83.83 sampled_reward_avg:0.00 train_time:0.54 time_spent:2.15
# 07/12/2024 04:47:54 - INFO - logger - iteration 55 : offline_loss:0.00 online_loss:3914.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.45 loss:3914.99 n_loss:0.00 tb_loss:3914.99 batch_entropy:8.11 traj_lens:5.97 grad_norm:3768.76 grad_norm_clip:81.35 sampled_reward_avg:0.00 train_time:0.69 time_spent:2.57
# 07/12/2024 04:47:57 - INFO - logger - iteration 56 : offline_loss:0.00 online_loss:4059.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.51 loss:4059.05 n_loss:0.00 tb_loss:4059.05 batch_entropy:6.48 traj_lens:5.83 grad_norm:3265.14 grad_norm_clip:80.74 sampled_reward_avg:0.00 train_time:0.78 time_spent:2.67
# 07/12/2024 04:47:59 - INFO - logger - iteration 57 : offline_loss:0.00 online_loss:4088.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.56 loss:4088.71 n_loss:0.00 tb_loss:4088.71 batch_entropy:5.32 traj_lens:5.08 grad_norm:3222.75 grad_norm_clip:79.72 sampled_reward_avg:0.00 train_time:0.49 time_spent:1.75
# 07/12/2024 04:48:01 - INFO - logger - iteration 58 : offline_loss:0.00 online_loss:4277.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.62 loss:4277.69 n_loss:0.00 tb_loss:4277.69 batch_entropy:3.56 traj_lens:4.89 grad_norm:2565.63 grad_norm_clip:76.33 sampled_reward_avg:0.00 train_time:0.54 time_spent:2.53
# 07/12/2024 04:48:03 - INFO - logger - iteration 59 : offline_loss:0.00 online_loss:4461.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.68 loss:4461.08 n_loss:0.00 tb_loss:4461.08 batch_entropy:2.13 traj_lens:4.84 grad_norm:1394.15 grad_norm_clip:71.65 sampled_reward_avg:0.00 train_time:0.53 time_spent:1.74
# 07/12/2024 04:48:05 - INFO - logger - iteration 60 : offline_loss:0.00 online_loss:4453.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.73 loss:4453.04 n_loss:0.00 tb_loss:4453.04 batch_entropy:2.51 traj_lens:5.36 grad_norm:1894.63 grad_norm_clip:73.39 sampled_reward_avg:0.00 train_time:0.62 time_spent:2.32
# 07/12/2024 04:48:07 - INFO - logger - iteration 61 : offline_loss:0.00 online_loss:4471.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.79 loss:4471.93 n_loss:0.00 tb_loss:4471.93 batch_entropy:1.92 traj_lens:5.00 grad_norm:1442.51 grad_norm_clip:71.75 sampled_reward_avg:0.00 train_time:0.54 time_spent:2.11
# 07/12/2024 04:48:10 - INFO - logger - iteration 62 : offline_loss:0.00 online_loss:4577.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.85 loss:4577.13 n_loss:0.00 tb_loss:4577.13 batch_entropy:1.26 traj_lens:5.22 grad_norm:1218.52 grad_norm_clip:64.84 sampled_reward_avg:0.00 train_time:0.56 time_spent:2.23
# 07/12/2024 04:48:12 - INFO - logger - iteration 63 : offline_loss:0.00 online_loss:4566.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.90 loss:4566.98 n_loss:0.00 tb_loss:4566.98 batch_entropy:1.55 traj_lens:5.36 grad_norm:1296.76 grad_norm_clip:68.27 sampled_reward_avg:0.00 train_time:0.61 time_spent:2.36
# 07/12/2024 04:48:13 - INFO - logger - iteration 64 : offline_loss:0.00 online_loss:4591.58 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.96 loss:4591.58 n_loss:0.00 tb_loss:4591.58 batch_entropy:0.89 traj_lens:5.03 grad_norm:1221.75 grad_norm_clip:58.74 sampled_reward_avg:0.00 train_time:0.43 time_spent:1.52
# 07/12/2024 04:48:15 - INFO - logger - iteration 65 : offline_loss:0.00 online_loss:4592.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.02 loss:4592.72 n_loss:0.00 tb_loss:4592.72 batch_entropy:0.80 traj_lens:5.02 grad_norm:1222.05 grad_norm_clip:42.09 sampled_reward_avg:0.00 train_time:0.52 time_spent:1.80
# 07/12/2024 04:48:17 - INFO - logger - iteration 66 : offline_loss:0.00 online_loss:4558.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.08 loss:4558.15 n_loss:0.00 tb_loss:4558.15 batch_entropy:0.99 traj_lens:4.98 grad_norm:1232.28 grad_norm_clip:51.73 sampled_reward_avg:0.00 train_time:0.51 time_spent:1.57
# 07/12/2024 04:48:18 - INFO - logger - iteration 67 : offline_loss:0.00 online_loss:4575.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.14 loss:4575.82 n_loss:0.00 tb_loss:4575.82 batch_entropy:0.80 traj_lens:5.02 grad_norm:1248.84 grad_norm_clip:48.73 sampled_reward_avg:0.00 train_time:0.43 time_spent:1.48
# 07/12/2024 04:48:20 - INFO - logger - iteration 68 : offline_loss:0.00 online_loss:4566.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.20 loss:4566.36 n_loss:0.00 tb_loss:4566.36 batch_entropy:0.81 traj_lens:5.02 grad_norm:1267.28 grad_norm_clip:56.47 sampled_reward_avg:0.00 train_time:0.43 time_spent:1.51
# 07/12/2024 04:48:21 - INFO - logger - iteration 69 : offline_loss:0.00 online_loss:4570.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.26 loss:4570.42 n_loss:0.00 tb_loss:4570.42 batch_entropy:0.70 traj_lens:5.00 grad_norm:1271.06 grad_norm_clip:33.73 sampled_reward_avg:0.00 train_time:0.46 time_spent:1.45
# 07/12/2024 04:48:23 - INFO - logger - iteration 70 : offline_loss:0.00 online_loss:4562.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.32 loss:4562.25 n_loss:0.00 tb_loss:4562.25 batch_entropy:0.70 traj_lens:5.00 grad_norm:1283.47 grad_norm_clip:32.09 sampled_reward_avg:0.00 train_time:0.47 time_spent:1.57
# 07/12/2024 04:48:24 - INFO - logger - iteration 71 : offline_loss:0.00 online_loss:4553.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.38 loss:4553.99 n_loss:0.00 tb_loss:4553.99 batch_entropy:0.70 traj_lens:5.00 grad_norm:1296.02 grad_norm_clip:31.39 sampled_reward_avg:0.00 train_time:0.50 time_spent:1.52
# 07/12/2024 04:48:26 - INFO - logger - iteration 72 : offline_loss:0.00 online_loss:4545.67 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.45 loss:4545.67 n_loss:0.00 tb_loss:4545.67 batch_entropy:0.70 traj_lens:5.00 grad_norm:1307.57 grad_norm_clip:31.55 sampled_reward_avg:0.00 train_time:0.45 time_spent:1.47
# 07/12/2024 04:48:28 - INFO - logger - iteration 73 : offline_loss:0.00 online_loss:4537.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.51 loss:4537.30 n_loss:0.00 tb_loss:4537.30 batch_entropy:0.70 traj_lens:5.00 grad_norm:1320.42 grad_norm_clip:32.45 sampled_reward_avg:0.00 train_time:0.44 time_spent:1.95
# 07/12/2024 04:48:29 - INFO - logger - iteration 74 : offline_loss:0.00 online_loss:4528.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.57 loss:4528.82 n_loss:0.00 tb_loss:4528.82 batch_entropy:0.70 traj_lens:5.00 grad_norm:1333.61 grad_norm_clip:35.14 sampled_reward_avg:0.00 train_time:0.46 time_spent:1.44
# 07/12/2024 04:48:31 - INFO - logger - iteration 75 : offline_loss:0.00 online_loss:4505.43 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.63 loss:4505.43 n_loss:0.00 tb_loss:4505.43 batch_entropy:0.84 traj_lens:5.02 grad_norm:1355.35 grad_norm_clip:53.66 sampled_reward_avg:0.00 train_time:0.47 time_spent:1.50
# 07/12/2024 04:48:32 - INFO - logger - iteration 76 : offline_loss:0.00 online_loss:4511.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.69 loss:4511.20 n_loss:0.00 tb_loss:4511.20 batch_entropy:0.70 traj_lens:5.00 grad_norm:1365.61 grad_norm_clip:50.54 sampled_reward_avg:0.00 train_time:0.45 time_spent:1.60
# 07/12/2024 04:48:34 - INFO - logger - iteration 77 : offline_loss:0.00 online_loss:4478.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.76 loss:4478.24 n_loss:0.00 tb_loss:4478.24 batch_entropy:0.93 traj_lens:5.03 grad_norm:1380.15 grad_norm_clip:54.11 sampled_reward_avg:0.00 train_time:0.47 time_spent:1.52
# 07/12/2024 04:48:35 - INFO - logger - iteration 78 : offline_loss:0.00 online_loss:4489.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.82 loss:4489.15 n_loss:0.00 tb_loss:4489.15 batch_entropy:0.74 traj_lens:5.00 grad_norm:1565.28 grad_norm_clip:65.99 sampled_reward_avg:0.00 train_time:0.46 time_spent:1.52
# 07/12/2024 04:48:37 - INFO - logger - iteration 79 : offline_loss:0.00 online_loss:4468.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.88 loss:4468.65 n_loss:0.00 tb_loss:4468.65 batch_entropy:0.83 traj_lens:5.00 grad_norm:2475.25 grad_norm_clip:74.03 sampled_reward_avg:0.00 train_time:0.44 time_spent:1.53
# 07/12/2024 04:48:38 - INFO - logger - iteration 80 : offline_loss:0.00 online_loss:4419.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.95 loss:4419.74 n_loss:0.00 tb_loss:4419.74 batch_entropy:1.13 traj_lens:5.00 grad_norm:5866.15 grad_norm_clip:81.33 sampled_reward_avg:0.00 train_time:0.45 time_spent:1.45
# 07/12/2024 04:48:40 - INFO - logger - iteration 81 : offline_loss:0.00 online_loss:4303.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.01 loss:4303.72 n_loss:0.00 tb_loss:4303.72 batch_entropy:1.95 traj_lens:5.00 grad_norm:11403.96 grad_norm_clip:84.34 sampled_reward_avg:0.00 train_time:0.52 time_spent:1.82
# 07/12/2024 04:48:42 - INFO - logger - iteration 82 : offline_loss:0.00 online_loss:4114.83 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.08 loss:4114.83 n_loss:0.00 tb_loss:4114.83 batch_entropy:3.35 traj_lens:5.02 grad_norm:14444.80 grad_norm_clip:84.69 sampled_reward_avg:0.00 train_time:0.48 time_spent:1.70
# 07/12/2024 04:48:43 - INFO - logger - iteration 83 : offline_loss:0.00 online_loss:3891.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.14 loss:3891.51 n_loss:0.00 tb_loss:3891.51 batch_entropy:5.10 traj_lens:5.06 grad_norm:14936.36 grad_norm_clip:84.58 sampled_reward_avg:0.00 train_time:0.51 time_spent:1.64
# 07/12/2024 04:48:46 - INFO - logger - iteration 84 : offline_loss:0.00 online_loss:3654.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.21 loss:3654.09 n_loss:0.00 tb_loss:3654.09 batch_entropy:7.00 traj_lens:5.09 grad_norm:14634.39 grad_norm_clip:84.24 sampled_reward_avg:0.00 train_time:0.59 time_spent:2.05
# 07/12/2024 04:48:47 - INFO - logger - iteration 85 : offline_loss:0.00 online_loss:3418.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.28 loss:3418.88 n_loss:0.00 tb_loss:3418.88 batch_entropy:9.06 traj_lens:5.25 grad_norm:14268.53 grad_norm_clip:84.18 sampled_reward_avg:0.00 train_time:0.50 time_spent:1.84
# 07/12/2024 04:48:49 - INFO - logger - iteration 86 : offline_loss:0.00 online_loss:3190.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.34 loss:3190.21 n_loss:0.00 tb_loss:3190.21 batch_entropy:11.45 traj_lens:5.75 grad_norm:14131.82 grad_norm_clip:84.55 sampled_reward_avg:0.00 train_time:0.58 time_spent:1.91
# 07/12/2024 04:48:52 - INFO - logger - iteration 87 : offline_loss:0.00 online_loss:2955.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.41 loss:2955.11 n_loss:0.00 tb_loss:2955.11 batch_entropy:14.49 traj_lens:6.83 grad_norm:14433.98 grad_norm_clip:84.98 sampled_reward_avg:0.00 train_time:0.82 time_spent:2.45
# 07/12/2024 04:48:56 - INFO - logger - iteration 88 : offline_loss:0.00 online_loss:2654.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.47 loss:2654.08 n_loss:0.00 tb_loss:2654.08 batch_entropy:19.07 traj_lens:8.94 grad_norm:15604.61 grad_norm_clip:84.71 sampled_reward_avg:0.00 train_time:1.25 time_spent:3.90
# 07/12/2024 04:49:04 - INFO - logger - iteration 89 : offline_loss:0.00 online_loss:2185.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.54 loss:2185.09 n_loss:0.00 tb_loss:2185.09 batch_entropy:27.75 traj_lens:13.88 grad_norm:18220.21 grad_norm_clip:84.51 sampled_reward_avg:0.00 train_time:3.20 time_spent:8.15
# 07/12/2024 04:49:20 - INFO - logger - iteration 90 : offline_loss:0.00 online_loss:3934.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.61 loss:3934.82 n_loss:0.00 tb_loss:3934.82 batch_entropy:17.63 traj_lens:20.31 grad_norm:4646.74 grad_norm_clip:74.42 sampled_reward_avg:0.00 train_time:6.47 time_spent:15.96
# 07/12/2024 04:49:36 - INFO - logger - iteration 91 : offline_loss:0.00 online_loss:4481.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.68 loss:4481.22 n_loss:0.00 tb_loss:4481.22 batch_entropy:13.82 traj_lens:21.81 grad_norm:1790.68 grad_norm_clip:66.99 sampled_reward_avg:0.00 train_time:7.18 time_spent:16.74
# 07/12/2024 04:49:53 - INFO - logger - iteration 92 : offline_loss:0.00 online_loss:4611.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.74 loss:4611.88 n_loss:0.00 tb_loss:4611.88 batch_entropy:12.59 traj_lens:22.00 grad_norm:4994.62 grad_norm_clip:72.45 sampled_reward_avg:0.00 train_time:7.07 time_spent:16.68
# 07/12/2024 04:50:10 - INFO - logger - iteration 93 : offline_loss:0.00 online_loss:4268.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.81 loss:4268.82 n_loss:0.00 tb_loss:4268.82 batch_entropy:15.09 traj_lens:22.00 grad_norm:40842.50 grad_norm_clip:82.21 sampled_reward_avg:0.00 train_time:7.19 time_spent:17.26
# 07/12/2024 04:50:27 - INFO - logger - iteration 94 : offline_loss:0.00 online_loss:3604.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.88 loss:3604.47 n_loss:0.00 tb_loss:3604.47 batch_entropy:20.21 traj_lens:21.77 grad_norm:40691.03 grad_norm_clip:82.95 sampled_reward_avg:0.00 train_time:7.10 time_spent:16.56
# 07/12/2024 04:50:44 - INFO - logger - iteration 95 : offline_loss:0.00 online_loss:3021.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-4.95 loss:3021.76 n_loss:0.00 tb_loss:3021.76 batch_entropy:25.32 traj_lens:22.00 grad_norm:38124.80 grad_norm_clip:82.21 sampled_reward_avg:0.00 train_time:7.28 time_spent:17.20
# 07/12/2024 04:51:02 - INFO - logger - iteration 96 : offline_loss:0.00 online_loss:2436.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.02 loss:2436.29 n_loss:0.00 tb_loss:2436.29 batch_entropy:30.87 traj_lens:22.00 grad_norm:34758.42 grad_norm_clip:82.17 sampled_reward_avg:0.00 train_time:7.41 time_spent:17.36
# 07/12/2024 04:51:19 - INFO - logger - iteration 97 : offline_loss:0.00 online_loss:1893.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.09 loss:1893.61 n_loss:0.00 tb_loss:1893.61 batch_entropy:36.64 traj_lens:22.00 grad_norm:31215.13 grad_norm_clip:82.16 sampled_reward_avg:0.00 train_time:7.21 time_spent:17.29
# 07/12/2024 04:51:36 - INFO - logger - iteration 98 : offline_loss:0.00 online_loss:1402.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.16 loss:1402.09 n_loss:0.00 tb_loss:1402.09 batch_entropy:42.64 traj_lens:22.00 grad_norm:27424.63 grad_norm_clip:82.15 sampled_reward_avg:0.00 train_time:7.22 time_spent:17.41
# 07/12/2024 04:51:53 - INFO - logger - iteration 99 : offline_loss:0.00 online_loss:1119.89 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.23 loss:1119.89 n_loss:0.00 tb_loss:1119.89 batch_entropy:47.16 traj_lens:21.95 grad_norm:22273.34 grad_norm_clip:82.07 sampled_reward_avg:0.00 train_time:7.27 time_spent:16.85
# 07/12/2024 04:52:09 - INFO - logger - iteration 100 : offline_loss:0.00 online_loss:3824.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.30 loss:3824.03 n_loss:0.00 tb_loss:3824.03 batch_entropy:16.49 traj_lens:21.09 grad_norm:2358.32 grad_norm_clip:67.15 sampled_reward_avg:0.00 train_time:6.86 time_spent:16.10
# 07/12/2024 04:52:26 - INFO - logger - iteration 101 : offline_loss:0.00 online_loss:4147.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.37 loss:4147.85 n_loss:0.00 tb_loss:4147.85 batch_entropy:12.48 traj_lens:21.00 grad_norm:1658.65 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.72 time_spent:16.45
# 07/12/2024 04:52:41 - INFO - logger - iteration 102 : offline_loss:0.00 online_loss:4138.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:4138.74 n_loss:0.00 tb_loss:4138.74 batch_entropy:12.48 traj_lens:21.00 grad_norm:1671.74 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.64 time_spent:15.66
# 07/12/2024 04:52:57 - INFO - logger - iteration 103 : offline_loss:0.00 online_loss:4129.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.51 loss:4129.60 n_loss:0.00 tb_loss:4129.60 batch_entropy:12.48 traj_lens:21.00 grad_norm:1684.82 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.70 time_spent:15.37
# 07/12/2024 04:53:13 - INFO - logger - iteration 104 : offline_loss:0.00 online_loss:4120.43 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.58 loss:4120.43 n_loss:0.00 tb_loss:4120.43 batch_entropy:12.48 traj_lens:21.00 grad_norm:1697.90 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.82 time_spent:16.16
# 07/12/2024 04:53:29 - INFO - logger - iteration 105 : offline_loss:0.00 online_loss:4111.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.65 loss:4111.23 n_loss:0.00 tb_loss:4111.23 batch_entropy:12.48 traj_lens:21.00 grad_norm:1710.97 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.76 time_spent:15.83
# 07/12/2024 04:53:44 - INFO - logger - iteration 106 : offline_loss:0.00 online_loss:4101.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.72 loss:4101.99 n_loss:0.00 tb_loss:4101.99 batch_entropy:12.48 traj_lens:21.00 grad_norm:1724.02 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.70 time_spent:15.53
# 07/12/2024 04:54:00 - INFO - logger - iteration 107 : offline_loss:0.00 online_loss:4092.73 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.80 loss:4092.73 n_loss:0.00 tb_loss:4092.73 batch_entropy:12.48 traj_lens:21.00 grad_norm:1737.07 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.70 time_spent:15.70
# 07/12/2024 04:54:18 - INFO - logger - iteration 108 : offline_loss:0.00 online_loss:4083.43 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.87 loss:4083.43 n_loss:0.00 tb_loss:4083.43 batch_entropy:12.48 traj_lens:21.00 grad_norm:1750.10 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:7.50 time_spent:17.87
# 07/12/2024 04:54:36 - INFO - logger - iteration 109 : offline_loss:0.00 online_loss:4074.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.94 loss:4074.11 n_loss:0.00 tb_loss:4074.11 batch_entropy:12.48 traj_lens:21.00 grad_norm:1763.11 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:7.36 time_spent:18.57
# 07/12/2024 04:54:53 - INFO - logger - iteration 110 : offline_loss:0.00 online_loss:4064.75 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.02 loss:4064.75 n_loss:0.00 tb_loss:4064.75 batch_entropy:12.48 traj_lens:21.00 grad_norm:1776.11 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.91 time_spent:16.82
# 07/12/2024 04:55:14 - INFO - logger - iteration 111 : offline_loss:0.00 online_loss:4055.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.09 loss:4055.32 n_loss:0.00 tb_loss:4055.32 batch_entropy:12.48 traj_lens:21.00 grad_norm:1790.43 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:7.90 time_spent:20.61
# 07/12/2024 04:55:37 - INFO - logger - iteration 112 : offline_loss:0.00 online_loss:4045.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.16 loss:4045.84 n_loss:0.00 tb_loss:4045.84 batch_entropy:12.48 traj_lens:21.00 grad_norm:1803.36 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:9.03 time_spent:23.36
# 07/12/2024 04:56:00 - INFO - logger - iteration 113 : offline_loss:0.00 online_loss:4036.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.24 loss:4036.30 n_loss:0.00 tb_loss:4036.30 batch_entropy:12.48 traj_lens:21.00 grad_norm:1816.26 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:7.69 time_spent:22.84
# 07/12/2024 04:56:16 - INFO - logger - iteration 114 : offline_loss:0.00 online_loss:4026.73 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.31 loss:4026.73 n_loss:0.00 tb_loss:4026.73 batch_entropy:12.48 traj_lens:21.00 grad_norm:1829.14 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.89 time_spent:16.36
# 07/12/2024 04:56:32 - INFO - logger - iteration 115 : offline_loss:0.00 online_loss:4017.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.39 loss:4017.12 n_loss:0.00 tb_loss:4017.12 batch_entropy:12.48 traj_lens:21.00 grad_norm:1842.00 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.48 time_spent:15.21
# 07/12/2024 04:56:46 - INFO - logger - iteration 116 : offline_loss:0.00 online_loss:4007.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.47 loss:4007.47 n_loss:0.00 tb_loss:4007.47 batch_entropy:12.48 traj_lens:21.00 grad_norm:1854.83 grad_norm_clip:24.49 sampled_reward_avg:0.00 train_time:6.16 time_spent:14.50
# 07/12/2024 04:57:01 - INFO - logger - iteration 117 : offline_loss:0.00 online_loss:3997.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.54 loss:3997.79 n_loss:0.00 tb_loss:3997.79 batch_entropy:12.48 traj_lens:21.00 grad_norm:1867.64 grad_norm_clip:24.50 sampled_reward_avg:0.00 train_time:6.38 time_spent:14.75
# 07/12/2024 04:57:16 - INFO - logger - iteration 118 : offline_loss:0.00 online_loss:3988.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.62 loss:3988.08 n_loss:0.00 tb_loss:3988.08 batch_entropy:12.48 traj_lens:21.00 grad_norm:1880.42 grad_norm_clip:24.50 sampled_reward_avg:0.00 train_time:6.32 time_spent:15.09
# 07/12/2024 04:57:31 - INFO - logger - iteration 119 : offline_loss:0.00 online_loss:3978.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.70 loss:3978.34 n_loss:0.00 tb_loss:3978.34 batch_entropy:12.48 traj_lens:21.00 grad_norm:1893.19 grad_norm_clip:24.50 sampled_reward_avg:0.00 train_time:6.30 time_spent:14.97
# 07/12/2024 04:57:45 - INFO - logger - iteration 120 : offline_loss:0.00 online_loss:3968.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.77 loss:3968.57 n_loss:0.00 tb_loss:3968.57 batch_entropy:12.48 traj_lens:21.00 grad_norm:1905.93 grad_norm_clip:24.50 sampled_reward_avg:0.00 train_time:6.34 time_spent:14.54
# 07/12/2024 04:58:00 - INFO - logger - iteration 121 : offline_loss:0.00 online_loss:3958.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.85 loss:3958.77 n_loss:0.00 tb_loss:3958.77 batch_entropy:12.48 traj_lens:21.00 grad_norm:1918.64 grad_norm_clip:24.50 sampled_reward_avg:0.00 train_time:6.21 time_spent:14.75
# 07/12/2024 04:58:15 - INFO - logger - iteration 122 : offline_loss:0.00 online_loss:3948.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-6.93 loss:3948.94 n_loss:0.00 tb_loss:3948.94 batch_entropy:12.48 traj_lens:21.00 grad_norm:1931.33 grad_norm_clip:24.50 sampled_reward_avg:0.00 train_time:6.34 time_spent:14.91
# 07/12/2024 04:58:29 - INFO - logger - iteration 123 : offline_loss:0.00 online_loss:3939.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-7.01 loss:3939.08 n_loss:0.00 tb_loss:3939.08 batch_entropy:12.48 traj_lens:21.00 grad_norm:1943.99 grad_norm_clip:24.50 sampled_reward_avg:0.00 train_time:6.14 time_spent:14.48
# 07/12/2024 04:58:44 - INFO - logger - iteration 124 : offline_loss:0.00 online_loss:3929.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-7.09 loss:3929.19 n_loss:0.00 tb_loss:3929.19 batch_entropy:12.48 traj_lens:21.00 grad_norm:1956.63 grad_norm_clip:24.50 sampled_reward_avg:0.00 train_time:6.33 time_spent:15.00
# 07/12/2024 04:58:59 - INFO - logger - iteration 125 : offline_loss:0.00 online_loss:3919.28 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-7.17 loss:3919.28 n_loss:0.00 tb_loss:3919.28 batch_entropy:12.48 traj_lens:21.00 grad_norm:1969.24 grad_norm_clip:24.50 sampled_reward_avg:0.00 train_time:6.33 time_spent:15.00
# ...
# 07/12/2024 05:27:52 - INFO - logger - iteration 458 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.47 grad_norm_clip:0.47 sampled_reward_avg:0.00 train_time:0.19 time_spent:1.47
# 07/12/2024 05:27:53 - INFO - logger - iteration 459 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.46 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.48 grad_norm_clip:0.48 sampled_reward_avg:0.00 train_time:0.19 time_spent:1.42
# 07/12/2024 05:27:55 - INFO - logger - iteration 460 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.46 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.49 grad_norm_clip:0.49 sampled_reward_avg:0.00 train_time:0.17 time_spent:1.40
# 07/12/2024 05:27:56 - INFO - logger - iteration 461 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.46 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.49 grad_norm_clip:0.49 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.69
# 07/12/2024 05:27:58 - INFO - logger - iteration 462 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.46 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.48 grad_norm_clip:0.48 sampled_reward_avg:0.00 train_time:0.20 time_spent:1.49
# 07/12/2024 05:27:59 - INFO - logger - iteration 463 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.46 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.47 grad_norm_clip:0.47 sampled_reward_avg:0.00 train_time:0.20 time_spent:1.48
# 07/12/2024 05:28:01 - INFO - logger - iteration 464 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.46 grad_norm_clip:0.46 sampled_reward_avg:0.00 train_time:0.20 time_spent:1.43
# 07/12/2024 05:28:02 - INFO - logger - iteration 465 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.45 grad_norm_clip:0.45 sampled_reward_avg:0.00 train_time:0.19 time_spent:1.42
# 07/12/2024 05:28:04 - INFO - logger - iteration 466 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.43 grad_norm_clip:0.43 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.43
# 07/12/2024 05:28:05 - INFO - logger - iteration 467 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.41 grad_norm_clip:0.41 sampled_reward_avg:0.00 train_time:0.19 time_spent:1.62
# 07/12/2024 05:28:07 - INFO - logger - iteration 468 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.39 grad_norm_clip:0.39 sampled_reward_avg:0.00 train_time:0.19 time_spent:1.48
# 07/12/2024 05:28:08 - INFO - logger - iteration 469 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.37 grad_norm_clip:0.37 sampled_reward_avg:0.00 train_time:0.19 time_spent:1.42
# 07/12/2024 05:28:10 - INFO - logger - iteration 470 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.35 grad_norm_clip:0.35 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.66
# 07/12/2024 05:28:11 - INFO - logger - iteration 471 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.32 grad_norm_clip:0.32 sampled_reward_avg:0.00 train_time:0.20 time_spent:1.38
# 07/12/2024 05:28:13 - INFO - logger - iteration 472 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.30 grad_norm_clip:0.30 sampled_reward_avg:0.00 train_time:0.17 time_spent:1.47
# 07/12/2024 05:28:14 - INFO - logger - iteration 473 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.27 grad_norm_clip:0.27 sampled_reward_avg:0.00 train_time:0.17 time_spent:1.63
# 07/12/2024 05:28:16 - INFO - logger - iteration 474 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.25 grad_norm_clip:0.25 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.40
# 07/12/2024 05:28:17 - INFO - logger - iteration 475 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.45 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.22 grad_norm_clip:0.22 sampled_reward_avg:0.00 train_time:0.17 time_spent:1.40
# 07/12/2024 05:28:19 - INFO - logger - iteration 476 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.20 grad_norm_clip:0.20 sampled_reward_avg:0.00 train_time:0.20 time_spent:1.40
# 07/12/2024 05:28:20 - INFO - logger - iteration 477 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.17 grad_norm_clip:0.17 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.35
# 07/12/2024 05:28:21 - INFO - logger - iteration 478 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.15 grad_norm_clip:0.15 sampled_reward_avg:0.00 train_time:0.27 time_spent:1.62
# 07/12/2024 05:28:23 - INFO - logger - iteration 479 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.13 grad_norm_clip:0.13 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.40
# 07/12/2024 05:28:25 - INFO - logger - iteration 480 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.11 grad_norm_clip:0.11 sampled_reward_avg:0.00 train_time:0.17 time_spent:1.77
# 07/12/2024 05:28:26 - INFO - logger - iteration 481 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.09 grad_norm_clip:0.09 sampled_reward_avg:0.00 train_time:0.17 time_spent:1.42
# 07/12/2024 05:28:28 - INFO - logger - iteration 482 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.07 grad_norm_clip:0.07 sampled_reward_avg:0.00 train_time:0.19 time_spent:1.56
# 07/12/2024 05:28:29 - INFO - logger - iteration 483 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.05 grad_norm_clip:0.05 sampled_reward_avg:0.00 train_time:0.20 time_spent:1.44
# 07/12/2024 05:28:30 - INFO - logger - iteration 484 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.04 grad_norm_clip:0.04 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.42
# 07/12/2024 05:28:32 - INFO - logger - iteration 485 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.02 grad_norm_clip:0.02 sampled_reward_avg:0.00 train_time:0.43 time_spent:1.69
# 07/12/2024 05:28:34 - INFO - logger - iteration 486 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.01 grad_norm_clip:0.01 sampled_reward_avg:0.00 train_time:0.17 time_spent:1.40
# 07/12/2024 05:28:35 - INFO - logger - iteration 487 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.01 grad_norm_clip:0.01 sampled_reward_avg:0.00 train_time:0.19 time_spent:1.43
# 07/12/2024 05:28:36 - INFO - logger - iteration 488 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.02 grad_norm_clip:0.02 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.41
# 07/12/2024 05:28:38 - INFO - logger - iteration 489 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.03 grad_norm_clip:0.03 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.48
# 07/12/2024 05:28:39 - INFO - logger - iteration 490 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.03 grad_norm_clip:0.03 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.42
# 07/12/2024 05:28:41 - INFO - logger - iteration 491 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.04 grad_norm_clip:0.04 sampled_reward_avg:0.00 train_time:0.21 time_spent:1.55
# 07/12/2024 05:28:42 - INFO - logger - iteration 492 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.05 grad_norm_clip:0.05 sampled_reward_avg:0.00 train_time:0.20 time_spent:1.46
# 07/12/2024 05:28:44 - INFO - logger - iteration 493 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.05 grad_norm_clip:0.05 sampled_reward_avg:0.00 train_time:0.19 time_spent:1.47
# 07/12/2024 05:28:45 - INFO - logger - iteration 494 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.06 grad_norm_clip:0.06 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.44
# 07/12/2024 05:28:47 - INFO - logger - iteration 495 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.06 grad_norm_clip:0.06 sampled_reward_avg:0.00 train_time:0.17 time_spent:1.58
# 07/12/2024 05:28:48 - INFO - logger - iteration 496 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.06 grad_norm_clip:0.06 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.47
# 07/12/2024 05:28:50 - INFO - logger - iteration 497 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.07 grad_norm_clip:0.07 sampled_reward_avg:0.00 train_time:0.17 time_spent:1.41
# 07/12/2024 05:28:51 - INFO - logger - iteration 498 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.07 grad_norm_clip:0.07 sampled_reward_avg:0.00 train_time:0.18 time_spent:1.57
# 07/12/2024 05:28:53 - INFO - logger - iteration 499 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.07 grad_norm_clip:0.07 sampled_reward_avg:0.00 train_time:0.19 time_spent:1.43
# 07/12/2024 05:28:54 - INFO - logger - iteration 500 : offline_loss:0.00 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-5.44 loss:0.00 n_loss:0.00 tb_loss:0.00 batch_entropy:-0.00 traj_lens:2.00 grad_norm:0.07 grad_norm_clip:0.07 sampled_reward_avg:0.00 train_time:0.17 time_spent:1.41

# %%
with open(os.path.join(config.log_dir, "params.json"), "w+") as file:
    json.dump(params,file)

with open(os.path.join(config.log_dir, "target.json"), "w+") as file:
    json.dump(target,file)

state = {
    "models_state_dict": [trial.model.state_dict()],
    "cfg": trial.cfg,
    "env_ctx": trial.model.env_ctx,
    #"model": trial.model,
}
if trial.sampling_model is not trial.model:
    state["sampling_model_state_dict"] = [trial.sampling_model.state_dict()]
fn = pathlib.Path(trial.cfg.log_dir) / "model_final_save.pt"
with open(fn, "wb") as fd:
    torch.save(
        state,
        fd,
    )

# %%
# Generate molecules
trajs = trial.algo.create_training_data_from_own_samples(trial.model, 25)
objs = [trial.ctx.graph_to_obj(i['result']) for i in trajs]
obj_props, is_valid = trial.task.compute_obj_properties(objs)
cond_info = trial.task.sample_conditional_information(len(obj_props), 1)
log_rewards = trial.task.cond_info_to_logreward(cond_info, obj_props)
index = 0
rewards = []
for i in is_valid:
    if i:
        rewards.append(list(log_rewards)[index])
        index += 1 
    else:
        rewards.append(0)

MolsToGridImage(objs[:25], molsPerRow=5, subImgSize=(200, 120), legends=[f'reward: {r}' if r==0 else f'reward: {r.exp().item():.2f}' for r in rewards[:25]])

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')])
ax[0].set_yscale('log')
ax[1].set_ylabel('TB loss')
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')])
ax[1].set_ylabel('Average reward')
ax[2].plot([i.value for i in ea.Scalars('train_logZ')])
ax[2].set_ylabel('Predicted logZ')
pp.tight_layout()

# %%
tags = ea.Tags()
print("Available tags:", tags)

# %%
from pycirclize import Circos
import pandas as pd
import matplotlib.pyplot as plt
from pom_models.functions import fragance_propabilities_from_smiles
from rdkit import Chem
import numpy as np

# %%
indices = np.argsort(-np.array(target))
indices

# %%
labels = df.keys()[2:]
labels

# %%
data_lst  = []
for i, obj in enumerate(objs):
    smiles = Chem.MolToSmiles(obj)
    probs = fragance_propabilities_from_smiles(smiles)[0]

    data_lst.append( [smiles] + list(probs))
result_df = pd.DataFrame(
    data=data_lst,
    index=[i for i in range(len(data_lst))],
    columns=["smiles"]+list(labels)
    )
result_df.head()

# %%
target_df = pd.DataFrame(
    data=[["target"] + list(target)],
    columns=result_df.keys(),
    index=["Target"]
)
target_df

# %%
most_important_indicies = indices[:8]
most_important_keys = []
for i in most_important_indicies:
    most_important_keys.append(labels[i])
most_important_keys

# %%
rewards_plot = [f'{r}' if r==-1 else f'{r.exp().item():.2f}' for r in rewards[:25]]
rewards_plot

# %%
plot_df = result_df[most_important_keys].set_index(pd.Series([f"{i+1} r:{rewards_plot[i]}" for i in range(len(result_df["smiles"]))]))
plot_df

# %%
plot_target_df = target_df[most_important_keys]
plot_target_df

# %%
plot_df.loc["target"] = []

# %%
# Create 5 x 5 subplots
fig = plt.figure(figsize=(26, 16), dpi=100)
fig.subplots(5, 5, subplot_kw=dict(polar=True))
fig.subplots_adjust(wspace=1, hspace=0.25)

# Plot radar chart into subplots for each target
for target_name, ax in zip(plot_df.index, fig.axes):
    target_df = plot_df.loc[[target_name]]
    target_df = pd.concat([target_df, plot_target_df])
    # Initialize Circos instance for radar chart plot
    circos = Circos.radar_chart(
        target_df,
        vmax=1,
        marker_size=6,
        #cmap=dict(Hero="salmon", Warrior="skyblue", Wizard="lime", Assassin="magenta"),
        grid_interval_ratio=0.2,
        line_kws_handler=lambda _: dict(lw=2, ls="solid"),
        marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
    )

    # Plot figure & set legend on upper right
    circos.plotfig(ax=ax)
    circos.ax.legend(loc="upper right", fontsize=10,bbox_to_anchor=(1.7, 1.1))

# %%
np.array(result_df[labels].sum())/len(result_df[labels])

# %%
import seaborn as sns

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[0].set_yscale('log')
ax[0].set_ylabel('TB loss')
ax[0].grid()
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[1].set_ylabel('Average reward')
ax[1].set_xlabel('Iteration')
ax[1].grid()
ax[2].plot([i.value for i in ea.Scalars('train_logZ')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[2].set_ylabel('Predicted logZ')
ax[2].grid()
pp.tight_layout()
plt.savefig("images/pine_run_plots.pdf")
