# %% [markdown]
# # Run Vanilla

# %%
import sys
import os
path_to_top_dir = "../"
# Dynamically add the `project` directory to the path
sys.path.append(os.path.abspath(path_to_top_dir))

# %%
os.path.abspath(path_to_top_dir)
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model'

# %%
# Print current working directory
os.getcwd()
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model\\runs'

# %%
# Import scent_gfn functions
from scent_gfn.fragments import FRAGMENTS, FRAGMENTS_OPENPOM_DATASET, FRAGMENTS_OPENPOM_VANILLA
from scent_gfn.molecule import MoleculeTrainer
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# Skipped loading some PyTorch models, missing a dependency. No module named 'tensorflow'
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)

# %% [markdown]
# | **Parameter**                | **Value**      |
# |------------------------------|----------------|
# | Reward function type         | Structure        |
# | Similarity measure           | Cosine         |
# | Graph building               | Atoms      |
# | Iterations                   | 500            |
# | Max number of nodes          | 20              |
# | Illegal action logreward     | -100           |
# | β                            | 10              |
# | Large molecule penalty       | None           |

# %%
params = {
    "save_name": "vanilla6",
    "reward_func": "structure", # structure, openpom
    "similarity": "cosine",
    "graph_building": None,#FRAGMENTS,
    "iterations": 500,
    "max_nodes": 20,
    "illegal_logreward": -100,
    "beta": 10.0,
    "large_mol_pen": [None,None]# ["hard", 23]# ["exponential", 15] # ["exponential", 15] , ["hard", 15], [None,None]
}

# %%
# Utilities
import warnings
import random
import datetime

# Data processing and file management
import pathlib
import pandas as pd
import json
import numpy as np

# Machine learning
import torch
from gflownet.config import init_empty, Config
from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage, MolToImage


# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Run on cpu
dev = torch.device('cpu')

# %%
def get_pine_openpom_target():
    with open('../data/pine_target_2.json', 'r') as file:
        target = json.load(file)
    return [target]

# %%
def get_vanilla_test_and_training(split_ratio=0.7):
    df = pd.read_csv("../data/data.csv")
    vanilla_mols_df = df.loc[df['vanilla'] == 1]
    vanilla_smiles_trainig= list(vanilla_mols_df["nonStereoSMILES"])
    vanilla_smiles_trainig = random.sample(vanilla_smiles_trainig, round(len(vanilla_mols_df)*split_ratio))
    random.shuffle(vanilla_smiles_trainig)
    vanilla_smiles_test = []
    for i in vanilla_mols_df["nonStereoSMILES"]:
        if i not in vanilla_smiles_trainig:
            vanilla_smiles_test.append(i)
    return vanilla_smiles_trainig, vanilla_smiles_test

def get_vanillin():
    return ["COc1cc(C=O)ccc1O"]

# %%
target = get_vanillin()

# %%
# Initialize model
config = init_empty(Config())
config.print_every = 1
config.log_dir = f"{os.path.abspath(path_to_top_dir)}/results/{params['save_name']}_{datetime.datetime.now().strftime('%Y-%m-%d__%H_%M_%S')}"
config.device = dev
config.num_training_steps = params["iterations"]
config.num_workers = 0
config.num_validation_gen_steps = 1
config.overwrite_existing_exp=False
config.checkpoint_every = 100
config.algo.max_nodes = params["max_nodes"] #12 # 95 quantil
config.store_all_checkpoints = True
config.algo.illegal_action_logreward = params["illegal_logreward"]

if params["graph_building"] == None:
     trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]), print_config=True) #,fragments=FRAGMENTS, print_config=True)
else:
    trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]),fragments=params["graph_building"], print_config=True) #,fragments=FRAGMENTS, print_config=True)
# Out:
# SMILES input data detected ...
# Reward function: reward_function_structure | Similarity measure: CosineSimilarity | exp_penalty: False | max_mol=None
# Building molecules using atoms ...
#
#
# Hyperparameters:
#
# desc: noDesc
# log_dir: c:\Users\paulj\Desktop\prosjekt\pom_cpu-model/results/vanilla6_2024-12-04__22_30_41
# device: cpu
# seed: 0
# validate_every: 1000
# checkpoint_every: 100
# store_all_checkpoints: true
# print_every: 1
# start_at_step: 0
# num_final_gen_steps: null
# num_validation_gen_steps: 1
# num_training_steps: 500
# num_workers: 0
# hostname: null
# pickle_mp_messages: false
# git_hash: f106cde
# overwrite_existing_exp: false
# algo:
#   method: TB
#   num_from_policy: 64
#   num_from_dataset: 0
#   valid_num_from_policy: 64
#   valid_num_from_dataset: 0
#   max_len: 128
#   max_nodes: 20
#   max_edges: 128
#   illegal_action_logreward: -100.0
#   train_random_action_prob: 0.0
#   train_det_after: null
#   valid_random_action_prob: 0.0
#   sampling_tau: 0.9
#   tb:
#     bootstrap_own_reward: false
#     epsilon: null
#     reward_loss_multiplier: 1.0
#     variant: TB
#     do_correct_idempotent: false
#     do_parameterize_p_b: false
#     do_predict_n: false
#     do_sample_p_b: false
#     do_length_normalize: false
#     subtb_max_len: 128
#     Z_learning_rate: 0.0001
#     Z_lr_decay: 50000.0
#     cum_subtb: true
#     loss_fn: MSE
#     loss_fn_par: 1.0
#     n_loss: none
#     n_loss_multiplier: 1.0
#     backward_policy: Uniform
#   moql:
#     gamma: 1.0
#     num_omega_samples: 32
#     num_objectives: 2
#     lambda_decay: 10000
#     penalty: -10.0
#   a2c:
#     entropy: 0.01
#     gamma: 1.0
#     penalty: -10.0
#   fm:
#     epsilon: 1.0e-38
#     balanced_loss: false
#     leaf_coef: 10.0
#     correct_idempotent: false
#   sql:
#     alpha: 0.01
#     gamma: 1.0
#     penalty: -10.0
# model:
#   num_layers: 3
#   num_emb: 128
#   dropout: 0.0
#   graph_transformer:
#     num_heads: 2
#     ln_type: pre
#     num_mlp_layers: 0
#     concat_heads: true
#   seq_transformer:
#     num_heads: 2
#     posenc: Rotary
# opt:
#   opt: adam
#   learning_rate: 0.0001
#   lr_decay: 20000.0
#   weight_decay: 1.0e-08
#   momentum: 0.9
#   clip_grad_type: norm
#   clip_grad_param: 10.0
#   adam_eps: 1.0e-08
# replay:
#   use: false
#   capacity: null
#   warmup: null
#   hindsight_ratio: 0.0
#   num_from_replay: null
#   num_new_samples: null
# task:
#   qm9:
#     h5_path: ./data/qm9/qm9.h5
#     model_path: ./data/qm9/qm9_model.pt
#   qm9_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - gap
#     - qed
#     - sa
#     online_pareto_front: true
#   seh:
#     reduced_frag: false
#   seh_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - seh
#     - qed
#     - sa
#     - mw
#     log_topk: false
#     online_pareto_front: true
# cond:
#   valid_sample_cond_info: true
#   temperature:
#     sample_dist: uniform
#     dist_params:
#     - 0.5
#     - 32
#     num_thermometer_dim: 32
#   moo:
#     num_objectives: 2
#     num_thermometer_dim: 16
#   weighted_prefs:
#     preference_type: dirichlet
#     preference_param: 1.5
#   focus_region:
#     focus_type: centered
#     use_steer_thermomether: false
#     focus_cosim: 0.98
#     focus_limit_coef: 0.1
#     focus_model_training_limits:
#     - 0.25
#     - 0.75
#     focus_model_state_space_res: 30
#     max_train_it: 20000

# %%
trial.run()
# Out:
# 04/12/2024 22:30:42 - INFO - logger - Starting training
# 04/12/2024 22:30:51 - INFO - logger - iteration 1 : offline_loss:0.00 online_loss:2740.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.21 loss:2740.65 n_loss:0.00 tb_loss:2740.65 batch_entropy:31.88 traj_lens:10.66 grad_norm:914.14 grad_norm_clip:78.25 sampled_reward_avg:0.04 train_time:2.43 time_spent:8.82
# 04/12/2024 22:30:58 - INFO - logger - iteration 2 : offline_loss:0.00 online_loss:2713.89 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.18 loss:2713.89 n_loss:0.00 tb_loss:2713.89 batch_entropy:31.88 traj_lens:10.88 grad_norm:1711.67 grad_norm_clip:81.78 sampled_reward_avg:0.05 train_time:2.28 time_spent:7.57
# 04/12/2024 22:31:14 - INFO - logger - iteration 3 : offline_loss:0.00 online_loss:2360.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.15 loss:2360.00 n_loss:0.00 tb_loss:2360.00 batch_entropy:58.93 traj_lens:18.36 grad_norm:3197.85 grad_norm_clip:87.85 sampled_reward_avg:0.01 train_time:5.61 time_spent:15.25
# 04/12/2024 22:31:25 - INFO - logger - iteration 4 : offline_loss:0.00 online_loss:2051.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.12 loss:2051.47 n_loss:0.00 tb_loss:2051.47 batch_entropy:46.90 traj_lens:14.39 grad_norm:4070.75 grad_norm_clip:88.42 sampled_reward_avg:0.07 train_time:3.75 time_spent:10.78
# 04/12/2024 22:31:41 - INFO - logger - iteration 5 : offline_loss:0.00 online_loss:2406.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.09 loss:2406.09 n_loss:0.00 tb_loss:2406.09 batch_entropy:62.42 traj_lens:18.48 grad_norm:6761.23 grad_norm_clip:89.98 sampled_reward_avg:0.01 train_time:5.96 time_spent:16.55
# 04/12/2024 22:32:02 - INFO - logger - iteration 6 : offline_loss:0.00 online_loss:2204.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.05 loss:2204.65 n_loss:0.00 tb_loss:2204.65 batch_entropy:74.15 traj_lens:22.31 grad_norm:13167.55 grad_norm_clip:91.54 sampled_reward_avg:0.02 train_time:7.93 time_spent:21.19
# 04/12/2024 22:32:29 - INFO - logger - iteration 7 : offline_loss:0.00 online_loss:1902.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.02 loss:1902.76 n_loss:0.00 tb_loss:1902.76 batch_entropy:97.32 traj_lens:28.11 grad_norm:13411.48 grad_norm_clip:91.50 sampled_reward_avg:0.02 train_time:10.53 time_spent:26.85
# 04/12/2024 22:32:59 - INFO - logger - iteration 8 : offline_loss:0.00 online_loss:1732.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.01 loss:1732.69 n_loss:0.00 tb_loss:1732.69 batch_entropy:105.24 traj_lens:29.56 grad_norm:13071.72 grad_norm_clip:91.42 sampled_reward_avg:0.01 train_time:11.54 time_spent:29.60
# 04/12/2024 22:33:31 - INFO - logger - iteration 9 : offline_loss:0.00 online_loss:2029.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.05 loss:2029.23 n_loss:0.00 tb_loss:2029.23 batch_entropy:107.90 traj_lens:32.34 grad_norm:19879.64 grad_norm_clip:91.70 sampled_reward_avg:0.01 train_time:12.27 time_spent:32.57
# 04/12/2024 22:34:00 - INFO - logger - iteration 10 : offline_loss:0.00 online_loss:3232.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.08 loss:3232.79 n_loss:0.00 tb_loss:3232.79 batch_entropy:75.04 traj_lens:25.69 grad_norm:17556.58 grad_norm_clip:91.46 sampled_reward_avg:0.00 train_time:10.20 time_spent:28.36
# 04/12/2024 22:34:35 - INFO - logger - iteration 11 : offline_loss:0.00 online_loss:4238.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.12 loss:4238.70 n_loss:0.00 tb_loss:4238.70 batch_entropy:86.89 traj_lens:32.66 grad_norm:20373.00 grad_norm_clip:91.59 sampled_reward_avg:0.01 train_time:13.58 time_spent:35.32
# 04/12/2024 22:35:05 - INFO - logger - iteration 12 : offline_loss:0.00 online_loss:4956.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.15 loss:4956.30 n_loss:0.00 tb_loss:4956.30 batch_entropy:74.36 traj_lens:30.34 grad_norm:18007.80 grad_norm_clip:91.11 sampled_reward_avg:0.01 train_time:10.92 time_spent:29.83
# 04/12/2024 22:35:34 - INFO - logger - iteration 13 : offline_loss:0.00 online_loss:6238.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.18 loss:6238.54 n_loss:0.00 tb_loss:6238.54 batch_entropy:61.94 traj_lens:28.66 grad_norm:17988.10 grad_norm_clip:90.47 sampled_reward_avg:0.01 train_time:10.49 time_spent:28.95
# 04/12/2024 22:35:58 - INFO - logger - iteration 14 : offline_loss:0.00 online_loss:6167.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.22 loss:6167.34 n_loss:0.00 tb_loss:6167.34 batch_entropy:54.41 traj_lens:26.69 grad_norm:15403.54 grad_norm_clip:89.46 sampled_reward_avg:0.00 train_time:8.87 time_spent:24.28
# 04/12/2024 22:36:27 - INFO - logger - iteration 15 : offline_loss:0.00 online_loss:7771.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.25 loss:7771.09 n_loss:0.00 tb_loss:7771.09 batch_entropy:57.54 traj_lens:30.16 grad_norm:21243.38 grad_norm_clip:90.17 sampled_reward_avg:0.00 train_time:11.02 time_spent:29.26
# 04/12/2024 22:36:55 - INFO - logger - iteration 16 : offline_loss:0.00 online_loss:7924.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.29 loss:7924.88 n_loss:0.00 tb_loss:7924.88 batch_entropy:51.36 traj_lens:29.38 grad_norm:18464.63 grad_norm_clip:89.97 sampled_reward_avg:0.00 train_time:10.06 time_spent:27.31
# 04/12/2024 22:37:21 - INFO - logger - iteration 17 : offline_loss:0.00 online_loss:8053.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.32 loss:8053.30 n_loss:0.00 tb_loss:8053.30 batch_entropy:47.24 traj_lens:27.97 grad_norm:18715.36 grad_norm_clip:89.83 sampled_reward_avg:0.00 train_time:9.89 time_spent:26.43
# 04/12/2024 22:37:48 - INFO - logger - iteration 18 : offline_loss:0.00 online_loss:8718.62 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.35 loss:8718.62 n_loss:0.00 tb_loss:8718.62 batch_entropy:44.54 traj_lens:28.30 grad_norm:18940.69 grad_norm_clip:89.78 sampled_reward_avg:0.00 train_time:10.17 time_spent:27.01
# 04/12/2024 22:38:14 - INFO - logger - iteration 19 : offline_loss:0.00 online_loss:8900.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.39 loss:8900.98 n_loss:0.00 tb_loss:8900.98 batch_entropy:40.33 traj_lens:27.30 grad_norm:16632.77 grad_norm_clip:89.67 sampled_reward_avg:0.01 train_time:9.91 time_spent:26.11
# 04/12/2024 22:38:34 - INFO - logger - iteration 20 : offline_loss:0.00 online_loss:8224.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.42 loss:8224.84 n_loss:0.00 tb_loss:8224.84 batch_entropy:29.07 traj_lens:22.39 grad_norm:10768.78 grad_norm_clip:88.18 sampled_reward_avg:0.00 train_time:7.12 time_spent:19.72
# 04/12/2024 22:38:57 - INFO - logger - iteration 21 : offline_loss:0.00 online_loss:9209.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.46 loss:9209.10 n_loss:0.00 tb_loss:9209.10 batch_entropy:31.76 traj_lens:24.84 grad_norm:16368.35 grad_norm_clip:88.11 sampled_reward_avg:0.00 train_time:8.68 time_spent:23.61
# 04/12/2024 22:39:12 - INFO - logger - iteration 22 : offline_loss:0.00 online_loss:7419.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.49 loss:7419.87 n_loss:0.00 tb_loss:7419.87 batch_entropy:21.08 traj_lens:18.44 grad_norm:12644.34 grad_norm_clip:86.63 sampled_reward_avg:0.00 train_time:5.21 time_spent:14.74
# 04/12/2024 22:39:28 - INFO - logger - iteration 23 : offline_loss:0.00 online_loss:7759.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.53 loss:7759.22 n_loss:0.00 tb_loss:7759.22 batch_entropy:19.97 traj_lens:18.72 grad_norm:15685.25 grad_norm_clip:86.98 sampled_reward_avg:0.00 train_time:5.48 time_spent:15.68
# 04/12/2024 22:39:37 - INFO - logger - iteration 24 : offline_loss:0.00 online_loss:6284.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.56 loss:6284.00 n_loss:0.00 tb_loss:6284.00 batch_entropy:13.95 traj_lens:14.20 grad_norm:14401.52 grad_norm_clip:87.41 sampled_reward_avg:0.00 train_time:2.83 time_spent:8.95
# 04/12/2024 22:39:49 - INFO - logger - iteration 25 : offline_loss:0.00 online_loss:6566.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.60 loss:6566.12 n_loss:0.00 tb_loss:6566.12 batch_entropy:16.94 traj_lens:15.62 grad_norm:16662.86 grad_norm_clip:87.04 sampled_reward_avg:0.00 train_time:3.92 time_spent:11.71
# 04/12/2024 22:39:56 - INFO - logger - iteration 26 : offline_loss:0.00 online_loss:6093.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.63 loss:6093.52 n_loss:0.00 tb_loss:6093.52 batch_entropy:9.81 traj_lens:12.19 grad_norm:7892.63 grad_norm_clip:85.17 sampled_reward_avg:0.00 train_time:2.18 time_spent:7.11
# 04/12/2024 22:40:02 - INFO - logger - iteration 27 : offline_loss:0.00 online_loss:5500.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.67 loss:5500.84 n_loss:0.00 tb_loss:5500.84 batch_entropy:11.90 traj_lens:11.83 grad_norm:8772.04 grad_norm_clip:86.79 sampled_reward_avg:0.00 train_time:1.98 time_spent:6.56
# 04/12/2024 22:40:08 - INFO - logger - iteration 28 : offline_loss:0.00 online_loss:5827.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.71 loss:5827.94 n_loss:0.00 tb_loss:5827.94 batch_entropy:7.89 traj_lens:10.92 grad_norm:4969.43 grad_norm_clip:82.65 sampled_reward_avg:0.00 train_time:1.68 time_spent:6.16
# 04/12/2024 22:40:13 - INFO - logger - iteration 29 : offline_loss:0.00 online_loss:5167.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.74 loss:5167.04 n_loss:0.00 tb_loss:5167.04 batch_entropy:7.78 traj_lens:9.61 grad_norm:4998.42 grad_norm_clip:83.01 sampled_reward_avg:0.00 train_time:1.18 time_spent:4.38
# 04/12/2024 22:40:16 - INFO - logger - iteration 30 : offline_loss:0.00 online_loss:5192.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.78 loss:5192.77 n_loss:0.00 tb_loss:5192.77 batch_entropy:5.52 traj_lens:8.67 grad_norm:2304.86 grad_norm_clip:78.98 sampled_reward_avg:0.00 train_time:0.91 time_spent:3.53
# 04/12/2024 22:40:21 - INFO - logger - iteration 31 : offline_loss:0.00 online_loss:5489.96 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.82 loss:5489.96 n_loss:0.00 tb_loss:5489.96 batch_entropy:4.07 traj_lens:8.88 grad_norm:1384.08 grad_norm_clip:75.51 sampled_reward_avg:0.00 train_time:1.15 time_spent:4.26
# 04/12/2024 22:40:24 - INFO - logger - iteration 32 : offline_loss:0.00 online_loss:5533.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.86 loss:5533.70 n_loss:0.00 tb_loss:5533.70 batch_entropy:3.79 traj_lens:8.84 grad_norm:1111.20 grad_norm_clip:72.72 sampled_reward_avg:0.00 train_time:1.07 time_spent:3.87
# 04/12/2024 22:40:28 - INFO - logger - iteration 33 : offline_loss:0.00 online_loss:5526.49 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.90 loss:5526.49 n_loss:0.00 tb_loss:5526.49 batch_entropy:3.94 traj_lens:8.92 grad_norm:1078.36 grad_norm_clip:74.33 sampled_reward_avg:0.00 train_time:1.03 time_spent:3.95
# 04/12/2024 22:40:32 - INFO - logger - iteration 34 : offline_loss:0.00 online_loss:5544.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.93 loss:5544.24 n_loss:0.00 tb_loss:5544.24 batch_entropy:3.74 traj_lens:8.89 grad_norm:1015.90 grad_norm_clip:71.97 sampled_reward_avg:0.00 train_time:1.06 time_spent:3.97
# 04/12/2024 22:40:36 - INFO - logger - iteration 35 : offline_loss:0.00 online_loss:5603.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.97 loss:5603.65 n_loss:0.00 tb_loss:5603.65 batch_entropy:2.90 traj_lens:8.72 grad_norm:930.43 grad_norm_clip:67.28 sampled_reward_avg:0.00 train_time:0.98 time_spent:4.04
# 04/12/2024 22:40:39 - INFO - logger - iteration 36 : offline_loss:0.00 online_loss:5285.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.01 loss:5285.64 n_loss:0.00 tb_loss:5285.64 batch_entropy:2.68 traj_lens:8.02 grad_norm:872.79 grad_norm_clip:51.87 sampled_reward_avg:0.00 train_time:0.75 time_spent:2.59
# 04/12/2024 22:40:41 - INFO - logger - iteration 37 : offline_loss:0.00 online_loss:5301.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.05 loss:5301.40 n_loss:0.00 tb_loss:5301.40 batch_entropy:2.49 traj_lens:8.00 grad_norm:876.31 grad_norm_clip:33.80 sampled_reward_avg:0.00 train_time:0.75 time_spent:2.53
# 04/12/2024 22:40:44 - INFO - logger - iteration 38 : offline_loss:0.00 online_loss:5295.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.09 loss:5295.65 n_loss:0.00 tb_loss:5295.65 batch_entropy:2.49 traj_lens:8.00 grad_norm:886.46 grad_norm_clip:34.42 sampled_reward_avg:0.00 train_time:0.74 time_spent:2.48
# 04/12/2024 22:40:48 - INFO - logger - iteration 39 : offline_loss:0.00 online_loss:5427.80 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.13 loss:5427.80 n_loss:0.00 tb_loss:5427.80 batch_entropy:2.73 traj_lens:8.36 grad_norm:1005.15 grad_norm_clip:64.94 sampled_reward_avg:0.00 train_time:0.92 time_spent:3.75
# 04/12/2024 22:40:50 - INFO - logger - iteration 40 : offline_loss:0.00 online_loss:5283.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.17 loss:5283.78 n_loss:0.00 tb_loss:5283.78 batch_entropy:2.49 traj_lens:8.00 grad_norm:905.31 grad_norm_clip:36.38 sampled_reward_avg:0.00 train_time:0.79 time_spent:2.54
# 04/12/2024 22:40:54 - INFO - logger - iteration 41 : offline_loss:0.00 online_loss:5392.73 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.21 loss:5392.73 n_loss:0.00 tb_loss:5392.73 batch_entropy:2.74 traj_lens:8.27 grad_norm:966.08 grad_norm_clip:63.52 sampled_reward_avg:0.00 train_time:0.88 time_spent:3.43
# 04/12/2024 22:40:57 - INFO - logger - iteration 42 : offline_loss:0.00 online_loss:5388.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.25 loss:5388.30 n_loss:0.00 tb_loss:5388.30 batch_entropy:2.79 traj_lens:8.28 grad_norm:944.91 grad_norm_clip:56.94 sampled_reward_avg:0.00 train_time:0.88 time_spent:3.39
# 04/12/2024 22:41:00 - INFO - logger - iteration 43 : offline_loss:0.00 online_loss:5265.66 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.29 loss:5265.66 n_loss:0.00 tb_loss:5265.66 batch_entropy:2.49 traj_lens:8.00 grad_norm:933.01 grad_norm_clip:38.90 sampled_reward_avg:0.00 train_time:0.75 time_spent:2.76
# 04/12/2024 22:41:03 - INFO - logger - iteration 44 : offline_loss:0.00 online_loss:5370.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.34 loss:5370.88 n_loss:0.00 tb_loss:5370.88 batch_entropy:2.84 traj_lens:8.36 grad_norm:1161.94 grad_norm_clip:66.33 sampled_reward_avg:0.00 train_time:0.90 time_spent:3.47
# 04/12/2024 22:41:06 - INFO - logger - iteration 45 : offline_loss:0.00 online_loss:5253.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.38 loss:5253.21 n_loss:0.00 tb_loss:5253.21 batch_entropy:2.49 traj_lens:8.00 grad_norm:953.52 grad_norm_clip:42.52 sampled_reward_avg:0.00 train_time:0.78 time_spent:2.58
# 04/12/2024 22:41:08 - INFO - logger - iteration 46 : offline_loss:0.00 online_loss:5204.37 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.42 loss:5204.37 n_loss:0.00 tb_loss:5204.37 batch_entropy:2.58 traj_lens:7.81 grad_norm:965.96 grad_norm_clip:50.80 sampled_reward_avg:0.00 train_time:0.80 time_spent:2.55
# 04/12/2024 22:41:12 - INFO - logger - iteration 47 : offline_loss:0.00 online_loss:5340.95 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.46 loss:5340.95 n_loss:0.00 tb_loss:5340.95 batch_entropy:2.80 traj_lens:8.27 grad_norm:1290.56 grad_norm_clip:67.50 sampled_reward_avg:0.00 train_time:0.92 time_spent:3.64
# 04/12/2024 22:41:15 - INFO - logger - iteration 48 : offline_loss:0.00 online_loss:5212.83 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.51 loss:5212.83 n_loss:0.00 tb_loss:5212.83 batch_entropy:2.54 traj_lens:7.91 grad_norm:981.01 grad_norm_clip:32.30 sampled_reward_avg:0.00 train_time:0.75 time_spent:2.54
# 04/12/2024 22:41:17 - INFO - logger - iteration 49 : offline_loss:0.00 online_loss:5226.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.55 loss:5226.22 n_loss:0.00 tb_loss:5226.22 batch_entropy:2.51 traj_lens:8.00 grad_norm:1010.71 grad_norm_clip:56.65 sampled_reward_avg:0.00 train_time:0.78 time_spent:2.48
# 04/12/2024 22:41:20 - INFO - logger - iteration 50 : offline_loss:0.00 online_loss:5198.81 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.59 loss:5198.81 n_loss:0.00 tb_loss:5198.81 batch_entropy:2.55 traj_lens:7.91 grad_norm:1019.14 grad_norm_clip:56.66 sampled_reward_avg:0.00 train_time:0.78 time_spent:2.57
# 04/12/2024 22:41:22 - INFO - logger - iteration 51 : offline_loss:0.00 online_loss:5207.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.64 loss:5207.26 n_loss:0.00 tb_loss:5207.26 batch_entropy:2.55 traj_lens:8.00 grad_norm:1158.49 grad_norm_clip:67.30 sampled_reward_avg:0.00 train_time:0.77 time_spent:2.57
# 04/12/2024 22:41:25 - INFO - logger - iteration 52 : offline_loss:0.00 online_loss:5190.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.69 loss:5190.33 n_loss:0.00 tb_loss:5190.33 batch_entropy:2.62 traj_lens:8.00 grad_norm:1561.91 grad_norm_clip:72.73 sampled_reward_avg:0.00 train_time:0.79 time_spent:2.77
# 04/12/2024 22:41:28 - INFO - logger - iteration 53 : offline_loss:0.00 online_loss:5156.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.73 loss:5156.70 n_loss:0.00 tb_loss:5156.70 batch_entropy:2.81 traj_lens:8.00 grad_norm:2913.99 grad_norm_clip:77.41 sampled_reward_avg:0.00 train_time:0.78 time_spent:2.54
# 04/12/2024 22:41:30 - INFO - logger - iteration 54 : offline_loss:0.00 online_loss:5067.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.78 loss:5067.52 n_loss:0.00 tb_loss:5067.52 batch_entropy:3.28 traj_lens:7.91 grad_norm:6201.06 grad_norm_clip:82.82 sampled_reward_avg:0.00 train_time:0.77 time_spent:2.51
# 04/12/2024 22:41:33 - INFO - logger - iteration 55 : offline_loss:0.00 online_loss:4897.92 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.82 loss:4897.92 n_loss:0.00 tb_loss:4897.92 batch_entropy:4.47 traj_lens:7.95 grad_norm:12494.66 grad_norm_clip:84.74 sampled_reward_avg:0.00 train_time:0.74 time_spent:2.51
# 04/12/2024 22:41:35 - INFO - logger - iteration 56 : offline_loss:0.00 online_loss:4578.01 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.87 loss:4578.01 n_loss:0.00 tb_loss:4578.01 batch_entropy:6.51 traj_lens:7.77 grad_norm:18101.84 grad_norm_clip:85.82 sampled_reward_avg:0.00 train_time:0.77 time_spent:2.75
# 04/12/2024 22:41:38 - INFO - logger - iteration 57 : offline_loss:0.00 online_loss:4183.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.92 loss:4183.21 n_loss:0.00 tb_loss:4183.21 batch_entropy:8.85 traj_lens:7.30 grad_norm:19169.41 grad_norm_clip:85.66 sampled_reward_avg:0.00 train_time:0.70 time_spent:2.27
# 04/12/2024 22:41:40 - INFO - logger - iteration 58 : offline_loss:0.00 online_loss:3730.48 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-1.96 loss:3730.48 n_loss:0.00 tb_loss:3730.48 batch_entropy:12.28 traj_lens:7.28 grad_norm:19643.18 grad_norm_clip:85.69 sampled_reward_avg:0.00 train_time:0.70 time_spent:2.28
# 04/12/2024 22:41:42 - INFO - logger - iteration 59 : offline_loss:0.00 online_loss:3267.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.01 loss:3267.40 n_loss:0.00 tb_loss:3267.40 batch_entropy:16.54 traj_lens:7.33 grad_norm:18816.12 grad_norm_clip:86.82 sampled_reward_avg:0.00 train_time:0.74 time_spent:2.49
# 04/12/2024 22:41:44 - INFO - logger - iteration 60 : offline_loss:0.00 online_loss:3222.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.06 loss:3222.93 n_loss:0.00 tb_loss:3222.93 batch_entropy:14.82 traj_lens:5.77 grad_norm:14636.98 grad_norm_clip:85.48 sampled_reward_avg:0.00 train_time:0.54 time_spent:1.84
# 04/12/2024 22:41:46 - INFO - logger - iteration 61 : offline_loss:0.00 online_loss:3435.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.11 loss:3435.93 n_loss:0.00 tb_loss:3435.93 batch_entropy:11.21 traj_lens:4.14 grad_norm:10148.69 grad_norm_clip:85.08 sampled_reward_avg:0.00 train_time:0.38 time_spent:1.45
# 04/12/2024 22:41:47 - INFO - logger - iteration 62 : offline_loss:0.00 online_loss:3880.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.16 loss:3880.21 n_loss:0.00 tb_loss:3880.21 batch_entropy:5.82 traj_lens:2.80 grad_norm:4565.80 grad_norm_clip:81.64 sampled_reward_avg:0.00 train_time:0.24 time_spent:0.95
# 04/12/2024 22:41:47 - INFO - logger - iteration 63 : offline_loss:0.00 online_loss:4249.91 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.21 loss:4249.91 n_loss:0.00 tb_loss:4249.91 batch_entropy:2.15 traj_lens:2.22 grad_norm:2018.37 grad_norm_clip:76.00 sampled_reward_avg:0.00 train_time:0.21 time_spent:0.79
# 04/12/2024 22:41:48 - INFO - logger - iteration 64 : offline_loss:0.00 online_loss:4337.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.26 loss:4337.54 n_loss:0.00 tb_loss:4337.54 batch_entropy:1.03 traj_lens:2.05 grad_norm:2687.06 grad_norm_clip:78.37 sampled_reward_avg:0.00 train_time:0.19 time_spent:0.89
# 04/12/2024 22:41:49 - INFO - logger - iteration 65 : offline_loss:0.00 online_loss:4259.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.31 loss:4259.90 n_loss:0.00 tb_loss:4259.90 batch_entropy:1.55 traj_lens:2.03 grad_norm:4112.62 grad_norm_clip:80.68 sampled_reward_avg:0.00 train_time:0.20 time_spent:0.63
# 04/12/2024 22:41:50 - INFO - logger - iteration 66 : offline_loss:0.00 online_loss:4156.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.36 loss:4156.86 n_loss:0.00 tb_loss:4156.86 batch_entropy:2.27 traj_lens:2.02 grad_norm:5215.86 grad_norm_clip:80.69 sampled_reward_avg:0.00 train_time:0.18 time_spent:0.58
# 04/12/2024 22:41:50 - INFO - logger - iteration 67 : offline_loss:0.00 online_loss:3960.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.42 loss:3960.99 n_loss:0.00 tb_loss:3960.99 batch_entropy:3.18 traj_lens:2.00 grad_norm:5526.99 grad_norm_clip:80.05 sampled_reward_avg:0.01 train_time:0.18 time_spent:0.60
# 04/12/2024 22:41:51 - INFO - logger - iteration 68 : offline_loss:0.00 online_loss:3794.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.47 loss:3794.15 n_loss:0.00 tb_loss:3794.15 batch_entropy:4.46 traj_lens:2.00 grad_norm:5603.12 grad_norm_clip:80.06 sampled_reward_avg:0.01 train_time:0.18 time_spent:0.58
# 04/12/2024 22:41:51 - INFO - logger - iteration 69 : offline_loss:0.00 online_loss:3342.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.52 loss:3342.24 n_loss:0.00 tb_loss:3342.24 batch_entropy:5.29 traj_lens:2.00 grad_norm:5012.56 grad_norm_clip:80.05 sampled_reward_avg:0.06 train_time:0.19 time_spent:0.69
# 04/12/2024 22:41:52 - INFO - logger - iteration 70 : offline_loss:0.00 online_loss:3055.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.58 loss:3055.53 n_loss:0.00 tb_loss:3055.53 batch_entropy:6.54 traj_lens:2.02 grad_norm:4744.03 grad_norm_clip:80.68 sampled_reward_avg:0.07 train_time:0.19 time_spent:0.71
# 04/12/2024 22:41:53 - INFO - logger - iteration 71 : offline_loss:0.00 online_loss:2198.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.63 loss:2198.22 n_loss:0.00 tb_loss:2198.22 batch_entropy:5.65 traj_lens:2.00 grad_norm:3509.44 grad_norm_clip:79.21 sampled_reward_avg:0.20 train_time:0.18 time_spent:0.85
# 04/12/2024 22:41:54 - INFO - logger - iteration 72 : offline_loss:0.00 online_loss:850.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.69 loss:850.94 n_loss:0.00 tb_loss:850.94 batch_entropy:2.08 traj_lens:2.00 grad_norm:1188.50 grad_norm_clip:70.84 sampled_reward_avg:0.44 train_time:0.18 time_spent:1.17
# 04/12/2024 22:41:55 - INFO - logger - iteration 73 : offline_loss:0.00 online_loss:426.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.74 loss:426.12 n_loss:0.00 tb_loss:426.12 batch_entropy:1.06 traj_lens:2.00 grad_norm:600.44 grad_norm_clip:67.10 sampled_reward_avg:0.51 train_time:0.20 time_spent:1.30
# 04/12/2024 22:41:57 - INFO - logger - iteration 74 : offline_loss:0.00 online_loss:244.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.80 loss:244.53 n_loss:0.00 tb_loss:244.53 batch_entropy:0.87 traj_lens:2.00 grad_norm:379.15 grad_norm_clip:62.93 sampled_reward_avg:0.54 train_time:0.19 time_spent:1.35
# 04/12/2024 22:41:58 - INFO - logger - iteration 75 : offline_loss:0.00 online_loss:322.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.85 loss:322.52 n_loss:0.00 tb_loss:322.52 batch_entropy:0.76 traj_lens:2.00 grad_norm:523.08 grad_norm_clip:64.79 sampled_reward_avg:0.53 train_time:0.19 time_spent:1.33
# 04/12/2024 22:41:59 - INFO - logger - iteration 76 : offline_loss:0.00 online_loss:57.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.91 loss:57.14 n_loss:0.00 tb_loss:57.14 batch_entropy:0.14 traj_lens:2.00 grad_norm:110.80 grad_norm_clip:42.23 sampled_reward_avg:0.57 train_time:0.18 time_spent:1.40
# 04/12/2024 22:42:01 - INFO - logger - iteration 77 : offline_loss:0.00 online_loss:6.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-2.97 loss:6.09 n_loss:0.00 tb_loss:6.09 batch_entropy:0.00 traj_lens:2.00 grad_norm:45.97 grad_norm_clip:15.51 sampled_reward_avg:0.58 train_time:0.19 time_spent:1.40
# 04/12/2024 22:42:02 - INFO - logger - iteration 78 : offline_loss:0.00 online_loss:50.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.03 loss:50.60 n_loss:0.00 tb_loss:50.60 batch_entropy:0.20 traj_lens:2.00 grad_norm:112.10 grad_norm_clip:43.64 sampled_reward_avg:0.57 train_time:0.17 time_spent:1.47
# 04/12/2024 22:42:04 - INFO - logger - iteration 79 : offline_loss:0.00 online_loss:5.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.08 loss:5.52 n_loss:0.00 tb_loss:5.52 batch_entropy:0.01 traj_lens:2.00 grad_norm:44.69 grad_norm_clip:15.51 sampled_reward_avg:0.58 train_time:0.17 time_spent:1.40
# 04/12/2024 22:42:05 - INFO - logger - iteration 80 : offline_loss:0.00 online_loss:5.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.14 loss:5.23 n_loss:0.00 tb_loss:5.23 batch_entropy:0.01 traj_lens:2.00 grad_norm:44.03 grad_norm_clip:15.65 sampled_reward_avg:0.58 train_time:0.17 time_spent:1.43
# 04/12/2024 22:42:07 - INFO - logger - iteration 81 : offline_loss:0.00 online_loss:4.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.20 loss:4.94 n_loss:0.00 tb_loss:4.94 batch_entropy:0.02 traj_lens:2.00 grad_norm:43.46 grad_norm_clip:16.08 sampled_reward_avg:0.58 train_time:0.20 time_spent:1.39
# 04/12/2024 22:42:08 - INFO - logger - iteration 82 : offline_loss:0.00 online_loss:4.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.26 loss:4.64 n_loss:0.00 tb_loss:4.64 batch_entropy:0.02 traj_lens:2.00 grad_norm:42.98 grad_norm_clip:17.12 sampled_reward_avg:0.58 train_time:0.19 time_spent:1.40
# 04/12/2024 22:42:09 - INFO - logger - iteration 83 : offline_loss:0.00 online_loss:4.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.32 loss:4.33 n_loss:0.00 tb_loss:4.33 batch_entropy:0.04 traj_lens:2.00 grad_norm:42.96 grad_norm_clip:19.39 sampled_reward_avg:0.58 train_time:0.19 time_spent:1.40
# 04/12/2024 22:42:11 - INFO - logger - iteration 84 : offline_loss:0.00 online_loss:3.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.38 loss:3.99 n_loss:0.00 tb_loss:3.99 batch_entropy:0.06 traj_lens:2.00 grad_norm:44.09 grad_norm_clip:21.83 sampled_reward_avg:0.58 train_time:0.19 time_spent:1.40
# 04/12/2024 22:42:12 - INFO - logger - iteration 85 : offline_loss:0.00 online_loss:3.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.44 loss:3.61 n_loss:0.00 tb_loss:3.61 batch_entropy:0.10 traj_lens:2.00 grad_norm:47.93 grad_norm_clip:23.48 sampled_reward_avg:0.58 train_time:0.20 time_spent:1.43
# 04/12/2024 22:42:14 - INFO - logger - iteration 86 : offline_loss:0.00 online_loss:3.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.50 loss:3.13 n_loss:0.00 tb_loss:3.13 batch_entropy:0.17 traj_lens:2.00 grad_norm:57.33 grad_norm_clip:26.77 sampled_reward_avg:0.58 train_time:0.19 time_spent:1.40
# 04/12/2024 22:42:15 - INFO - logger - iteration 87 : offline_loss:0.00 online_loss:2.48 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.56 loss:2.48 n_loss:0.00 tb_loss:2.48 batch_entropy:0.30 traj_lens:2.00 grad_norm:74.72 grad_norm_clip:32.73 sampled_reward_avg:0.58 train_time:0.18 time_spent:1.43
# 04/12/2024 22:42:16 - INFO - logger - iteration 88 : offline_loss:0.00 online_loss:1.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.62 loss:1.55 n_loss:0.00 tb_loss:1.55 batch_entropy:0.57 traj_lens:2.00 grad_norm:92.94 grad_norm_clip:38.27 sampled_reward_avg:0.58 train_time:0.18 time_spent:1.38
# 04/12/2024 22:42:18 - INFO - logger - iteration 89 : offline_loss:0.00 online_loss:0.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.68 loss:0.47 n_loss:0.00 tb_loss:0.47 batch_entropy:1.08 traj_lens:2.00 grad_norm:75.62 grad_norm_clip:33.16 sampled_reward_avg:0.58 train_time:0.18 time_spent:1.47
# 04/12/2024 22:42:19 - INFO - logger - iteration 90 : offline_loss:0.00 online_loss:0.02 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.74 loss:0.02 n_loss:0.00 tb_loss:0.02 batch_entropy:1.85 traj_lens:2.02 grad_norm:20.83 grad_norm_clip:16.35 sampled_reward_avg:0.58 train_time:0.20 time_spent:1.47
# 04/12/2024 22:42:21 - INFO - logger - iteration 91 : offline_loss:0.00 online_loss:0.95 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.79 loss:0.95 n_loss:0.00 tb_loss:0.95 batch_entropy:2.64 traj_lens:2.09 grad_norm:152.18 grad_norm_clip:46.07 sampled_reward_avg:0.58 train_time:0.20 time_spent:1.69
# 04/12/2024 22:42:22 - INFO - logger - iteration 92 : offline_loss:0.00 online_loss:1.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.83 loss:1.98 n_loss:0.00 tb_loss:1.98 batch_entropy:3.02 traj_lens:2.05 grad_norm:227.48 grad_norm_clip:52.56 sampled_reward_avg:0.58 train_time:0.18 time_spent:1.43
# 04/12/2024 22:42:24 - INFO - logger - iteration 93 : offline_loss:0.00 online_loss:2.44 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.87 loss:2.44 n_loss:0.00 tb_loss:2.44 batch_entropy:3.19 traj_lens:2.19 grad_norm:259.16 grad_norm_clip:54.27 sampled_reward_avg:0.59 train_time:0.20 time_spent:1.52
# 04/12/2024 22:42:26 - INFO - logger - iteration 94 : offline_loss:0.00 online_loss:2.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.89 loss:2.03 n_loss:0.00 tb_loss:2.03 batch_entropy:3.03 traj_lens:2.27 grad_norm:236.78 grad_norm_clip:52.89 sampled_reward_avg:0.59 train_time:0.22 time_spent:1.53
# 04/12/2024 22:42:27 - INFO - logger - iteration 95 : offline_loss:0.00 online_loss:1.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.90 loss:1.00 n_loss:0.00 tb_loss:1.00 batch_entropy:2.63 traj_lens:2.36 grad_norm:162.60 grad_norm_clip:46.40 sampled_reward_avg:0.59 train_time:0.21 time_spent:1.54
# 04/12/2024 22:42:29 - INFO - logger - iteration 96 : offline_loss:0.00 online_loss:0.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.91 loss:0.35 n_loss:0.00 tb_loss:0.35 batch_entropy:2.18 traj_lens:2.53 grad_norm:74.88 grad_norm_clip:31.28 sampled_reward_avg:0.59 train_time:0.25 time_spent:1.67
# 04/12/2024 22:42:30 - INFO - logger - iteration 97 : offline_loss:0.00 online_loss:0.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.91 loss:0.20 n_loss:0.00 tb_loss:0.20 batch_entropy:1.66 traj_lens:2.53 grad_norm:12.76 grad_norm_clip:12.76 sampled_reward_avg:0.59 train_time:0.22 time_spent:1.57
# 04/12/2024 22:42:32 - INFO - logger - iteration 98 : offline_loss:0.00 online_loss:0.39 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.91 loss:0.39 n_loss:0.00 tb_loss:0.39 batch_entropy:1.30 traj_lens:2.52 grad_norm:54.04 grad_norm_clip:24.52 sampled_reward_avg:0.59 train_time:0.21 time_spent:1.63
# 04/12/2024 22:42:34 - INFO - logger - iteration 99 : offline_loss:0.00 online_loss:0.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.92 loss:0.68 n_loss:0.00 tb_loss:0.68 batch_entropy:1.34 traj_lens:2.70 grad_norm:72.47 grad_norm_clip:29.62 sampled_reward_avg:0.60 train_time:0.25 time_spent:1.72
# 04/12/2024 22:42:35 - INFO - logger - iteration 100 : offline_loss:0.00 online_loss:1.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.92 loss:1.22 n_loss:0.00 tb_loss:1.22 batch_entropy:1.49 traj_lens:2.80 grad_norm:128.44 grad_norm_clip:40.64 sampled_reward_avg:0.60 train_time:0.24 time_spent:1.75
# 04/12/2024 22:42:37 - INFO - logger - iteration 101 : offline_loss:0.00 online_loss:2.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.93 loss:2.11 n_loss:0.00 tb_loss:2.11 batch_entropy:1.53 traj_lens:2.77 grad_norm:212.05 grad_norm_clip:48.60 sampled_reward_avg:0.60 train_time:0.25 time_spent:1.88
# 04/12/2024 22:42:39 - INFO - logger - iteration 102 : offline_loss:0.00 online_loss:0.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.94 loss:0.71 n_loss:0.00 tb_loss:0.71 batch_entropy:1.51 traj_lens:2.84 grad_norm:89.61 grad_norm_clip:33.84 sampled_reward_avg:0.60 train_time:0.28 time_spent:1.77
# 04/12/2024 22:42:41 - INFO - logger - iteration 103 : offline_loss:0.00 online_loss:0.50 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.95 loss:0.50 n_loss:0.00 tb_loss:0.50 batch_entropy:1.54 traj_lens:2.77 grad_norm:61.07 grad_norm_clip:25.32 sampled_reward_avg:0.60 train_time:0.24 time_spent:1.73
# 04/12/2024 22:42:43 - INFO - logger - iteration 104 : offline_loss:0.00 online_loss:0.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.96 loss:0.23 n_loss:0.00 tb_loss:0.23 batch_entropy:1.68 traj_lens:2.78 grad_norm:17.85 grad_norm_clip:15.03 sampled_reward_avg:0.60 train_time:0.27 time_spent:1.92
# 04/12/2024 22:42:45 - INFO - logger - iteration 105 : offline_loss:0.00 online_loss:0.75 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.97 loss:0.75 n_loss:0.00 tb_loss:0.75 batch_entropy:2.25 traj_lens:2.97 grad_norm:24.80 grad_norm_clip:19.03 sampled_reward_avg:0.60 train_time:0.30 time_spent:1.96
# 04/12/2024 22:42:46 - INFO - logger - iteration 106 : offline_loss:0.00 online_loss:0.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.98 loss:0.41 n_loss:0.00 tb_loss:0.41 batch_entropy:2.23 traj_lens:2.77 grad_norm:77.73 grad_norm_clip:31.02 sampled_reward_avg:0.60 train_time:0.28 time_spent:1.79
# 04/12/2024 22:42:49 - INFO - logger - iteration 107 : offline_loss:0.00 online_loss:1.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.98 loss:1.54 n_loss:0.00 tb_loss:1.54 batch_entropy:3.04 traj_lens:3.58 grad_norm:138.77 grad_norm_clip:42.94 sampled_reward_avg:0.62 train_time:0.36 time_spent:2.11
# 04/12/2024 22:42:51 - INFO - logger - iteration 108 : offline_loss:0.00 online_loss:1.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.98 loss:1.14 n_loss:0.00 tb_loss:1.14 batch_entropy:2.89 traj_lens:3.55 grad_norm:117.11 grad_norm_clip:39.33 sampled_reward_avg:0.62 train_time:0.33 time_spent:2.30
# 04/12/2024 22:42:53 - INFO - logger - iteration 109 : offline_loss:0.00 online_loss:1.48 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.97 loss:1.48 n_loss:0.00 tb_loss:1.48 batch_entropy:2.91 traj_lens:3.67 grad_norm:84.26 grad_norm_clip:32.80 sampled_reward_avg:0.62 train_time:0.35 time_spent:2.08
# 04/12/2024 22:42:55 - INFO - logger - iteration 110 : offline_loss:0.00 online_loss:1.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.96 loss:1.26 n_loss:0.00 tb_loss:1.26 batch_entropy:2.80 traj_lens:3.78 grad_norm:23.02 grad_norm_clip:19.57 sampled_reward_avg:0.62 train_time:0.36 time_spent:2.05
# 04/12/2024 22:42:57 - INFO - logger - iteration 111 : offline_loss:0.00 online_loss:1.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.94 loss:1.19 n_loss:0.00 tb_loss:1.19 batch_entropy:2.67 traj_lens:3.94 grad_norm:43.23 grad_norm_clip:21.36 sampled_reward_avg:0.63 train_time:0.36 time_spent:2.15
# 04/12/2024 22:42:59 - INFO - logger - iteration 112 : offline_loss:0.00 online_loss:2.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.93 loss:2.03 n_loss:0.00 tb_loss:2.03 batch_entropy:2.58 traj_lens:3.67 grad_norm:136.03 grad_norm_clip:41.69 sampled_reward_avg:0.62 train_time:0.35 time_spent:2.04
# 04/12/2024 22:43:01 - INFO - logger - iteration 113 : offline_loss:0.00 online_loss:1.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.91 loss:1.52 n_loss:0.00 tb_loss:1.52 batch_entropy:2.79 traj_lens:3.86 grad_norm:194.26 grad_norm_clip:46.96 sampled_reward_avg:0.62 train_time:0.39 time_spent:2.14
# 04/12/2024 22:43:03 - INFO - logger - iteration 114 : offline_loss:0.00 online_loss:0.91 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.89 loss:0.91 n_loss:0.00 tb_loss:0.91 batch_entropy:2.57 traj_lens:3.78 grad_norm:40.27 grad_norm_clip:19.97 sampled_reward_avg:0.62 train_time:0.35 time_spent:2.01
# 04/12/2024 22:43:05 - INFO - logger - iteration 115 : offline_loss:0.00 online_loss:1.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.87 loss:1.13 n_loss:0.00 tb_loss:1.13 batch_entropy:2.88 traj_lens:4.03 grad_norm:24.96 grad_norm_clip:18.03 sampled_reward_avg:0.63 train_time:0.35 time_spent:2.10
# 04/12/2024 22:43:07 - INFO - logger - iteration 116 : offline_loss:0.00 online_loss:1.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.86 loss:1.16 n_loss:0.00 tb_loss:1.16 batch_entropy:3.00 traj_lens:3.64 grad_norm:14.26 grad_norm_clip:12.24 sampled_reward_avg:0.62 train_time:0.34 time_spent:1.97
# 04/12/2024 22:43:09 - INFO - logger - iteration 117 : offline_loss:0.00 online_loss:0.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.84 loss:0.98 n_loss:0.00 tb_loss:0.98 batch_entropy:2.96 traj_lens:3.92 grad_norm:87.97 grad_norm_clip:33.37 sampled_reward_avg:0.63 train_time:0.37 time_spent:2.06
# 04/12/2024 22:43:12 - INFO - logger - iteration 118 : offline_loss:0.00 online_loss:1.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.82 loss:1.47 n_loss:0.00 tb_loss:1.47 batch_entropy:3.44 traj_lens:4.20 grad_norm:65.49 grad_norm_clip:27.95 sampled_reward_avg:0.63 train_time:0.39 time_spent:2.24
# 04/12/2024 22:43:14 - INFO - logger - iteration 119 : offline_loss:0.00 online_loss:1.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.79 loss:1.22 n_loss:0.00 tb_loss:1.22 batch_entropy:3.41 traj_lens:4.59 grad_norm:47.13 grad_norm_clip:22.35 sampled_reward_avg:0.64 train_time:0.43 time_spent:2.51
# 04/12/2024 22:43:17 - INFO - logger - iteration 120 : offline_loss:0.00 online_loss:1.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.77 loss:1.11 n_loss:0.00 tb_loss:1.11 batch_entropy:3.38 traj_lens:4.58 grad_norm:40.83 grad_norm_clip:21.40 sampled_reward_avg:0.64 train_time:0.43 time_spent:2.28
# 04/12/2024 22:43:19 - INFO - logger - iteration 121 : offline_loss:0.00 online_loss:1.83 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.74 loss:1.83 n_loss:0.00 tb_loss:1.83 batch_entropy:3.43 traj_lens:4.41 grad_norm:15.69 grad_norm_clip:15.29 sampled_reward_avg:0.64 train_time:0.39 time_spent:2.29
# 04/12/2024 22:43:21 - INFO - logger - iteration 122 : offline_loss:0.00 online_loss:4.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.72 loss:4.87 n_loss:0.00 tb_loss:4.87 batch_entropy:3.66 traj_lens:4.28 grad_norm:320.40 grad_norm_clip:56.39 sampled_reward_avg:0.63 train_time:0.44 time_spent:2.29
# 04/12/2024 22:43:23 - INFO - logger - iteration 123 : offline_loss:0.00 online_loss:2.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.69 loss:2.04 n_loss:0.00 tb_loss:2.04 batch_entropy:4.03 traj_lens:5.03 grad_norm:53.80 grad_norm_clip:25.78 sampled_reward_avg:0.65 train_time:0.48 time_spent:2.37
# 04/12/2024 22:43:26 - INFO - logger - iteration 124 : offline_loss:0.00 online_loss:2.01 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.66 loss:2.01 n_loss:0.00 tb_loss:2.01 batch_entropy:3.92 traj_lens:4.80 grad_norm:29.45 grad_norm_clip:21.12 sampled_reward_avg:0.64 train_time:0.49 time_spent:2.41
# 04/12/2024 22:43:28 - INFO - logger - iteration 125 : offline_loss:0.00 online_loss:1.01 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.63 loss:1.01 n_loss:0.00 tb_loss:1.01 batch_entropy:3.56 traj_lens:4.53 grad_norm:55.58 grad_norm_clip:24.53 sampled_reward_avg:0.64 train_time:0.46 time_spent:2.24
# 04/12/2024 22:43:31 - INFO - logger - iteration 126 : offline_loss:0.00 online_loss:1.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.60 loss:1.11 n_loss:0.00 tb_loss:1.11 batch_entropy:3.80 traj_lens:4.67 grad_norm:69.29 grad_norm_clip:28.94 sampled_reward_avg:0.64 train_time:0.49 time_spent:2.41
# 04/12/2024 22:43:33 - INFO - logger - iteration 127 : offline_loss:0.00 online_loss:2.02 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.57 loss:2.02 n_loss:0.00 tb_loss:2.02 batch_entropy:4.37 traj_lens:5.09 grad_norm:67.53 grad_norm_clip:29.13 sampled_reward_avg:0.65 train_time:0.49 time_spent:2.77
# 04/12/2024 22:43:36 - INFO - logger - iteration 128 : offline_loss:0.00 online_loss:1.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-3.54 loss:1.52 n_loss:0.00 tb_loss:1.52 batch_entropy:4.00 traj_lens:4.95 grad_norm:20.14 grad_norm_clip:18.31 sampled_reward_avg:0.65 train_time:0.53 time_spent:2.52
# ...
# 04/12/2024 23:42:58 - INFO - logger - iteration 458 : offline_loss:0.00 online_loss:0.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.56 loss:0.18 n_loss:0.00 tb_loss:0.18 batch_entropy:35.25 traj_lens:20.22 grad_norm:15.30 grad_norm_clip:15.30 sampled_reward_avg:0.80 train_time:6.21 time_spent:14.84
# 04/12/2024 23:43:14 - INFO - logger - iteration 459 : offline_loss:0.00 online_loss:0.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.57 loss:0.22 n_loss:0.00 tb_loss:0.22 batch_entropy:34.71 traj_lens:20.30 grad_norm:19.55 grad_norm_clip:18.70 sampled_reward_avg:0.79 train_time:6.32 time_spent:15.33
# 04/12/2024 23:43:29 - INFO - logger - iteration 460 : offline_loss:0.00 online_loss:0.28 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.57 loss:0.28 n_loss:0.00 tb_loss:0.28 batch_entropy:35.25 traj_lens:20.36 grad_norm:17.20 grad_norm_clip:17.06 sampled_reward_avg:0.80 train_time:6.44 time_spent:15.39
# 04/12/2024 23:43:44 - INFO - logger - iteration 461 : offline_loss:0.00 online_loss:0.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.57 loss:0.31 n_loss:0.00 tb_loss:0.31 batch_entropy:34.75 traj_lens:19.92 grad_norm:11.57 grad_norm_clip:11.57 sampled_reward_avg:0.79 train_time:6.19 time_spent:14.59
# 04/12/2024 23:43:59 - INFO - logger - iteration 462 : offline_loss:0.00 online_loss:0.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.58 loss:0.18 n_loss:0.00 tb_loss:0.18 batch_entropy:34.99 traj_lens:20.20 grad_norm:11.78 grad_norm_clip:11.78 sampled_reward_avg:0.80 train_time:6.22 time_spent:15.12
# 04/12/2024 23:44:14 - INFO - logger - iteration 463 : offline_loss:0.00 online_loss:0.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.58 loss:0.24 n_loss:0.00 tb_loss:0.24 batch_entropy:34.78 traj_lens:20.17 grad_norm:13.08 grad_norm_clip:13.08 sampled_reward_avg:0.80 train_time:6.33 time_spent:15.18
# 04/12/2024 23:44:29 - INFO - logger - iteration 464 : offline_loss:0.00 online_loss:0.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.58 loss:0.18 n_loss:0.00 tb_loss:0.18 batch_entropy:34.91 traj_lens:20.05 grad_norm:13.81 grad_norm_clip:13.81 sampled_reward_avg:0.79 train_time:6.17 time_spent:14.79
# 04/12/2024 23:44:44 - INFO - logger - iteration 465 : offline_loss:0.00 online_loss:0.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.57 loss:0.34 n_loss:0.00 tb_loss:0.34 batch_entropy:35.57 traj_lens:20.30 grad_norm:13.13 grad_norm_clip:13.13 sampled_reward_avg:0.80 train_time:6.34 time_spent:15.32
# 04/12/2024 23:44:59 - INFO - logger - iteration 466 : offline_loss:0.00 online_loss:58.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.57 loss:58.23 n_loss:0.00 tb_loss:58.23 batch_entropy:35.99 traj_lens:20.50 grad_norm:307.61 grad_norm_clip:62.66 sampled_reward_avg:0.79 train_time:6.44 time_spent:15.39
# 04/12/2024 23:45:15 - INFO - logger - iteration 467 : offline_loss:0.00 online_loss:0.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.56 loss:0.29 n_loss:0.00 tb_loss:0.29 batch_entropy:35.21 traj_lens:20.23 grad_norm:22.39 grad_norm_clip:20.35 sampled_reward_avg:0.80 train_time:6.30 time_spent:15.23
# 04/12/2024 23:45:29 - INFO - logger - iteration 468 : offline_loss:0.00 online_loss:0.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.55 loss:0.40 n_loss:0.00 tb_loss:0.40 batch_entropy:34.98 traj_lens:20.12 grad_norm:61.58 grad_norm_clip:33.71 sampled_reward_avg:0.80 train_time:6.23 time_spent:14.77
# 04/12/2024 23:45:45 - INFO - logger - iteration 469 : offline_loss:0.00 online_loss:0.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.54 loss:0.21 n_loss:0.00 tb_loss:0.21 batch_entropy:35.36 traj_lens:20.36 grad_norm:15.57 grad_norm_clip:14.65 sampled_reward_avg:0.80 train_time:6.37 time_spent:15.44
# 04/12/2024 23:46:00 - INFO - logger - iteration 470 : offline_loss:0.00 online_loss:0.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.53 loss:0.18 n_loss:0.00 tb_loss:0.18 batch_entropy:35.56 traj_lens:20.42 grad_norm:14.92 grad_norm_clip:14.92 sampled_reward_avg:0.80 train_time:6.33 time_spent:15.22
# 04/12/2024 23:46:15 - INFO - logger - iteration 471 : offline_loss:0.00 online_loss:0.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.52 loss:0.29 n_loss:0.00 tb_loss:0.29 batch_entropy:35.20 traj_lens:19.97 grad_norm:26.76 grad_norm_clip:24.50 sampled_reward_avg:0.80 train_time:6.12 time_spent:14.72
# 04/12/2024 23:46:30 - INFO - logger - iteration 472 : offline_loss:0.00 online_loss:0.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.52 loss:0.30 n_loss:0.00 tb_loss:0.30 batch_entropy:35.59 traj_lens:20.25 grad_norm:20.82 grad_norm_clip:20.82 sampled_reward_avg:0.80 train_time:6.38 time_spent:15.26
# 04/12/2024 23:46:45 - INFO - logger - iteration 473 : offline_loss:0.00 online_loss:0.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.51 loss:0.25 n_loss:0.00 tb_loss:0.25 batch_entropy:36.01 traj_lens:20.42 grad_norm:24.82 grad_norm_clip:24.82 sampled_reward_avg:0.80 train_time:6.28 time_spent:15.37
# 04/12/2024 23:47:00 - INFO - logger - iteration 474 : offline_loss:0.00 online_loss:0.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.51 loss:0.17 n_loss:0.00 tb_loss:0.17 batch_entropy:34.91 traj_lens:20.05 grad_norm:15.03 grad_norm_clip:15.03 sampled_reward_avg:0.80 train_time:6.01 time_spent:14.47
# 04/12/2024 23:47:15 - INFO - logger - iteration 475 : offline_loss:0.00 online_loss:0.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.50 loss:0.25 n_loss:0.00 tb_loss:0.25 batch_entropy:35.62 traj_lens:20.41 grad_norm:18.52 grad_norm_clip:18.52 sampled_reward_avg:0.80 train_time:6.35 time_spent:15.26
# 04/12/2024 23:47:30 - INFO - logger - iteration 476 : offline_loss:0.00 online_loss:0.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.50 loss:0.23 n_loss:0.00 tb_loss:0.23 batch_entropy:35.60 traj_lens:20.42 grad_norm:10.15 grad_norm_clip:10.15 sampled_reward_avg:0.80 train_time:6.31 time_spent:15.29
# 04/12/2024 23:47:45 - INFO - logger - iteration 477 : offline_loss:0.00 online_loss:0.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.49 loss:0.29 n_loss:0.00 tb_loss:0.29 batch_entropy:35.39 traj_lens:20.34 grad_norm:20.44 grad_norm_clip:20.44 sampled_reward_avg:0.80 train_time:6.25 time_spent:14.91
# 04/12/2024 23:48:00 - INFO - logger - iteration 478 : offline_loss:0.00 online_loss:0.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.49 loss:0.29 n_loss:0.00 tb_loss:0.29 batch_entropy:34.68 traj_lens:20.23 grad_norm:28.81 grad_norm_clip:28.13 sampled_reward_avg:0.80 train_time:6.08 time_spent:15.14
# 04/12/2024 23:48:16 - INFO - logger - iteration 479 : offline_loss:0.00 online_loss:0.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.50 loss:0.17 n_loss:0.00 tb_loss:0.17 batch_entropy:35.66 traj_lens:20.28 grad_norm:5.92 grad_norm_clip:5.92 sampled_reward_avg:0.80 train_time:6.26 time_spent:15.16
# 04/12/2024 23:48:31 - INFO - logger - iteration 480 : offline_loss:0.00 online_loss:0.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.50 loss:0.15 n_loss:0.00 tb_loss:0.15 batch_entropy:36.27 traj_lens:20.61 grad_norm:20.86 grad_norm_clip:17.90 sampled_reward_avg:0.80 train_time:6.38 time_spent:15.28
# 04/12/2024 23:48:46 - INFO - logger - iteration 481 : offline_loss:0.00 online_loss:0.92 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.51 loss:0.92 n_loss:0.00 tb_loss:0.92 batch_entropy:35.23 traj_lens:20.22 grad_norm:58.90 grad_norm_clip:35.87 sampled_reward_avg:0.80 train_time:5.96 time_spent:14.88
# 04/12/2024 23:49:01 - INFO - logger - iteration 482 : offline_loss:0.00 online_loss:0.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.51 loss:0.30 n_loss:0.00 tb_loss:0.30 batch_entropy:35.68 traj_lens:20.52 grad_norm:35.70 grad_norm_clip:30.22 sampled_reward_avg:0.80 train_time:6.27 time_spent:15.23
# 04/12/2024 23:49:15 - INFO - logger - iteration 483 : offline_loss:0.00 online_loss:0.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.52 loss:0.21 n_loss:0.00 tb_loss:0.21 batch_entropy:35.11 traj_lens:20.11 grad_norm:31.92 grad_norm_clip:26.85 sampled_reward_avg:0.80 train_time:6.06 time_spent:14.44
# 04/12/2024 23:49:30 - INFO - logger - iteration 484 : offline_loss:0.00 online_loss:0.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.53 loss:0.29 n_loss:0.00 tb_loss:0.29 batch_entropy:35.66 traj_lens:20.16 grad_norm:33.97 grad_norm_clip:30.48 sampled_reward_avg:0.80 train_time:5.94 time_spent:14.65
# 04/12/2024 23:49:45 - INFO - logger - iteration 485 : offline_loss:0.00 online_loss:0.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.54 loss:0.15 n_loss:0.00 tb_loss:0.15 batch_entropy:35.60 traj_lens:20.33 grad_norm:8.91 grad_norm_clip:8.91 sampled_reward_avg:0.80 train_time:6.10 time_spent:14.95
# 04/12/2024 23:50:00 - INFO - logger - iteration 486 : offline_loss:0.00 online_loss:0.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.54 loss:0.52 n_loss:0.00 tb_loss:0.52 batch_entropy:34.84 traj_lens:20.36 grad_norm:27.84 grad_norm_clip:27.46 sampled_reward_avg:0.80 train_time:6.14 time_spent:14.78
# 04/12/2024 23:50:15 - INFO - logger - iteration 487 : offline_loss:0.00 online_loss:0.27 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.55 loss:0.27 n_loss:0.00 tb_loss:0.27 batch_entropy:35.52 traj_lens:20.25 grad_norm:28.77 grad_norm_clip:25.29 sampled_reward_avg:0.80 train_time:6.47 time_spent:15.20
# 04/12/2024 23:50:30 - INFO - logger - iteration 488 : offline_loss:0.00 online_loss:0.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.56 loss:0.76 n_loss:0.00 tb_loss:0.76 batch_entropy:34.57 traj_lens:20.22 grad_norm:51.12 grad_norm_clip:32.37 sampled_reward_avg:0.80 train_time:6.01 time_spent:15.12
# 04/12/2024 23:50:45 - INFO - logger - iteration 489 : offline_loss:0.00 online_loss:0.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.57 loss:0.42 n_loss:0.00 tb_loss:0.42 batch_entropy:35.51 traj_lens:20.38 grad_norm:30.28 grad_norm_clip:27.58 sampled_reward_avg:0.80 train_time:6.18 time_spent:14.98
# 04/12/2024 23:51:00 - INFO - logger - iteration 490 : offline_loss:0.00 online_loss:0.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.58 loss:0.52 n_loss:0.00 tb_loss:0.52 batch_entropy:35.01 traj_lens:20.31 grad_norm:12.26 grad_norm_clip:12.26 sampled_reward_avg:0.80 train_time:6.02 time_spent:14.82
# 04/12/2024 23:51:15 - INFO - logger - iteration 491 : offline_loss:0.00 online_loss:0.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.59 loss:0.30 n_loss:0.00 tb_loss:0.30 batch_entropy:35.29 traj_lens:20.45 grad_norm:31.47 grad_norm_clip:24.04 sampled_reward_avg:0.80 train_time:6.22 time_spent:15.11
# 04/12/2024 23:51:30 - INFO - logger - iteration 492 : offline_loss:0.00 online_loss:0.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.60 loss:0.20 n_loss:0.00 tb_loss:0.20 batch_entropy:35.73 traj_lens:20.50 grad_norm:37.90 grad_norm_clip:27.81 sampled_reward_avg:0.80 train_time:6.07 time_spent:14.73
# 04/12/2024 23:51:45 - INFO - logger - iteration 493 : offline_loss:0.00 online_loss:0.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.61 loss:0.42 n_loss:0.00 tb_loss:0.42 batch_entropy:35.39 traj_lens:20.28 grad_norm:41.89 grad_norm_clip:32.12 sampled_reward_avg:0.80 train_time:5.90 time_spent:14.77
# 04/12/2024 23:52:00 - INFO - logger - iteration 494 : offline_loss:0.00 online_loss:0.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.62 loss:0.53 n_loss:0.00 tb_loss:0.53 batch_entropy:36.07 traj_lens:20.78 grad_norm:58.26 grad_norm_clip:41.22 sampled_reward_avg:0.80 train_time:6.21 time_spent:15.39
# 04/12/2024 23:52:15 - INFO - logger - iteration 495 : offline_loss:0.00 online_loss:0.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.62 loss:0.33 n_loss:0.00 tb_loss:0.33 batch_entropy:36.14 traj_lens:20.56 grad_norm:65.48 grad_norm_clip:34.64 sampled_reward_avg:0.80 train_time:6.08 time_spent:15.08
# 04/12/2024 23:52:30 - INFO - logger - iteration 496 : offline_loss:0.00 online_loss:0.45 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.63 loss:0.45 n_loss:0.00 tb_loss:0.45 batch_entropy:34.89 traj_lens:20.23 grad_norm:115.77 grad_norm_clip:46.08 sampled_reward_avg:0.80 train_time:6.06 time_spent:14.53
# 04/12/2024 23:52:44 - INFO - logger - iteration 497 : offline_loss:0.00 online_loss:1.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.63 loss:1.05 n_loss:0.00 tb_loss:1.05 batch_entropy:35.03 traj_lens:20.28 grad_norm:83.55 grad_norm_clip:43.12 sampled_reward_avg:0.79 train_time:6.05 time_spent:14.95
# 04/12/2024 23:52:59 - INFO - logger - iteration 498 : offline_loss:0.00 online_loss:0.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.64 loss:0.19 n_loss:0.00 tb_loss:0.19 batch_entropy:35.15 traj_lens:20.30 grad_norm:13.43 grad_norm_clip:13.43 sampled_reward_avg:0.80 train_time:6.14 time_spent:14.93
# 04/12/2024 23:53:14 - INFO - logger - iteration 499 : offline_loss:0.00 online_loss:0.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.64 loss:0.33 n_loss:0.00 tb_loss:0.33 batch_entropy:35.17 traj_lens:20.34 grad_norm:58.11 grad_norm_clip:32.40 sampled_reward_avg:0.80 train_time:6.09 time_spent:14.58
# 04/12/2024 23:53:29 - INFO - logger - iteration 500 : offline_loss:0.00 online_loss:0.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:9.64 loss:0.57 n_loss:0.00 tb_loss:0.57 batch_entropy:35.65 traj_lens:20.41 grad_norm:98.63 grad_norm_clip:43.91 sampled_reward_avg:0.80 train_time:6.01 time_spent:15.03

# %%
with open(os.path.join(config.log_dir, "params.json"), "w+") as file:
    json.dump(params,file)

with open(os.path.join(config.log_dir, "target.json"), "w+") as file:
    json.dump(target,file)

state = {
    "models_state_dict": [trial.model.state_dict()],
    "cfg": trial.cfg,
    "env_ctx": trial.model.env_ctx,
    #"model": trial.model,
}
if trial.sampling_model is not trial.model:
    state["sampling_model_state_dict"] = [trial.sampling_model.state_dict()]
fn = pathlib.Path(trial.cfg.log_dir) / "model_final_save.pt"
with open(fn, "wb") as fd:
    torch.save(
        state,
        fd,
    )

# %%
# Generate molecules
trajs = trial.algo.create_training_data_from_own_samples(trial.model, 25)
objs = [trial.ctx.graph_to_obj(i['result']) for i in trajs]
obj_props, is_valid = trial.task.compute_obj_properties(objs)
log_rewards = trial.task.cond_info_to_logreward({'beta': torch.ones(len(trajs))}, obj_props)
index = 0
rewards = []
for i in is_valid:
    if i:
        rewards.append(list(log_rewards)[index])
        index += 1 
    else:
        rewards.append(0)

MolsToGridImage(objs[:25], molsPerRow=5, subImgSize=(200, 120), legends=[f'reward: {r}' if r==0 else f'reward: {r.exp().item():.2f}' for r in rewards[:25]])

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')])
ax[0].set_yscale('log')
ax[1].set_ylabel('TB loss')
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')])
ax[1].set_ylabel('Average reward')
ax[2].plot([i.value for i in ea.Scalars('train_logZ')])
ax[2].set_ylabel('Predicted logZ')
pp.tight_layout()

# %%
tags = ea.Tags()
print("Available tags:", tags)

# %%
from pycirclize import Circos
import pandas as pd
import matplotlib.pyplot as plt
from pom_models.functions import fragance_propabilities_from_smiles
from rdkit import Chem
import numpy as np

# %%
indices = np.argsort(-np.array(target))
indices

# %%
labels = df.keys()[2:]
labels

# %%
data_lst  = []
for i, obj in enumerate(objs):
    smiles = Chem.MolToSmiles(obj)
    probs = fragance_propabilities_from_smiles(smiles)[0]

    data_lst.append( [smiles] + list(probs))
result_df = pd.DataFrame(
    data=data_lst,
    index=[i for i in range(len(data_lst))],
    columns=["smiles"]+list(labels)
    )
result_df.head()

# %%
target_df = pd.DataFrame(
    data=[["target"] + list(target)],
    columns=result_df.keys(),
    index=["Target"]
)
target_df

# %%
most_important_indicies = indices[:8]
most_important_keys = []
for i in most_important_indicies:
    most_important_keys.append(labels[i])
most_important_keys

# %%
rewards_plot = [f'{r}' if r==-1 else f'{r.exp().item():.2f}' for r in rewards[:25]]
rewards_plot

# %%
plot_df = result_df[most_important_keys].set_index(pd.Series([f"{i+1} r:{rewards_plot[i]}" for i in range(len(result_df["smiles"]))]))
plot_df

# %%
plot_target_df = target_df[most_important_keys]
plot_target_df

# %%
plot_df.loc["target"] = []

# %%
# Create 5 x 5 subplots
fig = plt.figure(figsize=(26, 16), dpi=100)
fig.subplots(5, 5, subplot_kw=dict(polar=True))
fig.subplots_adjust(wspace=1, hspace=0.25)

# Plot radar chart into subplots for each target
for target_name, ax in zip(plot_df.index, fig.axes):
    target_df = plot_df.loc[[target_name]]
    target_df = pd.concat([target_df, plot_target_df])
    # Initialize Circos instance for radar chart plot
    circos = Circos.radar_chart(
        target_df,
        vmax=1,
        marker_size=6,
        #cmap=dict(Hero="salmon", Warrior="skyblue", Wizard="lime", Assassin="magenta"),
        grid_interval_ratio=0.2,
        line_kws_handler=lambda _: dict(lw=2, ls="solid"),
        marker_kws_handler=lambda _: dict(marker="D", ec="grey", lw=0.5),
    )

    # Plot figure & set legend on upper right
    circos.plotfig(ax=ax)
    circos.ax.legend(loc="upper right", fontsize=10,bbox_to_anchor=(1.7, 1.1))

# %%
np.array(result_df[labels].sum())/len(result_df[labels])

# %%
import seaborn as sns

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[0].set_yscale('log')
ax[0].set_ylabel('TB loss')
ax[0].grid()
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[1].set_ylabel('Average reward')
ax[1].set_xlabel('Iteration')
ax[1].grid()
ax[2].plot([i.value for i in ea.Scalars('train_logZ')], color=sns.color_palette("Set2")[0],linewidth=1)
ax[2].set_ylabel('Predicted logZ')
ax[2].grid()
pp.tight_layout()
plt.savefig("images/pine_run_plots.pdf")
