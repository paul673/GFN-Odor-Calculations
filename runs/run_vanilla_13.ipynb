# %% [markdown]
# # Run Vanilla (combined)

# %%
import sys
import os
path_to_top_dir = "../"
# Dynamically add the `project` directory to the path
sys.path.append(os.path.abspath(path_to_top_dir))

# %%
os.path.abspath(path_to_top_dir)
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model'

# %%
# Print current working directory
os.getcwd()
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model\\runs'

# %%
# Import scent_gfn functions
from scent_gfn.fragments import FRAGMENTS, FRAGMENTS_OPENPOM_DATASET, FRAGMENTS_OPENPOM_VANILLA
from scent_gfn.molecule import MoleculeTrainer
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# Skipped loading some PyTorch models, missing a dependency. No module named 'tensorflow'
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)

# %% [markdown]
# | **Parameter**                | **Value**      |
# |------------------------------|----------------|
# | Reward function type         | Combined        |
# | Similarity measure           | Cosine         |
# | Graph building               | Fragments Vanilla      |
# | Iterations                   | 500            |
# | Max number of nodes          | 6              |
# | Illegal action logreward     | -100           |
# | β                            | 1             |
# | Large molecule penalty       | None           |

# %%
params = {
    "save_name": "vanilla13",
    "reward_func": "combined", # structure, openpom
    "similarity": "cosine",
    "graph_building": FRAGMENTS_OPENPOM_VANILLA,#FRAGMENTS,
    "iterations": 500,
    "max_nodes": 6,
    "illegal_logreward": -100,
    "beta": 1.0,
    "large_mol_pen": [None,None], #["hard", 17]# ["exponential", 15] # ["exponential", 15] , ["hard", 15], [None,None]
}

# %%
# Utilities
import warnings
import random
import datetime

# Data processing and file management
import pathlib
import pandas as pd
import json
import numpy as np

# Machine learning
import torch
from gflownet.config import init_empty, Config
from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage, MolToImage


# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Run on cpu
dev = torch.device('cpu')

# %%
def get_vanilla_test_and_training(split_ratio=0.7):
    df = pd.read_csv("../data/data.csv")
    vanilla_mols_df = df.loc[df['vanilla'] == 1]
    vanilla_smiles_trainig= list(vanilla_mols_df["nonStereoSMILES"])
    vanilla_smiles_trainig = random.sample(vanilla_smiles_trainig, round(len(vanilla_mols_df)*split_ratio))
    random.shuffle(vanilla_smiles_trainig)
    vanilla_smiles_test = []
    for i in vanilla_mols_df["nonStereoSMILES"]:
        if i not in vanilla_smiles_trainig:
            vanilla_smiles_test.append(i)
    return vanilla_smiles_trainig, vanilla_smiles_test

def get_vanillin():
    return ["COc1cc(C=O)ccc1O"]

# %%
target = get_vanillin()

# %%
# Initialize model
config = init_empty(Config())
config.print_every = 1
config.log_dir = f"{os.path.abspath(path_to_top_dir)}/results/{params['save_name']}_{datetime.datetime.now().strftime('%Y-%m-%d__%H_%M_%S')}"
config.device = dev
config.num_training_steps = params["iterations"]
config.num_workers = 0
config.num_validation_gen_steps = 1
config.overwrite_existing_exp=False
config.checkpoint_every = 100
config.algo.max_nodes = params["max_nodes"] #12 # 95 quantil
config.store_all_checkpoints = True
config.algo.illegal_action_logreward = params["illegal_logreward"]

if params["graph_building"] == None:
     trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]), print_config=True) #,fragments=FRAGMENTS, print_config=True)
else:
    trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]),fragments=params["graph_building"], print_config=True) #,fragments=FRAGMENTS, print_config=True)
# Out:
# SMILES input data detected ...
# Reward function: reward_function_combined | Similarity measure: <lambda> | exp_penalty: False | max_mol=None
# Building molecules using fragments ...
#
#
# Hyperparameters:
#
# desc: noDesc
# log_dir: c:\Users\paulj\Desktop\prosjekt\pom_cpu-model/results/vanilla13_2025-01-31__11_29_09
# device: cpu
# seed: 0
# validate_every: 1000
# checkpoint_every: 100
# store_all_checkpoints: true
# print_every: 1
# start_at_step: 0
# num_final_gen_steps: null
# num_validation_gen_steps: 1
# num_training_steps: 500
# num_workers: 0
# hostname: null
# pickle_mp_messages: false
# git_hash: f106cde
# overwrite_existing_exp: false
# algo:
#   method: TB
#   num_from_policy: 64
#   num_from_dataset: 0
#   valid_num_from_policy: 64
#   valid_num_from_dataset: 0
#   max_len: 128
#   max_nodes: 6
#   max_edges: 128
#   illegal_action_logreward: -100.0
#   train_random_action_prob: 0.0
#   train_det_after: null
#   valid_random_action_prob: 0.0
#   sampling_tau: 0.9
#   tb:
#     bootstrap_own_reward: false
#     epsilon: null
#     reward_loss_multiplier: 1.0
#     variant: TB
#     do_correct_idempotent: false
#     do_parameterize_p_b: false
#     do_predict_n: false
#     do_sample_p_b: false
#     do_length_normalize: false
#     subtb_max_len: 128
#     Z_learning_rate: 0.0001
#     Z_lr_decay: 50000.0
#     cum_subtb: true
#     loss_fn: MSE
#     loss_fn_par: 1.0
#     n_loss: none
#     n_loss_multiplier: 1.0
#     backward_policy: Uniform
#   moql:
#     gamma: 1.0
#     num_omega_samples: 32
#     num_objectives: 2
#     lambda_decay: 10000
#     penalty: -10.0
#   a2c:
#     entropy: 0.01
#     gamma: 1.0
#     penalty: -10.0
#   fm:
#     epsilon: 1.0e-38
#     balanced_loss: false
#     leaf_coef: 10.0
#     correct_idempotent: false
#   sql:
#     alpha: 0.01
#     gamma: 1.0
#     penalty: -10.0
# model:
#   num_layers: 3
#   num_emb: 128
#   dropout: 0.0
#   graph_transformer:
#     num_heads: 2
#     ln_type: pre
#     num_mlp_layers: 0
#     concat_heads: true
#   seq_transformer:
#     num_heads: 2
#     posenc: Rotary
# opt:
#   opt: adam
#   learning_rate: 0.0001
#   lr_decay: 20000.0
#   weight_decay: 1.0e-08
#   momentum: 0.9
#   clip_grad_type: norm
#   clip_grad_param: 10.0
#   adam_eps: 1.0e-08
# replay:
#   use: false
#   capacity: null
#   warmup: null
#   hindsight_ratio: 0.0
#   num_from_replay: null
#   num_new_samples: null
# task:
#   qm9:
#     h5_path: ./data/qm9/qm9.h5
#     model_path: ./data/qm9/qm9_model.pt
#   qm9_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - gap
#     - qed
#     - sa
#     online_pareto_front: true
#   seh:
#     reduced_frag: false
#   seh_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - seh
#     - qed
#     - sa
#     - mw
#     log_topk: false
#     online_pareto_front: true
# cond:
#   valid_sample_cond_info: true
#   temperature:
#     sample_dist: uniform
#     dist_params:
#     - 0.5
#     - 32
#     num_thermometer_dim: 32
#   moo:
#     num_objectives: 2
#     num_thermometer_dim: 16
#   weighted_prefs:
#     preference_type: dirichlet
#     preference_param: 1.5
#   focus_region:
#     focus_type: centered
#     use_steer_thermomether: false
#     focus_cosim: 0.98
#     focus_limit_coef: 0.1
#     focus_model_training_limits:
#     - 0.25
#     - 0.75
#     focus_model_state_space_res: 30
#     max_train_it: 20000

# %%
trial.run()
# Out:
# 31/01/2025 11:29:09 - INFO - logger - Starting training
# 31/01/2025 11:29:19 - INFO - logger - iteration 1 : offline_loss:0.00 online_loss:1016.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.41 loss:1016.26 n_loss:0.00 tb_loss:1016.26 batch_entropy:23.45 traj_lens:10.30 grad_norm:299.50 grad_norm_clip:65.88 sampled_reward_avg:0.44 train_time:1.65 time_spent:9.60
# 31/01/2025 11:29:28 - INFO - logger - iteration 2 : offline_loss:0.00 online_loss:840.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.37 loss:840.98 n_loss:0.00 tb_loss:840.98 batch_entropy:24.21 traj_lens:10.62 grad_norm:356.04 grad_norm_clip:67.02 sampled_reward_avg:0.46 train_time:1.20 time_spent:9.24
# 31/01/2025 11:29:39 - INFO - logger - iteration 3 : offline_loss:0.00 online_loss:605.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.38 loss:605.04 n_loss:0.00 tb_loss:605.04 batch_entropy:27.00 traj_lens:11.42 grad_norm:288.25 grad_norm_clip:67.58 sampled_reward_avg:0.49 train_time:1.63 time_spent:10.44
# 31/01/2025 11:29:49 - INFO - logger - iteration 4 : offline_loss:0.00 online_loss:735.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.39 loss:735.16 n_loss:0.00 tb_loss:735.16 batch_entropy:26.95 traj_lens:11.42 grad_norm:260.00 grad_norm_clip:66.80 sampled_reward_avg:0.48 train_time:1.37 time_spent:10.30
# 31/01/2025 11:29:58 - INFO - logger - iteration 5 : offline_loss:0.00 online_loss:945.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.42 loss:945.04 n_loss:0.00 tb_loss:945.04 batch_entropy:25.88 traj_lens:11.09 grad_norm:329.57 grad_norm_clip:65.48 sampled_reward_avg:0.45 train_time:1.25 time_spent:8.90
# 31/01/2025 11:30:07 - INFO - logger - iteration 6 : offline_loss:0.00 online_loss:686.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.44 loss:686.74 n_loss:0.00 tb_loss:686.74 batch_entropy:23.99 traj_lens:10.53 grad_norm:311.69 grad_norm_clip:66.75 sampled_reward_avg:0.48 train_time:1.23 time_spent:9.40
# 31/01/2025 11:30:17 - INFO - logger - iteration 7 : offline_loss:0.00 online_loss:740.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.46 loss:740.84 n_loss:0.00 tb_loss:740.84 batch_entropy:26.48 traj_lens:11.52 grad_norm:297.70 grad_norm_clip:66.71 sampled_reward_avg:0.48 train_time:1.46 time_spent:9.44
# 31/01/2025 11:30:26 - INFO - logger - iteration 8 : offline_loss:0.00 online_loss:429.37 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.49 loss:429.37 n_loss:0.00 tb_loss:429.37 batch_entropy:27.99 traj_lens:11.80 grad_norm:253.97 grad_norm_clip:65.32 sampled_reward_avg:0.54 train_time:1.40 time_spent:9.80
# 31/01/2025 11:30:36 - INFO - logger - iteration 9 : offline_loss:0.00 online_loss:697.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.52 loss:697.54 n_loss:0.00 tb_loss:697.54 batch_entropy:27.60 traj_lens:11.84 grad_norm:296.76 grad_norm_clip:66.07 sampled_reward_avg:0.49 train_time:1.35 time_spent:9.27
# 31/01/2025 11:30:46 - INFO - logger - iteration 10 : offline_loss:0.00 online_loss:403.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.55 loss:403.42 n_loss:0.00 tb_loss:403.42 batch_entropy:31.42 traj_lens:12.88 grad_norm:339.80 grad_norm_clip:68.08 sampled_reward_avg:0.54 train_time:1.52 time_spent:10.36
# 31/01/2025 11:30:56 - INFO - logger - iteration 11 : offline_loss:0.00 online_loss:490.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.59 loss:490.99 n_loss:0.00 tb_loss:490.99 batch_entropy:30.52 traj_lens:12.88 grad_norm:315.48 grad_norm_clip:66.23 sampled_reward_avg:0.53 train_time:1.51 time_spent:9.91
# 31/01/2025 11:31:05 - INFO - logger - iteration 12 : offline_loss:0.00 online_loss:529.89 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.62 loss:529.89 n_loss:0.00 tb_loss:529.89 batch_entropy:28.22 traj_lens:11.89 grad_norm:260.25 grad_norm_clip:65.14 sampled_reward_avg:0.49 train_time:1.45 time_spent:9.43
# 31/01/2025 11:31:16 - INFO - logger - iteration 13 : offline_loss:0.00 online_loss:575.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.66 loss:575.23 n_loss:0.00 tb_loss:575.23 batch_entropy:32.20 traj_lens:13.30 grad_norm:283.45 grad_norm_clip:65.87 sampled_reward_avg:0.53 train_time:1.62 time_spent:10.18
# 31/01/2025 11:31:25 - INFO - logger - iteration 14 : offline_loss:0.00 online_loss:511.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.69 loss:511.65 n_loss:0.00 tb_loss:511.65 batch_entropy:25.88 traj_lens:11.09 grad_norm:232.38 grad_norm_clip:63.39 sampled_reward_avg:0.51 train_time:1.28 time_spent:9.67
# 31/01/2025 11:31:36 - INFO - logger - iteration 15 : offline_loss:0.00 online_loss:484.80 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.73 loss:484.80 n_loss:0.00 tb_loss:484.80 batch_entropy:34.06 traj_lens:13.67 grad_norm:328.77 grad_norm_clip:66.48 sampled_reward_avg:0.55 train_time:1.73 time_spent:10.66
# 31/01/2025 11:31:46 - INFO - logger - iteration 16 : offline_loss:0.00 online_loss:432.27 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.77 loss:432.27 n_loss:0.00 tb_loss:432.27 batch_entropy:31.04 traj_lens:12.97 grad_norm:265.59 grad_norm_clip:64.71 sampled_reward_avg:0.54 train_time:1.60 time_spent:10.23
# 31/01/2025 11:31:57 - INFO - logger - iteration 17 : offline_loss:0.00 online_loss:330.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.81 loss:330.69 n_loss:0.00 tb_loss:330.69 batch_entropy:35.15 traj_lens:14.09 grad_norm:452.92 grad_norm_clip:68.62 sampled_reward_avg:0.57 train_time:1.72 time_spent:10.88
# 31/01/2025 11:32:08 - INFO - logger - iteration 18 : offline_loss:0.00 online_loss:342.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.85 loss:342.93 n_loss:0.00 tb_loss:342.93 batch_entropy:32.19 traj_lens:13.16 grad_norm:338.29 grad_norm_clip:66.42 sampled_reward_avg:0.55 train_time:1.60 time_spent:10.92
# 31/01/2025 11:32:18 - INFO - logger - iteration 19 : offline_loss:0.00 online_loss:417.81 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.89 loss:417.81 n_loss:0.00 tb_loss:417.81 batch_entropy:30.38 traj_lens:12.69 grad_norm:334.24 grad_norm_clip:66.35 sampled_reward_avg:0.54 train_time:1.49 time_spent:10.10
# 31/01/2025 11:32:28 - INFO - logger - iteration 20 : offline_loss:0.00 online_loss:288.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.93 loss:288.09 n_loss:0.00 tb_loss:288.09 batch_entropy:31.17 traj_lens:12.64 grad_norm:395.89 grad_norm_clip:67.70 sampled_reward_avg:0.56 train_time:1.65 time_spent:10.40
# 31/01/2025 11:32:39 - INFO - logger - iteration 21 : offline_loss:0.00 online_loss:464.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.97 loss:464.51 n_loss:0.00 tb_loss:464.51 batch_entropy:36.82 traj_lens:14.42 grad_norm:381.19 grad_norm_clip:67.76 sampled_reward_avg:0.55 train_time:1.86 time_spent:11.00
# 31/01/2025 11:32:51 - INFO - logger - iteration 22 : offline_loss:0.00 online_loss:420.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.01 loss:420.53 n_loss:0.00 tb_loss:420.53 batch_entropy:34.11 traj_lens:13.86 grad_norm:294.53 grad_norm_clip:65.74 sampled_reward_avg:0.54 train_time:1.69 time_spent:11.25
# 31/01/2025 11:33:01 - INFO - logger - iteration 23 : offline_loss:0.00 online_loss:503.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.05 loss:503.13 n_loss:0.00 tb_loss:503.13 batch_entropy:34.42 traj_lens:13.67 grad_norm:321.38 grad_norm_clip:66.54 sampled_reward_avg:0.54 train_time:1.73 time_spent:10.46
# 31/01/2025 11:33:12 - INFO - logger - iteration 24 : offline_loss:0.00 online_loss:365.56 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.09 loss:365.56 n_loss:0.00 tb_loss:365.56 batch_entropy:34.41 traj_lens:13.77 grad_norm:366.98 grad_norm_clip:66.91 sampled_reward_avg:0.55 train_time:1.79 time_spent:10.87
# 31/01/2025 11:33:23 - INFO - logger - iteration 25 : offline_loss:0.00 online_loss:311.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.14 loss:311.78 n_loss:0.00 tb_loss:311.78 batch_entropy:34.11 traj_lens:13.62 grad_norm:391.61 grad_norm_clip:66.92 sampled_reward_avg:0.58 train_time:1.75 time_spent:10.69
# 31/01/2025 11:33:34 - INFO - logger - iteration 26 : offline_loss:0.00 online_loss:338.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.18 loss:338.51 n_loss:0.00 tb_loss:338.51 batch_entropy:32.99 traj_lens:13.62 grad_norm:355.74 grad_norm_clip:66.64 sampled_reward_avg:0.55 train_time:1.77 time_spent:11.26
# 31/01/2025 11:33:45 - INFO - logger - iteration 27 : offline_loss:0.00 online_loss:330.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.22 loss:330.72 n_loss:0.00 tb_loss:330.72 batch_entropy:36.89 traj_lens:14.66 grad_norm:543.96 grad_norm_clip:68.88 sampled_reward_avg:0.57 train_time:1.94 time_spent:11.25
# 31/01/2025 11:33:56 - INFO - logger - iteration 28 : offline_loss:0.00 online_loss:418.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.27 loss:418.35 n_loss:0.00 tb_loss:418.35 batch_entropy:32.75 traj_lens:13.06 grad_norm:377.27 grad_norm_clip:67.33 sampled_reward_avg:0.54 train_time:1.65 time_spent:10.64
# 31/01/2025 11:34:07 - INFO - logger - iteration 29 : offline_loss:0.00 online_loss:438.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.32 loss:438.13 n_loss:0.00 tb_loss:438.13 batch_entropy:38.04 traj_lens:14.66 grad_norm:470.98 grad_norm_clip:68.71 sampled_reward_avg:0.56 train_time:1.81 time_spent:11.38
# 31/01/2025 11:34:18 - INFO - logger - iteration 30 : offline_loss:0.00 online_loss:337.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.36 loss:337.00 n_loss:0.00 tb_loss:337.00 batch_entropy:36.35 traj_lens:14.38 grad_norm:443.71 grad_norm_clip:67.79 sampled_reward_avg:0.57 train_time:1.75 time_spent:11.19
# 31/01/2025 11:34:30 - INFO - logger - iteration 31 : offline_loss:0.00 online_loss:409.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.41 loss:409.51 n_loss:0.00 tb_loss:409.51 batch_entropy:38.64 traj_lens:15.12 grad_norm:437.97 grad_norm_clip:67.89 sampled_reward_avg:0.56 train_time:1.90 time_spent:11.26
# 31/01/2025 11:34:41 - INFO - logger - iteration 32 : offline_loss:0.00 online_loss:376.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.46 loss:376.26 n_loss:0.00 tb_loss:376.26 batch_entropy:36.07 traj_lens:14.28 grad_norm:388.62 grad_norm_clip:67.11 sampled_reward_avg:0.55 train_time:2.12 time_spent:11.30
# 31/01/2025 11:34:55 - INFO - logger - iteration 33 : offline_loss:0.00 online_loss:346.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.51 loss:346.52 n_loss:0.00 tb_loss:346.52 batch_entropy:37.99 traj_lens:14.94 grad_norm:380.85 grad_norm_clip:66.97 sampled_reward_avg:0.58 train_time:1.97 time_spent:13.89
# 31/01/2025 11:35:07 - INFO - logger - iteration 34 : offline_loss:0.00 online_loss:378.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.56 loss:378.84 n_loss:0.00 tb_loss:378.84 batch_entropy:40.74 traj_lens:15.73 grad_norm:439.61 grad_norm_clip:67.90 sampled_reward_avg:0.58 train_time:2.01 time_spent:11.84
# 31/01/2025 11:35:18 - INFO - logger - iteration 35 : offline_loss:0.00 online_loss:420.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.61 loss:420.76 n_loss:0.00 tb_loss:420.76 batch_entropy:40.03 traj_lens:15.64 grad_norm:390.85 grad_norm_clip:67.02 sampled_reward_avg:0.57 train_time:2.04 time_spent:11.62
# 31/01/2025 11:35:30 - INFO - logger - iteration 36 : offline_loss:0.00 online_loss:468.92 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.66 loss:468.92 n_loss:0.00 tb_loss:468.92 batch_entropy:39.10 traj_lens:15.08 grad_norm:399.60 grad_norm_clip:67.78 sampled_reward_avg:0.56 train_time:2.01 time_spent:11.74
# 31/01/2025 11:35:42 - INFO - logger - iteration 37 : offline_loss:0.00 online_loss:378.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.71 loss:378.53 n_loss:0.00 tb_loss:378.53 batch_entropy:40.37 traj_lens:15.50 grad_norm:348.35 grad_norm_clip:64.36 sampled_reward_avg:0.58 train_time:2.14 time_spent:11.73
# 31/01/2025 11:35:53 - INFO - logger - iteration 38 : offline_loss:0.00 online_loss:367.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.76 loss:367.24 n_loss:0.00 tb_loss:367.24 batch_entropy:36.58 traj_lens:14.47 grad_norm:440.81 grad_norm_clip:68.87 sampled_reward_avg:0.56 train_time:1.86 time_spent:11.21
# 31/01/2025 11:36:05 - INFO - logger - iteration 39 : offline_loss:0.00 online_loss:354.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.81 loss:354.90 n_loss:0.00 tb_loss:354.90 batch_entropy:40.34 traj_lens:15.64 grad_norm:412.42 grad_norm_clip:67.71 sampled_reward_avg:0.57 train_time:2.15 time_spent:11.82
# 31/01/2025 11:36:17 - INFO - logger - iteration 40 : offline_loss:0.00 online_loss:383.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.86 loss:383.17 n_loss:0.00 tb_loss:383.17 batch_entropy:41.64 traj_lens:15.97 grad_norm:421.65 grad_norm_clip:67.20 sampled_reward_avg:0.58 train_time:2.14 time_spent:12.38
# 31/01/2025 11:36:28 - INFO - logger - iteration 41 : offline_loss:0.00 online_loss:465.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.92 loss:465.60 n_loss:0.00 tb_loss:465.60 batch_entropy:39.19 traj_lens:15.17 grad_norm:470.13 grad_norm_clip:67.95 sampled_reward_avg:0.55 train_time:1.96 time_spent:11.21
# 31/01/2025 11:36:40 - INFO - logger - iteration 42 : offline_loss:0.00 online_loss:349.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.97 loss:349.74 n_loss:0.00 tb_loss:349.74 batch_entropy:39.84 traj_lens:15.45 grad_norm:418.95 grad_norm_clip:66.99 sampled_reward_avg:0.58 train_time:2.30 time_spent:12.00
# 31/01/2025 11:36:52 - INFO - logger - iteration 43 : offline_loss:0.00 online_loss:362.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.03 loss:362.99 n_loss:0.00 tb_loss:362.99 batch_entropy:39.86 traj_lens:15.31 grad_norm:435.63 grad_norm_clip:68.27 sampled_reward_avg:0.56 train_time:2.03 time_spent:11.97
# 31/01/2025 11:37:04 - INFO - logger - iteration 44 : offline_loss:0.00 online_loss:480.02 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.08 loss:480.02 n_loss:0.00 tb_loss:480.02 batch_entropy:40.90 traj_lens:15.55 grad_norm:417.86 grad_norm_clip:68.03 sampled_reward_avg:0.56 train_time:2.12 time_spent:11.51
# 31/01/2025 11:37:16 - INFO - logger - iteration 45 : offline_loss:0.00 online_loss:402.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.14 loss:402.52 n_loss:0.00 tb_loss:402.52 batch_entropy:43.12 traj_lens:16.34 grad_norm:448.98 grad_norm_clip:67.37 sampled_reward_avg:0.58 train_time:2.20 time_spent:12.20
# 31/01/2025 11:37:28 - INFO - logger - iteration 46 : offline_loss:0.00 online_loss:375.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.20 loss:375.26 n_loss:0.00 tb_loss:375.26 batch_entropy:41.88 traj_lens:16.02 grad_norm:433.58 grad_norm_clip:67.34 sampled_reward_avg:0.57 train_time:2.23 time_spent:12.38
# 31/01/2025 11:37:40 - INFO - logger - iteration 47 : offline_loss:0.00 online_loss:395.38 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.25 loss:395.38 n_loss:0.00 tb_loss:395.38 batch_entropy:40.81 traj_lens:15.36 grad_norm:471.43 grad_norm_clip:67.99 sampled_reward_avg:0.58 train_time:2.00 time_spent:11.49
# 31/01/2025 11:37:52 - INFO - logger - iteration 48 : offline_loss:0.00 online_loss:360.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.31 loss:360.25 n_loss:0.00 tb_loss:360.25 batch_entropy:40.87 traj_lens:15.59 grad_norm:443.66 grad_norm_clip:67.70 sampled_reward_avg:0.57 train_time:2.00 time_spent:11.68
# 31/01/2025 11:38:03 - INFO - logger - iteration 49 : offline_loss:0.00 online_loss:437.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.37 loss:437.32 n_loss:0.00 tb_loss:437.32 batch_entropy:41.99 traj_lens:15.97 grad_norm:458.47 grad_norm_clip:67.88 sampled_reward_avg:0.58 train_time:2.13 time_spent:11.85
# 31/01/2025 11:38:16 - INFO - logger - iteration 50 : offline_loss:0.00 online_loss:495.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.43 loss:495.13 n_loss:0.00 tb_loss:495.13 batch_entropy:40.66 traj_lens:15.50 grad_norm:503.17 grad_norm_clip:68.15 sampled_reward_avg:0.57 train_time:2.14 time_spent:12.10
# 31/01/2025 11:38:27 - INFO - logger - iteration 51 : offline_loss:0.00 online_loss:333.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.49 loss:333.42 n_loss:0.00 tb_loss:333.42 batch_entropy:38.85 traj_lens:14.94 grad_norm:407.91 grad_norm_clip:66.89 sampled_reward_avg:0.58 train_time:2.06 time_spent:11.62
# 31/01/2025 11:38:39 - INFO - logger - iteration 52 : offline_loss:0.00 online_loss:361.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.55 loss:361.78 n_loss:0.00 tb_loss:361.78 batch_entropy:41.71 traj_lens:15.97 grad_norm:545.97 grad_norm_clip:68.74 sampled_reward_avg:0.59 train_time:2.13 time_spent:12.01
# 31/01/2025 11:38:51 - INFO - logger - iteration 53 : offline_loss:0.00 online_loss:455.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.61 loss:455.82 n_loss:0.00 tb_loss:455.82 batch_entropy:42.12 traj_lens:15.78 grad_norm:545.40 grad_norm_clip:68.66 sampled_reward_avg:0.57 train_time:2.01 time_spent:11.97
# 31/01/2025 11:39:03 - INFO - logger - iteration 54 : offline_loss:0.00 online_loss:376.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.67 loss:376.98 n_loss:0.00 tb_loss:376.98 batch_entropy:41.94 traj_lens:15.88 grad_norm:452.16 grad_norm_clip:67.51 sampled_reward_avg:0.58 train_time:2.13 time_spent:11.70
# 31/01/2025 11:39:15 - INFO - logger - iteration 55 : offline_loss:0.00 online_loss:375.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.73 loss:375.65 n_loss:0.00 tb_loss:375.65 batch_entropy:42.35 traj_lens:15.97 grad_norm:519.09 grad_norm_clip:68.71 sampled_reward_avg:0.59 train_time:2.14 time_spent:12.14
# 31/01/2025 11:39:27 - INFO - logger - iteration 56 : offline_loss:0.00 online_loss:428.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.80 loss:428.85 n_loss:0.00 tb_loss:428.85 batch_entropy:41.34 traj_lens:15.64 grad_norm:472.41 grad_norm_clip:67.52 sampled_reward_avg:0.56 train_time:2.13 time_spent:11.94
# 31/01/2025 11:39:39 - INFO - logger - iteration 57 : offline_loss:0.00 online_loss:376.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.86 loss:376.79 n_loss:0.00 tb_loss:376.79 batch_entropy:42.97 traj_lens:16.25 grad_norm:450.75 grad_norm_clip:66.90 sampled_reward_avg:0.58 train_time:2.18 time_spent:12.39
# 31/01/2025 11:39:51 - INFO - logger - iteration 58 : offline_loss:0.00 online_loss:364.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.92 loss:364.74 n_loss:0.00 tb_loss:364.74 batch_entropy:41.29 traj_lens:15.64 grad_norm:574.17 grad_norm_clip:69.29 sampled_reward_avg:0.58 train_time:2.18 time_spent:12.10
# 31/01/2025 11:40:03 - INFO - logger - iteration 59 : offline_loss:0.00 online_loss:392.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.99 loss:392.69 n_loss:0.00 tb_loss:392.69 batch_entropy:43.96 traj_lens:16.34 grad_norm:499.79 grad_norm_clip:67.52 sampled_reward_avg:0.58 train_time:2.16 time_spent:12.02
# 31/01/2025 11:40:16 - INFO - logger - iteration 60 : offline_loss:0.00 online_loss:366.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.05 loss:366.54 n_loss:0.00 tb_loss:366.54 batch_entropy:42.25 traj_lens:15.92 grad_norm:538.21 grad_norm_clip:68.76 sampled_reward_avg:0.58 train_time:2.09 time_spent:12.15
# 31/01/2025 11:40:28 - INFO - logger - iteration 61 : offline_loss:0.00 online_loss:361.28 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.11 loss:361.28 n_loss:0.00 tb_loss:361.28 batch_entropy:43.34 traj_lens:16.48 grad_norm:463.47 grad_norm_clip:67.18 sampled_reward_avg:0.58 train_time:2.30 time_spent:12.20
# 31/01/2025 11:40:40 - INFO - logger - iteration 62 : offline_loss:0.00 online_loss:352.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.18 loss:352.16 n_loss:0.00 tb_loss:352.16 batch_entropy:41.84 traj_lens:15.88 grad_norm:509.39 grad_norm_clip:69.60 sampled_reward_avg:0.58 train_time:2.15 time_spent:11.95
# 31/01/2025 11:40:52 - INFO - logger - iteration 63 : offline_loss:0.00 online_loss:362.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.24 loss:362.22 n_loss:0.00 tb_loss:362.22 batch_entropy:43.49 traj_lens:16.39 grad_norm:469.44 grad_norm_clip:66.63 sampled_reward_avg:0.58 train_time:2.12 time_spent:12.49
# 31/01/2025 11:41:04 - INFO - logger - iteration 64 : offline_loss:0.00 online_loss:360.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.31 loss:360.59 n_loss:0.00 tb_loss:360.59 batch_entropy:43.02 traj_lens:16.25 grad_norm:504.38 grad_norm_clip:68.08 sampled_reward_avg:0.57 train_time:2.08 time_spent:11.91
# 31/01/2025 11:41:17 - INFO - logger - iteration 65 : offline_loss:0.00 online_loss:402.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.37 loss:402.79 n_loss:0.00 tb_loss:402.79 batch_entropy:45.31 traj_lens:16.67 grad_norm:504.29 grad_norm_clip:67.54 sampled_reward_avg:0.59 train_time:2.29 time_spent:12.37
# 31/01/2025 11:41:28 - INFO - logger - iteration 66 : offline_loss:0.00 online_loss:382.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.44 loss:382.08 n_loss:0.00 tb_loss:382.08 batch_entropy:43.21 traj_lens:15.97 grad_norm:548.81 grad_norm_clip:68.08 sampled_reward_avg:0.59 train_time:2.17 time_spent:11.93
# 31/01/2025 11:41:42 - INFO - logger - iteration 67 : offline_loss:0.00 online_loss:382.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.51 loss:382.17 n_loss:0.00 tb_loss:382.17 batch_entropy:44.78 traj_lens:16.77 grad_norm:583.76 grad_norm_clip:69.15 sampled_reward_avg:0.59 train_time:2.51 time_spent:13.08
# 31/01/2025 11:41:54 - INFO - logger - iteration 68 : offline_loss:0.00 online_loss:375.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.57 loss:375.59 n_loss:0.00 tb_loss:375.59 batch_entropy:43.87 traj_lens:16.30 grad_norm:563.14 grad_norm_clip:68.32 sampled_reward_avg:0.58 train_time:2.38 time_spent:12.36
# 31/01/2025 11:42:06 - INFO - logger - iteration 69 : offline_loss:0.00 online_loss:375.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.64 loss:375.47 n_loss:0.00 tb_loss:375.47 batch_entropy:44.15 traj_lens:16.44 grad_norm:539.15 grad_norm_clip:68.35 sampled_reward_avg:0.58 train_time:2.29 time_spent:12.23
# 31/01/2025 11:42:19 - INFO - logger - iteration 70 : offline_loss:0.00 online_loss:372.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.71 loss:372.21 n_loss:0.00 tb_loss:372.21 batch_entropy:44.78 traj_lens:16.67 grad_norm:552.15 grad_norm_clip:68.01 sampled_reward_avg:0.58 train_time:2.21 time_spent:12.54
# 31/01/2025 11:42:30 - INFO - logger - iteration 71 : offline_loss:0.00 online_loss:462.58 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.78 loss:462.58 n_loss:0.00 tb_loss:462.58 batch_entropy:41.31 traj_lens:15.59 grad_norm:477.22 grad_norm_clip:69.45 sampled_reward_avg:0.56 train_time:2.11 time_spent:11.54
# 31/01/2025 11:42:43 - INFO - logger - iteration 72 : offline_loss:0.00 online_loss:356.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.85 loss:356.14 n_loss:0.00 tb_loss:356.14 batch_entropy:44.21 traj_lens:16.53 grad_norm:527.79 grad_norm_clip:68.71 sampled_reward_avg:0.59 train_time:2.25 time_spent:12.37
# 31/01/2025 11:42:55 - INFO - logger - iteration 73 : offline_loss:0.00 online_loss:363.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.91 loss:363.94 n_loss:0.00 tb_loss:363.94 batch_entropy:43.27 traj_lens:16.06 grad_norm:643.61 grad_norm_clip:69.05 sampled_reward_avg:0.58 train_time:2.30 time_spent:12.51
# 31/01/2025 11:43:07 - INFO - logger - iteration 74 : offline_loss:0.00 online_loss:365.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.98 loss:365.20 n_loss:0.00 tb_loss:365.20 batch_entropy:44.46 traj_lens:16.48 grad_norm:571.15 grad_norm_clip:68.25 sampled_reward_avg:0.59 train_time:2.27 time_spent:12.21
# 31/01/2025 11:43:19 - INFO - logger - iteration 75 : offline_loss:0.00 online_loss:351.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.05 loss:351.52 n_loss:0.00 tb_loss:351.52 batch_entropy:43.94 traj_lens:16.34 grad_norm:469.49 grad_norm_clip:65.60 sampled_reward_avg:0.58 train_time:2.09 time_spent:12.08
# 31/01/2025 11:43:32 - INFO - logger - iteration 76 : offline_loss:0.00 online_loss:356.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.12 loss:356.26 n_loss:0.00 tb_loss:356.26 batch_entropy:43.49 traj_lens:16.11 grad_norm:495.56 grad_norm_clip:66.18 sampled_reward_avg:0.58 train_time:2.17 time_spent:12.32
# 31/01/2025 11:43:44 - INFO - logger - iteration 77 : offline_loss:0.00 online_loss:349.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.19 loss:349.11 n_loss:0.00 tb_loss:349.11 batch_entropy:43.97 traj_lens:16.44 grad_norm:500.04 grad_norm_clip:66.12 sampled_reward_avg:0.58 train_time:2.37 time_spent:12.13
# 31/01/2025 11:43:56 - INFO - logger - iteration 78 : offline_loss:0.00 online_loss:361.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.27 loss:361.29 n_loss:0.00 tb_loss:361.29 batch_entropy:43.47 traj_lens:16.06 grad_norm:545.16 grad_norm_clip:68.46 sampled_reward_avg:0.58 train_time:2.19 time_spent:12.14
# 31/01/2025 11:44:09 - INFO - logger - iteration 79 : offline_loss:0.00 online_loss:336.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.34 loss:336.12 n_loss:0.00 tb_loss:336.12 batch_entropy:44.23 traj_lens:16.58 grad_norm:514.25 grad_norm_clip:67.87 sampled_reward_avg:0.60 train_time:2.29 time_spent:12.68
# 31/01/2025 11:44:21 - INFO - logger - iteration 80 : offline_loss:0.00 online_loss:364.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.41 loss:364.59 n_loss:0.00 tb_loss:364.59 batch_entropy:45.73 traj_lens:16.95 grad_norm:562.45 grad_norm_clip:67.64 sampled_reward_avg:0.59 train_time:2.36 time_spent:12.34
# 31/01/2025 11:44:34 - INFO - logger - iteration 81 : offline_loss:0.00 online_loss:341.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.48 loss:341.78 n_loss:0.00 tb_loss:341.78 batch_entropy:44.74 traj_lens:16.67 grad_norm:608.63 grad_norm_clip:68.50 sampled_reward_avg:0.58 train_time:2.25 time_spent:12.81
# 31/01/2025 11:44:46 - INFO - logger - iteration 82 : offline_loss:0.00 online_loss:410.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.55 loss:410.76 n_loss:0.00 tb_loss:410.76 batch_entropy:44.68 traj_lens:16.58 grad_norm:522.75 grad_norm_clip:67.42 sampled_reward_avg:0.57 train_time:2.21 time_spent:12.00
# 31/01/2025 11:44:58 - INFO - logger - iteration 83 : offline_loss:0.00 online_loss:333.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.62 loss:333.19 n_loss:0.00 tb_loss:333.19 batch_entropy:43.35 traj_lens:16.06 grad_norm:524.93 grad_norm_clip:67.50 sampled_reward_avg:0.58 train_time:2.19 time_spent:12.49
# 31/01/2025 11:45:11 - INFO - logger - iteration 84 : offline_loss:0.00 online_loss:399.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.70 loss:399.61 n_loss:0.00 tb_loss:399.61 batch_entropy:44.83 traj_lens:16.72 grad_norm:494.24 grad_norm_clip:66.43 sampled_reward_avg:0.58 train_time:2.31 time_spent:12.26
# 31/01/2025 11:45:23 - INFO - logger - iteration 85 : offline_loss:0.00 online_loss:311.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.77 loss:311.64 n_loss:0.00 tb_loss:311.64 batch_entropy:43.29 traj_lens:16.30 grad_norm:579.41 grad_norm_clip:68.09 sampled_reward_avg:0.59 train_time:2.33 time_spent:12.29
# 31/01/2025 11:45:35 - INFO - logger - iteration 86 : offline_loss:0.00 online_loss:357.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.85 loss:357.52 n_loss:0.00 tb_loss:357.52 batch_entropy:45.35 traj_lens:16.62 grad_norm:563.29 grad_norm_clip:67.88 sampled_reward_avg:0.58 train_time:2.15 time_spent:12.38
# 31/01/2025 11:45:47 - INFO - logger - iteration 87 : offline_loss:0.00 online_loss:322.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.92 loss:322.25 n_loss:0.00 tb_loss:322.25 batch_entropy:44.25 traj_lens:16.39 grad_norm:563.75 grad_norm_clip:68.58 sampled_reward_avg:0.59 train_time:2.29 time_spent:12.15
# 31/01/2025 11:46:00 - INFO - logger - iteration 88 : offline_loss:0.00 online_loss:349.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.00 loss:349.68 n_loss:0.00 tb_loss:349.68 batch_entropy:45.81 traj_lens:16.77 grad_norm:563.71 grad_norm_clip:67.12 sampled_reward_avg:0.59 train_time:2.37 time_spent:12.45
# 31/01/2025 11:46:13 - INFO - logger - iteration 89 : offline_loss:0.00 online_loss:356.96 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.07 loss:356.96 n_loss:0.00 tb_loss:356.96 batch_entropy:45.27 traj_lens:16.58 grad_norm:587.53 grad_norm_clip:68.18 sampled_reward_avg:0.59 train_time:2.36 time_spent:12.80
# 31/01/2025 11:46:25 - INFO - logger - iteration 90 : offline_loss:0.00 online_loss:325.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.15 loss:325.82 n_loss:0.00 tb_loss:325.82 batch_entropy:44.22 traj_lens:16.34 grad_norm:506.62 grad_norm_clip:64.49 sampled_reward_avg:0.58 train_time:2.24 time_spent:12.21
# 31/01/2025 11:46:37 - INFO - logger - iteration 91 : offline_loss:0.00 online_loss:316.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.23 loss:316.60 n_loss:0.00 tb_loss:316.60 batch_entropy:44.21 traj_lens:16.34 grad_norm:533.06 grad_norm_clip:66.78 sampled_reward_avg:0.58 train_time:2.13 time_spent:12.24
# 31/01/2025 11:46:49 - INFO - logger - iteration 92 : offline_loss:0.00 online_loss:417.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.30 loss:417.00 n_loss:0.00 tb_loss:417.00 batch_entropy:45.60 traj_lens:16.67 grad_norm:638.11 grad_norm_clip:69.04 sampled_reward_avg:0.57 train_time:2.20 time_spent:12.40
# 31/01/2025 11:47:01 - INFO - logger - iteration 93 : offline_loss:0.00 online_loss:358.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.38 loss:358.64 n_loss:0.00 tb_loss:358.64 batch_entropy:43.79 traj_lens:16.48 grad_norm:564.60 grad_norm_clip:68.34 sampled_reward_avg:0.56 train_time:2.24 time_spent:11.94
# 31/01/2025 11:47:14 - INFO - logger - iteration 94 : offline_loss:0.00 online_loss:290.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.46 loss:290.26 n_loss:0.00 tb_loss:290.26 batch_entropy:43.58 traj_lens:16.34 grad_norm:517.93 grad_norm_clip:65.60 sampled_reward_avg:0.59 train_time:2.31 time_spent:12.24
# 31/01/2025 11:47:26 - INFO - logger - iteration 95 : offline_loss:0.00 online_loss:378.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.54 loss:378.70 n_loss:0.00 tb_loss:378.70 batch_entropy:44.54 traj_lens:16.44 grad_norm:556.43 grad_norm_clip:68.01 sampled_reward_avg:0.59 train_time:2.28 time_spent:12.68
# 31/01/2025 11:47:39 - INFO - logger - iteration 96 : offline_loss:0.00 online_loss:399.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.62 loss:399.51 n_loss:0.00 tb_loss:399.51 batch_entropy:45.88 traj_lens:16.67 grad_norm:649.11 grad_norm_clip:68.96 sampled_reward_avg:0.58 train_time:2.23 time_spent:12.16
# 31/01/2025 11:47:51 - INFO - logger - iteration 97 : offline_loss:0.00 online_loss:303.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.71 loss:303.90 n_loss:0.00 tb_loss:303.90 batch_entropy:44.65 traj_lens:16.53 grad_norm:543.50 grad_norm_clip:66.61 sampled_reward_avg:0.58 train_time:2.19 time_spent:12.11
# 31/01/2025 11:48:03 - INFO - logger - iteration 98 : offline_loss:0.00 online_loss:320.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.79 loss:320.09 n_loss:0.00 tb_loss:320.09 batch_entropy:44.74 traj_lens:16.53 grad_norm:546.85 grad_norm_clip:65.90 sampled_reward_avg:0.59 train_time:2.18 time_spent:12.25
# 31/01/2025 11:48:16 - INFO - logger - iteration 99 : offline_loss:0.00 online_loss:320.67 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.87 loss:320.67 n_loss:0.00 tb_loss:320.67 batch_entropy:45.63 traj_lens:16.72 grad_norm:588.79 grad_norm_clip:67.41 sampled_reward_avg:0.59 train_time:2.34 time_spent:12.74
# 31/01/2025 11:48:28 - INFO - logger - iteration 100 : offline_loss:0.00 online_loss:316.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.96 loss:316.12 n_loss:0.00 tb_loss:316.12 batch_entropy:45.48 traj_lens:16.77 grad_norm:600.01 grad_norm_clip:66.61 sampled_reward_avg:0.60 train_time:2.37 time_spent:12.41
# 31/01/2025 11:48:41 - INFO - logger - iteration 101 : offline_loss:0.00 online_loss:298.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.04 loss:298.87 n_loss:0.00 tb_loss:298.87 batch_entropy:45.26 traj_lens:16.72 grad_norm:577.46 grad_norm_clip:67.21 sampled_reward_avg:0.59 train_time:2.31 time_spent:12.53
# 31/01/2025 11:48:53 - INFO - logger - iteration 102 : offline_loss:0.00 online_loss:319.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.12 loss:319.61 n_loss:0.00 tb_loss:319.61 batch_entropy:46.64 traj_lens:17.00 grad_norm:701.58 grad_norm_clip:69.02 sampled_reward_avg:0.59 train_time:2.40 time_spent:12.85
# 31/01/2025 11:49:06 - INFO - logger - iteration 103 : offline_loss:0.00 online_loss:318.43 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.21 loss:318.43 n_loss:0.00 tb_loss:318.43 batch_entropy:45.57 traj_lens:16.62 grad_norm:628.00 grad_norm_clip:67.59 sampled_reward_avg:0.58 train_time:2.37 time_spent:12.31
# 31/01/2025 11:49:19 - INFO - logger - iteration 104 : offline_loss:0.00 online_loss:291.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.30 loss:291.78 n_loss:0.00 tb_loss:291.78 batch_entropy:44.89 traj_lens:16.62 grad_norm:599.79 grad_norm_clip:67.33 sampled_reward_avg:0.59 train_time:2.36 time_spent:12.86
# 31/01/2025 11:49:32 - INFO - logger - iteration 105 : offline_loss:0.00 online_loss:304.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.38 loss:304.04 n_loss:0.00 tb_loss:304.04 batch_entropy:46.54 traj_lens:17.00 grad_norm:682.17 grad_norm_clip:68.32 sampled_reward_avg:0.59 train_time:2.42 time_spent:13.11
# 31/01/2025 11:49:44 - INFO - logger - iteration 106 : offline_loss:0.00 online_loss:359.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.47 loss:359.21 n_loss:0.00 tb_loss:359.21 batch_entropy:44.66 traj_lens:16.25 grad_norm:624.19 grad_norm_clip:68.62 sampled_reward_avg:0.57 train_time:2.20 time_spent:12.12
# 31/01/2025 11:49:57 - INFO - logger - iteration 107 : offline_loss:0.00 online_loss:297.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.56 loss:297.19 n_loss:0.00 tb_loss:297.19 batch_entropy:45.54 traj_lens:16.58 grad_norm:600.88 grad_norm_clip:68.41 sampled_reward_avg:0.58 train_time:2.73 time_spent:13.06
# 31/01/2025 11:50:10 - INFO - logger - iteration 108 : offline_loss:0.00 online_loss:310.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.64 loss:310.20 n_loss:0.00 tb_loss:310.20 batch_entropy:45.81 traj_lens:16.62 grad_norm:662.95 grad_norm_clip:68.03 sampled_reward_avg:0.58 train_time:2.27 time_spent:13.19
# 31/01/2025 11:50:23 - INFO - logger - iteration 109 : offline_loss:0.00 online_loss:279.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.73 loss:279.03 n_loss:0.00 tb_loss:279.03 batch_entropy:45.10 traj_lens:16.62 grad_norm:598.01 grad_norm_clip:67.22 sampled_reward_avg:0.58 train_time:2.27 time_spent:12.48
# 31/01/2025 11:50:35 - INFO - logger - iteration 110 : offline_loss:0.00 online_loss:281.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.82 loss:281.68 n_loss:0.00 tb_loss:281.68 batch_entropy:45.05 traj_lens:16.58 grad_norm:611.07 grad_norm_clip:67.46 sampled_reward_avg:0.57 train_time:2.16 time_spent:12.22
# 31/01/2025 11:50:48 - INFO - logger - iteration 111 : offline_loss:0.00 online_loss:275.49 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:6.91 loss:275.49 n_loss:0.00 tb_loss:275.49 batch_entropy:45.72 traj_lens:16.81 grad_norm:644.80 grad_norm_clip:67.98 sampled_reward_avg:0.59 train_time:2.32 time_spent:12.90
# 31/01/2025 11:51:00 - INFO - logger - iteration 112 : offline_loss:0.00 online_loss:322.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.00 loss:322.16 n_loss:0.00 tb_loss:322.16 batch_entropy:43.80 traj_lens:16.20 grad_norm:525.16 grad_norm_clip:65.41 sampled_reward_avg:0.56 train_time:2.26 time_spent:12.07
# 31/01/2025 11:51:12 - INFO - logger - iteration 113 : offline_loss:0.00 online_loss:263.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.09 loss:263.04 n_loss:0.00 tb_loss:263.04 batch_entropy:44.19 traj_lens:16.25 grad_norm:556.67 grad_norm_clip:66.02 sampled_reward_avg:0.58 train_time:2.14 time_spent:11.98
# 31/01/2025 11:51:25 - INFO - logger - iteration 114 : offline_loss:0.00 online_loss:276.38 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.18 loss:276.38 n_loss:0.00 tb_loss:276.38 batch_entropy:46.17 traj_lens:16.81 grad_norm:583.21 grad_norm_clip:64.90 sampled_reward_avg:0.58 train_time:2.64 time_spent:13.09
# 31/01/2025 11:51:37 - INFO - logger - iteration 115 : offline_loss:0.00 online_loss:276.66 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.27 loss:276.66 n_loss:0.00 tb_loss:276.66 batch_entropy:44.88 traj_lens:16.48 grad_norm:602.58 grad_norm_clip:66.90 sampled_reward_avg:0.59 train_time:2.29 time_spent:12.27
# 31/01/2025 11:51:50 - INFO - logger - iteration 116 : offline_loss:0.00 online_loss:284.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.36 loss:284.00 n_loss:0.00 tb_loss:284.00 batch_entropy:46.30 traj_lens:16.77 grad_norm:584.28 grad_norm_clip:64.24 sampled_reward_avg:0.58 train_time:2.38 time_spent:12.57
# 31/01/2025 11:52:02 - INFO - logger - iteration 117 : offline_loss:0.00 online_loss:276.67 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.45 loss:276.67 n_loss:0.00 tb_loss:276.67 batch_entropy:45.72 traj_lens:16.67 grad_norm:623.81 grad_norm_clip:66.27 sampled_reward_avg:0.59 train_time:2.23 time_spent:12.81
# 31/01/2025 11:52:15 - INFO - logger - iteration 118 : offline_loss:0.00 online_loss:268.44 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.54 loss:268.44 n_loss:0.00 tb_loss:268.44 batch_entropy:45.93 traj_lens:16.77 grad_norm:589.36 grad_norm_clip:65.21 sampled_reward_avg:0.58 train_time:2.37 time_spent:12.46
# 31/01/2025 11:52:27 - INFO - logger - iteration 119 : offline_loss:0.00 online_loss:269.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.63 loss:269.46 n_loss:0.00 tb_loss:269.46 batch_entropy:46.04 traj_lens:16.81 grad_norm:608.65 grad_norm_clip:66.88 sampled_reward_avg:0.59 train_time:2.24 time_spent:12.30
# 31/01/2025 11:52:40 - INFO - logger - iteration 120 : offline_loss:0.00 online_loss:259.58 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.72 loss:259.58 n_loss:0.00 tb_loss:259.58 batch_entropy:45.65 traj_lens:16.62 grad_norm:574.67 grad_norm_clip:64.60 sampled_reward_avg:0.59 train_time:2.16 time_spent:12.48
# 31/01/2025 11:52:52 - INFO - logger - iteration 121 : offline_loss:0.00 online_loss:277.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.82 loss:277.16 n_loss:0.00 tb_loss:277.16 batch_entropy:46.45 traj_lens:16.86 grad_norm:655.89 grad_norm_clip:68.02 sampled_reward_avg:0.59 train_time:2.51 time_spent:12.61
# 31/01/2025 11:53:05 - INFO - logger - iteration 122 : offline_loss:0.00 online_loss:248.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:7.91 loss:248.86 n_loss:0.00 tb_loss:248.86 batch_entropy:45.00 traj_lens:16.39 grad_norm:599.75 grad_norm_clip:66.43 sampled_reward_avg:0.58 train_time:2.33 time_spent:12.38
# 31/01/2025 11:53:17 - INFO - logger - iteration 123 : offline_loss:0.00 online_loss:273.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:8.01 loss:273.12 n_loss:0.00 tb_loss:273.12 batch_entropy:46.64 traj_lens:16.77 grad_norm:620.05 grad_norm_clip:65.30 sampled_reward_avg:0.59 train_time:2.32 time_spent:12.42
# 31/01/2025 11:53:30 - INFO - logger - iteration 124 : offline_loss:0.00 online_loss:244.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:8.10 loss:244.90 n_loss:0.00 tb_loss:244.90 batch_entropy:44.50 traj_lens:16.30 grad_norm:584.64 grad_norm_clip:65.06 sampled_reward_avg:0.58 train_time:2.17 time_spent:12.54
# 31/01/2025 11:53:42 - INFO - logger - iteration 125 : offline_loss:0.00 online_loss:236.50 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:8.19 loss:236.50 n_loss:0.00 tb_loss:236.50 batch_entropy:45.27 traj_lens:16.81 grad_norm:583.16 grad_norm_clip:65.82 sampled_reward_avg:0.59 train_time:2.24 time_spent:12.19
# 31/01/2025 11:53:54 - INFO - logger - iteration 126 : offline_loss:0.00 online_loss:252.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:8.29 loss:252.90 n_loss:0.00 tb_loss:252.90 batch_entropy:46.22 traj_lens:16.81 grad_norm:597.79 grad_norm_clip:65.64 sampled_reward_avg:0.59 train_time:2.36 time_spent:12.51
# 31/01/2025 11:54:07 - INFO - logger - iteration 127 : offline_loss:0.00 online_loss:233.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:8.38 loss:233.53 n_loss:0.00 tb_loss:233.53 batch_entropy:45.65 traj_lens:16.72 grad_norm:568.40 grad_norm_clip:64.50 sampled_reward_avg:0.58 train_time:2.36 time_spent:12.93
# ...
# 31/01/2025 13:03:50 - INFO - logger - iteration 458 : offline_loss:0.00 online_loss:1.50 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.38 loss:1.50 n_loss:0.00 tb_loss:1.50 batch_entropy:48.97 traj_lens:17.00 grad_norm:65.82 grad_norm_clip:45.43 sampled_reward_avg:0.59 train_time:2.30 time_spent:13.00
# 31/01/2025 13:04:03 - INFO - logger - iteration 459 : offline_loss:0.00 online_loss:1.79 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.39 loss:1.79 n_loss:0.00 tb_loss:1.79 batch_entropy:49.19 traj_lens:17.00 grad_norm:41.22 grad_norm_clip:36.52 sampled_reward_avg:0.58 train_time:2.18 time_spent:12.54
# 31/01/2025 13:04:15 - INFO - logger - iteration 460 : offline_loss:0.00 online_loss:2.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.41 loss:2.04 n_loss:0.00 tb_loss:2.04 batch_entropy:48.42 traj_lens:16.95 grad_norm:35.04 grad_norm_clip:26.80 sampled_reward_avg:0.58 train_time:2.24 time_spent:12.37
# 31/01/2025 13:04:28 - INFO - logger - iteration 461 : offline_loss:0.00 online_loss:1.96 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.41 loss:1.96 n_loss:0.00 tb_loss:1.96 batch_entropy:48.63 traj_lens:17.00 grad_norm:40.71 grad_norm_clip:32.17 sampled_reward_avg:0.59 train_time:2.40 time_spent:12.89
# 31/01/2025 13:04:41 - INFO - logger - iteration 462 : offline_loss:0.00 online_loss:2.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.41 loss:2.22 n_loss:0.00 tb_loss:2.22 batch_entropy:48.81 traj_lens:17.00 grad_norm:41.43 grad_norm_clip:38.24 sampled_reward_avg:0.58 train_time:2.44 time_spent:12.70
# 31/01/2025 13:04:54 - INFO - logger - iteration 463 : offline_loss:0.00 online_loss:1.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.41 loss:1.71 n_loss:0.00 tb_loss:1.71 batch_entropy:48.84 traj_lens:17.00 grad_norm:37.96 grad_norm_clip:35.92 sampled_reward_avg:0.59 train_time:2.36 time_spent:12.54
# 31/01/2025 13:05:06 - INFO - logger - iteration 464 : offline_loss:0.00 online_loss:1.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.41 loss:1.60 n_loss:0.00 tb_loss:1.60 batch_entropy:48.91 traj_lens:17.00 grad_norm:37.41 grad_norm_clip:34.39 sampled_reward_avg:0.58 train_time:2.34 time_spent:12.58
# 31/01/2025 13:05:19 - INFO - logger - iteration 465 : offline_loss:0.00 online_loss:1.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.41 loss:1.25 n_loss:0.00 tb_loss:1.25 batch_entropy:48.83 traj_lens:17.00 grad_norm:37.55 grad_norm_clip:36.18 sampled_reward_avg:0.58 train_time:2.20 time_spent:12.83
# 31/01/2025 13:05:31 - INFO - logger - iteration 466 : offline_loss:0.00 online_loss:1.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.39 loss:1.36 n_loss:0.00 tb_loss:1.36 batch_entropy:48.95 traj_lens:17.00 grad_norm:31.14 grad_norm_clip:29.24 sampled_reward_avg:0.59 train_time:2.25 time_spent:12.33
# 31/01/2025 13:05:44 - INFO - logger - iteration 467 : offline_loss:0.00 online_loss:1.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.38 loss:1.65 n_loss:0.00 tb_loss:1.65 batch_entropy:49.20 traj_lens:17.00 grad_norm:43.54 grad_norm_clip:34.09 sampled_reward_avg:0.59 train_time:2.43 time_spent:13.16
# 31/01/2025 13:05:58 - INFO - logger - iteration 468 : offline_loss:0.00 online_loss:1.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.39 loss:1.34 n_loss:0.00 tb_loss:1.34 batch_entropy:48.83 traj_lens:17.00 grad_norm:36.47 grad_norm_clip:35.10 sampled_reward_avg:0.59 train_time:2.49 time_spent:13.11
# 31/01/2025 13:06:10 - INFO - logger - iteration 469 : offline_loss:0.00 online_loss:7.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.39 loss:7.18 n_loss:0.00 tb_loss:7.18 batch_entropy:48.07 traj_lens:16.72 grad_norm:62.98 grad_norm_clip:44.66 sampled_reward_avg:0.59 train_time:2.27 time_spent:12.46
# 31/01/2025 13:06:23 - INFO - logger - iteration 470 : offline_loss:0.00 online_loss:2.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.38 loss:2.11 n_loss:0.00 tb_loss:2.11 batch_entropy:48.79 traj_lens:17.00 grad_norm:40.12 grad_norm_clip:33.24 sampled_reward_avg:0.58 train_time:2.36 time_spent:12.53
# 31/01/2025 13:06:35 - INFO - logger - iteration 471 : offline_loss:0.00 online_loss:1.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.37 loss:1.65 n_loss:0.00 tb_loss:1.65 batch_entropy:48.84 traj_lens:17.00 grad_norm:35.83 grad_norm_clip:30.01 sampled_reward_avg:0.58 train_time:2.33 time_spent:12.91
# 31/01/2025 13:06:48 - INFO - logger - iteration 472 : offline_loss:0.00 online_loss:1.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.36 loss:1.34 n_loss:0.00 tb_loss:1.34 batch_entropy:48.71 traj_lens:17.00 grad_norm:27.12 grad_norm_clip:23.36 sampled_reward_avg:0.58 train_time:2.41 time_spent:12.64
# 31/01/2025 13:07:00 - INFO - logger - iteration 473 : offline_loss:0.00 online_loss:112.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.34 loss:112.88 n_loss:0.00 tb_loss:112.88 batch_entropy:48.44 traj_lens:16.81 grad_norm:152.69 grad_norm_clip:51.73 sampled_reward_avg:0.57 train_time:2.35 time_spent:12.36
# 31/01/2025 13:07:14 - INFO - logger - iteration 474 : offline_loss:0.00 online_loss:1.45 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.31 loss:1.45 n_loss:0.00 tb_loss:1.45 batch_entropy:48.72 traj_lens:17.00 grad_norm:37.45 grad_norm_clip:33.44 sampled_reward_avg:0.59 train_time:2.37 time_spent:13.13
# 31/01/2025 13:07:26 - INFO - logger - iteration 475 : offline_loss:0.00 online_loss:77.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.27 loss:77.71 n_loss:0.00 tb_loss:77.71 batch_entropy:48.98 traj_lens:17.00 grad_norm:289.17 grad_norm_clip:64.79 sampled_reward_avg:0.59 train_time:2.21 time_spent:12.42
# 31/01/2025 13:07:38 - INFO - logger - iteration 476 : offline_loss:0.00 online_loss:1.58 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.22 loss:1.58 n_loss:0.00 tb_loss:1.58 batch_entropy:48.86 traj_lens:17.00 grad_norm:55.77 grad_norm_clip:39.16 sampled_reward_avg:0.59 train_time:2.18 time_spent:12.43
# 31/01/2025 13:07:51 - INFO - logger - iteration 477 : offline_loss:0.00 online_loss:2.37 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.18 loss:2.37 n_loss:0.00 tb_loss:2.37 batch_entropy:49.30 traj_lens:17.00 grad_norm:97.15 grad_norm_clip:49.69 sampled_reward_avg:0.59 train_time:2.26 time_spent:12.86
# 31/01/2025 13:08:04 - INFO - logger - iteration 478 : offline_loss:0.00 online_loss:1.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.16 loss:1.78 n_loss:0.00 tb_loss:1.78 batch_entropy:49.19 traj_lens:17.00 grad_norm:55.56 grad_norm_clip:42.06 sampled_reward_avg:0.59 train_time:2.33 time_spent:12.61
# 31/01/2025 13:08:16 - INFO - logger - iteration 479 : offline_loss:0.00 online_loss:1.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.15 loss:1.55 n_loss:0.00 tb_loss:1.55 batch_entropy:48.73 traj_lens:17.00 grad_norm:40.33 grad_norm_clip:34.59 sampled_reward_avg:0.58 train_time:2.35 time_spent:12.57
# 31/01/2025 13:08:30 - INFO - logger - iteration 480 : offline_loss:0.00 online_loss:1.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.15 loss:1.70 n_loss:0.00 tb_loss:1.70 batch_entropy:48.71 traj_lens:17.00 grad_norm:25.14 grad_norm_clip:22.92 sampled_reward_avg:0.59 train_time:2.40 time_spent:13.13
# 31/01/2025 13:08:42 - INFO - logger - iteration 481 : offline_loss:0.00 online_loss:1.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.16 loss:1.77 n_loss:0.00 tb_loss:1.77 batch_entropy:48.98 traj_lens:17.00 grad_norm:46.52 grad_norm_clip:34.12 sampled_reward_avg:0.59 train_time:2.31 time_spent:12.41
# 31/01/2025 13:08:54 - INFO - logger - iteration 482 : offline_loss:0.00 online_loss:1.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.18 loss:1.65 n_loss:0.00 tb_loss:1.65 batch_entropy:48.75 traj_lens:17.00 grad_norm:34.39 grad_norm_clip:29.48 sampled_reward_avg:0.58 train_time:2.27 time_spent:12.40
# 31/01/2025 13:09:07 - INFO - logger - iteration 483 : offline_loss:0.00 online_loss:5.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.20 loss:5.10 n_loss:0.00 tb_loss:5.10 batch_entropy:48.37 traj_lens:16.81 grad_norm:43.19 grad_norm_clip:37.39 sampled_reward_avg:0.58 train_time:2.28 time_spent:12.41
# 31/01/2025 13:09:20 - INFO - logger - iteration 484 : offline_loss:0.00 online_loss:1.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.22 loss:1.30 n_loss:0.00 tb_loss:1.30 batch_entropy:49.08 traj_lens:17.00 grad_norm:37.36 grad_norm_clip:26.76 sampled_reward_avg:0.58 train_time:2.38 time_spent:13.19
# 31/01/2025 13:09:32 - INFO - logger - iteration 485 : offline_loss:0.00 online_loss:1.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.25 loss:1.08 n_loss:0.00 tb_loss:1.08 batch_entropy:49.18 traj_lens:17.00 grad_norm:24.97 grad_norm_clip:22.14 sampled_reward_avg:0.59 train_time:2.31 time_spent:12.53
# 31/01/2025 13:09:45 - INFO - logger - iteration 486 : offline_loss:0.00 online_loss:1.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.29 loss:1.17 n_loss:0.00 tb_loss:1.17 batch_entropy:48.67 traj_lens:17.00 grad_norm:31.33 grad_norm_clip:28.23 sampled_reward_avg:0.59 train_time:2.30 time_spent:12.39
# 31/01/2025 13:09:58 - INFO - logger - iteration 487 : offline_loss:0.00 online_loss:1.62 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.32 loss:1.62 n_loss:0.00 tb_loss:1.62 batch_entropy:48.91 traj_lens:17.00 grad_norm:34.42 grad_norm_clip:31.11 sampled_reward_avg:0.59 train_time:2.21 time_spent:12.75
# 31/01/2025 13:10:10 - INFO - logger - iteration 488 : offline_loss:0.00 online_loss:1.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.34 loss:1.35 n_loss:0.00 tb_loss:1.35 batch_entropy:48.86 traj_lens:17.00 grad_norm:24.55 grad_norm_clip:21.46 sampled_reward_avg:0.59 train_time:2.15 time_spent:12.49
# 31/01/2025 13:10:23 - INFO - logger - iteration 489 : offline_loss:0.00 online_loss:0.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.36 loss:0.94 n_loss:0.00 tb_loss:0.94 batch_entropy:48.87 traj_lens:17.00 grad_norm:24.79 grad_norm_clip:22.49 sampled_reward_avg:0.58 train_time:2.34 time_spent:12.58
# 31/01/2025 13:10:36 - INFO - logger - iteration 490 : offline_loss:0.00 online_loss:1.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.38 loss:1.68 n_loss:0.00 tb_loss:1.68 batch_entropy:48.97 traj_lens:17.00 grad_norm:32.98 grad_norm_clip:30.06 sampled_reward_avg:0.59 train_time:2.38 time_spent:13.03
# 31/01/2025 13:10:48 - INFO - logger - iteration 491 : offline_loss:0.00 online_loss:1.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.41 loss:1.51 n_loss:0.00 tb_loss:1.51 batch_entropy:49.02 traj_lens:17.00 grad_norm:30.61 grad_norm_clip:26.81 sampled_reward_avg:0.59 train_time:2.25 time_spent:12.59
# 31/01/2025 13:11:01 - INFO - logger - iteration 492 : offline_loss:0.00 online_loss:1.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.43 loss:1.25 n_loss:0.00 tb_loss:1.25 batch_entropy:48.89 traj_lens:17.00 grad_norm:23.09 grad_norm_clip:22.58 sampled_reward_avg:0.58 train_time:2.24 time_spent:12.29
# 31/01/2025 13:11:13 - INFO - logger - iteration 493 : offline_loss:0.00 online_loss:3.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.46 loss:3.04 n_loss:0.00 tb_loss:3.04 batch_entropy:48.85 traj_lens:16.95 grad_norm:42.85 grad_norm_clip:33.93 sampled_reward_avg:0.59 train_time:2.18 time_spent:12.53
# 31/01/2025 13:11:26 - INFO - logger - iteration 494 : offline_loss:0.00 online_loss:1.44 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.47 loss:1.44 n_loss:0.00 tb_loss:1.44 batch_entropy:49.08 traj_lens:17.00 grad_norm:40.88 grad_norm_clip:32.47 sampled_reward_avg:0.59 train_time:2.39 time_spent:12.71
# 31/01/2025 13:11:38 - INFO - logger - iteration 495 : offline_loss:0.00 online_loss:1.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.49 loss:1.42 n_loss:0.00 tb_loss:1.42 batch_entropy:49.01 traj_lens:17.00 grad_norm:22.56 grad_norm_clip:21.33 sampled_reward_avg:0.59 train_time:2.35 time_spent:12.63
# 31/01/2025 13:11:51 - INFO - logger - iteration 496 : offline_loss:0.00 online_loss:1.95 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.50 loss:1.95 n_loss:0.00 tb_loss:1.95 batch_entropy:48.80 traj_lens:17.00 grad_norm:30.08 grad_norm_clip:25.76 sampled_reward_avg:0.58 train_time:2.31 time_spent:12.98
# 31/01/2025 13:12:04 - INFO - logger - iteration 497 : offline_loss:0.00 online_loss:1.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.51 loss:1.36 n_loss:0.00 tb_loss:1.36 batch_entropy:48.86 traj_lens:17.00 grad_norm:39.12 grad_norm_clip:35.88 sampled_reward_avg:0.59 train_time:2.40 time_spent:12.58
# 31/01/2025 13:12:16 - INFO - logger - iteration 498 : offline_loss:0.00 online_loss:1.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.50 loss:1.34 n_loss:0.00 tb_loss:1.34 batch_entropy:48.79 traj_lens:17.00 grad_norm:27.76 grad_norm_clip:27.69 sampled_reward_avg:0.58 train_time:2.11 time_spent:12.15
# 31/01/2025 13:12:29 - INFO - logger - iteration 499 : offline_loss:0.00 online_loss:1.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.50 loss:1.76 n_loss:0.00 tb_loss:1.76 batch_entropy:48.71 traj_lens:17.00 grad_norm:38.41 grad_norm_clip:31.38 sampled_reward_avg:0.59 train_time:2.23 time_spent:12.70
# 31/01/2025 13:12:41 - INFO - logger - iteration 500 : offline_loss:0.00 online_loss:1.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.50 loss:1.31 n_loss:0.00 tb_loss:1.31 batch_entropy:48.88 traj_lens:17.00 grad_norm:34.07 grad_norm_clip:30.41 sampled_reward_avg:0.58 train_time:2.27 time_spent:12.41

# %%
with open(os.path.join(config.log_dir, "params.json"), "w+") as file:
    json.dump(params,file)

with open(os.path.join(config.log_dir, "target.json"), "w+") as file:
    json.dump(target,file)

state = {
    "models_state_dict": [trial.model.state_dict()],
    "cfg": trial.cfg,
    "env_ctx": trial.model.env_ctx,
    #"model": trial.model,
}
if trial.sampling_model is not trial.model:
    state["sampling_model_state_dict"] = [trial.sampling_model.state_dict()]
fn = pathlib.Path(trial.cfg.log_dir) / "model_final_save.pt"
with open(fn, "wb") as fd:
    torch.save(
        state,
        fd,
    )

# %%
# Generate molecules
trajs = trial.algo.create_training_data_from_own_samples(trial.model, 25)
objs = [trial.ctx.graph_to_obj(i['result']) for i in trajs]
obj_props, is_valid = trial.task.compute_obj_properties(objs)
cond_info = trial.task.sample_conditional_information(len(obj_props), 1)
log_rewards = trial.task.cond_info_to_logreward(cond_info, obj_props)
index = 0
rewards = []
for i in is_valid:
    if i:
        rewards.append(list(log_rewards)[index])
        index += 1 
    else:
        rewards.append(0)

MolsToGridImage(objs[:25], molsPerRow=5, subImgSize=(200, 120), legends=[f'reward: {r}' if r==0 else f'reward: {r.exp().item():.2f}' for r in rewards[:25]])

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')])
ax[0].set_yscale('log')
ax[1].set_ylabel('TB loss')
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')])
ax[1].set_ylabel('Average reward')
ax[2].plot([i.value for i in ea.Scalars('train_logZ')])
ax[2].set_ylabel('Predicted logZ')
pp.tight_layout()
