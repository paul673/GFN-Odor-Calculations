# %% [markdown]
# # Run Vanilla (combined)

# %%
import sys
import os
path_to_top_dir = "../"
# Dynamically add the `project` directory to the path
sys.path.append(os.path.abspath(path_to_top_dir))

# %%
os.path.abspath(path_to_top_dir)
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model'

# %%
# Print current working directory
os.getcwd()
# Out:
# 'c:\\Users\\paulj\\Desktop\\prosjekt\\pom_cpu-model\\runs'

# %%
# Import scent_gfn functions
from scent_gfn.fragments import FRAGMENTS, FRAGMENTS_OPENPOM_DATASET, FRAGMENTS_OPENPOM_VANILLA
from scent_gfn.molecule_train import MoleculeTrainer
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with transformers dependency. No module named 'transformers'
# cannot import name 'HuggingFaceModel' from 'deepchem.models.torch_models' (c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# Skipped loading some PyTorch models, missing a dependency. No module named 'tensorflow'
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)
# c:\Users\paulj\Desktop\prosjekt\pom_cpu-model\venv\lib\site-packages\deepchem\models\torch_models\torch_model.py:1078: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(checkpoint, map_location=self.device)

# %% [markdown]
# | **Parameter**                | **Value**      |
# |------------------------------|----------------|
# | Reward function type         | OpenPOM        |
# | Similarity measure           | Cosine         |
# | Graph building               | Fragments Vanilla      |
# | Iterations                   | 500            |
# | Max number of nodes          | 6              |
# | Illegal action logreward     | -100           |
# | β                            | 1             |
# | Large molecule penalty       | None           |

# %%
params = {
    "save_name": "vanilla15",
    "reward_func": "openpom", # structure, openpom
    "similarity": "cosine",
    "graph_building": FRAGMENTS_OPENPOM_VANILLA,#FRAGMENTS,
    "iterations": 500,
    "max_nodes": 6,
    "illegal_logreward": -100,
    "beta": 1.0,
    "large_mol_pen": [None,None], #["hard", 17]# ["exponential", 15] # ["exponential", 15] , ["hard", 15], [None,None]
}

# %%
# Utilities
import warnings
import random
import datetime

# Data processing and file management
import pathlib
import pandas as pd
import json
import numpy as np

# Machine learning
import torch
from gflownet.config import init_empty, Config
from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage, MolToImage


# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Run on cpu
dev = torch.device('cpu')

# %%
def get_vanilla_test_and_training(split_ratio=0.7):
    df = pd.read_csv("../data/data.csv")
    vanilla_mols_df = df.loc[df['vanilla'] == 1]
    vanilla_smiles_trainig= list(vanilla_mols_df["nonStereoSMILES"])
    vanilla_smiles_trainig = random.sample(vanilla_smiles_trainig, round(len(vanilla_mols_df)*split_ratio))
    random.shuffle(vanilla_smiles_trainig)
    vanilla_smiles_test = []
    for i in vanilla_mols_df["nonStereoSMILES"]:
        if i not in vanilla_smiles_trainig:
            vanilla_smiles_test.append(i)
    return vanilla_smiles_trainig, vanilla_smiles_test

def get_vanillin():
    return ["COc1cc(C=O)ccc1O"]

# %%
target = get_vanillin()

# %%
# Initialize model
config = init_empty(Config())
config.print_every = 1
config.log_dir = f"{os.path.abspath(path_to_top_dir)}/results/{params['save_name']}_{datetime.datetime.now().strftime('%Y-%m-%d__%H_%M_%S')}"
config.device = dev
config.num_training_steps = params["iterations"]
config.num_workers = 0
config.num_validation_gen_steps = 1
config.overwrite_existing_exp=False
config.checkpoint_every = 100
config.algo.max_nodes = params["max_nodes"] #12 # 95 quantil
config.store_all_checkpoints = True
config.algo.illegal_action_logreward = params["illegal_logreward"]

if params["graph_building"] == None:
     trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]), print_config=True) #,fragments=FRAGMENTS, print_config=True)
else:
    trial = MoleculeTrainer(config,(params["reward_func"], params["similarity"],params["large_mol_pen"], target, params["beta"]),fragments=params["graph_building"], print_config=True) #,fragments=FRAGMENTS, print_config=True)
# Out:
# SMILES input data detected ...
# Reward function: reward_function_openpom | Similarity measure: cosine_similarity | exp_penalty: False | max_mol=None
# Building molecules using fragments ...
#
#
# Hyperparameters:
#
# desc: noDesc
# log_dir: c:\Users\paulj\Desktop\prosjekt\pom_cpu-model/results/vanilla15_2025-02-12__14_27_42
# device: cpu
# seed: 0
# validate_every: 1000
# checkpoint_every: 100
# store_all_checkpoints: true
# print_every: 1
# start_at_step: 0
# num_final_gen_steps: null
# num_validation_gen_steps: 1
# num_training_steps: 500
# num_workers: 0
# hostname: null
# pickle_mp_messages: false
# git_hash: f106cde
# overwrite_existing_exp: false
# algo:
#   method: TB
#   num_from_policy: 64
#   num_from_dataset: 0
#   valid_num_from_policy: 64
#   valid_num_from_dataset: 0
#   max_len: 128
#   max_nodes: 6
#   max_edges: 128
#   illegal_action_logreward: -100.0
#   train_random_action_prob: 0.0
#   train_det_after: null
#   valid_random_action_prob: 0.0
#   sampling_tau: 0.9
#   tb:
#     bootstrap_own_reward: false
#     epsilon: null
#     reward_loss_multiplier: 1.0
#     variant: TB
#     do_correct_idempotent: false
#     do_parameterize_p_b: false
#     do_predict_n: false
#     do_sample_p_b: false
#     do_length_normalize: false
#     subtb_max_len: 128
#     Z_learning_rate: 0.0001
#     Z_lr_decay: 50000.0
#     cum_subtb: true
#     loss_fn: MSE
#     loss_fn_par: 1.0
#     n_loss: none
#     n_loss_multiplier: 1.0
#     backward_policy: Uniform
#   moql:
#     gamma: 1.0
#     num_omega_samples: 32
#     num_objectives: 2
#     lambda_decay: 10000
#     penalty: -10.0
#   a2c:
#     entropy: 0.01
#     gamma: 1.0
#     penalty: -10.0
#   fm:
#     epsilon: 1.0e-38
#     balanced_loss: false
#     leaf_coef: 10.0
#     correct_idempotent: false
#   sql:
#     alpha: 0.01
#     gamma: 1.0
#     penalty: -10.0
# model:
#   num_layers: 3
#   num_emb: 128
#   dropout: 0.0
#   graph_transformer:
#     num_heads: 2
#     ln_type: pre
#     num_mlp_layers: 0
#     concat_heads: true
#   seq_transformer:
#     num_heads: 2
#     posenc: Rotary
# opt:
#   opt: adam
#   learning_rate: 0.0001
#   lr_decay: 20000.0
#   weight_decay: 1.0e-08
#   momentum: 0.9
#   clip_grad_type: norm
#   clip_grad_param: 10.0
#   adam_eps: 1.0e-08
# replay:
#   use: false
#   capacity: null
#   warmup: null
#   hindsight_ratio: 0.0
#   num_from_replay: null
#   num_new_samples: null
# task:
#   qm9:
#     h5_path: ./data/qm9/qm9.h5
#     model_path: ./data/qm9/qm9_model.pt
#   qm9_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - gap
#     - qed
#     - sa
#     online_pareto_front: true
#   seh:
#     reduced_frag: false
#   seh_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - seh
#     - qed
#     - sa
#     - mw
#     log_topk: false
#     online_pareto_front: true
# cond:
#   valid_sample_cond_info: true
#   temperature:
#     sample_dist: uniform
#     dist_params:
#     - 0.5
#     - 32
#     num_thermometer_dim: 32
#   moo:
#     num_objectives: 2
#     num_thermometer_dim: 16
#   weighted_prefs:
#     preference_type: dirichlet
#     preference_param: 1.5
#   focus_region:
#     focus_type: centered
#     use_steer_thermomether: false
#     focus_cosim: 0.98
#     focus_limit_coef: 0.1
#     focus_model_training_limits:
#     - 0.25
#     - 0.75
#     focus_model_state_space_res: 30
#     max_train_it: 20000

# %%
trial.run()
# Out:
# 12/02/2025 14:27:43 - INFO - logger - Starting training
# 12/02/2025 14:27:51 - INFO - logger - iteration 1 : offline_loss:0.00 online_loss:1191.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.02 loss:1191.60 n_loss:0.00 tb_loss:1191.60 batch_entropy:24.28 traj_lens:10.86 grad_norm:338.31 grad_norm_clip:68.10 sampled_reward_avg:0.57 train_time:1.39 time_spent:7.90
# 12/02/2025 14:27:59 - INFO - logger - iteration 2 : offline_loss:0.00 online_loss:723.83 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.05 loss:723.83 n_loss:0.00 tb_loss:723.83 batch_entropy:25.97 traj_lens:11.28 grad_norm:340.51 grad_norm_clip:68.44 sampled_reward_avg:0.68 train_time:1.32 time_spent:8.14
# 12/02/2025 14:28:06 - INFO - logger - iteration 3 : offline_loss:0.00 online_loss:978.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.05 loss:978.53 n_loss:0.00 tb_loss:978.53 batch_entropy:21.58 traj_lens:9.78 grad_norm:284.97 grad_norm_clip:67.37 sampled_reward_avg:0.61 train_time:1.07 time_spent:7.00
# 12/02/2025 14:28:14 - INFO - logger - iteration 4 : offline_loss:0.00 online_loss:672.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.06 loss:672.09 n_loss:0.00 tb_loss:672.09 batch_entropy:26.55 traj_lens:11.28 grad_norm:384.08 grad_norm_clip:69.05 sampled_reward_avg:0.68 train_time:1.43 time_spent:8.21
# 12/02/2025 14:28:21 - INFO - logger - iteration 5 : offline_loss:0.00 online_loss:692.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.06 loss:692.32 n_loss:0.00 tb_loss:692.32 batch_entropy:18.36 traj_lens:8.80 grad_norm:242.15 grad_norm_clip:63.75 sampled_reward_avg:0.63 train_time:0.88 time_spent:7.22
# 12/02/2025 14:28:29 - INFO - logger - iteration 6 : offline_loss:0.00 online_loss:643.28 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.06 loss:643.28 n_loss:0.00 tb_loss:643.28 batch_entropy:24.87 traj_lens:10.72 grad_norm:259.58 grad_norm_clip:66.94 sampled_reward_avg:0.68 train_time:1.25 time_spent:7.97
# 12/02/2025 14:28:37 - INFO - logger - iteration 7 : offline_loss:0.00 online_loss:621.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.04 loss:621.68 n_loss:0.00 tb_loss:621.68 batch_entropy:23.24 traj_lens:10.34 grad_norm:219.98 grad_norm_clip:65.60 sampled_reward_avg:0.66 train_time:1.14 time_spent:7.68
# 12/02/2025 14:28:46 - INFO - logger - iteration 8 : offline_loss:0.00 online_loss:526.39 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.03 loss:526.39 n_loss:0.00 tb_loss:526.39 batch_entropy:29.10 traj_lens:12.22 grad_norm:241.89 grad_norm_clip:67.26 sampled_reward_avg:0.71 train_time:1.55 time_spent:8.58
# 12/02/2025 14:28:53 - INFO - logger - iteration 9 : offline_loss:0.00 online_loss:731.62 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.01 loss:731.62 n_loss:0.00 tb_loss:731.62 batch_entropy:25.75 traj_lens:11.23 grad_norm:280.51 grad_norm_clip:65.96 sampled_reward_avg:0.64 train_time:1.22 time_spent:7.62
# 12/02/2025 14:29:01 - INFO - logger - iteration 10 : offline_loss:0.00 online_loss:1059.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.01 loss:1059.78 n_loss:0.00 tb_loss:1059.78 batch_entropy:25.42 traj_lens:10.95 grad_norm:309.85 grad_norm_clip:65.94 sampled_reward_avg:0.60 train_time:1.28 time_spent:7.83
# 12/02/2025 14:29:09 - INFO - logger - iteration 11 : offline_loss:0.00 online_loss:678.02 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.02 loss:678.02 n_loss:0.00 tb_loss:678.02 batch_entropy:26.16 traj_lens:10.95 grad_norm:295.82 grad_norm_clip:67.07 sampled_reward_avg:0.69 train_time:1.23 time_spent:7.90
# 12/02/2025 14:29:18 - INFO - logger - iteration 12 : offline_loss:0.00 online_loss:514.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.04 loss:514.46 n_loss:0.00 tb_loss:514.46 batch_entropy:29.05 traj_lens:12.12 grad_norm:386.55 grad_norm_clip:67.73 sampled_reward_avg:0.71 train_time:1.50 time_spent:8.59
# 12/02/2025 14:29:25 - INFO - logger - iteration 13 : offline_loss:0.00 online_loss:648.91 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.06 loss:648.91 n_loss:0.00 tb_loss:648.91 batch_entropy:25.09 traj_lens:10.72 grad_norm:262.53 grad_norm_clip:65.35 sampled_reward_avg:0.68 train_time:1.25 time_spent:7.79
# 12/02/2025 14:29:34 - INFO - logger - iteration 14 : offline_loss:0.00 online_loss:774.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.08 loss:774.61 n_loss:0.00 tb_loss:774.61 batch_entropy:27.16 traj_lens:11.70 grad_norm:248.93 grad_norm_clip:64.63 sampled_reward_avg:0.66 train_time:1.52 time_spent:8.44
# 12/02/2025 14:29:42 - INFO - logger - iteration 15 : offline_loss:0.00 online_loss:729.50 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.10 loss:729.50 n_loss:0.00 tb_loss:729.50 batch_entropy:27.10 traj_lens:11.42 grad_norm:329.54 grad_norm_clip:67.35 sampled_reward_avg:0.66 train_time:1.40 time_spent:8.12
# 12/02/2025 14:29:51 - INFO - logger - iteration 16 : offline_loss:0.00 online_loss:718.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.12 loss:718.41 n_loss:0.00 tb_loss:718.41 batch_entropy:31.04 traj_lens:12.64 grad_norm:383.40 grad_norm_clip:68.29 sampled_reward_avg:0.69 train_time:1.70 time_spent:8.65
# 12/02/2025 14:29:59 - INFO - logger - iteration 17 : offline_loss:0.00 online_loss:499.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.15 loss:499.61 n_loss:0.00 tb_loss:499.61 batch_entropy:27.57 traj_lens:11.70 grad_norm:280.83 grad_norm_clip:66.06 sampled_reward_avg:0.70 train_time:1.36 time_spent:8.29
# 12/02/2025 14:30:08 - INFO - logger - iteration 18 : offline_loss:0.00 online_loss:580.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.17 loss:580.24 n_loss:0.00 tb_loss:580.24 batch_entropy:31.03 traj_lens:12.78 grad_norm:417.84 grad_norm_clip:68.19 sampled_reward_avg:0.69 train_time:1.51 time_spent:8.63
# 12/02/2025 14:30:17 - INFO - logger - iteration 19 : offline_loss:0.00 online_loss:715.25 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.20 loss:715.25 n_loss:0.00 tb_loss:715.25 batch_entropy:30.37 traj_lens:12.50 grad_norm:442.52 grad_norm_clip:67.03 sampled_reward_avg:0.67 train_time:1.73 time_spent:9.75
# 12/02/2025 14:30:27 - INFO - logger - iteration 20 : offline_loss:0.00 online_loss:596.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.23 loss:596.54 n_loss:0.00 tb_loss:596.54 batch_entropy:31.53 traj_lens:13.02 grad_norm:277.24 grad_norm_clip:65.46 sampled_reward_avg:0.72 train_time:1.86 time_spent:9.54
# 12/02/2025 14:30:36 - INFO - logger - iteration 21 : offline_loss:0.00 online_loss:545.62 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.26 loss:545.62 n_loss:0.00 tb_loss:545.62 batch_entropy:34.88 traj_lens:13.72 grad_norm:478.20 grad_norm_clip:69.28 sampled_reward_avg:0.74 train_time:1.83 time_spent:9.63
# 12/02/2025 14:30:46 - INFO - logger - iteration 22 : offline_loss:0.00 online_loss:651.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.28 loss:651.30 n_loss:0.00 tb_loss:651.30 batch_entropy:33.60 traj_lens:13.44 grad_norm:421.37 grad_norm_clip:67.70 sampled_reward_avg:0.72 train_time:1.76 time_spent:9.54
# 12/02/2025 14:30:55 - INFO - logger - iteration 23 : offline_loss:0.00 online_loss:448.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.31 loss:448.04 n_loss:0.00 tb_loss:448.04 batch_entropy:33.53 traj_lens:13.58 grad_norm:283.48 grad_norm_clip:65.03 sampled_reward_avg:0.75 train_time:1.85 time_spent:9.44
# 12/02/2025 14:31:05 - INFO - logger - iteration 24 : offline_loss:0.00 online_loss:565.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.34 loss:565.34 n_loss:0.00 tb_loss:565.34 batch_entropy:34.23 traj_lens:13.86 grad_norm:416.24 grad_norm_clip:67.37 sampled_reward_avg:0.73 train_time:1.77 time_spent:9.28
# 12/02/2025 14:31:15 - INFO - logger - iteration 25 : offline_loss:0.00 online_loss:399.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.37 loss:399.08 n_loss:0.00 tb_loss:399.08 batch_entropy:35.44 traj_lens:14.28 grad_norm:435.67 grad_norm_clip:67.52 sampled_reward_avg:0.75 train_time:2.11 time_spent:9.96
# 12/02/2025 14:31:24 - INFO - logger - iteration 26 : offline_loss:0.00 online_loss:479.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.40 loss:479.40 n_loss:0.00 tb_loss:479.40 batch_entropy:29.77 traj_lens:12.17 grad_norm:361.67 grad_norm_clip:66.83 sampled_reward_avg:0.73 train_time:1.48 time_spent:9.46
# 12/02/2025 14:31:34 - INFO - logger - iteration 27 : offline_loss:0.00 online_loss:456.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.44 loss:456.36 n_loss:0.00 tb_loss:456.36 batch_entropy:33.61 traj_lens:13.53 grad_norm:450.38 grad_norm_clip:67.31 sampled_reward_avg:0.76 train_time:1.91 time_spent:9.88
# 12/02/2025 14:31:44 - INFO - logger - iteration 28 : offline_loss:0.00 online_loss:479.81 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.47 loss:479.81 n_loss:0.00 tb_loss:479.81 batch_entropy:35.98 traj_lens:14.19 grad_norm:332.21 grad_norm_clip:66.19 sampled_reward_avg:0.75 train_time:2.02 time_spent:10.17
# 12/02/2025 14:31:54 - INFO - logger - iteration 29 : offline_loss:0.00 online_loss:404.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.50 loss:404.10 n_loss:0.00 tb_loss:404.10 batch_entropy:34.77 traj_lens:13.81 grad_norm:406.54 grad_norm_clip:67.42 sampled_reward_avg:0.76 train_time:1.80 time_spent:9.54
# 12/02/2025 14:32:04 - INFO - logger - iteration 30 : offline_loss:0.00 online_loss:514.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.53 loss:514.86 n_loss:0.00 tb_loss:514.86 batch_entropy:34.60 traj_lens:13.86 grad_norm:353.11 grad_norm_clip:67.26 sampled_reward_avg:0.73 train_time:1.85 time_spent:10.15
# 12/02/2025 14:32:14 - INFO - logger - iteration 31 : offline_loss:0.00 online_loss:508.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.57 loss:508.64 n_loss:0.00 tb_loss:508.64 batch_entropy:37.33 traj_lens:14.56 grad_norm:403.01 grad_norm_clip:67.07 sampled_reward_avg:0.76 train_time:1.93 time_spent:9.79
# 12/02/2025 14:32:24 - INFO - logger - iteration 32 : offline_loss:0.00 online_loss:389.56 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.60 loss:389.56 n_loss:0.00 tb_loss:389.56 batch_entropy:37.85 traj_lens:14.80 grad_norm:367.16 grad_norm_clip:66.16 sampled_reward_avg:0.78 train_time:1.98 time_spent:9.84
# 12/02/2025 14:32:34 - INFO - logger - iteration 33 : offline_loss:0.00 online_loss:404.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.64 loss:404.61 n_loss:0.00 tb_loss:404.61 batch_entropy:37.92 traj_lens:14.61 grad_norm:549.95 grad_norm_clip:68.86 sampled_reward_avg:0.79 train_time:2.02 time_spent:10.00
# 12/02/2025 14:32:44 - INFO - logger - iteration 34 : offline_loss:0.00 online_loss:538.37 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.67 loss:538.37 n_loss:0.00 tb_loss:538.37 batch_entropy:37.17 traj_lens:14.70 grad_norm:444.14 grad_norm_clip:68.11 sampled_reward_avg:0.74 train_time:2.01 time_spent:10.24
# 12/02/2025 14:32:53 - INFO - logger - iteration 35 : offline_loss:0.00 online_loss:410.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.71 loss:410.09 n_loss:0.00 tb_loss:410.09 batch_entropy:35.51 traj_lens:14.05 grad_norm:435.21 grad_norm_clip:68.43 sampled_reward_avg:0.76 train_time:1.73 time_spent:9.47
# 12/02/2025 14:33:03 - INFO - logger - iteration 36 : offline_loss:0.00 online_loss:562.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.75 loss:562.46 n_loss:0.00 tb_loss:562.46 batch_entropy:37.26 traj_lens:14.47 grad_norm:383.80 grad_norm_clip:68.09 sampled_reward_avg:0.76 train_time:1.98 time_spent:9.82
# 12/02/2025 14:33:13 - INFO - logger - iteration 37 : offline_loss:0.00 online_loss:373.89 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.78 loss:373.89 n_loss:0.00 tb_loss:373.89 batch_entropy:37.11 traj_lens:14.61 grad_norm:385.08 grad_norm_clip:66.89 sampled_reward_avg:0.79 train_time:2.01 time_spent:10.45
# 12/02/2025 14:33:24 - INFO - logger - iteration 38 : offline_loss:0.00 online_loss:473.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.82 loss:473.84 n_loss:0.00 tb_loss:473.84 batch_entropy:39.97 traj_lens:15.36 grad_norm:414.09 grad_norm_clip:67.11 sampled_reward_avg:0.78 train_time:1.99 time_spent:10.17
# 12/02/2025 14:33:34 - INFO - logger - iteration 39 : offline_loss:0.00 online_loss:435.37 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.86 loss:435.37 n_loss:0.00 tb_loss:435.37 batch_entropy:39.89 traj_lens:15.12 grad_norm:399.24 grad_norm_clip:67.11 sampled_reward_avg:0.78 train_time:2.09 time_spent:10.17
# 12/02/2025 14:33:44 - INFO - logger - iteration 40 : offline_loss:0.00 online_loss:555.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.90 loss:555.53 n_loss:0.00 tb_loss:555.53 batch_entropy:39.99 traj_lens:15.64 grad_norm:491.55 grad_norm_clip:68.21 sampled_reward_avg:0.75 train_time:2.17 time_spent:9.99
# 12/02/2025 14:33:55 - INFO - logger - iteration 41 : offline_loss:0.00 online_loss:428.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.94 loss:428.90 n_loss:0.00 tb_loss:428.90 batch_entropy:40.74 traj_lens:15.59 grad_norm:672.88 grad_norm_clip:70.45 sampled_reward_avg:0.79 train_time:2.15 time_spent:10.70
# 12/02/2025 14:34:05 - INFO - logger - iteration 42 : offline_loss:0.00 online_loss:398.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.97 loss:398.70 n_loss:0.00 tb_loss:398.70 batch_entropy:37.89 traj_lens:14.52 grad_norm:450.47 grad_norm_clip:67.37 sampled_reward_avg:0.79 train_time:2.03 time_spent:10.00
# 12/02/2025 14:34:14 - INFO - logger - iteration 43 : offline_loss:0.00 online_loss:371.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.01 loss:371.87 n_loss:0.00 tb_loss:371.87 batch_entropy:38.50 traj_lens:14.98 grad_norm:383.98 grad_norm_clip:66.66 sampled_reward_avg:0.78 train_time:2.01 time_spent:9.97
# 12/02/2025 14:34:25 - INFO - logger - iteration 44 : offline_loss:0.00 online_loss:426.49 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.05 loss:426.49 n_loss:0.00 tb_loss:426.49 batch_entropy:41.20 traj_lens:15.73 grad_norm:523.08 grad_norm_clip:68.45 sampled_reward_avg:0.78 train_time:2.15 time_spent:10.78
# 12/02/2025 14:34:35 - INFO - logger - iteration 45 : offline_loss:0.00 online_loss:518.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.09 loss:518.04 n_loss:0.00 tb_loss:518.04 batch_entropy:39.70 traj_lens:15.41 grad_norm:465.27 grad_norm_clip:67.79 sampled_reward_avg:0.76 train_time:2.05 time_spent:10.07
# 12/02/2025 14:34:47 - INFO - logger - iteration 46 : offline_loss:0.00 online_loss:436.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.13 loss:436.99 n_loss:0.00 tb_loss:436.99 batch_entropy:41.87 traj_lens:16.02 grad_norm:403.89 grad_norm_clip:66.89 sampled_reward_avg:0.79 train_time:2.48 time_spent:11.30
# 12/02/2025 14:34:57 - INFO - logger - iteration 47 : offline_loss:0.00 online_loss:558.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.17 loss:558.52 n_loss:0.00 tb_loss:558.52 batch_entropy:38.89 traj_lens:14.94 grad_norm:480.37 grad_norm_clip:68.58 sampled_reward_avg:0.75 train_time:1.98 time_spent:10.31
# 12/02/2025 14:35:07 - INFO - logger - iteration 48 : offline_loss:0.00 online_loss:393.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.21 loss:393.55 n_loss:0.00 tb_loss:393.55 batch_entropy:39.96 traj_lens:15.50 grad_norm:366.18 grad_norm_clip:66.31 sampled_reward_avg:0.79 train_time:2.11 time_spent:10.24
# 12/02/2025 14:35:18 - INFO - logger - iteration 49 : offline_loss:0.00 online_loss:430.95 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.25 loss:430.95 n_loss:0.00 tb_loss:430.95 batch_entropy:42.28 traj_lens:16.30 grad_norm:430.36 grad_norm_clip:67.52 sampled_reward_avg:0.79 train_time:2.23 time_spent:10.69
# 12/02/2025 14:35:28 - INFO - logger - iteration 50 : offline_loss:0.00 online_loss:387.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.29 loss:387.68 n_loss:0.00 tb_loss:387.68 batch_entropy:40.22 traj_lens:15.64 grad_norm:450.84 grad_norm_clip:67.65 sampled_reward_avg:0.78 train_time:2.06 time_spent:10.28
# 12/02/2025 14:35:38 - INFO - logger - iteration 51 : offline_loss:0.00 online_loss:374.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.33 loss:374.36 n_loss:0.00 tb_loss:374.36 batch_entropy:37.50 traj_lens:14.52 grad_norm:542.67 grad_norm_clip:68.58 sampled_reward_avg:0.79 train_time:1.79 time_spent:10.27
# 12/02/2025 14:35:49 - INFO - logger - iteration 52 : offline_loss:0.00 online_loss:428.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.37 loss:428.35 n_loss:0.00 tb_loss:428.35 batch_entropy:41.81 traj_lens:15.92 grad_norm:461.57 grad_norm_clip:68.30 sampled_reward_avg:0.80 train_time:2.25 time_spent:10.54
# 12/02/2025 14:35:59 - INFO - logger - iteration 53 : offline_loss:0.00 online_loss:427.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.41 loss:427.41 n_loss:0.00 tb_loss:427.41 batch_entropy:39.50 traj_lens:15.41 grad_norm:608.14 grad_norm_clip:69.14 sampled_reward_avg:0.78 train_time:2.00 time_spent:10.13
# 12/02/2025 14:36:10 - INFO - logger - iteration 54 : offline_loss:0.00 online_loss:485.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.46 loss:485.60 n_loss:0.00 tb_loss:485.60 batch_entropy:42.22 traj_lens:16.06 grad_norm:392.47 grad_norm_clip:66.66 sampled_reward_avg:0.78 train_time:2.24 time_spent:10.79
# 12/02/2025 14:36:21 - INFO - logger - iteration 55 : offline_loss:0.00 online_loss:491.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.50 loss:491.42 n_loss:0.00 tb_loss:491.42 batch_entropy:42.85 traj_lens:16.25 grad_norm:396.08 grad_norm_clip:66.59 sampled_reward_avg:0.78 train_time:2.31 time_spent:10.74
# 12/02/2025 14:36:31 - INFO - logger - iteration 56 : offline_loss:0.00 online_loss:407.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.54 loss:407.55 n_loss:0.00 tb_loss:407.55 batch_entropy:41.83 traj_lens:16.25 grad_norm:403.32 grad_norm_clip:66.72 sampled_reward_avg:0.80 train_time:2.20 time_spent:10.56
# 12/02/2025 14:36:42 - INFO - logger - iteration 57 : offline_loss:0.00 online_loss:486.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.58 loss:486.86 n_loss:0.00 tb_loss:486.86 batch_entropy:42.56 traj_lens:16.20 grad_norm:666.96 grad_norm_clip:69.71 sampled_reward_avg:0.78 train_time:2.25 time_spent:10.42
# 12/02/2025 14:36:52 - INFO - logger - iteration 58 : offline_loss:0.00 online_loss:440.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.63 loss:440.78 n_loss:0.00 tb_loss:440.78 batch_entropy:42.69 traj_lens:16.06 grad_norm:495.86 grad_norm_clip:68.09 sampled_reward_avg:0.79 train_time:2.19 time_spent:10.89
# 12/02/2025 14:37:03 - INFO - logger - iteration 59 : offline_loss:0.00 online_loss:396.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.67 loss:396.74 n_loss:0.00 tb_loss:396.74 batch_entropy:40.00 traj_lens:15.36 grad_norm:461.82 grad_norm_clip:67.74 sampled_reward_avg:0.78 train_time:1.93 time_spent:10.15
# 12/02/2025 14:37:13 - INFO - logger - iteration 60 : offline_loss:0.00 online_loss:450.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.71 loss:450.42 n_loss:0.00 tb_loss:450.42 batch_entropy:40.91 traj_lens:15.69 grad_norm:477.56 grad_norm_clip:69.11 sampled_reward_avg:0.78 train_time:2.11 time_spent:10.35
# 12/02/2025 14:37:24 - INFO - logger - iteration 61 : offline_loss:0.00 online_loss:607.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.76 loss:607.77 n_loss:0.00 tb_loss:607.77 batch_entropy:43.48 traj_lens:16.44 grad_norm:460.67 grad_norm_clip:68.02 sampled_reward_avg:0.76 train_time:2.28 time_spent:10.73
# 12/02/2025 14:37:34 - INFO - logger - iteration 62 : offline_loss:0.00 online_loss:435.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.80 loss:435.30 n_loss:0.00 tb_loss:435.30 batch_entropy:43.17 traj_lens:16.25 grad_norm:477.92 grad_norm_clip:68.33 sampled_reward_avg:0.79 train_time:2.23 time_spent:10.50
# 12/02/2025 14:37:45 - INFO - logger - iteration 63 : offline_loss:0.00 online_loss:408.66 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.85 loss:408.66 n_loss:0.00 tb_loss:408.66 batch_entropy:41.67 traj_lens:15.92 grad_norm:500.75 grad_norm_clip:68.09 sampled_reward_avg:0.79 train_time:2.21 time_spent:10.43
# 12/02/2025 14:37:55 - INFO - logger - iteration 64 : offline_loss:0.00 online_loss:463.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.90 loss:463.41 n_loss:0.00 tb_loss:463.41 batch_entropy:41.97 traj_lens:15.92 grad_norm:530.20 grad_norm_clip:68.44 sampled_reward_avg:0.79 train_time:2.18 time_spent:10.65
# 12/02/2025 14:38:06 - INFO - logger - iteration 65 : offline_loss:0.00 online_loss:470.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.94 loss:470.21 n_loss:0.00 tb_loss:470.21 batch_entropy:42.17 traj_lens:15.88 grad_norm:551.44 grad_norm_clip:69.51 sampled_reward_avg:0.78 train_time:2.45 time_spent:10.54
# 12/02/2025 14:38:16 - INFO - logger - iteration 66 : offline_loss:0.00 online_loss:480.58 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.99 loss:480.58 n_loss:0.00 tb_loss:480.58 batch_entropy:42.82 traj_lens:16.20 grad_norm:536.37 grad_norm_clip:68.36 sampled_reward_avg:0.77 train_time:2.20 time_spent:10.34
# 12/02/2025 14:38:26 - INFO - logger - iteration 67 : offline_loss:0.00 online_loss:464.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.04 loss:464.41 n_loss:0.00 tb_loss:464.41 batch_entropy:41.01 traj_lens:15.55 grad_norm:423.81 grad_norm_clip:66.66 sampled_reward_avg:0.77 train_time:2.11 time_spent:10.13
# 12/02/2025 14:38:38 - INFO - logger - iteration 68 : offline_loss:0.00 online_loss:425.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.09 loss:425.26 n_loss:0.00 tb_loss:425.26 batch_entropy:44.09 traj_lens:16.72 grad_norm:533.72 grad_norm_clip:68.49 sampled_reward_avg:0.79 train_time:2.36 time_spent:11.26
# 12/02/2025 14:38:48 - INFO - logger - iteration 69 : offline_loss:0.00 online_loss:422.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.14 loss:422.41 n_loss:0.00 tb_loss:422.41 batch_entropy:42.85 traj_lens:16.16 grad_norm:537.19 grad_norm_clip:68.45 sampled_reward_avg:0.80 train_time:2.41 time_spent:10.75
# 12/02/2025 14:38:59 - INFO - logger - iteration 70 : offline_loss:0.00 online_loss:455.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.19 loss:455.55 n_loss:0.00 tb_loss:455.55 batch_entropy:42.99 traj_lens:16.44 grad_norm:436.15 grad_norm_clip:66.74 sampled_reward_avg:0.79 train_time:2.35 time_spent:10.57
# 12/02/2025 14:39:10 - INFO - logger - iteration 71 : offline_loss:0.00 online_loss:430.56 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.24 loss:430.56 n_loss:0.00 tb_loss:430.56 batch_entropy:43.50 traj_lens:16.30 grad_norm:425.03 grad_norm_clip:66.06 sampled_reward_avg:0.79 train_time:2.25 time_spent:10.86
# 12/02/2025 14:39:20 - INFO - logger - iteration 72 : offline_loss:0.00 online_loss:436.07 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.29 loss:436.07 n_loss:0.00 tb_loss:436.07 batch_entropy:44.31 traj_lens:16.67 grad_norm:480.33 grad_norm_clip:67.46 sampled_reward_avg:0.81 train_time:2.27 time_spent:10.58
# 12/02/2025 14:39:31 - INFO - logger - iteration 73 : offline_loss:0.00 online_loss:399.63 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.34 loss:399.63 n_loss:0.00 tb_loss:399.63 batch_entropy:43.23 traj_lens:16.44 grad_norm:510.11 grad_norm_clip:68.32 sampled_reward_avg:0.79 train_time:2.29 time_spent:10.66
# 12/02/2025 14:39:42 - INFO - logger - iteration 74 : offline_loss:0.00 online_loss:418.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.39 loss:418.68 n_loss:0.00 tb_loss:418.68 batch_entropy:44.17 traj_lens:16.72 grad_norm:458.12 grad_norm_clip:67.67 sampled_reward_avg:0.79 train_time:2.38 time_spent:11.05
# 12/02/2025 14:39:52 - INFO - logger - iteration 75 : offline_loss:0.00 online_loss:391.98 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.45 loss:391.98 n_loss:0.00 tb_loss:391.98 batch_entropy:43.04 traj_lens:16.25 grad_norm:512.00 grad_norm_clip:67.77 sampled_reward_avg:0.80 train_time:2.27 time_spent:10.44
# 12/02/2025 14:40:03 - INFO - logger - iteration 76 : offline_loss:0.00 online_loss:476.06 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.50 loss:476.06 n_loss:0.00 tb_loss:476.06 batch_entropy:43.50 traj_lens:16.25 grad_norm:580.76 grad_norm_clip:68.82 sampled_reward_avg:0.78 train_time:2.27 time_spent:10.63
# 12/02/2025 14:40:14 - INFO - logger - iteration 77 : offline_loss:0.00 online_loss:424.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.55 loss:424.21 n_loss:0.00 tb_loss:424.21 batch_entropy:44.22 traj_lens:16.48 grad_norm:493.49 grad_norm_clip:67.69 sampled_reward_avg:0.79 train_time:2.44 time_spent:11.11
# 12/02/2025 14:40:25 - INFO - logger - iteration 78 : offline_loss:0.00 online_loss:389.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.60 loss:389.23 n_loss:0.00 tb_loss:389.23 batch_entropy:41.59 traj_lens:15.83 grad_norm:543.77 grad_norm_clip:67.94 sampled_reward_avg:0.79 train_time:2.38 time_spent:10.63
# 12/02/2025 14:40:35 - INFO - logger - iteration 79 : offline_loss:0.00 online_loss:418.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.66 loss:418.74 n_loss:0.00 tb_loss:418.74 batch_entropy:43.65 traj_lens:16.34 grad_norm:487.86 grad_norm_clip:68.04 sampled_reward_avg:0.80 train_time:2.23 time_spent:10.46
# 12/02/2025 14:40:46 - INFO - logger - iteration 80 : offline_loss:0.00 online_loss:401.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.71 loss:401.00 n_loss:0.00 tb_loss:401.00 batch_entropy:43.51 traj_lens:16.39 grad_norm:588.17 grad_norm_clip:69.79 sampled_reward_avg:0.78 train_time:2.30 time_spent:10.52
# 12/02/2025 14:40:57 - INFO - logger - iteration 81 : offline_loss:0.00 online_loss:480.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.76 loss:480.35 n_loss:0.00 tb_loss:480.35 batch_entropy:44.57 traj_lens:16.72 grad_norm:495.14 grad_norm_clip:67.81 sampled_reward_avg:0.79 train_time:2.35 time_spent:11.12
# 12/02/2025 14:41:08 - INFO - logger - iteration 82 : offline_loss:0.00 online_loss:434.75 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.82 loss:434.75 n_loss:0.00 tb_loss:434.75 batch_entropy:45.62 traj_lens:16.86 grad_norm:698.74 grad_norm_clip:69.23 sampled_reward_avg:0.81 train_time:2.33 time_spent:10.61
# 12/02/2025 14:41:18 - INFO - logger - iteration 83 : offline_loss:0.00 online_loss:413.69 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.87 loss:413.69 n_loss:0.00 tb_loss:413.69 batch_entropy:44.95 traj_lens:16.77 grad_norm:504.54 grad_norm_clip:67.76 sampled_reward_avg:0.79 train_time:2.37 time_spent:10.64
# 12/02/2025 14:41:29 - INFO - logger - iteration 84 : offline_loss:0.00 online_loss:391.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.93 loss:391.29 n_loss:0.00 tb_loss:391.29 batch_entropy:43.13 traj_lens:16.20 grad_norm:574.88 grad_norm_clip:69.80 sampled_reward_avg:0.79 train_time:2.30 time_spent:11.03
# 12/02/2025 14:41:40 - INFO - logger - iteration 85 : offline_loss:0.00 online_loss:392.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.98 loss:392.71 n_loss:0.00 tb_loss:392.71 batch_entropy:43.78 traj_lens:16.48 grad_norm:583.90 grad_norm_clip:68.72 sampled_reward_avg:0.79 train_time:2.24 time_spent:10.51
# 12/02/2025 14:41:50 - INFO - logger - iteration 86 : offline_loss:0.00 online_loss:406.95 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.04 loss:406.95 n_loss:0.00 tb_loss:406.95 batch_entropy:44.43 traj_lens:16.72 grad_norm:680.79 grad_norm_clip:70.16 sampled_reward_avg:0.79 train_time:2.29 time_spent:10.62
# 12/02/2025 14:42:01 - INFO - logger - iteration 87 : offline_loss:0.00 online_loss:380.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.09 loss:380.68 n_loss:0.00 tb_loss:380.68 batch_entropy:43.37 traj_lens:16.44 grad_norm:642.89 grad_norm_clip:69.61 sampled_reward_avg:0.79 train_time:2.35 time_spent:10.93
# 12/02/2025 14:42:12 - INFO - logger - iteration 88 : offline_loss:0.00 online_loss:461.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.15 loss:461.41 n_loss:0.00 tb_loss:461.41 batch_entropy:43.84 traj_lens:16.25 grad_norm:655.78 grad_norm_clip:69.30 sampled_reward_avg:0.78 train_time:2.36 time_spent:10.48
# 12/02/2025 14:42:23 - INFO - logger - iteration 89 : offline_loss:0.00 online_loss:403.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.20 loss:403.05 n_loss:0.00 tb_loss:403.05 batch_entropy:44.88 traj_lens:16.77 grad_norm:544.14 grad_norm_clip:68.01 sampled_reward_avg:0.79 train_time:2.38 time_spent:10.75
# 12/02/2025 14:42:33 - INFO - logger - iteration 90 : offline_loss:0.00 online_loss:404.06 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.26 loss:404.06 n_loss:0.00 tb_loss:404.06 batch_entropy:43.62 traj_lens:16.25 grad_norm:602.01 grad_norm_clip:68.50 sampled_reward_avg:0.79 train_time:2.23 time_spent:10.77
# 12/02/2025 14:42:44 - INFO - logger - iteration 91 : offline_loss:0.00 online_loss:573.06 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.32 loss:573.06 n_loss:0.00 tb_loss:573.06 batch_entropy:44.13 traj_lens:16.53 grad_norm:543.71 grad_norm_clip:69.11 sampled_reward_avg:0.76 train_time:2.34 time_spent:10.36
# 12/02/2025 14:42:54 - INFO - logger - iteration 92 : offline_loss:0.00 online_loss:423.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.37 loss:423.12 n_loss:0.00 tb_loss:423.12 batch_entropy:42.72 traj_lens:16.20 grad_norm:554.69 grad_norm_clip:68.35 sampled_reward_avg:0.78 train_time:2.32 time_spent:10.40
# 12/02/2025 14:43:05 - INFO - logger - iteration 93 : offline_loss:0.00 online_loss:398.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.43 loss:398.10 n_loss:0.00 tb_loss:398.10 batch_entropy:45.48 traj_lens:17.00 grad_norm:622.77 grad_norm_clip:68.46 sampled_reward_avg:0.80 train_time:2.40 time_spent:11.17
# 12/02/2025 14:43:16 - INFO - logger - iteration 94 : offline_loss:0.00 online_loss:396.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.49 loss:396.16 n_loss:0.00 tb_loss:396.16 batch_entropy:45.30 traj_lens:16.91 grad_norm:591.18 grad_norm_clip:68.27 sampled_reward_avg:0.79 train_time:2.29 time_spent:10.76
# 12/02/2025 14:43:27 - INFO - logger - iteration 95 : offline_loss:0.00 online_loss:381.91 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.55 loss:381.91 n_loss:0.00 tb_loss:381.91 batch_entropy:45.13 traj_lens:16.95 grad_norm:574.63 grad_norm_clip:68.27 sampled_reward_avg:0.80 train_time:2.37 time_spent:10.80
# 12/02/2025 14:43:38 - INFO - logger - iteration 96 : offline_loss:0.00 online_loss:428.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.61 loss:428.00 n_loss:0.00 tb_loss:428.00 batch_entropy:43.93 traj_lens:16.48 grad_norm:479.43 grad_norm_clip:66.45 sampled_reward_avg:0.78 train_time:2.25 time_spent:10.89
# 12/02/2025 14:43:48 - INFO - logger - iteration 97 : offline_loss:0.00 online_loss:387.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.66 loss:387.05 n_loss:0.00 tb_loss:387.05 batch_entropy:44.62 traj_lens:16.62 grad_norm:609.56 grad_norm_clip:68.57 sampled_reward_avg:0.79 train_time:2.33 time_spent:10.61
# 12/02/2025 14:43:59 - INFO - logger - iteration 98 : offline_loss:0.00 online_loss:362.84 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.72 loss:362.84 n_loss:0.00 tb_loss:362.84 batch_entropy:42.72 traj_lens:15.92 grad_norm:595.56 grad_norm_clip:69.43 sampled_reward_avg:0.80 train_time:2.18 time_spent:10.36
# 12/02/2025 14:44:09 - INFO - logger - iteration 99 : offline_loss:0.00 online_loss:392.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.78 loss:392.82 n_loss:0.00 tb_loss:392.82 batch_entropy:44.57 traj_lens:16.44 grad_norm:660.27 grad_norm_clip:69.22 sampled_reward_avg:0.81 train_time:2.37 time_spent:10.67
# 12/02/2025 14:44:20 - INFO - logger - iteration 100 : offline_loss:0.00 online_loss:374.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.84 loss:374.60 n_loss:0.00 tb_loss:374.60 batch_entropy:45.28 traj_lens:17.00 grad_norm:757.80 grad_norm_clip:70.06 sampled_reward_avg:0.80 train_time:2.27 time_spent:11.12
# 12/02/2025 14:44:32 - INFO - logger - iteration 101 : offline_loss:0.00 online_loss:374.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.90 loss:374.57 n_loss:0.00 tb_loss:374.57 batch_entropy:44.82 traj_lens:16.72 grad_norm:592.18 grad_norm_clip:68.02 sampled_reward_avg:0.81 train_time:2.63 time_spent:11.47
# 12/02/2025 14:44:43 - INFO - logger - iteration 102 : offline_loss:0.00 online_loss:383.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.96 loss:383.72 n_loss:0.00 tb_loss:383.72 batch_entropy:44.34 traj_lens:16.58 grad_norm:501.79 grad_norm_clip:66.14 sampled_reward_avg:0.80 train_time:2.45 time_spent:11.22
# 12/02/2025 14:44:54 - INFO - logger - iteration 103 : offline_loss:0.00 online_loss:361.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.02 loss:361.23 n_loss:0.00 tb_loss:361.23 batch_entropy:44.64 traj_lens:16.77 grad_norm:662.39 grad_norm_clip:69.25 sampled_reward_avg:0.79 train_time:2.33 time_spent:11.09
# 12/02/2025 14:45:05 - INFO - logger - iteration 104 : offline_loss:0.00 online_loss:373.80 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.08 loss:373.80 n_loss:0.00 tb_loss:373.80 batch_entropy:44.51 traj_lens:16.62 grad_norm:562.72 grad_norm_clip:68.04 sampled_reward_avg:0.80 train_time:2.33 time_spent:10.85
# 12/02/2025 14:45:16 - INFO - logger - iteration 105 : offline_loss:0.00 online_loss:372.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.15 loss:372.16 n_loss:0.00 tb_loss:372.16 batch_entropy:44.73 traj_lens:16.67 grad_norm:650.00 grad_norm_clip:69.59 sampled_reward_avg:0.80 train_time:2.36 time_spent:10.72
# 12/02/2025 14:45:27 - INFO - logger - iteration 106 : offline_loss:0.00 online_loss:365.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.21 loss:365.10 n_loss:0.00 tb_loss:365.10 batch_entropy:43.95 traj_lens:16.25 grad_norm:591.95 grad_norm_clip:68.68 sampled_reward_avg:0.79 train_time:2.45 time_spent:11.08
# 12/02/2025 14:45:38 - INFO - logger - iteration 107 : offline_loss:0.00 online_loss:382.50 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.27 loss:382.50 n_loss:0.00 tb_loss:382.50 batch_entropy:45.74 traj_lens:16.86 grad_norm:550.44 grad_norm_clip:67.19 sampled_reward_avg:0.80 train_time:2.39 time_spent:10.94
# 12/02/2025 14:45:48 - INFO - logger - iteration 108 : offline_loss:0.00 online_loss:351.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.33 loss:351.24 n_loss:0.00 tb_loss:351.24 batch_entropy:43.98 traj_lens:16.39 grad_norm:564.06 grad_norm_clip:67.86 sampled_reward_avg:0.80 train_time:2.35 time_spent:10.62
# 12/02/2025 14:46:00 - INFO - logger - iteration 109 : offline_loss:0.00 online_loss:358.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.40 loss:358.78 n_loss:0.00 tb_loss:358.78 batch_entropy:45.06 traj_lens:16.67 grad_norm:574.27 grad_norm_clip:68.61 sampled_reward_avg:0.80 train_time:2.46 time_spent:11.32
# 12/02/2025 14:46:11 - INFO - logger - iteration 110 : offline_loss:0.00 online_loss:377.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.46 loss:377.08 n_loss:0.00 tb_loss:377.08 batch_entropy:46.01 traj_lens:17.00 grad_norm:612.23 grad_norm_clip:67.95 sampled_reward_avg:0.80 train_time:2.32 time_spent:11.00
# 12/02/2025 14:46:22 - INFO - logger - iteration 111 : offline_loss:0.00 online_loss:389.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.52 loss:389.61 n_loss:0.00 tb_loss:389.61 batch_entropy:45.86 traj_lens:16.86 grad_norm:695.15 grad_norm_clip:68.56 sampled_reward_avg:0.80 train_time:2.34 time_spent:10.92
# 12/02/2025 14:46:32 - INFO - logger - iteration 112 : offline_loss:0.00 online_loss:366.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.59 loss:366.05 n_loss:0.00 tb_loss:366.05 batch_entropy:44.62 traj_lens:16.34 grad_norm:563.52 grad_norm_clip:67.40 sampled_reward_avg:0.80 train_time:2.36 time_spent:10.74
# 12/02/2025 14:46:44 - INFO - logger - iteration 113 : offline_loss:0.00 online_loss:346.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.65 loss:346.18 n_loss:0.00 tb_loss:346.18 batch_entropy:43.84 traj_lens:16.34 grad_norm:595.34 grad_norm_clip:67.72 sampled_reward_avg:0.80 train_time:2.56 time_spent:11.52
# 12/02/2025 14:46:55 - INFO - logger - iteration 114 : offline_loss:0.00 online_loss:386.92 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.72 loss:386.92 n_loss:0.00 tb_loss:386.92 batch_entropy:46.24 traj_lens:16.86 grad_norm:743.16 grad_norm_clip:69.11 sampled_reward_avg:0.80 train_time:2.41 time_spent:10.94
# 12/02/2025 14:47:06 - INFO - logger - iteration 115 : offline_loss:0.00 online_loss:348.28 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.78 loss:348.28 n_loss:0.00 tb_loss:348.28 batch_entropy:44.39 traj_lens:16.44 grad_norm:669.09 grad_norm_clip:68.37 sampled_reward_avg:0.80 train_time:2.32 time_spent:10.77
# 12/02/2025 14:47:17 - INFO - logger - iteration 116 : offline_loss:0.00 online_loss:347.39 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.85 loss:347.39 n_loss:0.00 tb_loss:347.39 batch_entropy:44.95 traj_lens:16.77 grad_norm:669.19 grad_norm_clip:68.37 sampled_reward_avg:0.79 train_time:2.48 time_spent:11.45
# 12/02/2025 14:47:28 - INFO - logger - iteration 117 : offline_loss:0.00 online_loss:385.09 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.91 loss:385.09 n_loss:0.00 tb_loss:385.09 batch_entropy:46.35 traj_lens:16.77 grad_norm:622.68 grad_norm_clip:68.04 sampled_reward_avg:0.81 train_time:2.35 time_spent:10.72
# 12/02/2025 14:47:38 - INFO - logger - iteration 118 : offline_loss:0.00 online_loss:414.71 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.98 loss:414.71 n_loss:0.00 tb_loss:414.71 batch_entropy:45.38 traj_lens:16.62 grad_norm:588.51 grad_norm_clip:68.32 sampled_reward_avg:0.80 train_time:2.27 time_spent:10.53
# 12/02/2025 14:47:50 - INFO - logger - iteration 119 : offline_loss:0.00 online_loss:364.75 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.05 loss:364.75 n_loss:0.00 tb_loss:364.75 batch_entropy:46.32 traj_lens:17.00 grad_norm:701.91 grad_norm_clip:68.53 sampled_reward_avg:0.79 train_time:2.32 time_spent:11.24
# 12/02/2025 14:48:00 - INFO - logger - iteration 120 : offline_loss:0.00 online_loss:344.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.11 loss:344.13 n_loss:0.00 tb_loss:344.13 batch_entropy:45.51 traj_lens:16.86 grad_norm:653.71 grad_norm_clip:68.43 sampled_reward_avg:0.80 train_time:2.36 time_spent:10.77
# 12/02/2025 14:48:11 - INFO - logger - iteration 121 : offline_loss:0.00 online_loss:338.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:338.05 n_loss:0.00 tb_loss:338.05 batch_entropy:44.82 traj_lens:16.53 grad_norm:660.96 grad_norm_clip:68.36 sampled_reward_avg:0.79 train_time:2.28 time_spent:10.78
# 12/02/2025 14:48:23 - INFO - logger - iteration 122 : offline_loss:0.00 online_loss:343.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.25 loss:343.19 n_loss:0.00 tb_loss:343.19 batch_entropy:45.15 traj_lens:16.72 grad_norm:711.11 grad_norm_clip:68.71 sampled_reward_avg:0.79 train_time:2.39 time_spent:11.43
# 12/02/2025 14:48:34 - INFO - logger - iteration 123 : offline_loss:0.00 online_loss:345.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.31 loss:345.99 n_loss:0.00 tb_loss:345.99 batch_entropy:46.13 traj_lens:17.00 grad_norm:673.99 grad_norm_clip:67.81 sampled_reward_avg:0.79 train_time:2.44 time_spent:10.97
# 12/02/2025 14:48:44 - INFO - logger - iteration 124 : offline_loss:0.00 online_loss:352.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.38 loss:352.46 n_loss:0.00 tb_loss:352.46 batch_entropy:45.76 traj_lens:16.67 grad_norm:591.28 grad_norm_clip:66.42 sampled_reward_avg:0.80 train_time:2.29 time_spent:10.68
# 12/02/2025 14:48:55 - INFO - logger - iteration 125 : offline_loss:0.00 online_loss:352.41 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.45 loss:352.41 n_loss:0.00 tb_loss:352.41 batch_entropy:45.99 traj_lens:16.81 grad_norm:684.02 grad_norm_clip:68.29 sampled_reward_avg:0.79 train_time:2.30 time_spent:11.03
# 12/02/2025 14:49:06 - INFO - logger - iteration 126 : offline_loss:0.00 online_loss:359.02 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.52 loss:359.02 n_loss:0.00 tb_loss:359.02 batch_entropy:46.28 traj_lens:16.81 grad_norm:625.32 grad_norm_clip:67.23 sampled_reward_avg:0.81 train_time:2.49 time_spent:10.87
# 12/02/2025 14:49:17 - INFO - logger - iteration 127 : offline_loss:0.00 online_loss:346.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.59 loss:346.20 n_loss:0.00 tb_loss:346.20 batch_entropy:45.80 traj_lens:16.72 grad_norm:694.74 grad_norm_clip:68.31 sampled_reward_avg:0.79 train_time:2.26 time_spent:10.58
# ...
# 12/02/2025 15:49:11 - INFO - logger - iteration 458 : offline_loss:0.00 online_loss:1.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.60 loss:1.26 n_loss:0.00 tb_loss:1.26 batch_entropy:48.67 traj_lens:17.00 grad_norm:23.14 grad_norm_clip:21.29 sampled_reward_avg:0.82 train_time:2.21 time_spent:10.53
# 12/02/2025 15:49:22 - INFO - logger - iteration 459 : offline_loss:0.00 online_loss:1.62 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.61 loss:1.62 n_loss:0.00 tb_loss:1.62 batch_entropy:48.69 traj_lens:17.00 grad_norm:34.57 grad_norm_clip:24.90 sampled_reward_avg:0.83 train_time:2.23 time_spent:10.46
# 12/02/2025 15:49:32 - INFO - logger - iteration 460 : offline_loss:0.00 online_loss:1.49 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.60 loss:1.49 n_loss:0.00 tb_loss:1.49 batch_entropy:48.80 traj_lens:17.00 grad_norm:37.35 grad_norm_clip:35.00 sampled_reward_avg:0.83 train_time:2.17 time_spent:10.65
# 12/02/2025 15:49:44 - INFO - logger - iteration 461 : offline_loss:0.00 online_loss:2.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.60 loss:2.10 n_loss:0.00 tb_loss:2.10 batch_entropy:48.75 traj_lens:17.00 grad_norm:57.31 grad_norm_clip:42.36 sampled_reward_avg:0.82 train_time:2.48 time_spent:11.24
# 12/02/2025 15:49:55 - INFO - logger - iteration 462 : offline_loss:0.00 online_loss:5.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.60 loss:5.59 n_loss:0.00 tb_loss:5.59 batch_entropy:48.10 traj_lens:16.81 grad_norm:55.48 grad_norm_clip:36.99 sampled_reward_avg:0.83 train_time:2.61 time_spent:11.72
# 12/02/2025 15:50:07 - INFO - logger - iteration 463 : offline_loss:0.00 online_loss:1.42 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.59 loss:1.42 n_loss:0.00 tb_loss:1.42 batch_entropy:48.42 traj_lens:17.00 grad_norm:35.37 grad_norm_clip:24.11 sampled_reward_avg:0.82 train_time:2.54 time_spent:11.63
# 12/02/2025 15:50:19 - INFO - logger - iteration 464 : offline_loss:0.00 online_loss:1.60 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.57 loss:1.60 n_loss:0.00 tb_loss:1.60 batch_entropy:48.54 traj_lens:17.00 grad_norm:42.16 grad_norm_clip:34.38 sampled_reward_avg:0.83 train_time:2.68 time_spent:12.28
# 12/02/2025 15:50:32 - INFO - logger - iteration 465 : offline_loss:0.00 online_loss:1.88 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.54 loss:1.88 n_loss:0.00 tb_loss:1.88 batch_entropy:48.60 traj_lens:17.00 grad_norm:34.22 grad_norm_clip:27.70 sampled_reward_avg:0.83 train_time:2.47 time_spent:12.31
# 12/02/2025 15:50:42 - INFO - logger - iteration 466 : offline_loss:0.00 online_loss:2.91 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.53 loss:2.91 n_loss:0.00 tb_loss:2.91 batch_entropy:48.61 traj_lens:16.91 grad_norm:41.97 grad_norm_clip:35.06 sampled_reward_avg:0.83 train_time:2.22 time_spent:10.51
# 12/02/2025 15:50:53 - INFO - logger - iteration 467 : offline_loss:0.00 online_loss:1.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.52 loss:1.74 n_loss:0.00 tb_loss:1.74 batch_entropy:48.42 traj_lens:17.00 grad_norm:48.69 grad_norm_clip:33.34 sampled_reward_avg:0.82 train_time:2.22 time_spent:11.05
# 12/02/2025 15:51:04 - INFO - logger - iteration 468 : offline_loss:0.00 online_loss:1.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.51 loss:1.35 n_loss:0.00 tb_loss:1.35 batch_entropy:48.91 traj_lens:17.00 grad_norm:30.57 grad_norm_clip:27.36 sampled_reward_avg:0.82 train_time:2.29 time_spent:10.63
# 12/02/2025 15:51:15 - INFO - logger - iteration 469 : offline_loss:0.00 online_loss:1.73 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.50 loss:1.73 n_loss:0.00 tb_loss:1.73 batch_entropy:48.51 traj_lens:17.00 grad_norm:42.35 grad_norm_clip:34.22 sampled_reward_avg:0.83 train_time:2.23 time_spent:10.79
# 12/02/2025 15:51:25 - INFO - logger - iteration 470 : offline_loss:0.00 online_loss:4.67 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.48 loss:4.67 n_loss:0.00 tb_loss:4.67 batch_entropy:48.24 traj_lens:16.86 grad_norm:67.21 grad_norm_clip:45.86 sampled_reward_avg:0.83 train_time:2.15 time_spent:10.81
# 12/02/2025 15:51:36 - INFO - logger - iteration 471 : offline_loss:0.00 online_loss:0.95 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.46 loss:0.95 n_loss:0.00 tb_loss:0.95 batch_entropy:48.75 traj_lens:17.00 grad_norm:31.65 grad_norm_clip:27.37 sampled_reward_avg:0.83 train_time:2.35 time_spent:10.72
# 12/02/2025 15:51:47 - INFO - logger - iteration 472 : offline_loss:0.00 online_loss:2.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.44 loss:2.19 n_loss:0.00 tb_loss:2.19 batch_entropy:48.84 traj_lens:17.00 grad_norm:54.65 grad_norm_clip:40.64 sampled_reward_avg:0.83 train_time:2.13 time_spent:10.41
# 12/02/2025 15:51:57 - INFO - logger - iteration 473 : offline_loss:0.00 online_loss:2.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.42 loss:2.15 n_loss:0.00 tb_loss:2.15 batch_entropy:48.83 traj_lens:17.00 grad_norm:45.58 grad_norm_clip:32.39 sampled_reward_avg:0.83 train_time:2.28 time_spent:10.94
# 12/02/2025 15:52:08 - INFO - logger - iteration 474 : offline_loss:0.00 online_loss:1.64 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.42 loss:1.64 n_loss:0.00 tb_loss:1.64 batch_entropy:48.71 traj_lens:17.00 grad_norm:36.22 grad_norm_clip:29.74 sampled_reward_avg:0.83 train_time:2.35 time_spent:10.62
# 12/02/2025 15:52:19 - INFO - logger - iteration 475 : offline_loss:0.00 online_loss:1.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.42 loss:1.22 n_loss:0.00 tb_loss:1.22 batch_entropy:48.59 traj_lens:17.00 grad_norm:26.06 grad_norm_clip:24.13 sampled_reward_avg:0.83 train_time:2.19 time_spent:10.44
# 12/02/2025 15:52:30 - INFO - logger - iteration 476 : offline_loss:0.00 online_loss:0.99 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.42 loss:0.99 n_loss:0.00 tb_loss:0.99 batch_entropy:48.82 traj_lens:17.00 grad_norm:37.86 grad_norm_clip:32.42 sampled_reward_avg:0.83 train_time:2.29 time_spent:11.00
# 12/02/2025 15:52:40 - INFO - logger - iteration 477 : offline_loss:0.00 online_loss:1.56 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.43 loss:1.56 n_loss:0.00 tb_loss:1.56 batch_entropy:48.79 traj_lens:17.00 grad_norm:37.04 grad_norm_clip:29.42 sampled_reward_avg:0.83 train_time:2.20 time_spent:10.46
# 12/02/2025 15:52:51 - INFO - logger - iteration 478 : offline_loss:0.00 online_loss:1.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.45 loss:1.21 n_loss:0.00 tb_loss:1.21 batch_entropy:48.80 traj_lens:17.00 grad_norm:25.81 grad_norm_clip:23.15 sampled_reward_avg:0.84 train_time:2.19 time_spent:10.61
# 12/02/2025 15:53:01 - INFO - logger - iteration 479 : offline_loss:0.00 online_loss:1.94 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.47 loss:1.94 n_loss:0.00 tb_loss:1.94 batch_entropy:48.54 traj_lens:17.00 grad_norm:47.86 grad_norm_clip:38.51 sampled_reward_avg:0.82 train_time:2.16 time_spent:10.44
# 12/02/2025 15:53:12 - INFO - logger - iteration 480 : offline_loss:0.00 online_loss:2.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.49 loss:2.00 n_loss:0.00 tb_loss:2.00 batch_entropy:48.75 traj_lens:17.00 grad_norm:35.87 grad_norm_clip:33.44 sampled_reward_avg:0.82 train_time:2.18 time_spent:10.88
# 12/02/2025 15:53:23 - INFO - logger - iteration 481 : offline_loss:0.00 online_loss:1.81 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.51 loss:1.81 n_loss:0.00 tb_loss:1.81 batch_entropy:48.80 traj_lens:17.00 grad_norm:48.30 grad_norm_clip:36.70 sampled_reward_avg:0.81 train_time:2.18 time_spent:10.55
# 12/02/2025 15:53:33 - INFO - logger - iteration 482 : offline_loss:0.00 online_loss:1.62 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.53 loss:1.62 n_loss:0.00 tb_loss:1.62 batch_entropy:48.86 traj_lens:17.00 grad_norm:29.89 grad_norm_clip:25.82 sampled_reward_avg:0.82 train_time:2.25 time_spent:10.57
# 12/02/2025 15:53:44 - INFO - logger - iteration 483 : offline_loss:0.00 online_loss:1.49 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.56 loss:1.49 n_loss:0.00 tb_loss:1.49 batch_entropy:48.77 traj_lens:17.00 grad_norm:34.88 grad_norm_clip:30.22 sampled_reward_avg:0.82 train_time:2.24 time_spent:10.90
# 12/02/2025 15:53:54 - INFO - logger - iteration 484 : offline_loss:0.00 online_loss:1.63 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.58 loss:1.63 n_loss:0.00 tb_loss:1.63 batch_entropy:48.84 traj_lens:17.00 grad_norm:37.60 grad_norm_clip:31.93 sampled_reward_avg:0.83 train_time:2.17 time_spent:10.47
# 12/02/2025 15:54:05 - INFO - logger - iteration 485 : offline_loss:0.00 online_loss:1.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.61 loss:1.13 n_loss:0.00 tb_loss:1.13 batch_entropy:48.83 traj_lens:17.00 grad_norm:32.55 grad_norm_clip:31.73 sampled_reward_avg:0.82 train_time:2.21 time_spent:10.50
# 12/02/2025 15:54:16 - INFO - logger - iteration 486 : offline_loss:0.00 online_loss:1.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.64 loss:1.55 n_loss:0.00 tb_loss:1.55 batch_entropy:48.69 traj_lens:17.00 grad_norm:38.46 grad_norm_clip:32.95 sampled_reward_avg:0.82 train_time:2.21 time_spent:10.88
# 12/02/2025 15:54:26 - INFO - logger - iteration 487 : offline_loss:0.00 online_loss:1.90 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.66 loss:1.90 n_loss:0.00 tb_loss:1.90 batch_entropy:48.60 traj_lens:16.95 grad_norm:39.20 grad_norm_clip:26.36 sampled_reward_avg:0.82 train_time:2.23 time_spent:10.53
# 12/02/2025 15:54:37 - INFO - logger - iteration 488 : offline_loss:0.00 online_loss:1.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.67 loss:1.55 n_loss:0.00 tb_loss:1.55 batch_entropy:48.57 traj_lens:17.00 grad_norm:23.83 grad_norm_clip:22.67 sampled_reward_avg:0.83 train_time:2.22 time_spent:10.53
# 12/02/2025 15:54:48 - INFO - logger - iteration 489 : offline_loss:0.00 online_loss:1.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.67 loss:1.55 n_loss:0.00 tb_loss:1.55 batch_entropy:48.89 traj_lens:17.00 grad_norm:29.27 grad_norm_clip:28.88 sampled_reward_avg:0.83 train_time:2.15 time_spent:10.81
# 12/02/2025 15:54:58 - INFO - logger - iteration 490 : offline_loss:0.00 online_loss:1.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.67 loss:1.00 n_loss:0.00 tb_loss:1.00 batch_entropy:48.78 traj_lens:17.00 grad_norm:21.96 grad_norm_clip:21.96 sampled_reward_avg:0.82 train_time:2.22 time_spent:10.57
# 12/02/2025 15:55:09 - INFO - logger - iteration 491 : offline_loss:0.00 online_loss:1.28 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.67 loss:1.28 n_loss:0.00 tb_loss:1.28 batch_entropy:48.77 traj_lens:17.00 grad_norm:34.82 grad_norm_clip:29.14 sampled_reward_avg:0.83 train_time:2.02 time_spent:10.32
# 12/02/2025 15:55:20 - INFO - logger - iteration 492 : offline_loss:0.00 online_loss:1.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.65 loss:1.18 n_loss:0.00 tb_loss:1.18 batch_entropy:48.86 traj_lens:17.00 grad_norm:23.94 grad_norm_clip:21.58 sampled_reward_avg:0.82 train_time:2.29 time_spent:10.95
# 12/02/2025 15:55:30 - INFO - logger - iteration 493 : offline_loss:0.00 online_loss:1.96 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.64 loss:1.96 n_loss:0.00 tb_loss:1.96 batch_entropy:49.05 traj_lens:17.00 grad_norm:30.45 grad_norm_clip:25.63 sampled_reward_avg:0.82 train_time:2.35 time_spent:10.74
# 12/02/2025 15:55:41 - INFO - logger - iteration 494 : offline_loss:0.00 online_loss:1.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.64 loss:1.34 n_loss:0.00 tb_loss:1.34 batch_entropy:49.14 traj_lens:17.00 grad_norm:29.85 grad_norm_clip:28.53 sampled_reward_avg:0.84 train_time:2.19 time_spent:10.50
# 12/02/2025 15:55:52 - INFO - logger - iteration 495 : offline_loss:0.00 online_loss:1.66 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.64 loss:1.66 n_loss:0.00 tb_loss:1.66 batch_entropy:48.97 traj_lens:17.00 grad_norm:46.31 grad_norm_clip:37.82 sampled_reward_avg:0.83 train_time:2.16 time_spent:10.80
# 12/02/2025 15:56:02 - INFO - logger - iteration 496 : offline_loss:0.00 online_loss:1.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.65 loss:1.46 n_loss:0.00 tb_loss:1.46 batch_entropy:48.86 traj_lens:17.00 grad_norm:24.10 grad_norm_clip:21.55 sampled_reward_avg:0.83 train_time:2.34 time_spent:10.72
# 12/02/2025 15:56:13 - INFO - logger - iteration 497 : offline_loss:0.00 online_loss:1.30 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.66 loss:1.30 n_loss:0.00 tb_loss:1.30 batch_entropy:48.87 traj_lens:17.00 grad_norm:42.04 grad_norm_clip:35.50 sampled_reward_avg:0.83 train_time:2.24 time_spent:10.47
# 12/02/2025 15:56:23 - INFO - logger - iteration 498 : offline_loss:0.00 online_loss:1.45 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.67 loss:1.45 n_loss:0.00 tb_loss:1.45 batch_entropy:48.91 traj_lens:17.00 grad_norm:32.91 grad_norm_clip:30.71 sampled_reward_avg:0.83 train_time:2.28 time_spent:10.49
# 12/02/2025 15:56:34 - INFO - logger - iteration 499 : offline_loss:0.00 online_loss:1.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.68 loss:1.32 n_loss:0.00 tb_loss:1.32 batch_entropy:48.89 traj_lens:17.00 grad_norm:27.07 grad_norm_clip:23.85 sampled_reward_avg:0.84 train_time:2.18 time_spent:11.10
# 12/02/2025 15:56:45 - INFO - logger - iteration 500 : offline_loss:0.00 online_loss:1.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:26.68 loss:1.51 n_loss:0.00 tb_loss:1.51 batch_entropy:48.92 traj_lens:17.00 grad_norm:24.52 grad_norm_clip:23.01 sampled_reward_avg:0.82 train_time:2.20 time_spent:10.50

# %%
with open(os.path.join(config.log_dir, "params.json"), "w+") as file:
    json.dump(params,file)

with open(os.path.join(config.log_dir, "target.json"), "w+") as file:
    json.dump(target,file)

state = {
    "models_state_dict": [trial.model.state_dict()],
    "cfg": trial.cfg,
    "env_ctx": trial.model.env_ctx,
    #"model": trial.model,
}
if trial.sampling_model is not trial.model:
    state["sampling_model_state_dict"] = [trial.sampling_model.state_dict()]
fn = pathlib.Path(trial.cfg.log_dir) / "model_final_save.pt"
with open(fn, "wb") as fd:
    torch.save(
        state,
        fd,
    )

# %%
# Generate molecules
trajs = trial.algo.create_training_data_from_own_samples(trial.model, 25)
objs = [trial.ctx.graph_to_obj(i['result']) for i in trajs]
obj_props, is_valid = trial.task.compute_obj_properties(objs)
cond_info = trial.task.sample_conditional_information(len(obj_props), 1)
log_rewards = trial.task.cond_info_to_logreward(cond_info, obj_props)
index = 0
rewards = []
for i in is_valid:
    if i:
        rewards.append(list(log_rewards)[index])
        index += 1 
    else:
        rewards.append(0)

MolsToGridImage(objs[:25], molsPerRow=5, subImgSize=(200, 120), legends=[f'reward: {r}' if r==0 else f'reward: {r.exp().item():.2f}' for r in rewards[:25]])

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator
cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(1, 3, figsize=(4*3,3))
ax[0].plot([i.value for i in ea.Scalars('train_loss')])
ax[0].set_yscale('log')
ax[1].set_ylabel('TB loss')
ax[1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')])
ax[1].set_ylabel('Average reward')
ax[2].plot([i.value for i in ea.Scalars('train_logZ')])
ax[2].set_ylabel('Predicted logZ')
pp.tight_layout()
